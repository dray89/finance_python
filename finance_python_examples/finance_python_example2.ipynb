# %%
from finance_python.stock import stock
from finance_python.industry import industry
import sys, os, time
import numpy as np
import pandas
from datetime import datetime, date, timedelta
from pandas import DataFrame

# %%
symbols = ['DOL.TO', 'SAP.TO']
start = date.today() - timedelta(days=365)
end = date.today()

# %%
stock_loop = lambda x: stock(x, start, end)

# %%
timer_start = time.time()

stocks = list(map(stock_loop, symbols))

timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 6.785593748092651

# %%
DOL = stocks[0]

# %%
SAP = stocks[1]

# %%
DOL.description
# Out:
# 'Dollarama Inc. operates a chain of dollar stores in Canada. Its stores offer general merchandise, consumables, and seasonal items. The company also offers products online. As of June 13, 2019, it operated 1,236 stores. The company was formerly known as Dollarama Capital Corporation and changed its name to Dollarama Inc. in September 2009. Dollarama Inc. was founded in 1992 and is headquartered in Montreal, Canada.'

# %%
SAP.description
# Out:
# "Saputo Inc. produces, markets, and distributes dairy products in Canada, the United States, Argentina, Australia, and internationally. The company offers cheeses, including mozzarella and cheddar; specialty cheeses, such as ricotta, provolone, parmesan, goat cheese, feta, and havarti; fine cheeses comprising brie and camembert; and other cheeses that include brick, colby, farmer, munster, monterey jack, fresh curd, and processed cheeses. It also provides fluid milk, cream, yogurt, sour cream, cottage cheese, and ice cream mixes, as well as other dairy and non-dairy products, which comprise butter, flavored cream, dips, and flavored coffee whitener. In addition, the company offers dairy ingredients, including milk powder, whey powder, lactose, and whey protein concentrates; and distributes fine imported cheese to specialty stores, as well as non-dairy products manufactured by third parties. It serves customers in the retail, foodservice, and industrial segments. The company sells its
# ...

# %%
DOL.sector
# Out:
# 'Discount Stores'

# %%
SAP.sector
# Out:
# 'Packaged Foods'

# %%
DOL.price
# Out:
# 50.95

# %%
SAP.price
# Out:
# 40.02

# %%
DOL.dividends
# Out:
# [                                                Date       Dividends
#  0                                       Jul 11, 2019  0.044 Dividend
#  1                                       Apr 17, 2019  0.044 Dividend
#  2                                       Jan 10, 2019   0.04 Dividend
#  3                                       Oct 04, 2018   0.04 Dividend
#  4  *Close price adjusted for splits.**Adjusted cl...             NaN]

# %%
SAP.dividends
# Out:
# [                                                Date       Dividends
#  0                                       Aug 30, 2019   0.17 Dividend
#  1                                       Jun 17, 2019  0.165 Dividend
#  2                                       Mar 04, 2019  0.165 Dividend
#  3                                       Dec 03, 2018  0.165 Dividend
#  4  *Close price adjusted for splits.**Adjusted cl...             NaN]

# %%
DOL.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()']]

# %%
DOL.stats()
SAP.stats()

# %%
DOL.statistics.dropna()
# Out:
#                                                  DOL.TO
# Market Cap (intraday) 5                         1619.00
# Trailing P/E                                      30.08
# Forward P/E 1                                     23.59
# PEG Ratio (5 yr expected) 1                        2.36
# Price/Sales (ttm)                                  4.47
# Enterprise Value/Revenue 3                         5.33
# Enterprise Value/EBITDA 6                         22.05
# Beta (3Y Monthly)                                  1.23
# 52-Week Change 3                                   3.98
# S&P500 52-Week Change 3                            0.96
# 52 Week High 3                                    52.49
# 52 Week Low 3                                     30.70
# 50-Day Moving Average 3                           49.92
# 200-Day Moving Average 3                          43.03
# Float                                            311.26
# Shares Short (Aug 15, 2019) 4                      3.06
# ...

# %%
SAP.statistics.dropna()
# Out:
#                                                  SAP.TO
# Market Cap (intraday) 5                         1565.00
# Trailing P/E                                      20.85
# Forward P/E 1                                     19.91
# PEG Ratio (5 yr expected) 1                        4.63
# Price/Sales (ttm)                                  1.13
# Price/Book (mrq)                                   2.93
# Enterprise Value/Revenue 3                         1.46
# Enterprise Value/EBITDA 6                         16.55
# Beta (3Y Monthly)                                  0.40
# 52-Week Change 3                                   3.15
# S&P500 52-Week Change 3                            0.96
# 52 Week High 3                                    46.41
# 52 Week Low 3                                     35.56
# 50-Day Moving Average 3                           40.38
# 200-Day Moving Average 3                          42.73
# Shares Outstanding 5                             388.17
# ...

# %%
DOL.balance()
SAP.balance()

# %%
DOL.balance_sheet.dropna()
# Out:
# Period Ending                          2/3/2019  1/28/2018  1/29/2017  \
# DOL.TO
# Cash And Cash Equivalents               50371.0    54844.0    62015.0
# Net Receivables                         42206.0    15263.0    15386.0
# Inventory                              581241.0   490927.0   465715.0
# Other Current Assets                     5505.0      286.0     8787.0
# Total Current Assets                   709639.0   569969.0   559065.0
# Property, plant and equipment          589513.0   490988.0   437089.0
# Goodwill                               727782.0   727782.0   727782.0
# Intangible Assets                      148879.0   143046.0   136478.0
# Other Assets                             2082.0     2554.0     3037.0
# Total Assets                          2177895.0  1934339.0  1863451.0
# Accounts Payable                        79560.0    59674.0    56775.0
# Short/Current Long Term Debt             7383.0   405192.0   278643.0
# ...

# %%
SAP.balance_sheet.dropna()
# Out:
# Period Ending                     3/31/2019  3/31/2018  3/31/2017  3/31/2016  \
# SAP.TO
# Cash And Cash Equivalents          112700.0   122200.0   250500.0   164300.0
# Net Receivables                   1282300.0   996900.0   878200.0   842200.0
# Inventory                         1681000.0  1234500.0  1172500.0  1077100.0
# Total Current Assets              3133800.0  2422400.0  2380500.0  2175800.0
# Long Term Investments               45200.0    47900.0    50800.0    48800.0
# Property, plant and equipment     3090400.0  2205700.0  2165500.0  2086000.0
# Goodwill                          2597600.0  2417300.0  2240500.0  2194100.0
# Intangible Assets                  876200.0   823100.0   662300.0   587000.0
# Other Assets                       142400.0    86600.0    97000.0    80600.0
# Deferred Long Term Asset Charges    51000.0    34500.0    48100.0    22900.0
# Total Assets                      9885600.0  8003000.0  7596600.0  7172300.0
# ...

# %%
DOL.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list'],
#  ['balance_sheet', 'bs_list']]

# %%
DOL.financial()
SAP.financial()

# %%
DOL.financials.dropna()
# Out:
# Period Ending                            2/3/2019  1/28/2018  1/29/2017  \
# DOL.TO
# Total Revenue                           3548503.0  3266090.0  2963219.0
# Cost of Revenue                         1838076.0  1665771.0  1523272.0
# Gross Profit                            1710427.0  1600319.0  1439947.0
# Selling General and Administrative       826600.0   774207.0   736689.0
# Total Operating Expenses                2744050.0  2510528.0  2317709.0
# Operating Income or Loss                 804453.0   755562.0   645510.0
# Total Other Income/Expenses Net          -48506.0   -39877.0   -33083.0
# Earnings Before Interest and Taxes       804453.0   755562.0   645510.0
# Interest Expense                         -48506.0   -39877.0   -33083.0
# Income Before Tax                        755947.0   715685.0   612427.0
# Income Tax Expense                       207073.0   196275.0   166791.0
# Net Income From Continuing Ops           548874.0   519410.0   445636.0
# ...

# %%
DOL.cash()
SAP.cash()

# %%
DOL.cashflow.dropna()
SAP.cashflow.dropna()
# Out:
# Period Ending                               3/31/2019  3/31/2018  3/31/2017  \
# SAP.TO
# Net Income                                   755300.0   852500.0   727800.0
# Depreciation                                 286000.0   219800.0   206100.0
# Adjustments To Net Income                    -84600.0  -154500.0   136100.0
# Changes In Other Operating Activities        -99200.0  -115200.0     2400.0
# Total Cash Flow From Operating Activities    884500.0   809100.0  1073600.0
# Capital Expenditure                         -370500.0  -277800.0  -236700.0
# Other Cash flows from Investing Activities     -400.0     -400.0    -1100.0
# Total Cash Flows From Investing Activities -1506600.0  -722900.0  -317800.0
# Dividends Paid                              -254600.0  -243500.0  -228300.0
# Net Borrowings                               800300.0    27400.0   -34300.0
# Total Cash Flows From Financing Activities   606100.0  -204100.0  -679800.0
# ...

# %%
DOL.analyze()
SAP.analyze()

# %%
DOL.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list'],
#  ['balance_sheet', 'bs_list'],
#  ['financials', 'fin_list'],
#  ['cashflow', 'cash_list'],
#  ['earnings_est',
#   'revenue',
#   'earnings_history',
#   'eps_trend',
#   'eps_revisions',
#   'growth_estimates',
#   'a_list']]

# %%
DOL.earnings_est
# Out:
#                    Current Qtr. (Jul 2019)  Next Qtr. (Oct 2019)  \
# Earnings Estimate
# No. of Analysts                      10.00                 10.00
# Avg. Estimate                         0.46                  0.48
# Low Estimate                          0.39                  0.45
# High Estimate                         0.49                  0.51
# Year Ago EPS                          0.43                  0.41
#
#                    Current Year (2020)  Next Year (2021)
# Earnings Estimate
# No. of Analysts                  12.00             12.00
# Avg. Estimate                     1.86              2.16
# Low Estimate                      1.82              2.08
# High Estimate                     1.95              2.34
# Year Ago EPS                      1.67              1.86

# %%
SAP.earnings_est
# Out:
#                    Current Qtr. (Sep 2019)  Next Qtr. (Dec 2019)  \
# Earnings Estimate
# No. of Analysts                       5.00                  5.00
# Avg. Estimate                         0.43                  0.50
# Low Estimate                          0.40                  0.47
# High Estimate                         0.46                  0.53
# Year Ago EPS                          0.42                  0.44
#
#                    Current Year (2020)  Next Year (2021)
# Earnings Estimate
# No. of Analysts                   7.00              8.00
# Avg. Estimate                     1.76              2.01
# Low Estimate                      1.72              1.74
# High Estimate                     1.84              2.33
# Year Ago EPS                      1.59              1.76

# %%
DOL.revenue
# Out:
#                         Current Qtr. (Jul 2019) Next Qtr. (Oct 2019)  \
# Revenue Estimate
# No. of Analysts                               4                    3
# Avg. Estimate                           938.15M              931.47M
# Low Estimate                               933M               929.4M
# High Estimate                            945.1M                 933M
# Year Ago Sales                          868.45M                  NaN
# Sales Growth (year/est)                   8.00%                  NaN
#
#                         Current Year (2020) Next Year (2021)
# Revenue Estimate
# No. of Analysts                          12               12
# Avg. Estimate                         3.79B            4.08B
# Low Estimate                          3.76B               4B
# High Estimate                          3.9B            4.27B
# Year Ago Sales                        3.55B            3.79B
# Sales Growth (year/est)               6.80%            7.50%

# %%
SAP.revenue
# Out:
#                         Current Qtr. (Sep 2019) Next Qtr. (Dec 2019)  \
# Revenue Estimate
# No. of Analysts                               2                    1
# Avg. Estimate                             3.77B                3.88B
# Low Estimate                              3.74B                3.88B
# High Estimate                             3.79B                3.88B
# Year Ago Sales                              NaN                  NaN
# Sales Growth (year/est)                     NaN                  NaN
#
#                         Current Year (2020) Next Year (2021)
# Revenue Estimate
# No. of Analysts                           8                8
# Avg. Estimate                        15.04B           15.68B
# Low Estimate                         14.86B           15.47B
# High Estimate                        15.49B           16.21B
# Year Ago Sales                        13.5B           15.04B
# Sales Growth (year/est)              11.40%            4.20%

# %%
DOL.earnings_history
# Out:
#                  7/30/2018 10/30/2018 1/30/2019 4/29/2019
# Earnings History
# EPS Est.              0.44       0.42      0.55      0.34
# EPS Actual            0.43       0.41      0.54      0.33
# Difference           -0.01      -0.01     -0.01     -0.01
# Surprise %          -2.30%     -2.40%    -1.80%    -2.90%

# %%
SAP.earnings_history
# Out:
#                  9/29/2018 12/30/2018 3/30/2019 6/29/2019
# Earnings History
# EPS Est.              0.44       0.45      0.38      0.41
# EPS Actual            0.42       0.44      0.32      0.42
# Difference           -0.02      -0.01     -0.06      0.01
# Surprise %          -4.50%     -2.20%   -15.80%     2.40%

# %%
DOL.eps_trend
# Out:
#                   Current Qtr. (Jul 2019)  Next Qtr. (Oct 2019)  \
# EPS Trend
# Current Estimate                     0.46                  0.48
# 7 Days Ago                           0.47                  0.47
# 30 Days Ago                          0.47                  0.47
# 60 Days Ago                          0.46                  0.47
# 90 Days Ago                          0.47                  0.46
#
#                   Current Year (2020)  Next Year (2021)
# EPS Trend
# Current Estimate                 1.86              2.16
# 7 Days Ago                       1.86              2.16
# 30 Days Ago                      1.86              2.16
# 60 Days Ago                      1.86              2.10
# 90 Days Ago                      1.84              2.08

# %%
SAP.eps_trend
# Out:
#                   Current Qtr. (Sep 2019)  Next Qtr. (Dec 2019)  \
# EPS Trend
# Current Estimate                     0.43                  0.50
# 7 Days Ago                           0.43                  0.48
# 30 Days Ago                          0.43                  0.49
# 60 Days Ago                          0.43                  0.49
# 90 Days Ago                          0.49                  0.55
#
#                   Current Year (2020)  Next Year (2021)
# EPS Trend
# Current Estimate                 1.76              2.01
# 7 Days Ago                       1.75              2.02
# 30 Days Ago                      1.75              2.02
# 60 Days Ago                      1.77              2.04
# 90 Days Ago                      2.04              2.27

# %%
DOL.eps_revisions
# Out:
#                    Current Qtr. (Jul 2019)  Next Qtr. (Oct 2019)  \
# EPS Revisions
# Up Last 7 Days                         NaN                   2.0
# Up Last 30 Days                        NaN                   2.0
# Down Last 7 Days                       NaN                   NaN
# Down Last 30 Days                      1.0                   NaN
#
#                    Current Year (2020)  Next Year (2021)
# EPS Revisions
# Up Last 7 Days                     NaN               NaN
# Up Last 30 Days                    NaN               NaN
# Down Last 7 Days                   NaN               NaN
# Down Last 30 Days                  NaN               NaN

# %%
SAP.eps_revisions
# Out:
#                    Current Qtr. (Sep 2019)  Next Qtr. (Dec 2019)  \
# EPS Revisions
# Up Last 7 Days                         2.0                   2.0
# Up Last 30 Days                        2.0                   2.0
# Down Last 7 Days                       NaN                   NaN
# Down Last 30 Days                      1.0                   2.0
#
#                    Current Year (2020)  Next Year (2021)
# EPS Revisions
# Up Last 7 Days                     3.0               2.0
# Up Last 30 Days                    3.0               3.0
# Down Last 7 Days                   NaN               NaN
# Down Last 30 Days                  2.0               2.0

# %%
DOL.growth_estimates
# Out:
#                           DOL.TO  Industry  Sector  S&P 500
# Growth Estimates
# Current Qtr.               7.00%       NaN     NaN     0.00
# Next Qtr.                 17.10%       NaN     NaN     0.08
# Current Year              11.40%       NaN     NaN     0.03
# Next Year                 16.10%       NaN     NaN     0.10
# Next 5 Years (per annum)  11.74%       NaN     NaN     0.08
# Past 5 Years (per annum)  23.10%       NaN     NaN      NaN

# %%
SAP.growth_estimates
# Out:
#                           SAP.TO  Industry  Sector  S&P 500
# Growth Estimates
# Current Qtr.               2.40%       NaN     NaN     0.00
# Next Qtr.                 13.60%       NaN     NaN     0.08
# Current Year              10.70%       NaN     NaN     0.03
# Next Year                 14.20%       NaN     NaN     0.10
# Next 5 Years (per annum)   4.91%       NaN     NaN     0.08
# Past 5 Years (per annum)   2.26%       NaN     NaN      NaN
