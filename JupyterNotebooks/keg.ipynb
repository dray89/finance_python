# %%
from finance_python.stock import stock
from finance_python.industry import industry
import sys, os, time
import numpy as np
import pandas
from datetime import datetime, date, timedelta
from pandas import DataFrame

# %%
def print_mult(item):
    for each in item:
        print(each, '\n', '--------------')

# %%
symbols = ["IGM.TO", "KEG-UN.TO"]

start = date.today() - timedelta(days=365)
end = date.today()

# %%
stock_loop = lambda x: stock(x, start, end)
stat = lambda x: stocks[x].stats()
bal = lambda x: stocks[x].balance()
fin = lambda x: stocks[x].financial()
ca = lambda x: stocks[x].cash()
an = lambda x: stocks[x].analyze()

# %%
timer_start = time.time()

stocks = list(map(stock_loop, symbols))

timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 6.981053113937378

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    stat(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 0.884624719619751

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    bal(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 0.7966406345367432

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    fin(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 0.9973278045654297

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    ca(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 0.872143030166626

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    an(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 1.7301578521728516

# %%
IGM, KEG = l

# %%
KEG.description
# Out:
# 'The Keg Royalties Income Fund operates as an unincorporated open-ended limited purpose trust. The company invests in The Keg Rights Limited Partnership, which owns the trademarks, trade names, operating procedures and systems, and other intellectual property used for the operation of Keg steakhouse restaurants and bars. It operates 105 Keg restaurants in Canada and the United States. The Keg Royalties Income Fund was founded in 2002 and is headquartered in Richmond, Canada.'

# %%
IGM.description
# Out:
# 'IGM Financial Inc., a financial services company, manages and distributes investment funds and other managed asset products in Canada. The company operates through Investors Group, Mackenzie Investments, and Corporate and Other segments. The company also offers financial planning services, including investment, tax, retirement, education, risk management, and estate planning; strategic investment planning tools; mutual funds; iProfile, a portfolio management program; and separately managed accounts and fee-based brokerage accounts. In addition, it provides segregated funds; term, universal life, whole life, disability, critical illness, long-term care, and personal health care coverage and group insurance products; securities services; and residential mortgages. Further, the company offers banking products, such as investment loans, lines of credit, personal loans, creditor insurance, deposit accounts, and credit cards; cash management solutions; guaranteed investment certificates; private wealth solutions; and investment management, advisory, and related services. It offers its products and services through a network of consultants, as well as retail, strategic alliance, and institutional distribution channels. The company was incorporated in 1978 and is headquartered in Winnipeg, Canada. IGM Financial Inc. is a subsidiary of Power Financial Corporation.'

# %%
price = list(map(lambda symbol, x: {symbol: stocks[x].price}, symbols, range(0, len(symbols))))

# %%
KEG.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list'],
#  ['balance_sheet', 'bs_list'],
#  ['financials', 'fin_list'],
#  ['cashflow', 'cash_list'],
#  ['earnings_est',
#   'revenue',
#   'earnings_history',
#   'eps_trend',
#   'eps_revisions',
#   'growth_estimates',
#   'a_list']]

# %%
KEG.sector
# Out:
# 'Restaurants'

# %%
IGM.statistics.dropna(how='all')
# Out:
#                                                      IGM.TO
# Market Cap (intraday) 5                          909.000000
# Enterprise Value 3                              1052.000000
# Trailing P/E                                      12.550000
# Forward P/E 1                                     11.090000
# PEG Ratio (5 yr expected) 1                        4.940000
# Price/Sales (ttm)                                  2.680000
# Price/Book (mrq)                                   2.070000
# Enterprise Value/Revenue 3                         3.110000
# Enterprise Value/EBITDA 6                          8.210000
# Beta (3Y Monthly)                                  1.320000
# 52-Week Change 3                                   6.300000
# S&P500 52-Week Change 3                            3.630000
# 52 Week High 3                                    38.600000
# 52 Week Low 3                                     29.840000
# 50-Day Moving Average 3                           35.880000
# 200-Day Moving Average 3                          36.150000
# Avg Vol (3 month) 3                                1.719700
# Avg Vol (10 day) 3                                 2.097500
# Shares Outstanding 5                             238.270000
# Float                                             80.840000
# Shares Short (Aug 30, 2019) 4                      3.600000
# Short Ratio (Aug 30, 2019) 4                      21.990000
# Short % of Shares Outstanding (Aug 30, 2019) 4     1.510000
# Shares Short (prior month Jul 31, 2019) 4          3.430000
# Forward Annual Dividend Rate 4                     2.250000
# Forward Annual Dividend Yield 4                    5.950000
# Trailing Annual Dividend Rate 3                    2.250000
# Trailing Annual Dividend Yield 3                   5.950000
# 5 Year Average Dividend Yield 4                    5.780000
# Payout Ratio 4                                    74.010000
# Profit Margin                                     21.760000
# Operating Margin (ttm)                            36.780000
# Return on Assets (ttm)                             4.960000
# Return on Equity (ttm)                            16.550000
# Revenue (ttm)                                    339.000000
# Revenue Per Share (ttm)                           14.090000
# Quarterly Revenue Growth (yoy)                    -1.500000
# Gross Profit (ttm)                               135.000000
# EBITDA                                           128.000000
# Net Income Avi to Common (ttm)                   730.700000
# Diluted EPS (ttm)                                  3.040000
# Quarterly Earnings Growth (yoy)                  -10.100000
# Total Cash (mrq)                                 686.100000
# Total Cash Per Share (mrq)                         2.880000
# Total Debt (mrq)                                 220.000000
# Total Debt/Equity (mrq)                           50.030000
# Current Ratio (mrq)                                4.020000
# Book Value Per Share (mrq)                        18.450000
# Operating Cash Flow (ttm)                        734.040000
# Levered Free Cash Flow (ttm)                     921.700000
# Adjusted Returns                                   4.507576
# Total Returns                                     12.250000

# %%
basic_df = lambda x: {'symbol': symbols[x], 'price': stocks[x].price, 'description': stocks[x].description, 'sector': stocks[x].sector}

# %%
dict = list(map(basic_df, range(0, len(stocks))))
df = DataFrame(dict)
df.sort_values('sector')
# Out:
#                                          description  price            sector  \
# 0  IGM Financial Inc., a financial services compa...   37.8  Asset Management
# 1  The Keg Royalties Income Fund operates as an u...  16.42       Restaurants
#
#       symbol
# 0     IGM.TO
# 1  KEG-UN.TO

# %%
KEG.balance_sheet.dropna(how='all')
# Out:
# Period Ending               12/31/2018  12/31/2017  12/31/2016  12/31/2015  \
# KEG-UN.TO
# Cash And Cash Equivalents       2567.0      2490.0      1990.0      2770.0
# Net Receivables                 3325.0      3226.0      3096.0      3131.0
# Total Current Assets            5901.0      5725.0      5097.0      5914.0
# Intangible Assets             176936.0    167946.0    164371.0    164200.0
# Other Assets                   57000.0     57000.0     57000.0     57000.0
# Total Assets                  239837.0    230671.0    226468.0    227114.0
# Accounts Payable                 318.0       307.0       308.0       322.0
# Other Current Liabilities       2826.0      2651.0      2305.0      3240.0
# Total Current Liabilities       3194.0      2999.0      2648.0      3597.0
# Long Term Debt                 13967.0     13947.0     13973.0     13956.0
# Other Liabilities             125148.0    132185.0    132421.0    120763.0
# Total Liabilities             142309.0    149131.0    149042.0    138316.0
# Common Stock                  123275.0    123275.0    123275.0    123275.0
# Retained Earnings             -25747.0    -41735.0    -45849.0    -34477.0
# Total stockholders' equity     97528.0     81540.0     77426.0     88798.0
# Net Tangible Assets           -79408.0    -86406.0    -86945.0    -75402.0
#
# Period Ending                Changes
# KEG-UN.TO
# Cash And Cash Equivalents  -0.073285
# Net Receivables             0.061961
# Total Current Assets       -0.002198
# Intangible Assets           0.077564
# Other Assets                0.000000
# Total Assets                0.056020
# Accounts Payable           -0.012422
# Other Current Liabilities  -0.127778
# Total Current Liabilities  -0.112038
# Long Term Debt              0.000788
# Other Liabilities           0.036311
# Total Liabilities           0.028869
# Common Stock                0.000000
# Retained Earnings          -0.253212
# Total stockholders' equity  0.098313
# Net Tangible Assets         0.053129

# %%
KEG.statistics.dropna()
# Out:
#                                                  KEG-UN.TO
# Market Cap (intraday) 5                         188.940000
# Enterprise Value 3                              198.300000
# Trailing P/E                                     19.840000
# Price/Sales (ttm)                                 6.310000
# Price/Book (mrq)                                  1.990000
# Enterprise Value/Revenue 3                        6.620000
# Beta (3Y Monthly)                                 0.420000
# 52-Week Change 3                                 -5.470000
# S&P500 52-Week Change 3                           3.630000
# 52 Week High 3                                   17.810000
# 52 Week Low 3                                    15.010000
# 50-Day Moving Average 3                          16.560000
# 200-Day Moving Average 3                         17.090000
# Avg Vol (3 month) 3                               0.075700
# Avg Vol (10 day) 3                                0.071000
# Shares Outstanding 5                             11.350000
# Float                                            11.240000
# Shares Short (Aug 30, 2019) 4                     0.054400
# Short Ratio (Aug 30, 2019) 4                      0.260000
# Short % of Shares Outstanding (Aug 30, 2019) 4    0.020000
# Shares Short (prior month Jul 31, 2019) 4         0.035200
# Forward Annual Dividend Rate 4                    1.140000
# Forward Annual Dividend Yield 4                   6.900000
# Trailing Annual Dividend Rate 3                   1.130000
# Trailing Annual Dividend Yield 3                  6.910000
# 5 Year Average Dividend Yield 4                   5.700000
# Payout Ratio 4                                  135.140000
# Profit Margin                                    51.030000
# Operating Margin (ttm)                           98.700000
# Return on Assets (ttm)                            7.680000
# Return on Equity (ttm)                           16.390000
# Revenue (ttm)                                    29.960000
# Revenue Per Share (ttm)                           2.640000
# Quarterly Revenue Growth (yoy)                    1.300000
# Gross Profit (ttm)                               29.660000
# Net Income Avi to Common (ttm)                   15.290000
# Diluted EPS (ttm)                                 0.830000
# Quarterly Earnings Growth (yoy)                 -28.800000
# Total Cash (mrq)                                  2.440000
# Total Cash Per Share (mrq)                        0.220000
# Total Debt (mrq)                                 13.980000
# Total Debt/Equity (mrq)                          14.820000
# Current Ratio (mrq)                               3.810000
# Book Value Per Share (mrq)                        8.310000
# Operating Cash Flow (ttm)                        24.700000
# Levered Free Cash Flow (ttm)                     11.200000
# Adjusted Returns                                 16.428571
# Total Returns                                     1.430000

# %%
IGM.dividends
# Out:
# [                                                Date        Dividends
#  0                                       Jun 27, 2019  0.5625 Dividend
#  1                                       Mar 28, 2019  0.5625 Dividend
#  2                                       Dec 28, 2018  0.5625 Dividend
#  3                                       Sep 27, 2018  0.5625 Dividend
#  4  *Close price adjusted for splits.**Adjusted cl...              NaN]

# %%
IGM.cashflow.dropna()
# Out:
# Period Ending                               12/31/2018  12/31/2017  \
# IGM.TO
# Net Income                                    776168.0    610765.0
# Depreciation                                   35019.0     39495.0
# Adjustments To Net Income                    -113168.0   -200222.0
# Changes In Other Operating Activities          51626.0    -25085.0
# Total Cash Flow From Operating Activities     785153.0    672099.0
# Capital Expenditure                            -7117.0    -16549.0
# Investments                                   -60965.0   -573716.0
# Total Cash Flows From Investing Activities     30030.0   -501255.0
# Dividends Paid                               -550609.0   -550132.0
# Net Borrowings                               -587694.0    732786.0
# Other Cash Flows from Financing Activities     -1248.0     -2758.0
# Total Cash Flows From Financing Activities  -1131798.0    184967.0
# Change In Cash and Cash Equivalents          -316615.0    355811.0
#
# Period Ending                               12/31/2016  12/31/2015   Changes
# IGM.TO
# Net Income                                    779304.0    780542.0 -0.005604
# Depreciation                                   34476.0     31137.0  0.124675
# Adjustments To Net Income                    -280239.0   -221184.0 -0.488354
# Changes In Other Operating Activities         -41209.0   -121068.0 -1.426422
# Total Cash Flow From Operating Activities     736649.0    710402.0  0.105224
# Capital Expenditure                           -42306.0    -36814.0 -0.806677
# Investments                                  -343972.0     39499.0 -2.543457
# Total Cash Flows From Investing Activities  -1033668.0   -434321.0 -1.069142
# Dividends Paid                               -553300.0   -568997.0 -0.032317
# Net Borrowings                                631134.0    335983.0 -2.749178
# Other Cash Flows from Financing Activities      -491.0     -1239.0  0.007264
# Total Cash Flows From Financing Activities    -74954.0   -508389.0  1.226244
# Change In Cash and Cash Equivalents          -371973.0   -232308.0  0.362910

# %%
portfolio = industry()

# %%
portfolio.statistics(IGM.stats_list)

# %%
portfolio.statistics.dropna(how='all')
# Out:
#                                                      IGM.TO   KEG-UN.TO  \
# 200-Day Moving Average 3                          36.150000   17.090000
# 5 Year Average Dividend Yield 4                    5.780000    5.700000
# 50-Day Moving Average 3                           35.880000   16.560000
# 52 Week High 3                                    38.600000   17.810000
# 52 Week Low 3                                     29.840000   15.010000
# 52-Week Change 3                                   6.300000   -5.470000
# Adjusted Returns                                   4.507576   16.428571
# Avg Vol (10 day) 3                                 2.097500    0.071000
# Avg Vol (3 month) 3                                1.719700    0.075700
# Beta (3Y Monthly)                                  1.320000    0.420000
# Book Value Per Share (mrq)                        18.450000    8.310000
# Current Ratio (mrq)                                4.020000    3.810000
# Diluted EPS (ttm)                                  3.040000    0.830000
# EBITDA                                           128.000000         NaN
# Enterprise Value 3                              1052.000000  198.300000
# Enterprise Value/EBITDA 6                          8.210000         NaN
# Enterprise Value/Revenue 3                         3.110000    6.620000
# Float                                             80.840000   11.240000
# Forward Annual Dividend Rate 4                     2.250000    1.140000
# Forward Annual Dividend Yield 4                    5.950000    6.900000
# Forward P/E 1                                     11.090000         NaN
# Gross Profit (ttm)                               135.000000   29.660000
# Levered Free Cash Flow (ttm)                     921.700000   11.200000
# Market Cap (intraday) 5                          909.000000  188.940000
# Net Income Avi to Common (ttm)                   730.700000   15.290000
# Operating Cash Flow (ttm)                        734.040000   24.700000
# Operating Margin (ttm)                            36.780000   98.700000
# PEG Ratio (5 yr expected) 1                        4.940000         NaN
# Payout Ratio 4                                    74.010000  135.140000
# Price/Book (mrq)                                   2.070000    1.990000
# Price/Sales (ttm)                                  2.680000    6.310000
# Profit Margin                                     21.760000   51.030000
# Quarterly Earnings Growth (yoy)                  -10.100000  -28.800000
# Quarterly Revenue Growth (yoy)                    -1.500000    1.300000
# Return on Assets (ttm)                             4.960000    7.680000
# Return on Equity (ttm)                            16.550000   16.390000
# Revenue (ttm)                                    339.000000   29.960000
# Revenue Per Share (ttm)                           14.090000    2.640000
# S&P500 52-Week Change 3                            3.630000    3.630000
# Shares Outstanding 5                             238.270000   11.350000
# Shares Short (Aug 30, 2019) 4                      3.600000    0.054400
# Shares Short (prior month Jul 31, 2019) 4          3.430000    0.035200
# Short % of Shares Outstanding (Aug 30, 2019) 4     1.510000    0.020000
# Short Ratio (Aug 30, 2019) 4                      21.990000    0.260000
# Total Cash (mrq)                                 686.100000    2.440000
# Total Cash Per Share (mrq)                         2.880000    0.220000
# Total Debt (mrq)                                 220.000000   13.980000
# Total Debt/Equity (mrq)                           50.030000   14.820000
# Total Returns                                     12.250000    1.430000
# Trailing Annual Dividend Rate 3                    2.250000    1.130000
# Trailing Annual Dividend Yield 3                   5.950000    6.910000
# Trailing P/E                                      12.550000   19.840000
#
#                                                   Averages
# 200-Day Moving Average 3                         26.620000
# 5 Year Average Dividend Yield 4                   5.740000
# 50-Day Moving Average 3                          26.220000
# 52 Week High 3                                   28.205000
# 52 Week Low 3                                    22.425000
# 52-Week Change 3                                  0.415000
# Adjusted Returns                                 10.468074
# Avg Vol (10 day) 3                                1.084250
# Avg Vol (3 month) 3                               0.897700
# Beta (3Y Monthly)                                 0.870000
# Book Value Per Share (mrq)                       13.380000
# Current Ratio (mrq)                               3.915000
# Diluted EPS (ttm)                                 1.935000
# EBITDA                                          128.000000
# Enterprise Value 3                              625.150000
# Enterprise Value/EBITDA 6                         8.210000
# Enterprise Value/Revenue 3                        4.865000
# Float                                            46.040000
# Forward Annual Dividend Rate 4                    1.695000
# Forward Annual Dividend Yield 4                   6.425000
# Forward P/E 1                                    11.090000
# Gross Profit (ttm)                               82.330000
# Levered Free Cash Flow (ttm)                    466.450000
# Market Cap (intraday) 5                         548.970000
# Net Income Avi to Common (ttm)                  372.995000
# Operating Cash Flow (ttm)                       379.370000
# Operating Margin (ttm)                           67.740000
# PEG Ratio (5 yr expected) 1                       4.940000
# Payout Ratio 4                                  104.575000
# Price/Book (mrq)                                  2.030000
# Price/Sales (ttm)                                 4.495000
# Profit Margin                                    36.395000
# Quarterly Earnings Growth (yoy)                 -19.450000
# Quarterly Revenue Growth (yoy)                   -0.100000
# Return on Assets (ttm)                            6.320000
# Return on Equity (ttm)                           16.470000
# Revenue (ttm)                                   184.480000
# Revenue Per Share (ttm)                           8.365000
# S&P500 52-Week Change 3                           3.630000
# Shares Outstanding 5                            124.810000
# Shares Short (Aug 30, 2019) 4                     1.827200
# Shares Short (prior month Jul 31, 2019) 4         1.732600
# Short % of Shares Outstanding (Aug 30, 2019) 4    0.765000
# Short Ratio (Aug 30, 2019) 4                     11.125000
# Total Cash (mrq)                                344.270000
# Total Cash Per Share (mrq)                        1.550000
# Total Debt (mrq)                                116.990000
# Total Debt/Equity (mrq)                          32.425000
# Total Returns                                     6.840000
# Trailing Annual Dividend Rate 3                   1.690000
# Trailing Annual Dividend Yield 3                  6.430000
# Trailing P/E                                     16.195000

# %%
statistics_df = portfolio.statistics.dropna(how='all').T.sort_values("Diluted EPS (ttm)", ascending=False)[['Diluted EPS (ttm)', 'EBITDA', 'Levered Free Cash Flow (ttm)', 'Beta (3Y Monthly)', 'Profit Margin','Trailing Annual Dividend Yield 3']]

# %%
statistics_df
# Out:
#            Diluted EPS (ttm)  EBITDA  Levered Free Cash Flow (ttm)  \
# IGM.TO                 3.040   128.0                        921.70
# Averages               1.935   128.0                        466.45
# KEG-UN.TO              0.830     NaN                         11.20
#
#            Beta (3Y Monthly)  Profit Margin  Trailing Annual Dividend Yield 3
# IGM.TO                  1.32         21.760                              5.95
# Averages                0.87         36.395                              6.43
# KEG-UN.TO               0.42         51.030                              6.91

# %%
portfolio.cashflow(IGM.cash_list)

# %%
portfolio.cashflow.dropna(how='all')
# Out:
#                                               IGM.TO  KEG-UN.TO
# Adjustments To Net Income                  -0.488354  -1.408656
# Capital Expenditure                        -0.806677        NaN
# Change In Cash and Cash Equivalents         0.362910  -0.931189
# Changes In Accounts Receivables                  NaN  -0.769767
# Changes In Liabilities                           NaN  -0.388889
# Changes In Other Operating Activities      -1.426422        NaN
# Depreciation                                0.124675        NaN
# Dividends Paid                             -0.032317   0.134008
# Investments                                -2.543457        NaN
# Net Borrowings                             -2.749178        NaN
# Net Income                                 -0.005604   1.600303
# Other Cash Flows from Financing Activities  0.007264   0.132555
# Total Cash Flow From Operating Activities   0.105224   0.095257
# Total Cash Flows From Financing Activities  1.226244   0.149411
# Total Cash Flows From Investing Activities -1.069142        NaN

# %%
portfolio.balance_sheet(IGM.bs_list)

# %%
portfolio.balance_sheet.dropna(how='all')
# Out:
#                                         IGM.TO  KEG-UN.TO  Averages
# Accounts Payable                      0.027544  -0.012422  0.007561
# Capital Surplus                       0.280216        NaN  0.280216
# Cash And Cash Equivalents            -0.338530  -0.073285 -0.205908
# Common Stock                         -0.007811   0.000000 -0.003906
# Deferred Long Term Asset Charges      0.164152        NaN  0.164152
# Deferred Long Term Liability Charges -0.804729        NaN -0.804729
# Goodwill                              0.000000        NaN  0.000000
# Intangible Assets                    -0.023491   0.077564  0.027037
# Long Term Debt                        0.349639   0.000788  0.175213
# Long Term Investments                 1.200578        NaN  1.200578
# Net Receivables                       0.050985   0.061961  0.056473
# Net Tangible Assets                  -0.138486   0.053129 -0.042679
# Other Assets                         -0.728941   0.000000 -0.364470
# Other Current Assets                  0.608484        NaN  0.608484
# Other Current Liabilities             9.138419  -0.127778  4.505321
# Other Liabilities                    -0.167567   0.036311 -0.065628
# Other Stockholder Equity              0.431456        NaN  0.431456
# Property, plant and equipment        -0.012176        NaN -0.012176
# Retained Earnings                    -0.036829  -0.253212 -0.145021
# Total Assets                          0.052403   0.056020  0.054212
# Total Current Assets                  0.034733  -0.002198  0.016267
# Total Current Liabilities             2.966933  -0.112038  1.427448
# Total Liabilities                     0.089300   0.028869  0.059084
# Total stockholders' equity           -0.027342   0.098313  0.035485
# Treasury Stock                        0.431456        NaN  0.431456

# %%
portfolio.financials(IGM.fin_list)

# %%
portfolio.financials.dropna(how='all').T.sort_values('Gross Profit', ascending=False)
# Out:
#            Total Revenue  Cost of Revenue  Gross Profit  \
# KEG-UN.TO       0.077219              NaN      0.077219
# Averages        0.078835         0.091755      0.070432
# IGM.TO          0.080450         0.091755      0.063645
#
#            Selling General and Administrative  Total Operating Expenses  \
# KEG-UN.TO                           -0.055172                 -0.055172
# Averages                            -0.018765                  0.017228
# IGM.TO                               0.017643                  0.089628
#
#            Operating Income or Loss  Total Other Income/Expenses Net  \
# KEG-UN.TO                  0.079345                        -1.420064
# Averages                   0.072552                        -0.521369
# IGM.TO                     0.065758                         0.377325
#
#            Earnings Before Interest and Taxes  Interest Expense  \
# KEG-UN.TO                            0.079345          0.128172
# Averages                             0.072552          0.201998
# IGM.TO                               0.065758          0.275825
#
#            Income Before Tax  Income Tax Expense  \
# KEG-UN.TO           1.157457            0.058317
# Averages            0.576354            0.028371
# IGM.TO             -0.004749           -0.001574
#
#            Net Income From Continuing Ops  Net Income  \
# KEG-UN.TO                        1.600303    1.600303
# Averages                         0.797349    0.797349
# IGM.TO                          -0.005604   -0.005604
#
#            Net Income Applicable To Common Shares
# KEG-UN.TO                                1.600303
# Averages                                 0.797317
# IGM.TO                                  -0.005668

# %%
GP = DataFrame(portfolio.financials.dropna(how='all').T.sort_values('Gross Profit', ascending=False)['Gross Profit'])

# %%
Debt = portfolio.balance_sheet.dropna(how='all').T.sort_values('Long Term Debt', ascending=False)['Long Term Debt']

# %%
NI = portfolio.cashflow.dropna(how='all').T.sort_values("Net Income", ascending=False)['Net Income']

# %%
pandas.concat([statistics_df, NI, Debt, GP], axis=1, sort=True).sort_values('Gross Profit', ascending=False)
# Out:
#            Diluted EPS (ttm)  EBITDA  Levered Free Cash Flow (ttm)  \
# KEG-UN.TO              0.830     NaN                         11.20
# Averages               1.935   128.0                        466.45
# IGM.TO                 3.040   128.0                        921.70
#
#            Beta (3Y Monthly)  Profit Margin  Trailing Annual Dividend Yield 3  \
# KEG-UN.TO               0.42         51.030                              6.91
# Averages                0.87         36.395                              6.43
# IGM.TO                  1.32         21.760                              5.95
#
#            Net Income  Long Term Debt  Gross Profit
# KEG-UN.TO    1.600303        0.000788      0.077219
# Averages          NaN        0.175213      0.070432
# IGM.TO      -0.005604        0.349639      0.063645

# %%
cash_debt = IGM.balance_sheet.T['Cash And Cash Equivalents'][0]/IGM.balance_sheet.T['Long Term Debt'][0]

# %%
cash_debt*100
# Out:
# 35.02283496078549

# %%
IGM.balance_sheet.dropna(how='all')
# Out:
# Period Ending                         12/31/2018  12/31/2017  12/31/2016  \
# IGM.TO
# Cash And Cash Equivalents               650228.0    966843.0    611032.0
# Net Receivables                        8066956.0   8203863.0   8283967.0
# Other Current Assets                    563151.0    525318.0    498295.0
# Total Current Assets                   9367850.0   9792964.0   9460098.0
# Long Term Investments                  2023700.0   1833769.0   1047231.0
# Property, plant and equipment           138647.0    150468.0    161337.0
# Goodwill                               2660267.0   2660267.0   2660267.0
# Intangible Assets                      1191068.0   1184451.0   1267789.0
# Other Assets                            227182.0    877534.0   1028571.0
# Deferred Long Term Asset Charges         75607.0     60661.0     61454.0
# Total Assets                          15608714.0  16499453.0  15625293.0
# Accounts Payable                        397379.0    406821.0    431049.0
# Short/Current Long Term Debt               511.0    150000.0         NaN
# Other Current Liabilities              1959067.0    145605.0    140896.0
# Total Current Liabilities              2384484.0    741221.0    599351.0
# Long Term Debt                         1856583.0   2031608.0   1350914.0
# Other Liabilities                      6766080.0   8901620.0   8928268.0
# Deferred Long Term Liability Charges    150505.0    815277.0    770036.0
# Total Liabilities                     11007147.0  11674449.0  10878533.0
# Common Stock                           1611263.0   1602726.0   1597208.0
# Retained Earnings                      2840566.0   3100775.0   3042442.0
# Treasury Stock                          -45798.0    -71130.0    -82442.0
# Capital Surplus                          45536.0     42633.0     39552.0
# Other Stockholder Equity                -45798.0    -71130.0    -82442.0
# Total stockholders' equity             4451567.0   4675004.0   4596760.0
# Net Tangible Assets                     600232.0    830286.0    668704.0
#
# Period Ending                         12/31/2015   Changes
# IGM.TO
# Cash And Cash Equivalents               983005.0 -0.338530
# Net Receivables                        7675613.0  0.050985
# Other Current Assets                    350113.0  0.608484
# Total Current Assets                   9053401.0  0.034733
# Long Term Investments                   919622.0  1.200578
# Property, plant and equipment           140356.0 -0.012176
# Goodwill                               2660267.0  0.000000
# Intangible Assets                      1219720.0 -0.023491
# Other Assets                            838126.0 -0.728941
# Deferred Long Term Asset Charges         64946.0  0.164152
# Total Assets                          14831492.0  0.052403
# Accounts Payable                        386727.0  0.027544
# Short/Current Long Term Debt                 NaN       NaN
# Other Current Liabilities               193232.0  9.138419
# Total Current Liabilities               601090.0  2.966933
# Long Term Debt                         1375615.0  0.349639
# Other Liabilities                      8128082.0 -0.167567
# Deferred Long Term Liability Charges    770751.0 -0.804729
# Total Liabilities                     10104787.0  0.089300
# Common Stock                           1623948.0 -0.007811
# Retained Earnings                      2949182.0 -0.036829
# Treasury Stock                          -31994.0  0.431456
# Capital Surplus                          35569.0  0.280216
# Other Stockholder Equity                -31994.0  0.431456
# Total stockholders' equity             4576705.0 -0.027342
# Net Tangible Assets                     696718.0 -0.138486
