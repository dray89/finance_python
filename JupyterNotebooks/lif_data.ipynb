# %%
import sys, os, time
import finance_python
from finance_python.stock_scraper_v3 import get_data
from finance_python.balance_sheet import balance_sheet
from finance_python.financials import financials
from finance_python.industry import industry
import numpy as np
import pandas
from datetime import datetime, date
from pandas import DataFrame

# %%
ind_list = ['WEED.TO', 'ACB.TO', 'CRON.TO', 
                  'APHA.TO', 'HEXO.TO', 'TGOD.TO', 'CWEB.TO',
                    'NEPT.TO', 'FIRE.TO', 'TRST.TO', 'ALEF.TO', 'CORV.TO']

# %%
start = date(2018, 8, 12)
end = date(2019, 8, 12)

weed = get_data('WEED.TO', start, end)
# Out:
# Either something went wrong or WEED.TO does not issue dividends.

# %%
weed.bsd.financials.dropna(how='all')
# Out:
# Dates                                  3/31/2019 3/31/2018 3/31/2017 3/31/2016
# Total Revenue                             226341     77948     39895     12699
# Cost of Revenue                           137411     11353      1181     -6287
# Gross Profit                               88930     66595     38714     18986
# Research Development                       15238      1453       810       721
# Selling General and Administrative        322826     82022     29818     13830
# Total Operating Expenses                  779986    156823     46609     14017
# Operating Income or Loss                 -553645    -78875     -6714     -1318
# Total Other Income/Expenses Net          -104131     26334     -3561     -2052
# Earnings Before Interest and Taxes       -553645    -78875     -6714     -1318
# Interest Expense                          -18415      -784      -784      -140
# Income Before Tax                        -657776    -52541    -10275     -3370
# Income Tax Expense                         12318      1593     -2703       126
# Minority Interest                         289815     84465       -32       -32
# Net Income From Continuing Ops           -670094    -54134     -7572     -3496
# Net Income                               -685438    -70353     -7521     -3496
# Net Income Applicable To Common Shares   -685438    -70353     -7521     -3496

# %%
from finance_python.scrape import scrape
import pandas as pd
tab = scrape('WEED.TO').flow()

# %%
import lxml

# %%
df = pd.read_html(lxml.etree.tostring(tab[0], method='xml'))[0]

# %%
df = df.replace('-', np.nan)
df = df.dropna(how = 'all')

# %%
# Out:
# 0                                       Period Ending  3/31/2019  3/31/2018  \
# 0                                       Period Ending  3/31/2019  3/31/2018
# 1                                          Net Income    -685438     -70353
# 2   Operating Activities, Cash Flows Provided By o...        NaN        NaN
# 3                                        Depreciation      44917      19914
# 4                           Adjustments To Net Income     380178       2054
# 5                     Changes In Accounts Receivables     -67688     -15738
# 6                              Changes In Liabilities      69540      27442
# 7                              Changes In Inventories    -176870     -29667
# 8               Changes In Other Operating Activities     -87150     -15418
# 9           Total Cash Flow From Operating Activities    -520510     -81506
# 10  Investing Activities, Cash Flows Provided By o...        NaN        NaN
# 11                                Capital Expenditure    -644456    -176037
# 12                                        Investments   -2158045     -48736
# 13         Other Cash flows from Investing Activities        NaN       -118
# 14         Total Cash Flows From Investing Activities   -3227985    -223583
# 15  Financing Activities, Cash Flows Provided By o...        NaN        NaN
# 16                                     Dividends Paid        NaN        NaN
# 17                             Sale Purchase of Stock        NaN        NaN
# 18                                     Net Borrowings     595320      -1512
# 19         Other Cash Flows from Financing Activities    1607780      44868
# 20         Total Cash Flows From Financing Activities    5837198     525849
# 21                    Effect Of Exchange Rate Changes      69567      69567
# 22                Change In Cash and Cash Equivalents    2158270     220760
#
# 0   3/31/2017  3/31/2016
# 0   3/31/2017  3/31/2016
# 1       -7521      -3496
# 2         NaN        NaN
# 3        6022       2245
# 4       -9288     -13831
# 5       -2184       -132
# 6        -145       1894
# 7      -12270     -12270
# 8       -1749       -218
# 9      -27093     -13527
# 10        NaN        NaN
# 11     -29391     -12196
# 12     -48736     -48736
# 13       -300       -236
# 14     -18602     -11378
# 15        NaN        NaN
# 16        NaN        NaN
# 17        NaN        NaN
# 18       2801      -1900
# 19      -8066      -1642
# 20     132098      18856
# 21      69567      69567
# 22      86403      -6049

# %%
df = df.set_index('Period Ending')
rows = list(df.index)
df.set_axis(rows, axis='rows', inplace=False)

# %%
df = df.replace('-', np.nan)
df.iloc[0][0] = 'Dates'
df = df.set_index(0)
df = df.dropna(how = 'all')
df
# Out:
#                                                 1          2          3  \
# 0
# Dates                                   3/31/2019  3/31/2018  3/31/2017
# Total Revenue                              226341      77948      39895
# Cost of Revenue                            137411      11353       1181
# Gross Profit                                88930      66595      38714
# Research Development                        15238       1453        810
# Selling General and Administrative         322826      82022      29818
# Total Operating Expenses                   779986     156823      46609
# Operating Income or Loss                  -553645     -78875      -6714
# Total Other Income/Expenses Net           -104131      26334      -3561
# Earnings Before Interest and Taxes        -553645     -78875      -6714
# Interest Expense                           -18415       -784       -784
# Income Before Tax                         -657776     -52541     -10275
# Income Tax Expense                          12318       1593      -2703
# Minority Interest                          289815      84465        -32
# Net Income From Continuing Ops            -670094     -54134      -7572
# Net Income                                -685438     -70353      -7521
# Net Income Applicable To Common Shares    -685438     -70353      -7521
#
#                                                 4
# 0
# Dates                                   3/31/2016
# Total Revenue                               12699
# Cost of Revenue                             -6287
# Gross Profit                                18986
# Research Development                          721
# Selling General and Administrative          13830
# Total Operating Expenses                    14017
# Operating Income or Loss                    -1318
# Total Other Income/Expenses Net             -2052
# Earnings Before Interest and Taxes          -1318
# Interest Expense                             -140
# Income Before Tax                           -3370
# Income Tax Expense                            126
# Minority Interest                             -32
# Net Income From Continuing Ops              -3496
# Net Income                                  -3496
# Net Income Applicable To Common Shares      -3496

# %%
df
# Out:
#                                          0          1          2          3  \
# 0                                  Revenue  3/31/2019  3/31/2018  3/31/2017
# 1                            Total Revenue     226341      77948      39895
# 2                          Cost of Revenue     137411      11353       1181
# 3                             Gross Profit      88930      66595      38714
# 4                       Operating Expenses        NaN        NaN        NaN
# 5                     Research Development      15238       1453        810
# 6       Selling General and Administrative     322826      82022      29818
# 7                            Non Recurring        NaN        NaN        NaN
# 8                                   Others        NaN        NaN        NaN
# 9                 Total Operating Expenses     779986     156823      46609
# 10                Operating Income or Loss    -553645     -78875      -6714
# 11       Income from Continuing Operations        NaN        NaN        NaN
# 12         Total Other Income/Expenses Net    -104131      26334      -3561
# 13      Earnings Before Interest and Taxes    -553645     -78875      -6714
# 14                        Interest Expense     -18415       -784       -784
# 15                       Income Before Tax    -657776     -52541     -10275
# 16                      Income Tax Expense      12318       1593      -2703
# 17                       Minority Interest     289815      84465        -32
# 18          Net Income From Continuing Ops    -670094     -54134      -7572
# 19                    Non-recurring Events        NaN        NaN        NaN
# 20                 Discontinued Operations        NaN        NaN        NaN
# 21                     Extraordinary Items        NaN        NaN        NaN
# 22            Effect Of Accounting Changes        NaN        NaN        NaN
# 23                             Other Items        NaN        NaN        NaN
# 24                              Net Income        NaN        NaN        NaN
# 25                              Net Income    -685438     -70353      -7521
# 26   Preferred Stock And Other Adjustments        NaN        NaN        NaN
# 27  Net Income Applicable To Common Shares    -685438     -70353      -7521
#
#             4
# 0   3/31/2016
# 1       12699
# 2       -6287
# 3       18986
# 4         NaN
# 5         721
# 6       13830
# 7         NaN
# 8         NaN
# 9       14017
# 10      -1318
# 11        NaN
# 12      -2052
# 13      -1318
# 14       -140
# 15      -3370
# 16        126
# 17        -32
# 18      -3496
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25      -3496
# 26        NaN
# 27      -3496

# %%
df = df.dropna(how = 'all')

# %%
df
# Out:
#                                          0          1          2          3  \
# 0                                  Revenue  3/31/2019  3/31/2018  3/31/2017
# 1                            Total Revenue     226341      77948      39895
# 2                          Cost of Revenue     137411      11353       1181
# 3                             Gross Profit      88930      66595      38714
# 4                       Operating Expenses        NaN        NaN        NaN
# 5                     Research Development      15238       1453        810
# 6       Selling General and Administrative     322826      82022      29818
# 7                            Non Recurring        NaN        NaN        NaN
# 8                                   Others        NaN        NaN        NaN
# 9                 Total Operating Expenses     779986     156823      46609
# 10                Operating Income or Loss    -553645     -78875      -6714
# 11       Income from Continuing Operations        NaN        NaN        NaN
# 12         Total Other Income/Expenses Net    -104131      26334      -3561
# 13      Earnings Before Interest and Taxes    -553645     -78875      -6714
# 14                        Interest Expense     -18415       -784       -784
# 15                       Income Before Tax    -657776     -52541     -10275
# 16                      Income Tax Expense      12318       1593      -2703
# 17                       Minority Interest     289815      84465        -32
# 18          Net Income From Continuing Ops    -670094     -54134      -7572
# 19                    Non-recurring Events        NaN        NaN        NaN
# 20                 Discontinued Operations        NaN        NaN        NaN
# 21                     Extraordinary Items        NaN        NaN        NaN
# 22            Effect Of Accounting Changes        NaN        NaN        NaN
# 23                             Other Items        NaN        NaN        NaN
# 24                              Net Income        NaN        NaN        NaN
# 25                              Net Income    -685438     -70353      -7521
# 26   Preferred Stock And Other Adjustments        NaN        NaN        NaN
# 27  Net Income Applicable To Common Shares    -685438     -70353      -7521
#
#             4
# 0   3/31/2016
# 1       12699
# 2       -6287
# 3       18986
# 4         NaN
# 5         721
# 6       13830
# 7         NaN
# 8         NaN
# 9       14017
# 10      -1318
# 11        NaN
# 12      -2052
# 13      -1318
# 14       -140
# 15      -3370
# 16        126
# 17        -32
# 18      -3496
# 19        NaN
# 20        NaN
# 21        NaN
# 22        NaN
# 23        NaN
# 24        NaN
# 25      -3496
# 26        NaN
# 27      -3496

# %%
weed.bsd.beta
# Out:
# WEED.TO    5.27
# Name: Beta (3Y Monthly), dtype: float64

# %%
timer_start = time.time()

for each in ind_list:
    try:        
        dict1.append({each: get_data(each, start, end)})
    except:
        print('error in ', each)
        
timer_end = time.time()

print(timer_end - timer_start)
# Out:
# error in  WEED.TO
# error in  ACB.TO
# error in  CRON.TO
# error in  APHA.TO
# error in  HEXO.TO
# error in  TGOD.TO
# error in  CWEB.TO
# error in  NEPT.TO
# error in  FIRE.TO
# error in  TRST.TO
# error in  ALEF.TO
# error in  CORV.TO
# 0.002977609634399414

# %%
data = list(map(lambda x, y: {y: dict1[x][y]}, range(0, len(dict1)), ind_list))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-76aebadaee11> in <module>
# ----> 1 data = list(map(lambda x, y: {y: dict1[x][y]}, range(0, len(dict1)), ind_list))
#
# NameError: name 'dict1' is not defined

# %%
df =

# %%
df.div_r

# %%
df.perc_change + df.div_r

# %%
df.returns_adj

# %%
for each in enumerate(ind_list):
    print(dict1[each[0]][each[1]].description, '\n')

# %%
ind_bsd = list(map(lambda x, y: dict1[x][y].bsd, range(0, len(ind_list)), ind_list))

# %%
for index, each in enumerate(ind_bsd):
    if hasattr(ind_bsd[index], 'changes'):
        print(ind_bsd[index].changes)
    else:
        ind_bsd.pop(index)

# %%
len(ind_bsd)

# %%
ind_df = list(map(lambda x: pandas.DataFrame(ind_bsd[x].changes), range(0, len(ind_bsd))))

# %%
frame = pandas.concat(ind_df, sort=True, axis=1)
frame

# %%
frame.idxmax(axis=1)

# %%
frame.idxmin(axis=1)

# %%
debt_inc = "{0} increased its debt by {1} in the past year, the largest increase in debt in the industry."
debt_dec =  "Meanwhile, {0} decreased its debt by {1}."

# %%
print(debt_inc.format(frame.idxmax(axis = 1)[1], np.max(frame.iloc[1])))
print(debt_dec.format(frame.idxmin(axis = 1)[1], np.min(frame.iloc[1])))

# %%
maximum = []
for each in enumerate(frame.idxmax(axis=1)):
        i = frame.idxmax(axis=1).index[each[0]]
        symbol = frame.idxmax(axis=1)[i]
        maximum.append({symbol: [i, frame[each[1]].T[i]]})

# %%
maximum

# %%
minimum = []
for each in enumerate(frame.idxmin(axis=1)):
        i = frame.idxmin(axis=1).index[each[0]]
        symbol = frame.idxmin(axis=1)[i]
        minimum.append({symbol: [i, frame[each[1]].T[i]]})

# %%
minimum

# %%
max_sentence = "{0} increased its {1} by {2} in the past year."
min_sentence =  "{0} decreased its {1} by {2}."

# %%
for each in enumerate(maximum):
    print(max_sentence.format(list(maximum[each[0]].keys())[0], list(maximum[each[0]].values())[0][0], list(maximum[each[0]].values())[0][1]))

# %%
for each in enumerate(minimum):
    print(max_sentence.format(list(minimum[each[0]].keys())[0], list(minimum[each[0]].values())[0][0], list(minimum[each[0]].values())[0][1]))

# %%
bsd_list = list(map(lambda x, y: y.stats, range(0, len(ind_bsd)), ind_bsd))

# %%
len(bsd_list)

# %%
dataframe = pandas.concat(bsd_list, sort=True, axis=1)
dataframe = dataframe.dropna(how='all')

# %%
a = industry(bsd_list)

# %%
a.attributes

# %%
ind = a.ind

# %%
averages = ind.mean(axis=1).dropna()

# %%
ind['Averages'] = averages

# %%
ind

# %%
maximum = []
for each in enumerate(ind.idxmax(axis=1)):
    if 'TGOD.TO' in each:
        i = ind.idxmax(axis=1).index[each[0]]
        maximum.append({i: ind['TGOD.TO'].T[i]})

# %%
maximum

# %%
minimum = []
for each in enumerate(ind.idxmin(axis=1)):
    if 'TGOD.TO' in each:
        i = ind.idxmin(axis=1).index[each[0]]
        minimum.append({i: ind['TGOD.TO'].T[i]})

# %% [markdown]
# minimum

# %%
minimum

# %%
timer_start = time.time()
ind_list = ['TGOD.TO', 'FIRE.TO']
dict1 = []
for each in ind_list:
    try:        
        dict1.append({each: get_data(each, start, end)})
    except:
        print('error in ', each)
        
timer_end = time.time()

print(timer_end - timer_start)

# %%
ind_bsd = list(map(lambda x, y: dict1[x][y].bsd, range(0, len(ind_list)), ind_list))

# %%
ind_bsd

# %%
ind_df = list(map(lambda x: pandas.DataFrame(ind_bsd[x].changes), range(0, len(ind_bsd))))

# %%
ind_df

# %%
frame = pandas.concat(ind_df, sort=True, axis=1)
frame

# %%
bsd_list = list(map(lambda x, y: y.stats, range(0, len(ind_bsd)), ind_bsd))

# %%
a = industry(bsd_list)

# %%
ind = a.ind

# %%
averages = ind.mean(axis=1).dropna()

# %%
ind['Averages'] = averages

# %%
ind
