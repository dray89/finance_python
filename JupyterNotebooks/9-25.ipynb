# %%
from finance_python import stock, sector, industry
import sys, os, time
import numpy as np
import pandas
from datetime import datetime, date, timedelta
from pandas import DataFrame

# %%
def print_mult(item):
    for each in item:
        print(each, '\n', '--------------')

# %%
fire_data = [{'rev_change':.61}, {'revenue':94.6}, {'production_cost': 1.14},
                      {'volume': 29034}, {'volume_chg': .86}, {'gross margin': .58},
                      {'medical patients': 89700}]

cgc_data = [{'rev_change': -.038}, {'revenue':90.5},
                      {'volume': 10549}, {'volume_chg': .13}, {'gross margin': .43}]

# %%
symbols = ['APHA.TO', 'CRON.TO']

start = date.today() - timedelta(days=365)
end = date.today()

# %%
stock_loop = lambda x: stock(x, start, end)
stat = lambda x: stocks[x].stats()
bal = lambda x: stocks[x].balance()
fin = lambda x: stocks[x].financial()
ca = lambda x: stocks[x].cash()
an = lambda x: stocks[x].analyze()

# %%
timer_start = time.time()

stocks = list(map(stock_loop, symbols))

timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 6.337111711502075

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    stat(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 1.2199723720550537

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    bal(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 0.82131028175354

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    fin(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 0.7666974067687988

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    ca(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 0.964562177658081

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    an(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 1.656689167022705

# %%
tgod, fire= stocks

# %%
price = list(map(lambda symbol, x: {symbol: stocks[x].price}, symbols, range(0, len(symbols))))

# %%
price
# Out:
# [{'TGOD.TO': 2.39}, {'FIRE.TO': 1.31}]

# %%
tgod.description
# Out:
# 'The Green Organic Dutchman Holdings Ltd., through its subsidiary, The Green Organic Dutchman Ltd., operates as a cannabinoid-based research and development company in Canada. It produces organic cannabis products, including organic dried cannabis, cannabis oils and edibles, fresh cannabis, and seeds for medical applications. The company also operates retail store. The Green Organic Dutchman Holdings Ltd. was incorporated in 2016 and is headquartered in Mississauga, Canada.'

# %%
tgod.statistics.dropna()
# Out:
#                                                  TGOD.TO
# Market Cap (intraday) 5                         639.0300
# Enterprise Value 3                              652.4000
# PEG Ratio (5 yr expected) 1                       0.0800
# Price/Sales (ttm)                                89.0000
# Price/Book (mrq)                                  1.5900
# Enterprise Value/Revenue 3                       90.8600
# Enterprise Value/EBITDA 6                       -11.7000
# 52-Week Change 3                                -70.2700
# S&P500 52-Week Change 3                           1.7500
# 52 Week High 3                                    8.0500
# 52 Week Low 3                                     2.1900
# 50-Day Moving Average 3                           2.9994
# 200-Day Moving Average 3                          3.6219
# Avg Vol (3 month) 3                               1.6000
# Avg Vol (10 day) 3                                2.4200
# ...

# %%
tgod.description
# Out:
# 'The Green Organic Dutchman Holdings Ltd., through its subsidiary, The Green Organic Dutchman Ltd., operates as a cannabinoid-based research and development company in Canada. It produces organic cannabis products, including organic dried cannabis, cannabis oils and edibles, fresh cannabis, and seeds for medical applications. The company also operates retail store. The Green Organic Dutchman Holdings Ltd. was incorporated in 2016 and is headquartered in Mississauga, Canada.'

# %%
tgod.earnings_est
# Out:
#                    Current Qtr. (Sep 2019)  Next Qtr. (Dec 2019)  \
# Earnings Estimate
# No. of Analysts                       3.00                  3.00
# Avg. Estimate                        -0.04                 -0.04
# Low Estimate                         -0.06                 -0.06
# High Estimate                        -0.02                 -0.01
# Year Ago EPS                           NaN                 -0.07
#
#                    Current Year (2019)  Next Year (2020)
# Earnings Estimate
# No. of Analysts                   6.00              6.00
# Avg. Estimate                    -0.17              0.00
# Low Estimate                     -0.21             -0.11
# High Estimate                    -0.10              0.24
# Year Ago EPS                     -0.21             -0.17

# %%
basic_df = lambda x: {'symbol': symbols[x], 'price': stocks[x].price, 'description': stocks[x].description, 'sector': stocks[x].sector}

# %%
dict = list(map(basic_df, range(0, len(stocks))))
df = DataFrame(dict)
df.sort_values('sector')
# Out:
#                                          description  price  \
# 0  The Green Organic Dutchman Holdings Ltd., thro...   2.39
# 1  The Supreme Cannabis Company, Inc. engages in ...   1.31
#
#                                     sector   symbol
# 0  Drug Manufacturers - Specialty  Generic  TGOD.TO
# 1  Drug Manufacturers - Specialty  Generic  FIRE.TO

# %%
tgod.dividends
# Out:
# [                                                Date  Dividends
#  0  *Close price adjusted for splits.**Adjusted cl...        NaN]

# %%
fire.dividends
# Out:
# [                                                Date  Dividends
#  0  *Close price adjusted for splits.**Adjusted cl...        NaN]

# %%
portfolio = industry()

# %%
portfolio.statistics(tgod.stats_list)

# %%
portfolio.statistics.dropna(how='all')
# Out:
#                                                  TGOD.TO   FIRE.TO   Averages
# 200-Day Moving Average 3                          3.6219    1.7021    2.66200
# 50-Day Moving Average 3                           2.9994    1.3991    2.19925
# 52 Week High 3                                    8.0500    2.4300    5.24000
# 52 Week Low 3                                     2.1900    1.1500    1.67000
# 52-Week Change 3                                -70.2700  -39.3500  -54.81000
# Avg Vol (10 day) 3                                2.4200    6.8994    4.65970
# Avg Vol (3 month) 3                               1.6000    6.5762    4.08810
# Beta (3Y Monthly)                                    NaN    4.2300    4.23000
# Book Value Per Share (mrq)                        1.4600    0.7000    1.08000
# Current Ratio (mrq)                               4.6600    3.4100    4.03500
# Diluted EPS (ttm)                                -0.2250   -0.0520   -0.13850
# ...

# %%
statistics_df = portfolio.statistics.dropna(how='all').T.sort_values("Diluted EPS (ttm)", ascending=False)[['Diluted EPS (ttm)', 'Beta (3Y Monthly)', 'Profit Margin']]

# %%
statistics_df
# Out:
#           Diluted EPS (ttm)  Beta (3Y Monthly)  Profit Margin
# FIRE.TO             -0.0520               4.23        -34.650
# Averages            -0.1385               4.23        -17.325
# TGOD.TO             -0.2250                NaN          0.000

# %%
portfolio.cashflow(tgod.cash_list)

# %%
portfolio.cashflow.dropna(how='all')
# Out:
#                                               TGOD.TO    FIRE.TO
# Adjustments To Net Income                  -29.406883   1.545866
# Capital Expenditure                         23.798166  62.091480
# Change In Cash and Cash Equivalents          3.444849  -1.339831
# Changes In Accounts Receivables             -0.000000  45.693482
# Changes In Inventories                       8.254902   5.183486
# Changes In Liabilities                      15.282754  31.189138
# Changes In Other Operating Activities       44.337582 -25.945958
# Depreciation                                 1.513540  28.473879
# Effect Of Exchange Rate Changes            -10.147541        NaN
# Investments                                 -0.000000        NaN
# Net Borrowings                              16.607954   0.941633
# Net Income                                  22.374640   2.304697
# Other Cash Flows from Financing Activities  99.306991        NaN
# ...

# %%
portfolio.balance_sheet(tgod.bs_list)

# %%
portfolio.statistics.dropna(how='all')
# Out:
#                                                  TGOD.TO   FIRE.TO   Averages
# 200-Day Moving Average 3                          3.6219    1.7021    2.66200
# 50-Day Moving Average 3                           2.9994    1.3991    2.19925
# 52 Week High 3                                    8.0500    2.4300    5.24000
# 52 Week Low 3                                     2.1900    1.1500    1.67000
# 52-Week Change 3                                -70.2700  -39.3500  -54.81000
# Avg Vol (10 day) 3                                2.4200    6.8994    4.65970
# Avg Vol (3 month) 3                               1.6000    6.5762    4.08810
# Beta (3Y Monthly)                                    NaN    4.2300    4.23000
# Book Value Per Share (mrq)                        1.4600    0.7000    1.08000
# Current Ratio (mrq)                               4.6600    3.4100    4.03500
# Diluted EPS (ttm)                                -0.2250   -0.0520   -0.13850
# ...

# %%
portfolio.financials(tgod.fin_list)

# %%
portfolio.financials.dropna(how='all').T.sort_values('Gross Profit', ascending=False)
# Out:
#           Cost of Revenue  Gross Profit  Research Development  \
# TGOD.TO         -1.955927      2.746134               2.94669
# Averages        -1.955927      2.746134               2.94669
# FIRE.TO               NaN           NaN                   NaN
#
#           Selling General and Administrative  Total Operating Expenses  \
# TGOD.TO                            24.720546                 28.183580
# Averages                           17.741098                 18.678331
# FIRE.TO                            10.761650                  9.173082
#
#           Operating Income or Loss  Total Other Income/Expenses Net  \
# TGOD.TO                  26.965924                         3.934048
# Averages                 13.199495                        57.034680
# FIRE.TO                  -0.566934                       110.135312
#
#           Earnings Before Interest and Taxes  Interest Expense  \
# TGOD.TO                            26.965924         -0.000000
# ...

# %%
GP = DataFrame(portfolio.financials.dropna(how='all').T.sort_values('Gross Profit', ascending=False)['Gross Profit'])

# %%
Debt = portfolio.balance_sheet.dropna(how='all').T.sort_values('Long Term Debt', ascending=False)['Long Term Debt']

# %%
NI = portfolio.cashflow.dropna(how='all').T.sort_values("Net Income", ascending=False)['Net Income']

# %%
pandas.concat([statistics_df, NI, Debt, GP], axis=1, sort=True).sort_values('Diluted EPS (ttm)', ascending=False)
# Out:
#           Diluted EPS (ttm)  Beta (3Y Monthly)  Profit Margin  Net Income  \
# FIRE.TO             -0.0520               4.23        -34.650    2.304697
# Averages            -0.1385               4.23        -17.325         NaN
# TGOD.TO             -0.2250                NaN          0.000   22.374640
#
#           Long Term Debt  Gross Profit
# FIRE.TO       146.296441           NaN
# Averages      146.296441      2.746134
# TGOD.TO              NaN      2.746134

# %%
cash_debt = tgod.statistics.T['Total Cash (mrq)'][0]/tgod.statistics.T['Total Debt (mrq)'][0]

# %%
cash_debt*100
# Out:
# 2863.3333333333335

# %%
cash_debt = tgod.statistics.T['Total Cash (mrq)'][0]/tgod.statistics.T['Total Debt (mrq)'][0]

# %%
cash_debt*100
# Out:
# 2863.3333333333335

# %%
tgod.statistics.dropna()
# Out:
#                                                  TGOD.TO
# Market Cap (intraday) 5                         639.0300
# Enterprise Value 3                              652.4000
# PEG Ratio (5 yr expected) 1                       0.0800
# Price/Sales (ttm)                                89.0000
# Price/Book (mrq)                                  1.5900
# Enterprise Value/Revenue 3                       90.8600
# Enterprise Value/EBITDA 6                       -11.7000
# 52-Week Change 3                                -70.2700
# S&P500 52-Week Change 3                           1.7500
# 52 Week High 3                                    8.0500
# 52 Week Low 3                                     2.1900
# 50-Day Moving Average 3                           2.9994
# 200-Day Moving Average 3                          3.6219
# Avg Vol (3 month) 3                               1.6000
# Avg Vol (10 day) 3                                2.4200
# ...

# %%
change = tgod.financials.T['Gross Profit'][0] - tgod.financials.T['Gross Profit'][-3]

# %%
change*100/tgod.financials.T['Gross Profit'][-3]
# Out:
# 399.0

# %%
change = fire.financials.T['Gross Profit'][0] - fire.financials.T['Gross Profit'][-3]

# %%
x = change/fire.financials.T['Gross Profit'][-3]

# %%
x
# Out:
# 79.19907773127989

# %%
fire.financials.T['Gross Profit']
# Out:
# Period Ending
# 6/30/2019    36853.000
# 6/30/2018     8924.000
# 6/30/2017      459.519
# 6/30/2016          NaN
# Changes            NaN
# Name: Gross Profit, dtype: float64
