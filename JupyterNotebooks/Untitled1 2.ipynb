# %%
from finance_python.stock import stock
import sys, os, time
import numpy as np
import pandas
from datetime import datetime, date, timedelta
from pandas import DataFrame

# %%
symbols = ['KXS.TO', 'SHOP.TO']
start = date.today() - timedelta(days=365)
end = date.today()

# %%
stock_loop = lambda x: stock(x, start, end)

# %%
timer_start = time.time()

stocks = list(map(stock_loop, symbols))

timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 67.10719704627991

# %%
kxs = stocks[0]
shop = stocks[1]

# %%
kxs.description
# Out:
# 'Kinaxis Inc. provides cloud-based subscription software for supply chain operations in the United States, Europe, Asia, and Canada. The company offers RapidResponse, which provide supply chain planning and analytics capabilities for managing various supply chain management processes, including demand planning, supply planning, inventory management, order fulfillment, capacity planning, and master scheduling, as well as sales and operations planning process. It also provides professional services, such as implementation, technical, and training services, as well as maintenance and support services to its software products. The company serves enterprises operating in various industries, including aerospace and defense, automotive, consumer products, high tech and electronics, industrial, life sciences, and pharmaceuticals. The company was formerly known as webPLAN Inc. and changed its name to Kinaxis Inc. in May 2005. Kinaxis Inc. was founded in 1984 and is headquartered in Ottawa, Canada.'

# %%
shop.description
# Out:
# 'Shopify Inc. provides a cloud-based multi-channel commerce platform for small and medium-sized businesses in the United States, the United Kingdom, Canada, Australia, and internationally. Its platform provides merchants with a single view of business and customers in various sales channels, including Web and mobile storefronts, physical retail locations, social media storefronts, and marketplaces; and enables to manage products and inventory, process orders and payments, ship orders, build customer relationships, leverage analytics and reporting, and access financing. The company was formerly known as Jaded Pixel Technologies Inc. and changed its name to Shopify Inc. in November 2011. Shopify Inc. was founded in 2004 and is headquartered in Ottawa, Canada.'

# %%
shop.sector
kxs.sector
# Out:
# 'Software - Application'

# %%
kxs.dividends
shop.dividends
# Out:
#                                                 Date  Dividends
# 0  *Close price adjusted for splits.**Adjusted cl...        NaN

# %%
kxs.stats()

# %%
shop.stats()

# %%
kxs.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list']]

# %%
shop.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list']]

# %%
kxs.history
shop.history
print(kxs.price)
print(shop.price)
# Out:
# 77.17
# 524.34

# %%
kxs.balance()
shop.balance()

# %%
kxs.balance_sheet
# Out:
# Period Ending                         12/31/2018  12/31/2017  12/31/2016  \
# KXS.TO
# Current Assets                               NaN         NaN         NaN
# Cash And Cash Equivalents               126144.0    103392.0    127910.0
# Short Term Investments                   55404.0     55138.0         NaN
# Net Receivables                          64330.0     32562.0     26158.0
# Inventory                                    NaN         NaN         NaN
# Other Current Assets                         NaN         NaN         NaN
# Total Current Assets                    251693.0    195288.0    157401.0
# Long Term Investments                        NaN         NaN         NaN
# Property, plant and equipment            30619.0     17095.0     10352.0
# Goodwill                                     NaN         NaN         NaN
# Intangible Assets                         1039.0       255.0       300.0
# Accumulated Amortization                     NaN         NaN         NaN
# Other Assets                             14408.0        55.0       239.0
# Deferred Long Term Asset Charges            49.0        55.0       239.0
# Total Assets                            297759.0    212693.0    168292.0
# Current Liabilities                          NaN         NaN         NaN
# Accounts Payable                          1406.0      3307.0      2201.0
# Short/Current Long Term Debt                 NaN         NaN         NaN
# Other Current Liabilities                89572.0     69393.0     57920.0
# Total Current Liabilities               102691.0     78216.0     65953.0
# Long Term Debt                               NaN         NaN         NaN
# Other Liabilities                         4075.0      9689.0     14628.0
# Deferred Long Term Liability Charges     13902.0         NaN         NaN
# Minority Interest                            NaN         NaN         NaN
# Negative Goodwill                            NaN         NaN         NaN
# Total Liabilities                       113077.0     87905.0     80581.0
# Stockholders' Equity                         NaN         NaN         NaN
# Misc. Stocks Options Warrants                NaN         NaN         NaN
# Redeemable Preferred Stock                   NaN         NaN         NaN
# Preferred Stock                              NaN         NaN         NaN
# Common Stock                            124951.0    108253.0     97164.0
# Retained Earnings                        35766.0     -2475.0    -22858.0
# Treasury Stock                            -319.0      -284.0      -519.0
# Capital Surplus                          24284.0     19294.0     13924.0
# Other Stockholder Equity                  -319.0      -284.0      -519.0
# Total stockholders' equity              184682.0    124788.0     87711.0
# Net Tangible Assets                     183643.0    124533.0     87411.0
#
# Period Ending                         12/31/2015   Changes
# KXS.TO
# Current Assets                               NaN       NaN
# Cash And Cash Equivalents                99390.0  0.269182
# Short Term Investments                       NaN       NaN
# Net Receivables                          19448.0  2.307795
# Inventory                                    NaN       NaN
# Other Current Assets                         NaN       NaN
# Total Current Assets                    120744.0  1.084518
# Long Term Investments                        NaN       NaN
# Property, plant and equipment             7002.0  3.372893
# Goodwill                                     NaN       NaN
# Intangible Assets                          350.0  1.968571
# Accumulated Amortization                     NaN       NaN
# Other Assets                                 NaN       NaN
# Deferred Long Term Asset Charges             NaN       NaN
# Total Assets                            128096.0  1.324499
# Current Liabilities                          NaN       NaN
# Accounts Payable                           721.0  0.950069
# Short/Current Long Term Debt                 NaN       NaN
# Other Current Liabilities                40946.0  1.187564
# Total Current Liabilities                47236.0  1.173999
# Long Term Debt                               NaN       NaN
# Other Liabilities                        15256.0 -0.732892
# Deferred Long Term Liability Charges         NaN       NaN
# Minority Interest                            NaN       NaN
# Negative Goodwill                            NaN       NaN
# Total Liabilities                        62492.0  0.809464
# Stockholders' Equity                         NaN       NaN
# Misc. Stocks Options Warrants                NaN       NaN
# Redeemable Preferred Stock                   NaN       NaN
# Preferred Stock                              NaN       NaN
# Common Stock                             90808.0  0.375991
# Retained Earnings                       -33603.0 -2.064369
# Treasury Stock                            -474.0 -0.327004
# Capital Surplus                           8873.0  1.736842
# Other Stockholder Equity                  -474.0 -0.327004
# Total stockholders' equity               65604.0  1.815103
# Net Tangible Assets                      65254.0  1.814280

# %%
kxs.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list'],
#  ['balance_sheet', 'changes', 'bs_list']]

# %%
shop.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list'],
#  ['balance_sheet', 'changes', 'bs_list']]

# %%
stats_list = shop.stats_list

# %%
from finance_python.industry import industry

# %%
technology = industry()
technology.attributes
# Out:
# []

# %%
technology.statistics(stats_list)

# %%
technology.attributes
# Out:
# ['statistics']

# %%
technology.statistics
# Out:
#                                                 KXS.TO  SHOP.TO  Averages
# Market Cap (intraday) 5                         202.00  5902.00  3052.000
# Trailing P/E                                    124.47      NaN   124.470
# Forward P/E 1                                    58.02      NaN    58.020
# PEG Ratio (5 yr expected) 1                      14.90      NaN    14.900
# Price/Sales (ttm)                                12.39    45.53    28.960
# Price/Book (mrq)                                  9.88    27.30    18.590
# Enterprise Value/Revenue 3                       11.22    42.68    26.950
# Enterprise Value/EBITDA 6                        64.03  -589.78  -262.875
# Beta (3Y Monthly)                                 0.76     0.95     0.855
# 52-Week Change 3                                -21.39   172.75    75.680
# S&P500 52-Week Change 3                          -1.71    -1.71    -1.710
# 52 Week High 3                                   99.45   528.15   313.800
# 52 Week Low 3                                    60.01   159.25   109.630
# 50-Day Moving Average 3                          80.74   450.17   265.455
# 200-Day Moving Average 3                         78.96   351.08   215.020
# Shares Outstanding 5                             26.12    98.88    62.500
# Float                                            26.08   100.15    63.115
# Short Ratio (Aug 15, 2019) 4                      4.39     1.91     3.150
# Short % of Shares Outstanding (Aug 15, 2019) 4    1.13     0.52     0.825
# Payout Ratio 4                                    0.00     0.00     0.000
# Profit Margin                                    10.16    -5.98     2.090
# Operating Margin (ttm)                           13.86    -8.97     2.445
# Return on Assets (ttm)                            4.91    -3.40     0.755
# Return on Equity (ttm)                            8.84    -4.06     2.390
# Revenue (ttm)                                   162.99      NaN   162.990
# Revenue Per Share (ttm)                           6.25    11.86     9.055
# Quarterly Revenue Growth (yoy)                    8.60    47.80    28.200
# Gross Profit (ttm)                              103.69   596.27   349.980
# EBITDA                                           28.55   -93.82   -32.635
# Net Income Avi to Common (ttm)                   16.56   -77.53   -30.485
# Diluted EPS (ttm)                                 0.62    -0.71    -0.045
# Quarterly Earnings Growth (yoy)                  -6.20      NaN    -6.200
# Total Cash (mrq)                                200.90      NaN   200.900
# Total Cash Per Share (mrq)                        7.68    17.89    12.785
# Total Debt (mrq)                                 11.15   114.52    62.835
# Total Debt/Equity (mrq)                           5.46     5.30     5.380
# Current Ratio (mrq)                               2.97    11.44     7.205
# Book Value Per Share (mrq)                        7.81    19.20    13.505
# Operating Cash Flow (ttm)                        35.97    59.52    47.745
# Levered Free Cash Flow (ttm)                     28.27    18.21    23.240

# %%
shop.balance()

# %%
shop.bal
