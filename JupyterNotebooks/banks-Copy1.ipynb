# %%
from finance_python.stock import stock
import sys, os, time
import numpy as np
import pandas
from datetime import datetime, date, timedelta
from pandas import DataFrame

# %%
symbols = ['H.TO']
start = date.today() - timedelta(days=365)
end = date.today()

# %%
stock_loop = lambda x: stock(x, start, end)

# %%
timer_start = time.time()

stocks = list(map(stock_loop, symbols))

timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 6.136404991149902

# %%
H = stocks[0]

# %%
H.description
# Out:
# 'Hydro One Limited, through its subsidiaries, operates as an electrical transmission and distribution company in Ontario. It operates through three segments: Transmission, Distribution, and Other Business. The company owns and operates approximately 123,000 circuit kilometers of low-voltage distribution network. It serves approximately 1.3 million residential, small business, commercial, and industrial customers. The company also provides telecommunications support services for its transmission and distribution businesses; and communications and information technology solutions to organizations for broadband network connectivity. Hydro One Limited was incorporated in 2015 and is headquartered in Toronto, Canada.'

# %%
H.sector
# Out:
# 'Utilities - Regulated Electric'

# %%
H.dividends[0].set_index('Date')
# Out:
#                                                           Dividends
# Date
# Jun 11, 2019                                        0.2415 Dividend
# Mar 12, 2019                                          0.23 Dividend
# Dec 10, 2018                                          0.23 Dividend
# Sep 10, 2018                                          0.23 Dividend
# *Close price adjusted for splits.**Adjusted clo...              NaN

# %%
H.stats()

# %%
H.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list']]

# %%
H.statistics.dropna()
# Out:
#                                                    H.TO
# Market Cap (intraday) 5                         1468.00
# Forward P/E 1                                     17.47
# PEG Ratio (5 yr expected) 1                        3.87
# Price/Sales (ttm)                                  2.34
# Price/Book (mrq)                                   1.60
# Enterprise Value/Revenue 3                         4.41
# Enterprise Value/EBITDA 6                         13.19
# Beta (3Y Monthly)                                  0.03
# 52-Week Change 3                                  27.49
# S&P500 52-Week Change 3                            0.81
# 52 Week High 3                                    24.64
# 52 Week Low 3                                     18.95
# 50-Day Moving Average 3                           23.70
# 200-Day Moving Average 3                          22.19
# Shares Outstanding 5                             596.01
# Float                                            314.38
# ...

# %%
H.price
# Out:
# 24.49

# %%
H.balance()

# %%
H.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list'],
#  ['balance_sheet', 'bs_list']]

# %%
H.balance_sheet.dropna()
# Out:
# Period Ending                         12/31/2018  12/31/2017  12/31/2016  \
# H.TO
# Cash And Cash Equivalents               483000.0     25000.0     50000.0
# Net Receivables                         883000.0    889000.0    996000.0
# Inventory                                20000.0     18000.0     19000.0
# Other Current Assets                     64000.0     46000.0     37000.0
# Total Current Assets                   1491000.0   1019000.0   1148000.0
# Property, plant and equipment         20687000.0  19947000.0  19140000.0
# Goodwill                                325000.0    325000.0    327000.0
# Intangible Assets                       410000.0    369000.0    349000.0
# Other Assets                           2744000.0   4041000.0   4387000.0
# Deferred Long Term Asset Charges       1018000.0    987000.0   1235000.0
# Total Assets                          25657000.0  25701000.0  25351000.0
# Accounts Payable                        268000.0    334000.0    328000.0
# ...

# %%
H_bs = H.balance_sheet.dropna()
H_bs.T['Long Term Debt'][0]/H_bs.T['Cash And Cash Equivalents'][0]
# Out:
# 21.67080745341615

# %%
H_bs.T['Cash And Cash Equivalents']
# Out:
# Period Ending
# 12/31/2018    483000.000000
# 12/31/2017     25000.000000
# 12/31/2016     50000.000000
# 12/31/2015     94000.000000
# Changes            4.138298
# Name: Cash And Cash Equivalents, dtype: float64

# %%
H.cash()

# %%
H.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list'],
#  ['balance_sheet', 'bs_list'],
#  ['cashflow', 'cash_list']]

# %%
H.cashflow.dropna()
# Out:
# Period Ending                               12/31/2018  12/31/2017  \
# H.TO
# Net Income                                    -71000.0    676000.0
# Depreciation                                  725000.0    703000.0
# Adjustments To Net Income                     922000.0    200000.0
# Changes In Accounts Receivables                11000.0    195000.0
# Changes In Liabilities                          2000.0      7000.0
# Changes In Other Operating Activities         -36000.0    -89000.0
# Total Cash Flow From Operating Activities    1575000.0   1716000.0
# Capital Expenditure                         -1418000.0  -1467000.0
# Other Cash flows from Investing Activities     22000.0      7000.0
# Total Cash Flows From Investing Activities  -1516000.0  -1540000.0
# Dividends Paid                               -560000.0   -536000.0
# Net Borrowings                                973000.0    368000.0
# Other Cash Flows from Financing Activities    -14000.0    -33000.0
# ...

# %%
H.financial()

# %%
H.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list'],
#  ['balance_sheet', 'bs_list'],
#  ['cashflow', 'cash_list'],
#  ['financials', 'fin_list']]

# %%
H.financials.dropna()
# Out:
# Period Ending                           12/31/2018  12/31/2017  12/31/2016  \
# H.TO
# Total Revenue                            6150000.0   5990000.0   6552000.0
# Cost of Revenue                          3993000.0   3921000.0   4496000.0
# Gross Profit                             2157000.0   2069000.0   2056000.0
# Total Operating Expenses                 4830000.0   4738000.0   5274000.0
# Operating Income or Loss                 1320000.0   1252000.0   1278000.0
# Total Other Income/Expenses Net          -470000.0   -459000.0   -393000.0
# Earnings Before Interest and Taxes       1320000.0   1252000.0   1278000.0
# Interest Expense                         -470000.0   -424000.0   -379000.0
# Income Before Tax                         850000.0    793000.0    885000.0
# Income Tax Expense                        915000.0    111000.0    139000.0
# Minority Interest                          70000.0     72000.0     72000.0
# ...

# %%
H.analyze()

# %%
H.revenue
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list'],
#  ['balance_sheet', 'bs_list'],
#  ['cashflow', 'cash_list'],
#  ['financials', 'fin_list'],
#  ['earnings_est',
#   'revenue',
#   'earnings_history',
#   'eps_trend',
#   'eps_revisions',
#   'growth_estimates',
#   'a_list']]

# %%
H.growth_estimates
# Out:
#                             H.TO  Industry  Sector  S&P 500
# Growth Estimates
# Current Qtr.              -2.60%       NaN     NaN     0.00
# Next Qtr.                 -3.40%       NaN     NaN     0.08
# Current Year               7.40%       NaN     NaN     0.03
# Next Year                 -2.80%       NaN     NaN     0.10
# Next 5 Years (per annum)   4.36%       NaN     NaN     0.08
# Past 5 Years (per annum)   7.50%       NaN     NaN      NaN
