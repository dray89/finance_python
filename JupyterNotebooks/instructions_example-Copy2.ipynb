# %%
from finance_python.stock import stock
from finance_python.industry import industry
import sys, os, time
import numpy as np
import pandas
from datetime import datetime, date, timedelta
from pandas import DataFrame

# %%
symbols = [ 'RBS', 'ORAN', 'LMRK', 'GSBD', 'GILT']
start = date.today() - timedelta(days=365)
end = date.today()

# %%
stock_loop = lambda x: stock(x, start, end)
stat = lambda x: stocks[x].stats()
bal = lambda x: stocks[x].balance()
fin = lambda x: stocks[x].financial()
ca = lambda x: stocks[x].cash()
an = lambda x: stocks[x].analyze()

# %%
timer_start = time.time()

stocks = list(map(stock_loop, symbols))

timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 18.01914668083191

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    stat(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 3.2746782302856445

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    bal(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 2.426229476928711

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    fin(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 2.7278249263763428

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    ca(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 2.411168336868286

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    an(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 5.919370174407959

# %%
RBS, ORAN, LMRK, GSBD, GILT = stocks

# %%
price = list(map(lambda symbol, x: {symbol: stocks[x].price}, symbols, range(0, len(symbols))))

# %%
price
# Out:
# [{'RBS': 4.51},
#  {'ORAN': 15.26},
#  {'LMRK': 15.44},
#  {'GSBD': 19.99},
#  {'GILT': 7.94}]

# %%
RBS.description
# Out:
# 'The Royal Bank of Scotland Group plc, together with its subsidiaries, provides banking and financial products and services to personal, commercial, corporate, and institutional customers worldwide. It operates through Personal  Business Banking, Commercial  Private Banking, RBS International, and NatWest Markets segments. The company also offers wealth management, financial planning, investment management, asset finance, and offshore banking; and financing and risk solutions, as well as trading and flow sales services. The Royal Bank of Scotland Group plc was founded in 1727 and is headquartered in Edinburgh, the United Kingdom.'

# %%
LMRK.earnings_history
# Out:
#                   9/29/2018 12/30/2018 3/30/2019 6/29/2019
# Earnings History
# EPS Est.               0.13       0.12      0.19       0.1
# EPS Actual             3.71      -0.21      0.15      0.23
# Difference             3.58      -0.33     -0.04      0.13
# Surprise %        2,753.80%   -275.00%   -21.10%   130.00%

# %%
RBS.statistics.dropna()
# Out:
#                                                       RBS
# Market Cap (intraday) 5                         2835.0000
# Trailing P/E                                      28.3100
# Price/Book (mrq)                                   0.4500
# Beta (3Y Monthly)                                  1.0900
# 52-Week Change 3                                 -30.7200
# S&P500 52-Week Change 3                            2.0800
# 52 Week High 3                                     7.3100
# 52 Week Low 3                                      4.3300
# 50-Day Moving Average 3                            5.0186
# 200-Day Moving Average 3                           5.9555
# Avg Vol (10 day) 3                                 1.0100
# % Held by Insiders 1                               0.0000
# % Held by Institutions 1                           0.5500
# Shares Short (Aug 15, 2019) 4                      2.7500
# Short Ratio (Aug 15, 2019) 4                       3.0500
# ...

# %%
LMRK.dividends
# Out:
# [                                                Date        Dividends
#  0                                       Aug 01, 2019   0.368 Dividend
#  1                                       Apr 30, 2019  0.3675 Dividend
#  2                                       Feb 01, 2019  0.3675 Dividend
#  3                                       Nov 02, 2018  0.3675 Dividend
#  4  *Close price adjusted for splits.**Adjusted cl...              NaN]

# %%
LMRK.cashflow.dropna()
# Out:
# Period Ending                               12/31/2018  12/31/2017  \
# LMRK
# Net Income                                    115010.0     18769.0
# Depreciation                                   14926.0     12311.0
# Adjustments To Net Income                     -98293.0        -2.0
# Changes In Accounts Receivables                   -3.0     -2338.0
# Changes In Liabilities                          -156.0      -289.0
# Changes In Other Operating Activities          -4037.0     -2215.0
# Total Cash Flow From Operating Activities      31256.0     28473.0
# Other Cash flows from Investing Activities      1108.0     -3209.0
# Total Cash Flows From Investing Activities    -37533.0   -140128.0
# Dividends Paid                                -47731.0    -38711.0
# Net Borrowings                                 13720.0    155908.0
# Other Cash Flows from Financing Activities    -27989.0    -19216.0
# Total Cash Flows From Financing Activities    -13652.0    133981.0
# ...

# %%
portfolio = industry()

# %%
portfolio.statistics(LMRK.stats_list)

# %%
4/LMRK.price
# Out:
# 0.2590673575129534

# %%
.38/GILT.price
# Out:
# 0.04785894206549118

# %%
portfolio.statistics.dropna(how='all')
# Out:
#                                                       RBS     ORAN    LMRK  \
# % Held by Insiders 1                               0.0000     0.00   19.95
# % Held by Institutions 1                           0.5500     1.46   25.18
# 200-Day Moving Average 3                           5.9555    15.48   15.82
# 5 Year Average Dividend Yield 4                       NaN     4.68     NaN
# 50-Day Moving Average 3                            5.0186    14.88   16.28
# 52 Week High 3                                     7.3100    17.06   17.54
# 52 Week Low 3                                      4.3300    14.57   10.32
# 52-Week Change 3                                 -30.7200    -2.93   19.23
# Avg Vol (10 day) 3                                 1.0100      NaN     NaN
# Beta (3Y Monthly)                                  1.0900     0.14    1.18
# Book Value Per Share (mrq)                            NaN      NaN   15.74
# ...

# %%
portfolio.cashflow(LMRK.cash_list)

# %%
portfolio.cashflow.dropna(how='all')
# Out:
#                                                  RBS      ORAN       LMRK  \
# Adjustments To Net Income                  -0.049891  4.488889 -17.233361
# Capital Expenditure                        -0.209451 -0.016600        NaN
# Change In Cash and Cash Equivalents         2.198980 -0.923547 -13.002391
# Changes In Accounts Receivables                  NaN -2.634615  -0.998026
# Changes In Inventories                           NaN  2.166667        NaN
# Changes In Liabilities                           NaN  1.058140  -1.053961
# Changes In Other Operating Activities      -1.300601 -1.951351   1.291146
# Depreciation                               -0.060411  0.090023   1.077673
# Dividends Paid                              0.846753 -0.000537   3.420765
# Effect Of Exchange Rate Changes             0.173611 -0.923077   1.220588
# Investments                                 0.208312 -4.748634        NaN
# Net Borrowings                             -0.258943 -1.291126  -0.887709
# ...

# %%
portfolio.balance_sheet(LMRK.bs_list)

# %%
portfolio.balance_sheet.dropna(how='all')
# Out:
#                                            RBS      ORAN        LMRK  \
# Accounts Payable                      0.022876  0.081741    3.160604
# Capital Surplus                      -0.959607  0.004110         NaN
# Cash And Cash Equivalents             0.044866  0.260685    1.070565
# Common Stock                          0.036473  0.004153    1.005776
# Deferred Long Term Asset Charges     -0.463322 -0.437860         NaN
# Deferred Long Term Liability Charges       NaN       NaN    0.796764
# Goodwill                              0.008636  0.003805         NaN
# Intangible Assets                     0.031665 -0.017729    0.588338
# Inventory                                  NaN  0.264744         NaN
# Long Term Debt                        0.210078 -0.090060    0.230966
# Long Term Investments                 0.243723  0.834786    5.923039
# Minority Interest                     0.053073  0.093220    2.502152
# Net Receivables                      -0.788571  0.790459    1.478576
# ...

# %%
portfolio.financials(LMRK.fin_list)

# %%
portfolio.financials.dropna(how='all')
# Out:
#                                               RBS      ORAN        LMRK  \
# Total Revenue                           -0.090863  0.028457    0.929458
# Cost of Revenue                               NaN  0.034920   -0.021624
# Gross Profit                            -0.090863  0.018136    1.077757
# Research Development                          NaN       NaN         NaN
# Selling General and Administrative      -0.233481  0.008942    0.618543
# Others                                        NaN  0.031690         NaN
# Total Operating Expenses                -0.233481  0.043466    0.571899
# Operating Income or Loss                 1.634652 -0.070218    1.258704
# Total Other Income/Expenses Net         -1.149004 -0.316303   -5.699804
# Earnings Before Interest and Taxes            NaN -0.070218    1.258704
# Interest Expense                              NaN -0.186589    1.039898
# Income Before Tax                       -2.242693  0.097499   95.305394
# ...
