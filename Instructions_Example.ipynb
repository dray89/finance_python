# %%
from finance_python.stock import stock
import sys, os, time
import numpy as np
import pandas
from datetime import datetime, date, timedelta
from pandas import DataFrame

# %%
symbols = ['BMO.TO', 'BNS.TO']
start = date.today() - timedelta(days=365)
end = date.today()

# %%
stock_loop = lambda x: stock(x, start, end)

# %%
timer_start = time.time()

stocks = list(map(stock_loop, symbols))

timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 6.958112716674805

# %%
bmo = stocks[0]
bns = stocks[1]

# %%
bmo.description
# Out:
# "Bank of Montreal provides diversified financial services primarily in North America. It operates through three groups: Personal and Commercial Banking, Wealth Management, and BMO Capital Markets. The company's personal banking products and services include checking and savings accounts, credit cards, mortgages, and financial and investment advice services; and commercial banking products and services comprise business deposit accounts, commercial credit cards, business loans and commercial mortgages, cash management solutions, foreign exchange, and specialized banking programs for small business and commercial banking customers, as well as wealth management products and services, such as insurance products. It also offers equity and debt underwriting, corporate lending and project financing, mergers and acquisitions advisory services, securitization, treasury management, risk management, equity and fixed income research, and institutional sales and trading services to corporate, ins
# ...

# %%
bns.description
# Out:
# 'The Bank of Nova Scotia provides various banking products and services in North America, Latin America, the Caribbean and Central America, and the Asia-Pacific. The company offers financial advice and solutions, and day-to-day banking products, including debit and credit cards, chequing and saving accounts, investments, mortgages, loans, and related creditor insurance to individuals and small businesses; and commercial banking solutions comprising lending, deposit, cash management, and trade finance solutions to medium and large businesses, including automotive dealers and their customers. It is also involved in the provision of investment and wealth management advice, services, products, and solutions to customers and advisors; wealth management solutions, such as private customer, online brokerage, full-service brokerage, pension, and institutional customer services, as well as asset management business focusing on developing investment solutions for retail and institutional inves
# ...

# %%
bmo.sector
bns.sector
# Out:
# 'Banks - Global'

# %%
#bmo.dividends.name = 'BMO'
#bns.dividends.name = 'BNS'

# %%
print(bmo.dividends,bns.dividends)
# Out:
# [                                                Date      Dividends
# 0                                       Jul 31, 2019  1.03 Dividend
# 1                                       Apr 30, 2019     1 Dividend
# 2                                       Jan 31, 2019     1 Dividend
# 3                                       Oct 31, 2018  0.96 Dividend
# 4  *Close price adjusted for splits.**Adjusted cl...            NaN] [                                                Date      Dividends
# 0                                       Jun 28, 2019  0.87 Dividend
# 1                                       Apr 01, 2019  0.87 Dividend
# 2                                       Dec 31, 2018  0.85 Dividend
# 3                                       Oct 01, 2018  0.85 Dividend
# 4  *Close price adjusted for splits.**Adjusted cl...            NaN]

# %%
bmo.stats()

# %%
bns.stats()

# %%
bmo.statistics
# Out:
#                                                  BMO.TO
# Market Cap (intraday) 5                         5709.00
# Enterprise Value 3                                  NaN
# Trailing P/E                                       9.45
# Forward P/E 1                                      8.98
# PEG Ratio (5 yr expected) 1                        1.84
# Price/Sales (ttm)                                  2.32
# Price/Book (mrq)                                   1.24
# Enterprise Value/Revenue 3                        -1.91
# Enterprise Value/EBITDA 6                           NaN
# Beta (3Y Monthly)                                  1.30
# 52-Week Change 3                                 -16.12
# S&P500 52-Week Change 3                           -0.98
# 52 Week High 3                                   109.00
# 52 Week Low 3                                     86.25
# 50-Day Moving Average 3                           96.64
# 200-Day Moving Average 3                         100.51
# ...

# %%
#import pandas as pd
#row = pd.Series({'BMO.TO':4}, name='Total Returns', dtype=float)
#bmo.statistics.append(row)

# %%
bns.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list']]

# %%
bmo.history
bns.history
print(bmo.price)
print(bns.price)
# Out:
# 89.21
# 68.57

# %%
bmo.balance()
bns.balance()

# %%
bmo.balance_sheet
# Out:
# Period Ending                          10/31/2018   10/31/2017   10/31/2016  \
# BMO.TO
# Current Assets                                NaN          NaN          NaN
# Cash And Cash Equivalents              40487000.0   31164000.0   29695000.0
# Short Term Investments                 93356000.0   81537000.0   71095000.0
# Net Receivables                         8367000.0    7824000.0    8692000.0
# Inventory                                 58000.0      55000.0      76000.0
# Other Current Assets                   25323000.0   22807000.0   15950000.0
# Total Current Assets                  293492000.0  271407000.0  249149000.0
# Long Term Investments                  81238000.0   64129000.0   65527000.0
# Property, plant and equipment           2923000.0    2961000.0    2147000.0
# Goodwill                                6373000.0    6244000.0    6381000.0
# Intangible Assets                       2272000.0    2159000.0    2178000.0
# ...

# %%
bmo.balance_sheet['Changes']
# Out:
# BMO.TO
# Current Assets                               NaN
# Cash And Cash Equivalents               0.063684
# Short Term Investments                  0.237356
# Net Receivables                         0.203192
# Inventory                              -0.467890
# Other Current Assets                    0.755981
# Total Current Assets                    0.194548
# Long Term Investments                   0.389681
# Property, plant and equipment           0.279212
# Goodwill                                0.050091
# Intangible Assets                       0.028986
# Accumulated Amortization                     NaN
# Other Assets                            0.185171
# Deferred Long Term Asset Charges       -0.355787
# Total Assets                            0.205906
# Current Liabilities                          NaN
# Accounts Payable                        0.161723
# Short/Current Long Term Debt           -0.113903
# Other Current Liabilities               0.586701
# ...

# %%
bmo.cash()

# %%
bns.cash()

# %%
bmo.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list'],
#  ['balance_sheet', 'bs_list'],
#  ['cashflow', 'cash_list']]

# %%
bmo.cashflow
# Out:
# Period Ending                                       10/31/2018  10/31/2017  \
# BMO.TO
# Net Income                                           5450000.0   5348000.0
# Operating Activities, Cash Flows Provided By or...         NaN         NaN
# Depreciation                                          740000.0    767000.0
# Adjustments To Net Income                             423000.0    577000.0
# Changes In Accounts Receivables                            NaN         NaN
# Changes In Liabilities                                836000.0    144000.0
# Changes In Inventories                                     NaN         NaN
# Changes In Other Operating Activities              -27137000.0 -18405000.0
# Total Cash Flow From Operating Activities          -17349000.0 -12501000.0
# Investing Activities, Cash Flows Provided By or...         NaN         NaN
# Capital Expenditure                                  -330000.0   -301000.0
# ...

# %%
bns.cashflow
# Out:
# Period Ending                                       10/31/2018  10/31/2017  \
# BNS.TO
# Net Income                                           8548000.0   8005000.0
# Operating Activities, Cash Flows Provided By or...         NaN         NaN
# Depreciation                                          439000.0    422000.0
# Adjustments To Net Income                            2657000.0   3151000.0
# Changes In Accounts Receivables                            NaN         NaN
# Changes In Liabilities                                     NaN         NaN
# Changes In Inventories                                     NaN         NaN
# Changes In Other Operating Activities              -34691000.0 -31226000.0
# Total Cash Flow From Operating Activities          -22527000.0 -10932000.0
# Investing Activities, Cash Flows Provided By or...         NaN         NaN
# Capital Expenditure                                  -416000.0   -416000.0
# ...

# %%
bns.analyze()

# %%
bmo.analyze()

# %%
bns.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list'],
#  ['balance_sheet', 'bs_list'],
#  ['cashflow', 'cash_list'],
#  ['earnings_est',
#   'revenue',
#   'earnings_history',
#   'eps_trend',
#   'eps_revisions',
#   'growth_estimates',
#   'a_list']]

# %%
bns.earnings_est
# Out:
#                    Current Qtr. (Oct 2019)  Next Qtr. (Jan 2020)  \
# Earnings Estimate
# No. of Analysts                      13.00                  8.00
# Avg. Estimate                         1.83                  1.86
# Low Estimate                          1.75                  1.80
# High Estimate                         1.94                  1.93
# Year Ago EPS                          1.77                  1.75
#
#                    Current Year (2019)  Next Year (2020)
# Earnings Estimate
# No. of Analysts                  14.00             14.00
# Avg. Estimate                     7.13              7.53
# Low Estimate                      7.03              7.03
# High Estimate                     7.32              7.76
# Year Ago EPS                      6.99              7.13

# %%
bmo.revenue
# Out:
#                         Current Qtr. (Oct 2019) Next Qtr. (Jan 2020)  \
# Revenue Estimate
# No. of Analysts                               3                    1
# Avg. Estimate                             5.86B                5.87B
# Low Estimate                              5.84B                5.87B
# High Estimate                             5.88B                5.87B
# Year Ago Sales                            5.92B                  NaN
# Sales Growth (year/est)                  -1.00%                  NaN
#
#                         Current Year (2019) Next Year (2020)
# Revenue Estimate
# No. of Analysts                           6                6
# Avg. Estimate                        23.01B           23.83B
# Low Estimate                         22.71B           23.35B
# High Estimate                        23.11B           24.08B
# Year Ago Sales                       23.04B           23.01B
# Sales Growth (year/est)              -0.10%            3.60%

# %%
bns.financial()

# %%
bns.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list'],
#  ['balance_sheet', 'bs_list'],
#  ['cashflow', 'cash_list'],
#  ['earnings_est',
#   'revenue',
#   'earnings_history',
#   'eps_trend',
#   'eps_revisions',
#   'growth_estimates',
#   'a_list'],
#  ['financials', 'fin_list']]

# %%
bns.financials
# Out:
# Dates                                  10/31/2018 10/31/2017 10/31/2016  \
# Total Revenue                            26164000   24906000   23938000
# Cost of Revenue                               NaN        NaN        NaN
# Gross Profit                             26164000   24906000   23938000
# Operating Expenses                            NaN        NaN        NaN
# Research Development                          NaN        NaN        NaN
# Selling General and Administrative       12691000   12272000   11610000
# Non Recurring                                 NaN        NaN        NaN
# Others                                    2367000    2358000    2930000
# Total Operating Expenses                 15058000   14630000   14540000
# Operating Income or Loss                 11106000   10276000    9398000
# Income from Continuing Operations             NaN        NaN        NaN
# Total Other Income/Expenses Net               NaN        NaN        NaN
# ...
