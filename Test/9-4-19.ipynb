# %%
from finance_python.stock import stock
from finance_python.industry import industry
import sys, os, time
import numpy as np
import pandas
from datetime import datetime, date, timedelta
from pandas import DataFrame

# %%
symbols = ['ATD-A.TO', 'DSG.TO', 'VFF.TO']

symbols = set(symbols)
symbols = list(symbols)
start = date.today() - timedelta(days=365)
end = date.today()

# %%
stock_loop = lambda x: stock(x, start, end)
stat = lambda x: stocks[x].stats()
bal = lambda x: stocks[x].balance()
fin = lambda x: stocks[x].financial()
ca = lambda x: stocks[x].cash()
an = lambda x: stocks[x].analyze()

# %%
timer_start = time.time()

stocks = list(map(stock_loop, symbols))

timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 17.697929859161377

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    stat(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 4.069112062454224

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    bal(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 2.28488826751709

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    fin(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 2.1612207889556885

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    ca(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 2.235023021697998

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    an(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 5.228779554367065

# %%
ATD, DSG, VFF = stocks

# %%
DSG.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list'],
#  ['balance_sheet', 'bs_list'],
#  ['financials', 'fin_list'],
#  ['cashflow', 'cash_list'],
#  ['earnings_est',
#   'revenue',
#   'earnings_history',
#   'eps_trend',
#   'eps_revisions',
#   'growth_estimates',
#   'a_list']]

# %%
ATD.price
# Out:
# 14.37

# %%
VFF.description
# Out:
# "The Descartes Systems Group Inc. provides federated network and logistics technology solutions worldwide. Its Logistics Application Suite offers a range of modular, cloud-based, and interoperable Web and wireless logistics management applications. The company's Logistics Application Suite offers solutions, such as route planning and execution, mobile applications, and telematics and compliance; transportation management solutions comprising carrier compliance and rate management, freight audit and settlement, dock scheduling and yard management, pool distribution, transportation planning and execution, and logistics flow control, as well as visibility, tracking, and performance management; and global logistics network services, such as document management, community, and connectivity services. Its Logistics Application Suite solutions also include customs and regulatory compliance solutions, such as cargo security compliance, declaration and fiscal compliance, customs warehouse mana
# ...

# %%
VFF.sector
# Out:
# 'Software - Application'

# %%
VFF.price
# Out:
# 47.46

# %%
DSG.revenue
# Out:
# nan

# %%
VFF.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list'],
#  ['balance_sheet', 'bs_list'],
#  ['financials', 'fin_list'],
#  ['cashflow', 'cash_list'],
#  ['earnings_est',
#   'revenue',
#   'earnings_history',
#   'eps_trend',
#   'eps_revisions',
#   'growth_estimates',
#   'a_list']]

# %%
VFF.cashflow.dropna()
# Out:
# Empty DataFrame
# Columns: [Changes]
# Index: []

# %%
portfolio = industry()

# %%
portfolio.statistics(ATD.stats_list)

# %%
portfolio.attributes
# Out:
# ['cashflow()', 'balance_sheet()', 'financials()', 'analysis()', 'statistics']

# %%
portfolio.statistics.dropna(how='all')
# Out:
#                                                 VFF.TO  ATD-A.TO  DSG.TO  \
# Market Cap (intraday) 5                         724.85   4563.00  404.00
# Enterprise Value 3                              739.73       NaN     NaN
# Trailing P/E                                     46.85     25.50  120.05
# Forward P/E 1                                    15.99       NaN     NaN
# Price/Sales (ttm)                                 4.78      0.77   14.12
# Price/Book (mrq)                                  5.40      5.24    6.75
# Enterprise Value/Revenue 3                        4.88      0.92   13.59
# Enterprise Value/EBITDA 6                       -80.93     15.43   40.37
# Beta (3Y Monthly)                                 5.14      0.30    1.23
# 52-Week Change 3                                107.66     29.69    3.24
# S&P500 52-Week Change 3                           0.33      0.33    0.33
# 52 Week High 3                                   24.25     88.70   56.01
# ...

# %%
portfolio.cashflow(ATD.cash_list)

# %%
portfolio.attributes
# Out:
# ['cashflow()',
#  'balance_sheet()',
#  'financials()',
#  'analysis()',
#  'statistics',
#  'cashflow']

# %%
portfolio.cashflow.dropna(how='all')
# Out:
#                                               VFF.TO   ATD-A.TO  DSG.TO
# Net Income                                 -3.457020   0.539540     NaN
# Depreciation                               -0.151841   0.583497     NaN
# Adjustments To Net Income                  -0.652582 -54.066667     NaN
# Changes In Accounts Receivables            -2.916667  -0.248598     NaN
# Changes In Liabilities                     -1.490129 -43.895833     NaN
# Changes In Inventories                     -4.509014  -6.113360     NaN
# Changes In Other Operating Activities      -3.622222  13.800000     NaN
# Total Cash Flow From Operating Activities  -1.307410   0.633349     NaN
# Capital Expenditure                         0.490602   0.264326     NaN
# Other Cash flows from Investing Activities -0.000000 -43.250000     NaN
# Total Cash Flows From Investing Activities  5.501205  -0.208330     NaN
# Dividends Paid                                   NaN   0.741595     NaN
# ...

# %%
portfolio.financials(ATD.fin_list)

# %%
portfolio.financials
# Out:
#                                           VFF.TO  ATD-A.TO  DSG.TO
# Total Revenue                           0.056829  0.731389     NaN
# Cost of Revenue                         0.117697  0.778945     NaN
# Gross Profit                           -0.433346  0.511946     NaN
# Selling General and Administrative      0.291881  0.481009     NaN
# Total Operating Expenses                0.132869  0.741463     NaN
# Operating Income or Loss               -2.838656  0.534197     NaN
# Total Other Income/Expenses Net        -0.650982  4.068768     NaN
# Earnings Before Interest and Taxes     -2.838656  0.534197     NaN
# Interest Expense                        0.204787  2.118474     NaN
# Income Before Tax                      -9.167203  0.379002     NaN
# Income Tax Expense                      1.131783 -0.068792     NaN
# Minority Interest                            NaN -0.211315     NaN
# Net Income From Continuing Ops         -3.457020  0.528706     NaN
# ...

# %%
portfolio.balance_sheet(ATD.bs_list)

# %%
portfolio.balance_sheet
# Out:
#                                      VFF.TO   ATD-A.TO  DSG.TO
# Cash And Cash Equivalents          1.404680   0.178512     NaN
# Net Receivables                    1.351029   0.444452     NaN
# Inventory                          0.378483   0.797110     NaN
# Other Current Assets              37.807339  20.470588     NaN
# Total Current Assets               0.813267   0.499514     NaN
# Long Term Investments                   NaN   0.434286     NaN
# Property, plant and equipment     -0.178247   0.746826     NaN
# Goodwill                                NaN   2.204997     NaN
# Intangible Assets                       NaN   0.249372     NaN
# Other Assets                       0.451019  -0.018338     NaN
# Deferred Long Term Asset Charges        NaN   0.866091     NaN
# Total Assets                       0.229252   0.843300     NaN
# Accounts Payable                   0.648527   0.789544     NaN
# Short/Current Long Term Debt      -0.221969  44.528662     NaN
# ...
