# %%
import pandas
from finance_python.stock_scraper import calculations, industry
from datetime import datetime
from pandas import DataFrame
from balance_sheet import balance_sheet

# %%
symbol = 'ORAN'
source = "yahoo"
start = datetime(2018, 7, 19)
end = datetime(2019, 7, 19)

# %%
d = calculations(symbol, source, start, end)

# %%
from pandas.tseries import converter as pdtc
import matplotlib.units as munits
import numpy as np
munits.registry[np.datetime64] = pdtc.DatetimeConverter()




































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































































d.daily['Adj Close'].values
# Out:
# array([15.58834457, 15.73109627, 15.75012875, 15.68351173, 15.71206379,
#        15.80722904, 16.23547935, 16.30209732, 16.23547935, 16.24499702,
#        16.09272957, 16.17838097, 16.08321381, 16.23547935, 15.99756336,
#        15.92142868, 15.43607807, 15.46462822, 15.44559383, 15.35994339,
#        15.4265604 , 15.40752888, 15.48366165, 15.76916218, 15.86433029,
#        15.75964546, 15.85481358, 16.03563118, 15.90239525, 15.94046307,
#        15.56931305, 15.37897873, 15.25526237, 15.09347725, 14.96024323,
#        14.96975994, 15.09347725, 15.07444382, 15.11251068, 15.20767689,
#        15.0649271 , 15.11251068, 15.17912674, 15.14105988, 15.35042763,
#        15.34091187, 15.31236172, 15.32187748, 15.34091187, 15.37897873,
#        15.1220274 , 14.95072746, 14.92217731, 15.03637695, 15.03637695,
#        14.94120979, 14.88411045, 14.79846001, 15.04589462, 14.99831009,
#        14.76990986, 14.94120979, 15.10299397, 15.0649271 , 15.08396053,
# ...

# %%
d.description
d2 = balance_sheet(symbol)

# %%
d2.bsd
d2.cash/d2.cash3
d2.equity/d2.equity3
d2.netrec/d2.netrec3
d2.assets/d2.assets3
d2.debt/d2.debt3
# Out:
# 1.07139403836023

# %%
symbol_list = d[x][y].calcdf, range(0, len(symbol)), symbol))

# %%
symbol_df = industry(symbol_list)

# %%
pandas.DataFrame.from_dict(symbol_list.industry_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-358da4ab4913> in <module>
# ----> 1 pandas.DataFrame.from_dict(symbol_list.industry_dict)
#
# NameError: name 'symbol_list' is not defined

# %%
pandas.DataFrame.from_dict(cannabis_df.industry_dict).T
# Out:
#                      WEED.TO      APHA.TO       ACB.TO      CRON.TO  \
# to avg_return        0.97453      1.59143      1.16318     0.985974
# to avg_pe                NaN          NaN          NaN            1
# to avg_dividend          NaN          NaN          NaN          NaN
# to avg_pb           0.535386     0.274133     0.471065      1.61407
# to avg_mc            2.36126     0.285607      1.27688     0.972462
# to avg_so           0.490324       1.8323            0      1.72109
# price to mc      2.89118e-09  3.99073e-09  9.87567e-10  2.99322e-09
# price*avgmc/mc           NaN          NaN          NaN          NaN
# cg                       NaN          NaN          NaN          NaN
#
#                      NEPT.TO
# to avg_return       0.284891
# to avg_pe                NaN
# to avg_dividend          NaN
# to avg_pb            2.10535
# to avg_mc           0.103794
# to avg_so           0.956292
# price to mc      1.08245e-08
# price*avgmc/mc           NaN
# ...
