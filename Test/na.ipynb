# %%
from news_updates.news_sources_v3 import News
import time

# %%
pwd
# Out:
# 'C:\\Users\\rayde\\iCloudDrive\\GitHub'

# %%
search = ['National-Bank-Of-Canada-Earnings']

# %%
start_time = time.time()
Weed = News(search[0])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 16.12410569190979 seconds ---

# %%
Weed

# %%
len(Weed.links)
# Out:
# 20

# %%
arts = Weed.art_list

for each in arts:
    if each.summary == ' ':
        print(each.index)
    else:
        pass

# %%
len(arts)
# Out:
# 20

# %%
for each in arts:
    print(each.title, each.authors, '\n', each.summary, '\n' + '-'*100)
# Out:
# Before the Bell: What every Canadian investor needs to know today ['Follow Us On Twitter', 'Terry Weber']
#  A 0A +2A +4A +6The subject who is truly loyal to the Chief Magistrate will neither advise nor submit to arbitrary measures.
# ----------------------------------------------------------------------------------------------------
# National Bank reports its results for the Third Quarter of 2019 ['National Bank Of Canada']
#  MONTREAL, Aug. 28, 2019 /CNW/ - For the third quarter of 2019, National Bank is reporting net income of $608 million, a 7% increase from $569 million in the third quarter of 2018.
# Personal and CommercialNet income totalled $277 million in the third quarter of 2019, up 11% from $250 million in the third quarter of 2018.in the third quarter of 2019, up 11% from in the third quarter of 2018.
# Net interest margin stood at 2.23% in the third quarter of 2019 versus 2.26% in the third quarter of 2018.
# As at July 31, 2019 , the Basel III leverage ratio was 4.0%, stable compared to October 31, 2018 .
# Disclosure of the Third Quarter 2019 resultsConference CallA conference call for analysts and institutional investors will be held on Wednesday, August 28, 2019 at 1:00 p.m. EDT .
# ----------------------------------------------------------------------------------------------------
# National Bank shakes up its Dividend All-Stars portfolio ['Follow Jennifer Dowty On Twitter', 'Jennifer Dowty']
#  A 0A +2A +4A +6The subject who is truly loyal to the Chief Magistrate will neither advise nor submit to arbitrary measures.
# ----------------------------------------------------------------------------------------------------
# National Bank tops estimates as profit rises in third quarter []
#  National Bank tops estimates as profit rises in third quarterThe stock symbol {{StockChart.Ric}} does not existMONTREAL -- National Bank of Canada reported its third-quarter profit climbed to $608 million, helped by growth across the bank.
# The company said Wednesday the profit amounted to $1.66 per diluted share for the quarter ended July 31.
# The result compared with a profit of $569 million or $1.52 per diluted share in the same quarter last year.
# Excluding specified items, National Bank says it earned $606 million or $1.66 per diluted share, up from $569 million or $1.52 per share a year ago.
# National Bank chief executive Louis Vachon said each business segment contributed to earnings growth, to help the bank to post "solid performance" for the quarter.
# ----------------------------------------------------------------------------------------------------
# National Bank hikes dividend, but earnings fall short of expectations ['Armina Ligaya', 'The Canadian Press']
#  National Bank of Canada hiked its dividend Thursday as it reported its second-quarter profit rose compared with a year ago, but fell just short of market expectations.
# Net income rose in personal and commercial banking, U.S. specialty finance and international, and wealth management divisions, tempered by a slowdown in its financial markets segment.
# In its personal and commercial arm, the bank reported net income of $234 million, up nine per cent from $215 million last year.
# In financial markets, however, the bank reported net income of $160 million, down 16 per cent from $190 million in the same quarter in 2018.
# Last week, the Canadian Imperial Bank of Commerce missed analyst estimates, while Royal Bank of Canada and Toronto-Dominion Bank delivered better-than-expected results.
# ----------------------------------------------------------------------------------------------------
# Bank of Montreal (BMO) Q3 2019 Earnings Call Transcript ['Motley Fool Transcription']
#  ETContents:Prepared RemarksQuestions and AnswersCall ParticipantsPrepared Remarks:OperatorGood morning, and welcome to the BMO Financial Group's Q3 2019 Earnings Release and Conference Call for August 27th of 2019.
# Dan Barclay is here from BMO Capital Markets, and Joanna Rotenberg is here from BMO Wealth Management.
# On a year-to-date basis, earnings per share are up 5% or 7%, excluding the impact of the severance charge in Capital Markets last quarter.
# Moving now to slide 12, BMO Capital Markets net income was good at $318 million, up 5% from last year.
# Sumit Malhotra -- Scotia Capital Markets -- AnalystAt this level of capital, do you anticipate once again becoming active on your NCIB?
# ----------------------------------------------------------------------------------------------------
# National Bank of Canada (NA) Set to Announce Quarterly Earnings on Wednesday ['Orville Tucker']
#  National Bank of Canada (TSE:NA) is scheduled to announce its earnings results before the market opens on Wednesday, August 28th.
# National Bank of Canada (TSE:NA) last announced its earnings results on Thursday, May 30th.
# Get National Bank of Canada alerts:Shares of National Bank of Canada stock opened at C$60.63 on Tuesday.
# National Bank of Canada Company ProfileNational Bank of Canada provides various financial products and services to retail, commercial, corporate, and institutional clients in Canada and internationally.
# See Also: Put OptionReceive News & Ratings for National Bank of Canada Daily - Enter your email address below to receive a concise daily summary of the latest news and analysts' ratings for National Bank of Canada and related companies with MarketBeat.com's FREE daily email newsletter.
# ----------------------------------------------------------------------------------------------------
# National Bank of Canada's Profit Increases []
#  By Allison PrangNational Bank of Canada's (NA.T) earnings climbed as total revenue increased from the comparable period a year earlier.
# Profit for the quarter was C$591 million, up 8.2% from the comparable quarter a year prior.
# Total revenue was C$1.95 billion, up 8.7%.
# Adjusted revenue on a taxable-equivalent basis was C$1.95 billion, up 5%.
# Write to Allison Prang at allison.prang@wsj.com(END) Dow Jones NewswiresAugust 28, 2019 08:12 ET (12:12 GMT)Copyright (c) 2019 Dow Jones & Company, Inc.
# ----------------------------------------------------------------------------------------------------
# Posthaste: Good and not great news on Canadian banks, former Fed raps Trump and BMO's new rate call []
#  Scotiabank beat expectations and unlike its rivals saw a drop in credit loss provisions.
# The news wasn’t as good for Bank of Montreal which missed expectations on higher loan loss provisions and slower growth at its U.S. operations.
# Both RBC and CIBC posted higher credit loss provisions last week.
# If the goal of monetary policy is to achieve the best long-term economic outcome, then Fed officials should consider how their decisions will affect the political outcome in 2020,” Dudley writes.
# Meanwhile, escalation of the trade war has led at least one Canadian bank to revise its forecast for the Bank of Canada.
# ----------------------------------------------------------------------------------------------------
# National Bank of Canada (NTIOF) Earnings Expected to Grow: What to Know Ahead of Next Week's Release ['Zacks Equity Research']
#  Estimate Revisions TrendThe consensus EPS estimate for the quarter has remained unchanged over the last 30 days.
# Our proprietary surprise prediction model -- the Zacks Earnings ESP (Expected Surprise Prediction) -- has this insight at its core.
# The Zacks Earnings ESP compares the Most Accurate Estimate to the Zacks Consensus Estimate for the quarter; the Most Accurate Estimate is a more recent version of the Zacks Consensus EPS estimate.
# Thus, a positive or negative Earnings ESP reading theoretically indicates the likely deviation of the actual earnings from the consensus estimate.
# Please note that a negative Earnings ESP reading is not indicative of an earnings miss.
# ----------------------------------------------------------------------------------------------------
# FY2019 Earnings Forecast for Genworth MI Canada Inc Issued By National Bank Financial (TSE:MIC) ['Maria Luz-Campos']
# Smaller, niche lenders Canadian Western Bank and Laurentian Bank also report that day.
# Barclays Plc analyst John Aiken, who called the dividend hike for CIBC, also expects Scotiabank and Canadian Western Bank to follow suit.
# ----------------------------------------------------------------------------------------------------

# %%
keywords = set()
for each in arts:
    for i in each.keywords:
        keywords.add(i)

# %%
for each in keywords:
    print(each + ",")
# Out:
# writes,
# nysecm,
# today,
# genworth,
# close,
# strength,
# signage,
# magistrate,
# release,
# québec,
# big,
# profit,
# falls,
# jones,
# tsevii,
# heres,
# rating,
# canada,
# fed,
# post,
# wake,
# million,
# theres,
# seven,
# upcoming,
# trading,
# good,
# shares,
# plenty,
# scotiabank,
# misses,
# c195,
# q3,
# transaction,
# montreal,
# measures,
# commercial,
# provisions,
# thirdquarter,
# question,
# cent,
# grow,
# hold,
# raps,
# comparable,
# commerce,
# promoted,
# rbc,
# canadas,
# company,
# shakes,
# trade,
# expected,
# estimates,
# tsxna,
# results,
# positive,
# royal,
# canadian,
# watch,
# ltds,
# transcript,
# loans,
# capital,
# truly,
# imperial,
# strong,
# investor,
# research,
# tops,
# earnings,
# weeks,
# week,
# portfolio,
# national,
# rises,
# increases,
# issued,
# violation,
# arbitrary,
# solid,
# loss,
# zacks,
# speech,
# ntiof,
# reported,
# fall,
# signs,
# scotiabanks,
# comments,
# income,
# generations,
# accurate,
# great,
# earned,
# price,
# yes,
# bmo,
# revenue,
# announce,
# short,
# amid,
# climbs,
# subject,
# employment,
# target,
# submit,
# stock,
# financial,
# allison,
# think,
# banks,
# 6the,
# growth,
# loyal,
# dudley,
# dow,
# muzzling,
# banking,
# personal,
# days,
# dechaine,
# advise,
# forecasts,
# hikes,
# trump,
# rate,
# report,
# allstars,
# beat,
# rose,
# preview,
# mi,
# billion,
# posthaste,
# quarterly,
# net,
# segment,
# treasury,
# bell,
# needs,
# bank,
# share,
# weak,
# stocks,
# expectations,
# eps,
# esp,
# tsemic,
# specified,
# consensus,
# ahead,
# chief,
# know,
# equity,
# tensions,
# summer,
# reports,
# markets,
# bmos,
# set,
# credit,
# trumps,
# fy2019,
# statements,
# 31,
# business,
# estimate,
# energy,
# note,
# quarter,
# forecast,
# 2018,
# war,
# 2019,
# pattisons,
# expect,
# dividend,

# %%
search = ['Bank-of-nova-scotia-earnings']

# %%
start_time = time.time()
Weed = News(search[0])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 20.62847399711609 seconds ---

# %%
Weed

# %%
arts = Weed.art_list

for each in arts:
    if each.summary == ' ':
        print(each.index)
    else:
        pass

# %%
for each in arts:
    print(each.title, each.authors, '\n', each.summary, '\n' + '-'*100)
# Out:
# Before the Bell: What every Canadian investor needs to know today ['Follow Us On Twitter', 'Terry Weber']
#  A 0A +2A +4A +6The subject who is truly loyal to the Chief Magistrate will neither advise nor submit to arbitrary measures.
# ----------------------------------------------------------------------------------------------------
# The Daily Chase: BMO misses, Scotia beats; Air Canada-Transat deal under additional scrutiny ['Noah Zivitz']
#  Noah Zivitz Managing Editor, BNN Bloomberg Follow|ArchiveWe’ve got two wildly different storylines in the latest batch of Canadian bank earnings.
# FEDS RATCHET UP SCRUTINY OF AIR CANADA-TRANSATTransport Minister Marc Garneau’s office announced late yesterday he’s going ahead with an in-depth public interest assessment of Air Canada’s proposed takeover of Transat.
# OSC TARGETS RBC, TD ON FX ACTIVITIESThe Ontario Securities Commission has released allegations of inappropriate behaviour by RBC and TD currency traders, including “many hundreds of prohibited disclosures”, between 2011-2013.
# An RBC spokesperson told us the bank is prepared to terminate anyone who doesn’t comply with its standards.
# A TD spokesperson told us the bank is treating this matter “extremely seriously.” Hearings about proposed settlements with both banks are scheduled for Friday.
# ----------------------------------------------------------------------------------------------------
# Bank of Nova Scotia (TSX:BNS): Should You Buy This Stock for the 5% Yield? []
#  The Motley Fool Canada » Bank Stocks » Bank of Nova Scotia (TSX:BNS): Should You Buy This Stock for the 5% Yield?
# Let’s take a look at Bank of Nova Scotia (TSX:BNS)(NYSE:BNS) to see if it deserves to be on your buy list today.
# OpportunityInvestors often sidestep Bank of Nova Scotia in favour of its larger Canadian peers, but the stock probably deserves more respect.
# Last year, for example, Bank of Nova Scotia spent US$2.2 billion to acquire a majority position in BBVA Chile.
# At the time of writing, Bank of Nova Scotia trades at close to $68 per share.
# ----------------------------------------------------------------------------------------------------
# Bank Of Nova Scotia: A Strong Buy Before Earnings ['Stefan Redlich']
#  While the earnings season for the big American banks has come to an end with results generally beating expectations, Canadian banks are yet to follow.
# Canada's Big Five banks - the Royal Bank of Canada (RY), Bank of Montreal (BMO), Canadian Imperial Bank of Commerce (CM), Toronto-Dominion Bank (TD) and Bank of Nova Scotia, aka Scotiabank (BNS) - are all due to report earnings in late August, with the Royal Bank of Canada being first on August 21, 2019.
# Over the past 10 full years, EPS (C$) has been growing at a CAGR of 9%, followed by average dividend growth of 6%.
# Over the past 45 years, strong earnings growth has led to dividend increases in 43 years.
# With the stock trading at an attractive valuation, it makes the case for a strong buy into earnings for any long-term oriented dividend growth portfolio.
# ----------------------------------------------------------------------------------------------------
# Pre-Market Earnings Report for August 27, 2019 : BNS, BMO, SJM, CTLT, MOMO, EV, FRO, AMWD, RGS, JILL ['Nasdaq.Com News']
#  Zacks Investment Research reports that the 2019 Price to Earnings ratio for BNS is 9.62 vs. an industry ratio of 9.80.
# The bank (foreign) company's consensus earnings per share forecast from the 4 analysts that follow the stock is $1.86.
# Zacks Investment Research reports that the 2019 Price to Earnings ratio for BMO is 9.68 vs. an industry ratio of 9.80.
# JILL missed the consensus earnings per share in the 2nd calendar quarter of 2019 by -41.18%.
# Zacks Investment Research reports that the 2020 Price to Earnings ratio for JILL is 9.21 vs. an industry ratio of 17.80.
# ----------------------------------------------------------------------------------------------------
# The Bank of Nova Scotia (BNS) Q3 2019 Earnings Call Transcript ['Motley Fool Transcription']
#  Our PCL ratio on unpaid loans was 52 basis points, up 11 basis points from last year.
# Margins declined 25 basis points year-over-year, within the plus or minus 10 basis points of 450 basis points that we had previously guided to.
# Prudent expense management contributed to the productivity ratio improving by 140 basis points, year-over-year.
# The total PCL ratio was 48 basis points, improving by three basis points quarter-over-quarter, but up eight basis points, year-over-year.
# Our PCL ratio on impaired loans we 52 basis points, which is up 11 basis points from last year, and just slightly above the historical average of 46 basis points.
# ----------------------------------------------------------------------------------------------------
# Posthaste: Good and not great news on Canadian banks, former Fed raps Trump and BMO's new rate call []
#  Scotiabank beat expectations and unlike its rivals saw a drop in credit loss provisions.
# The news wasn’t as good for Bank of Montreal which missed expectations on higher loan loss provisions and slower growth at its U.S. operations.
# Both RBC and CIBC posted higher credit loss provisions last week.
# If the goal of monetary policy is to achieve the best long-term economic outcome, then Fed officials should consider how their decisions will affect the political outcome in 2020,” Dudley writes.
# Meanwhile, escalation of the trade war has led at least one Canadian bank to revise its forecast for the Bank of Canada.
# ----------------------------------------------------------------------------------------------------
# Streetwise newsletter: Scotiabank profit rises while BMO stays flat; OSC allegations against RBC and TD ['Follow Us On Twitter']
#  A 0A +2A +4A +6The subject who is truly loyal to the Chief Magistrate will neither advise nor submit to arbitrary measures.
# ----------------------------------------------------------------------------------------------------
# Three Things You Should Check Before Buying The Bank of Nova Scotia (TSE:BNS) For Its Dividend ['Simply Wall St']
#  Today we’ll take a closer look at The Bank of Nova Scotia (TSE:BNS) from a dividend investor’s perspective.
# Explore this interactive chart for our latest analysis on Bank of Nova Scotia!
# Comparing dividend payments to a company’s net profit after tax is a simple way of reality-checking whether a dividend is sustainable.
# We’d also point out that Bank of Nova Scotia issued a meaningful number of new shares in the past year.
# While we’re not hugely bearish on it, overall we think there are potentially better dividend stocks than Bank of Nova Scotia out there.
# ----------------------------------------------------------------------------------------------------
# Canadian banks to report 'solid' quarter amid trade tensions, strong employment []
#  TORONTO — Trade uncertainty may weigh on the Canadian banks’ upcoming financial results, but strong employment numbers on both sides of the border and a continued boost from their international footprints will likely result in a “solid” quarter, analysts say.
# The Royal Bank of Canada is the first of the country’s biggest lenders to report its results for the quarter ended July 31 on Wednesday, followed by the Canadian Imperial Bank of Commerce on Thursday.
# The Bank of Montreal and Bank of Nova Scotia both report their latest earnings on Aug. 27, followed by National Bank of Canada on Aug. 28 and Toronto-Dominion Bank on Aug. 29.
# The contribution from outside Canada’s borders is expected to be a positive factor this quarter as well.
# Another element will be expenses, which have been an important headwind, said Gabriel Dechaine, an analyst with National Bank of Canada Financial Markets.
# ----------------------------------------------------------------------------------------------------
# Mortgage and international banking units bolster Scotiabank’s income ['Ephraim Vecina']
#  With a robust mortgage segment and a surging international banking arm, the Bank of Nova Scotia saw its net income rise to $1.98 billion in the quarter ending July 31.
# As of the beginning of Q2 2019, the bank said that its $205-billion-plus mortgage business is significantly buffered against the worst effects of a possible downturn.
# On top of these, Scotiabank’s vigorous drive into the Latin America and U.S. markets yielded positive results in the fiscal third quarter.
# During this period, the international banking division enjoyed $902 million in earnings, a massive 90% year-over-year increase.
# Among Scotiabank’s main units, this represented the largest upward movement during the quarter, Bloomberg reported.
# ----------------------------------------------------------------------------------------------------
# The close: TSX ends higher as commodity stocks rise ['Follow Us On Twitter']
#  But the TSX closed higher, thanks to higher crude oil prices and gold continuing to gain traction amid recession concerns.
# U.S. stocks initially advanced, building on Monday’s bounce, as President Donald Trump forecast another round of talks with Beijing.
# China’s foreign ministry, however, reiterated on Tuesday that it had not received any recent U.S. telephone call on trade.
# Financial stocks were weighed down by disappointing earnings from the Bank of Montreal, with BMO down 3.4 per cent on the day.
# Bank of Nova Scotia, which also reported earnings this morning, closed up 1.1 per cent.
# ----------------------------------------------------------------------------------------------------
# Bank of Nova Scotia (TSX:BNS) Is Too Cheap to Ignore, Making Now the Time to Buy []
#  While the likes of Royal Bank of Canada and Toronto-Dominion Bank have made modest gains over that period, Canada’s most international lender Bank of Nova Scotia (TSX:BNS)(NYSE:BNS) has lost almost 8%.
# By the end of the second quarter 2019, 24% of Scotiabank’s earnings came from Mexico, Colombia, Chile, and Peru.
# The mortgage lender is also focused on expanding its Canadian business, notably its wealth management operations with the late-2018 $2.6 billion acquisition of MD Financial Management.
# This is a leading wealth management business catering to doctors, and the deal, on completion, added over $49 billion in assets under management to Scotiabank’s operations.
# In late June 2019, Scotiabank announced it would sell its business in Puerto Rico and the U.S. Virgin Islands for US$560 million.
# ----------------------------------------------------------------------------------------------------
# Scotiabank hikes dividend on profit beat while BMO lags expectations ['Doug Alexander', 'Bloomberg News']
#  Scotiabank’s earnings topped analysts’ estimates on a surge in profit in its international-banking division, fuelled by a sharpened focus on Latin America.
# The bank will raise its quarterly payment to shareholders by three cents to 90 cents per share.
# Bank of Montreal, meanwhile, fell short of expectations as growth was more muted at its U.S. personal-and-commercial banking division, which includes Chicago-based BMO Harris Bank.
# Adjusted profit in the division was up 20 per cent, the biggest gain among the Toronto-based lender’s three main segments.
# Bank of Montreal also said Tuesday that it’s winding down its property and casualty insurance operations.
# ----------------------------------------------------------------------------------------------------
#  []
#
# ----------------------------------------------------------------------------------------------------
# The Week Ahead: Bank earnings continue; Canadian GDP report ['Noah Zivitz']
#  McCreath's Lookahead: Not the time to be bold amid market turmoilNoah Zivitz Managing Editor, BNN Bloomberg Follow|ArchiveBNN Bloomberg sets up the week ahead with what investors need to know.
# Monday, August 26-Notable data: U.S. durable goods orders-G7 summit wraps up in Biarritz, FranceTuesday, August 27-Notable earnings: Bank of Montreal, Bank of Nova Scotia-Notable data: S&P/Case Shiller U.S. home price indexWednesday, August 28-Notable earnings: National Bank, Tiffany & Co.-Deadline for Alcohol and Gaming Commission of Ontario cannabis retail lottery winners to formally apply for licenceThursday, August 29-Notable earnings: Toronto-Dominion Bank, Canadian Western Bank, Laurentian Bank, BRP, Best Buy, Dollar Tree, Dollar General-Notable data: Canadian current account balance, U.S. GDPFriday, August 30-Notable earnings: Campbell Soup-Notable data: Canadian GDP, U.S. personal income and spendingSaturday, September 1-First round of new U.S. and China tariffs take effect Sept. 1
# ----------------------------------------------------------------------------------------------------
# Canada’s big banks are about to release earnings. Here’s what to expect ['Follow James Bradshaw On Twitter', 'James Bradshaw']
#  A 0A +2A +4A +6The subject who is truly loyal to the Chief Magistrate will neither advise nor submit to arbitrary measures.
# ----------------------------------------------------------------------------------------------------
# Bank of Nova Scotia (BNS) Reports Next Week: Wall Street Expects Earnings Growth []
#  Our proprietary surprise prediction model -- the Zacks Earnings ESP (Expected Surprise Prediction) -- has this insight at its core.
# The Zacks Earnings ESP compares the Most Accurate Estimate to the Zacks Consensus Estimate for the quarter; the Most Accurate Estimate is a more recent version of the Zacks Consensus EPS estimate.
# Thus, a positive or negative Earnings ESP reading theoretically indicates the likely deviation of the actual earnings from the consensus estimate.
# Please note that a negative Earnings ESP reading is not indicative of an earnings miss.
# For Bank of Nova Scotia, the Most Accurate Estimate is higher than the Zacks Consensus Estimate, suggesting that analysts have recently become bullish on the company's earnings prospects.
# ----------------------------------------------------------------------------------------------------
# Wake up Canada: There's still plenty of news to watch for in the last days of summer ['Divya Balji', 'Bloomberg News']
#  But there’s still news to watch, as trade tensions escalate and four of the six major Canadian banks report fiscal third-quarter results.
# The slide in Canadian stocks wasn’t as painful as the plunge in their U.S. counterparts — the Nasdaq was down 3 per cent — thanks to the heavy weighting of gold miners in Canada.
# It looks like money manager Steve Eisman’s short bets on Royal Bank of Canada and Canadian Imperial Bank of Commerce haven’t panned out.
# Smaller, niche lenders Canadian Western Bank and Laurentian Bank also report that day.
# Barclays Plc analyst John Aiken, who called the dividend hike for CIBC, also expects Scotiabank and Canadian Western Bank to follow suit.
# ----------------------------------------------------------------------------------------------------
# Scotiabank hikes dividend on boost from international banking, while BMO’s profit stays flat ['Follow James Bradshaw On Twitter', 'James Bradshaw']
#  A 0A +2A +4A +6The subject who is truly loyal to the Chief Magistrate will neither advise nor submit to arbitrary measures.
# ----------------------------------------------------------------------------------------------------

# %%
for each in keywords:
    print(each + ",")
# Out:
# writes,
# nysecm,
# today,
# genworth,
# close,
# strength,
# signage,
# magistrate,
# release,
# québec,
# big,
# profit,
# falls,
# jones,
# tsevii,
# heres,
# rating,
# canada,
# fed,
# post,
# wake,
# million,
# theres,
# seven,
# upcoming,
# trading,
# good,
# shares,
# plenty,
# scotiabank,
# misses,
# c195,
# q3,
# transaction,
# montreal,
# measures,
# commercial,
# provisions,
# thirdquarter,
# question,
# cent,
# grow,
# hold,
# raps,
# comparable,
# commerce,
# promoted,
# rbc,
# canadas,
# company,
# shakes,
# trade,
# expected,
# estimates,
# tsxna,
# results,
# positive,
# royal,
# canadian,
# watch,
# ltds,
# transcript,
# loans,
# capital,
# truly,
# imperial,
# strong,
# investor,
# research,
# tops,
# earnings,
# weeks,
# week,
# portfolio,
# national,
# rises,
# increases,
# issued,
# violation,
# arbitrary,
# solid,
# loss,
# zacks,
# speech,
# ntiof,
# reported,
# fall,
# signs,
# scotiabanks,
# comments,
# income,
# generations,
# accurate,
# great,
# earned,
# price,
# yes,
# bmo,
# revenue,
# announce,
# short,
# amid,
# climbs,
# subject,
# employment,
# target,
# submit,
# stock,
# financial,
# allison,
# think,
# banks,
# 6the,
# growth,
# loyal,
# dudley,
# dow,
# muzzling,
# banking,
# personal,
# days,
# dechaine,
# advise,
# forecasts,
# hikes,
# trump,
# rate,
# report,
# allstars,
# beat,
# rose,
# preview,
# mi,
# billion,
# posthaste,
# quarterly,
# net,
# segment,
# treasury,
# bell,
# needs,
# bank,
# share,
# weak,
# stocks,
# expectations,
# eps,
# esp,
# tsemic,
# specified,
# consensus,
# ahead,
# chief,
# know,
# equity,
# tensions,
# summer,
# reports,
# markets,
# bmos,
# set,
# credit,
# trumps,
# fy2019,
# statements,
# 31,
# business,
# estimate,
# energy,
# note,
# quarter,
# forecast,
# 2018,
# war,
# 2019,
# pattisons,
# expect,
# dividend,
