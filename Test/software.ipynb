# %%
import sys
sys.path.append("C:\\Users\\rayde\\iCloudDrive\\GitHub\\finance_python")
from stock_scraper_v3 import get_data
from balance_sheet import balance_sheet
from financials import financials
from datetime import datetime, date
from pandas import DataFrame
import numpy as np
import pandas
from industry import industry

# %%
retail = ['CSU.TO', 'OTEX.TO', 'REAL.TO', 'KXS.TO', 'SHOP.TO', 
          'GIB-A.TO', 'CDAY.TO', 'DSG.TO', 'LSPD.TO', 'ENGH.TO']

start = date(2018, 7, 19)
end = date(2019, 8, 2)

# %%
dict1 = []
for each in retail:
    try:        
        dict1.append({each: get_data(each, start, end)})
    except:
        print('error in ', each)

# %%
get_data('DSG.TO', start, end)

# %%
dict1[0]['CSU.TO'].div_r
# Out:
# 0.0010566838820062737

# %%
dict1[0]['CSU.TO'].bsd.changes
# Out:
# retained_earnings    0.511475
# equity               0.433466
# net_tangibles        0.187479
# debt                 0.341226
# liabilities          0.146941
# netrec               0.201792
# total_assets         0.215832
# int_assets           0.354275
# cash                 0.203681
# net_assets          -0.235196
# Name: CSU.TO, dtype: float64

# %%
retail_list = list(map(lambda x, y: dict1[x][y].bsd, range(0, len(retail)), retail))

# %%
retail_list
# Out:
# [<balance_sheet.balance_sheet at 0x21e73531128>,
#  <balance_sheet.balance_sheet at 0x21e76849f60>,
#  <balance_sheet.balance_sheet at 0x21e768e7358>,
#  <balance_sheet.balance_sheet at 0x21e7797b128>,
#  <balance_sheet.balance_sheet at 0x21e77a0cef0>,
#  <balance_sheet.balance_sheet at 0x21e77ab7828>,
#  <balance_sheet.balance_sheet at 0x21e78b10e48>,
#  <balance_sheet.balance_sheet at 0x21e78b9a2b0>,
#  <balance_sheet.balance_sheet at 0x21e78c43630>,
#  <balance_sheet.balance_sheet at 0x21e78cdefd0>]

# %%
for x in enumerate(retail_list):
    if hasattr(x[1], 'changes'):
        pass
    else:
        retail_list.pop(x[0])
        continue

# %%
retail_list2 = list(map(lambda x, y: pandas.DataFrame(retail_list[x].changes), range(0, len(retail_list)), retail_list))

# %%
retail_list = list(map(lambda x, y: dict1[x][y].bsd.stats, range(0, len(retail)), retail))

# %%
pandas.concat(retail_list2, sort=True, axis=1)
# Out:
#                      CSU.TO   OTEX.TO   REAL.TO     KXS.TO   SHOP.TO  \
# cash               0.203681  0.540388 -0.050102   0.220056  1.898727
# debt               0.341226  0.093616       NaN        NaN       NaN
# equity             0.433466  0.052051 -0.041722   0.479966  1.088471
# int_assets         0.354275 -0.113442 -0.494589   3.074510  0.514933
# liabilities        0.146941 -0.117515 -0.469076   0.312916  0.463664
# net_assets        -0.235196 -3.694762 -0.006095   0.272738  1.138087
# net_tangibles      0.187479 -0.136862  0.099149   0.474653  1.103294
# netrec             0.201792  0.136018 -0.252366   0.975616  0.884635
# retained_earnings  0.511475  0.050912  0.073004 -15.450909  0.523952
# total_assets       0.215832  0.322980 -0.111681   0.288830  1.075782
#
#                    GIB-A.TO   CDAY.TO     LSPD.TO   ENGH.TO
# cash               0.109838  1.312102    7.425743  0.555046
# debt              -0.179753 -0.407483         NaN -0.340929
# equity             0.077738  0.691323   -1.740568  0.142706
# int_assets        -0.029098 -0.092010   -0.359432 -0.248626
# liabilities        0.154769 -0.354781    0.417599 -0.060189
# net_assets        -1.094352 -0.030251 -350.424242  0.729739
# net_tangibles     -0.156915 -0.538004   -1.591315  0.773862
# netrec             0.096521  0.049550    0.182482 -0.136437
# retained_earnings  0.120435  0.204193    0.627040  0.174641
# total_assets       0.084321 -0.342029    5.553692  0.257184

# %%
retail_list
# Out:
# [                                                      CSU.TO
#  Market Cap (intraday) 5                               26.75B
#  Enterprise Value 3                                     27.1B
#  Trailing P/E                                           66.17
#  Forward P/E 1                                          34.04
#  PEG Ratio (5 yr expected) 1                             2.28
#  Price/Sales (ttm)                                       8.22
#  Price/Book (mrq)                                       47.44
#  Enterprise Value/Revenue 3                              8.33
#  Enterprise Value/EBITDA 6                              50.31
#  Beta (3Y Monthly)                                       0.91
#  52-Week Change 3                                      38.00%
#  S&P500 52-Week Change 3                                2.86%
#  52 Week High 3                                       1320.31
#  52 Week Low 3                                         814.32
#  50-Day Moving Average 3                              1242.58
#  200-Day Moving Average 3                             1152.68
#  Avg Vol (3 month) 3                                   42.17k
#  Avg Vol (10 day) 3                                     47.6k
#  Shares Outstanding 5                                  21.19M
#  Float                                                 19.72M
#  % Held by Insiders 1                                     NaN
#  % Held by Institutions 1                                 NaN
#  Shares Short (Jul 15, 2019) 4                        260.86k
#  Short Ratio (Jul 15, 2019) 4                            5.36
#  Short % of Float (Jul 15, 2019) 4                        NaN
#  Short % of Shares Outstanding (Jul 15, 2019) 4         1.23%
#  Shares Short (prior month Jun 14, 2019) 4            161.21k
#  Forward Annual Dividend Rate 4                          5.23
#  Forward Annual Dividend Yield 4                        0.41%
#  Trailing Annual Dividend Rate 3                         4.00
#  Trailing Annual Dividend Yield 3                       0.32%
#  5 Year Average Dividend Yield 4                         0.78
#  Payout Ratio 4                                        16.58%
#  Dividend Date 3                                  Jul 8, 2019
#  Ex-Dividend Date 4                              Sep 13, 2019
#  Last Split Factor (new per old) 2                        NaN
#  Last Split Date 3                                        NaN
#  Fiscal Year Ends                                Dec 31, 2018
#  Most Recent Quarter (mrq)                       Jun 30, 2019
#  Profit Margin                                         12.42%
#  Operating Margin (ttm)                                16.17%
#  Return on Assets (ttm)                                12.00%
#  Return on Equity (ttm)                                65.73%
#  Revenue (ttm)                                          3.25B
#  Revenue Per Share (ttm)                               153.56
#  Quarterly Revenue Growth (yoy)                        12.50%
#  Gross Profit (ttm)                                     1.13B
#  EBITDA                                                538.6M
#  Net Income Avi to Common (ttm)                        404.3M
#  Diluted EPS (ttm)                                      19.08
#  Quarterly Earnings Growth (yoy)                       40.40%
#  Total Cash (mrq)                                        219M
#  Total Cash Per Share (mrq)                             10.33
#  Total Debt (mrq)                                        563M
#  Total Debt/Equity (mrq)                                99.82
#  Current Ratio (mrq)                                     0.63
#  Book Value Per Share (mrq)                             26.61
#  Operating Cash Flow (ttm)                               685M
#  Levered Free Cash Flow (ttm)                         680.56M,
#                                                       OTEX.TO
#  Market Cap (intraday) 5                               13.81B
#  Enterprise Value 3                                    15.62B
#  Trailing P/E                                           50.25
#  Forward P/E 1                                            NaN
#  PEG Ratio (5 yr expected) 1                              NaN
#  Price/Sales (ttm)                                       4.80
#  Price/Book (mrq)                                        3.59
#  Enterprise Value/Revenue 3                              5.43
#  Enterprise Value/EBITDA 6                              17.72
#  Beta (3Y Monthly)                                       0.76
#  52-Week Change 3                                      11.39%
#  S&P500 52-Week Change 3                                2.86%
#  52 Week High 3                                         58.65
#  52 Week Low 3                                          42.10
#  50-Day Moving Average 3                                55.44
#  200-Day Moving Average 3                               52.30
#  Avg Vol (3 month) 3                                   555.4k
#  Avg Vol (10 day) 3                                    762.7k
#  Shares Outstanding 5                                 269.49M
#  Float                                                264.03M
#  % Held by Insiders 1                                     NaN
#  % Held by Institutions 1                                 NaN
#  Shares Short (Jul 15, 2019) 4                          1.67M
#  Short Ratio (Jul 15, 2019) 4                            2.92
#  Short % of Float (Jul 15, 2019) 4                        NaN
#  Short % of Shares Outstanding (Jul 15, 2019) 4         0.71%
#  Shares Short (prior month Jun 14, 2019) 4              1.71M
#  Forward Annual Dividend Rate 4                          0.92
#  Forward Annual Dividend Yield 4                        1.64%
#  Trailing Annual Dividend Rate 3                         0.61
#  Trailing Annual Dividend Yield 3                       1.08%
#  5 Year Average Dividend Yield 4                         1.45
#  Payout Ratio 4                                        59.53%
#  Dividend Date 3                                 Jun 21, 2019
#  Ex-Dividend Date 4                              May 30, 2019
#  Last Split Factor (new per old) 2                        1/2
#  Last Split Date 3                               Jan 25, 2017
#  Fiscal Year Ends                                Jun 30, 2018
#  Most Recent Quarter (mrq)                       Mar 31, 2019
#  Profit Margin                                          9.57%
#  Operating Margin (ttm)                                20.81%
#  Return on Assets (ttm)                                 4.77%
#  Return on Equity (ttm)                                 7.31%
#  Revenue (ttm)                                          2.88B
#  Revenue Per Share (ttm)                                10.72
#  Quarterly Revenue Growth (yoy)                         4.90%
#  Gross Profit (ttm)                                     2.05B
#  EBITDA                                               881.97M
#  Net Income Avi to Common (ttm)                       275.24M
#  Diluted EPS (ttm)                                       1.02
#  Quarterly Earnings Growth (yoy)                       23.80%
#  Total Cash (mrq)                                     765.22M
#  Total Cash Per Share (mrq)                              2.85
#  Total Debt (mrq)                                       2.62B
#  Total Debt/Equity (mrq)                                68.16
#  Current Ratio (mrq)                                     1.38
#  Book Value Per Share (mrq)                             14.29
#  Operating Cash Flow (ttm)                            852.36M
#  Levered Free Cash Flow (ttm)                         738.18M,
#                                                       REAL.TO
#  Market Cap (intraday) 5                               745.7M
#  Enterprise Value 3                                    686.7M
#  Trailing P/E                                             NaN
#  Forward P/E 1                                          36.29
#  PEG Ratio (5 yr expected) 1                             0.73
#  Price/Sales (ttm)                                       2.63
#  Price/Book (mrq)                                        4.44
#  Enterprise Value/Revenue 3                              2.42
#  Enterprise Value/EBITDA 6                              45.26
#  Beta (3Y Monthly)                                       2.38
#  52-Week Change 3                                      61.13%
#  S&P500 52-Week Change 3                                2.86%
#  52 Week High 3                                          9.04
#  52 Week Low 3                                           2.95
#  50-Day Moving Average 3                                 7.60
#  200-Day Moving Average 3                                5.89
#  Avg Vol (3 month) 3                                  110.62k
#  Avg Vol (10 day) 3                                   219.93k
#  Shares Outstanding 5                                  87.53M
#  Float                                                 76.94M
#  % Held by Insiders 1                                     NaN
#  % Held by Institutions 1                                 NaN
#  Shares Short (Jul 15, 2019) 4                        231.52k
#  Short Ratio (Jul 15, 2019) 4                            3.57
#  Short % of Float (Jul 15, 2019) 4                        NaN
#  Short % of Shares Outstanding (Jul 15, 2019) 4         0.27%
#  Shares Short (prior month Jun 14, 2019) 4            270.18k
#  Forward Annual Dividend Rate 4                           NaN
#  Forward Annual Dividend Yield 4                          NaN
#  Trailing Annual Dividend Rate 3                          NaN
#  Trailing Annual Dividend Yield 3                         NaN
#  5 Year Average Dividend Yield 4                          NaN
#  Payout Ratio 4                                         0.00%
#  Dividend Date 3                                          NaN
#  Ex-Dividend Date 4                                       NaN
#  Last Split Factor (new per old) 2                        NaN
#  Last Split Date 3                                        NaN
#  Fiscal Year Ends                                Sep 30, 2018
#  Most Recent Quarter (mrq)                       Jun 30, 2019
#  Profit Margin                                         -0.51%
#  Operating Margin (ttm)                                 0.45%
#  Return on Assets (ttm)                                 0.40%
#  Return on Equity (ttm)                                -0.23%
#  Revenue (ttm)                                         283.2M
#  Revenue Per Share (ttm)                                 3.25
#  Quarterly Revenue Growth (yoy)                        24.30%
#  Gross Profit (ttm)                                    82.77M
#  EBITDA                                                15.17M
#  Net Income Avi to Common (ttm)                        -1.44M
#  Diluted EPS (ttm)                                      -0.02
#  Quarterly Earnings Growth (yoy)                      412.50%
#  Total Cash (mrq)                                      60.49M
#  Total Cash Per Share (mrq)                              0.71
#  Total Debt (mrq)                                         25k
#  Total Debt/Equity (mrq)                                 0.01
#  Current Ratio (mrq)                                     5.51
#  Book Value Per Share (mrq)                              1.96
#  Operating Cash Flow (ttm)                             11.49M
#  Levered Free Cash Flow (ttm)                          11.33M,
#                                                        KXS.TO
#  Market Cap (intraday) 5                                2.16B
#  Enterprise Value 3                                     1.97B
#  Trailing P/E                                          132.84
#  Forward P/E 1                                          61.92
#  PEG Ratio (5 yr expected) 1                            15.88
#  Price/Sales (ttm)                                      13.22
#  Price/Book (mrq)                                       10.55
#  Enterprise Value/Revenue 3                             12.06
#  Enterprise Value/EBITDA 6                              68.86
#  Beta (3Y Monthly)                                       0.76
#  52-Week Change 3                                     -11.76%
#  S&P500 52-Week Change 3                                2.86%
#  52 Week High 3                                        100.68
#  52 Week Low 3                                          60.01
#  50-Day Moving Average 3                                82.09
#  200-Day Moving Average 3                               78.65
#  Avg Vol (3 month) 3                                   86.77k
#  Avg Vol (10 day) 3                                    82.43k
#  Shares Outstanding 5                                  26.12M
#  Float                                                 26.08M
#  % Held by Insiders 1                                     NaN
#  % Held by Institutions 1                                 NaN
#  Shares Short (Jul 15, 2019) 4                        226.65k
#  Short Ratio (Jul 15, 2019) 4                            3.05
#  Short % of Float (Jul 15, 2019) 4                        NaN
#  Short % of Shares Outstanding (Jul 15, 2019) 4         0.87%
#  Shares Short (prior month Jun 14, 2019) 4            238.32k
#  Forward Annual Dividend Rate 4                           NaN
#  Forward Annual Dividend Yield 4                          NaN
#  Trailing Annual Dividend Rate 3                          NaN
#  Trailing Annual Dividend Yield 3                         NaN
#  5 Year Average Dividend Yield 4                          NaN
#  Payout Ratio 4                                         0.00%
#  Dividend Date 3                                          NaN
#  Ex-Dividend Date 4                                       NaN
#  Last Split Factor (new per old) 2                        NaN
#  Last Split Date 3                                        NaN
#  Fiscal Year Ends                                Dec 31, 2018
#  Most Recent Quarter (mrq)                       Jun 30, 2019
#  Profit Margin                                         10.16%
#  Operating Margin (ttm)                                13.86%
#  Return on Assets (ttm)                                 4.91%
#  Return on Equity (ttm)                                 8.84%
#  Revenue (ttm)                                        162.99M
#  Revenue Per Share (ttm)                                 6.25
#  Quarterly Revenue Growth (yoy)                         8.60%
#  Gross Profit (ttm)                                   103.69M
#  EBITDA                                                28.55M
#  Net Income Avi to Common (ttm)                        16.56M
#  Diluted EPS (ttm)                                       0.62
#  Quarterly Earnings Growth (yoy)                       -6.20%
#  Total Cash (mrq)                                      200.9M
#  Total Cash Per Share (mrq)                              7.68
#  Total Debt (mrq)                                      11.15M
#  Total Debt/Equity (mrq)                                 5.46
#  Current Ratio (mrq)                                     2.97
#  Book Value Per Share (mrq)                              7.81
#  Operating Cash Flow (ttm)                             35.97M
#  Levered Free Cash Flow (ttm)                          28.27M,
#                                                       SHOP.TO
#  Market Cap (intraday) 5                               49.41B
#  Enterprise Value 3                                    47.51B
#  Trailing P/E                                             NaN
#  Forward P/E 1                                            NaN
#  PEG Ratio (5 yr expected) 1                              NaN
#  Price/Sales (ttm)                                      38.11
#  Price/Book (mrq)                                       22.86
#  Enterprise Value/Revenue 3                             36.65
#  Enterprise Value/EBITDA 6                            -506.44
#  Beta (3Y Monthly)                                       0.95
#  52-Week Change 3                                     144.19%
#  S&P500 52-Week Change 3                                2.86%
#  52 Week High 3                                        463.00
#  52 Week Low 3                                         159.25
#  50-Day Moving Average 3                               418.38
#  200-Day Moving Average 3                              323.14
#  Avg Vol (3 month) 3                                  300.73k
#  Avg Vol (10 day) 3                                   362.63k
#  Shares Outstanding 5                                  98.88M
#  Float                                                100.14M
#  % Held by Insiders 1                                     NaN
#  % Held by Institutions 1                                 NaN
#  Shares Short (Jul 15, 2019) 4                        602.48k
#  Short Ratio (Jul 15, 2019) 4                            2.06
#  Short % of Float (Jul 15, 2019) 4                        NaN
#  Short % of Shares Outstanding (Jul 15, 2019) 4         0.54%
#  Shares Short (prior month Jun 14, 2019) 4            761.99k
#  Forward Annual Dividend Rate 4                           NaN
#  Forward Annual Dividend Yield 4                          NaN
#  Trailing Annual Dividend Rate 3                          NaN
#  Trailing Annual Dividend Yield 3                         NaN
#  5 Year Average Dividend Yield 4                          NaN
#  Payout Ratio 4                                         0.00%
#  Dividend Date 3                                          NaN
#  Ex-Dividend Date 4                                       NaN
#  Last Split Factor (new per old) 2                        NaN
#  Last Split Date 3                                        NaN
#  Fiscal Year Ends                                Dec 31, 2018
#  Most Recent Quarter (mrq)                       Jun 30, 2019
#  Profit Margin                                         -5.98%
#  Operating Margin (ttm)                                -8.97%
#  Return on Assets (ttm)                                -3.40%
#  Return on Equity (ttm)                                -4.06%
#  Revenue (ttm)                                           1.3B
#  Revenue Per Share (ttm)                                11.86
#  Quarterly Revenue Growth (yoy)                        47.80%
#  Gross Profit (ttm)                                   596.27M
#  EBITDA                                               -93.82M
#  Net Income Avi to Common (ttm)                       -77.53M
#  Diluted EPS (ttm)                                      -0.71
#  Quarterly Earnings Growth (yoy)                          NaN
#  Total Cash (mrq)                                       2.01B
#  Total Cash Per Share (mrq)                             17.89
#  Total Debt (mrq)                                     114.52M
#  Total Debt/Equity (mrq)                                 5.30
#  Current Ratio (mrq)                                    11.44
#  Book Value Per Share (mrq)                             19.20
#  Operating Cash Flow (ttm)                             59.52M
#  Levered Free Cash Flow (ttm)                          18.21M,
#                                                      GIB-A.TO
#  Market Cap (intraday) 5                               27.49B
#  Enterprise Value 3                                    29.37B
#  Trailing P/E                                           22.91
#  Forward P/E 1                                          19.33
#  PEG Ratio (5 yr expected) 1                             1.91
#  Price/Sales (ttm)                                       2.30
#  Price/Book (mrq)                                        4.05
#  Enterprise Value/Revenue 3                              2.46
#  Enterprise Value/EBITDA 6                              14.42
#  Beta (3Y Monthly)                                       0.39
#  52-Week Change 3                                      23.51%
#  S&P500 52-Week Change 3                                2.86%
#  52 Week High 3                                        106.11
#  52 Week Low 3                                          75.54
#  50-Day Moving Average 3                               102.41
#  200-Day Moving Average 3                               95.03
#  Avg Vol (3 month) 3                                  475.43k
#  Avg Vol (10 day) 3                                   568.43k
#  Shares Outstanding 5                                     NaN
#  Float                                                200.52M
#  % Held by Insiders 1                                     NaN
#  % Held by Institutions 1                                 NaN
#  Shares Short (Jul 15, 2019) 4                             2M
#  Short Ratio (Jul 15, 2019) 4                               4
#  Short % of Float (Jul 15, 2019) 4                        NaN
#  Short % of Shares Outstanding (Jul 15, 2019) 4         0.76%
#  Shares Short (prior month Jun 14, 2019) 4              2.14M
#  Forward Annual Dividend Rate 4                           NaN
#  Forward Annual Dividend Yield 4                          NaN
#  Trailing Annual Dividend Rate 3                          NaN
#  Trailing Annual Dividend Yield 3                         NaN
#  5 Year Average Dividend Yield 4                          NaN
#  Payout Ratio 4                                         0.00%
#  Dividend Date 3                                          NaN
#  Ex-Dividend Date 4                                       NaN
#  Last Split Factor (new per old) 2                        1/2
#  Last Split Date 3                                Jan 5, 2000
#  Fiscal Year Ends                                Sep 30, 2018
#  Most Recent Quarter (mrq)                       Jun 30, 2019
#  Profit Margin                                         10.31%
#  Operating Margin (ttm)                                15.07%
#  Return on Assets (ttm)                                 9.02%
#  Return on Equity (ttm)                                18.40%
#  Revenue (ttm)                                         11.95B
#  Revenue Per Share (ttm)                                43.37
#  Quarterly Revenue Growth (yoy)                         6.10%
#  Gross Profit (ttm)                                     3.52B
#  EBITDA                                                 2.04B
#  Net Income Avi to Common (ttm)                         1.23B
#  Diluted EPS (ttm)                                       4.39
#  Quarterly Earnings Growth (yoy)                        7.30%
#  Total Cash (mrq)                                     225.15M
#  Total Cash Per Share (mrq)                              0.84
#  Total Debt (mrq)                                       2.59B
#  Total Debt/Equity (mrq)                                38.85
#  Current Ratio (mrq)                                     1.09
#  Book Value Per Share (mrq)                             24.85
#  Operating Cash Flow (ttm)                              1.57B
#  Levered Free Cash Flow (ttm)                           1.16B,
#                                                       CDAY.TO
#  Market Cap (intraday) 5                                9.81B
#  Enterprise Value 3                                    10.35B
#  Trailing P/E                                          579.08
#  Forward P/E 1                                            NaN
#  PEG Ratio (5 yr expected) 1                              NaN
#  Price/Sales (ttm)                                      12.60
#  Price/Book (mrq)                                        5.61
#  Enterprise Value/Revenue 3                             13.29
#  Enterprise Value/EBITDA 6                              72.42
#  Beta (3Y Monthly)                                        NaN
#  52-Week Change 3                                      42.07%
#  S&P500 52-Week Change 3                                2.86%
#  52 Week High 3                                         73.70
#  52 Week Low 3                                          42.62
#  50-Day Moving Average 3                                66.72
#  200-Day Moving Average 3                               65.03
#  Avg Vol (3 month) 3                                    2.13k
#  Avg Vol (10 day) 3                                     6.28k
#  Shares Outstanding 5                                  136.7M
#  Float                                                  69.6M
#  % Held by Insiders 1                                     NaN
#  % Held by Institutions 1                                 NaN
#  Shares Short (Jul 15, 2019) 4                         79.97k
#  Short Ratio (Jul 15, 2019) 4                           92.45
#  Short % of Float (Jul 15, 2019) 4                      0.18%
#  Short % of Shares Outstanding (Jul 15, 2019) 4         0.06%
#  Shares Short (prior month Jun 14, 2019) 4            100.73k
#  Forward Annual Dividend Rate 4                           NaN
#  Forward Annual Dividend Yield 4                          NaN
#  Trailing Annual Dividend Rate 3                          NaN
#  Trailing Annual Dividend Yield 3                         NaN
#  5 Year Average Dividend Yield 4                          NaN
#  Payout Ratio 4                                         0.00%
#  Dividend Date 3                                          NaN
#  Ex-Dividend Date 4                                       NaN
#  Last Split Factor (new per old) 2                        NaN
#  Last Split Date 3                                        NaN
#  Fiscal Year Ends                                Dec 31, 2018
#  Most Recent Quarter (mrq)                       Jun 30, 2019
#  Profit Margin                                          2.16%
#  Operating Margin (ttm)                                10.97%
#  Return on Assets (ttm)                                 0.82%
#  Return on Equity (ttm)                                 1.88%
#  Revenue (ttm)                                         778.6M
#  Revenue Per Share (ttm)                                 5.57
#  Quarterly Revenue Growth (yoy)                         9.70%
#  Gross Profit (ttm)                                    354.9M
#  EBITDA                                                142.9M
#  Net Income Avi to Common (ttm)                         30.8M
#  Diluted EPS (ttm)                                       0.12
#  Quarterly Earnings Growth (yoy)                          NaN
#  Total Cash (mrq)                                      237.9M
#  Total Cash Per Share (mrq)                              1.67
#  Total Debt (mrq)                                        716M
#  Total Debt/Equity (mrq)                                40.75
#  Current Ratio (mrq)                                     1.06
#  Book Value Per Share (mrq)                             12.38
#  Operating Cash Flow (ttm)                              54.9M
#  Levered Free Cash Flow (ttm)                          -19.2M,
#                                                        DSG.TO
#  Market Cap (intraday) 5                                3.95B
#  Enterprise Value 3                                     3.85B
#  Trailing P/E                                          117.52
#  Forward P/E 1                                            NaN
#  PEG Ratio (5 yr expected) 1                              NaN
#  Price/Sales (ttm)                                      13.82
#  Price/Book (mrq)                                        6.61
#  Enterprise Value/Revenue 3                             13.47
#  Enterprise Value/EBITDA 6                              40.01
#  Beta (3Y Monthly)                                       1.21
#  52-Week Change 3                                      12.10%
#  S&P500 52-Week Change 3                                2.86%
#  52 Week High 3                                         56.01
#  52 Week Low 3                                          33.96
#  50-Day Moving Average 3                                48.74
#  200-Day Moving Average 3                               48.57
#  Avg Vol (3 month) 3                                  172.35k
#  Avg Vol (10 day) 3                                   124.32k
#  Shares Outstanding 5                                  61.28M
#  Float                                                 76.93M
#  % Held by Insiders 1                                     NaN
#  % Held by Institutions 1                                 NaN
#  Shares Short (Jul 15, 2019) 4                        816.48k
#  Short Ratio (Jul 15, 2019) 4                            5.18
#  Short % of Float (Jul 15, 2019) 4                        NaN
#  Short % of Shares Outstanding (Jul 15, 2019) 4         0.98%
#  Shares Short (prior month Jun 14, 2019) 4            660.94k
#  Forward Annual Dividend Rate 4                           NaN
#  Forward Annual Dividend Yield 4                          NaN
#  Trailing Annual Dividend Rate 3                          NaN
#  Trailing Annual Dividend Yield 3                         NaN
#  5 Year Average Dividend Yield 4                          NaN
#  Payout Ratio 4                                         0.00%
#  Dividend Date 3                                          NaN
#  Ex-Dividend Date 4                                       NaN
#  Last Split Factor (new per old) 2                        NaN
#  Last Split Date 3                                        NaN
#  Fiscal Year Ends                                Jan 31, 2019
#  Most Recent Quarter (mrq)                       Apr 30, 2019
#  Profit Margin                                         11.05%
#  Operating Margin (ttm)                                16.91%
#  Return on Assets (ttm)                                 3.88%
#  Return on Equity (ttm)                                 5.97%
#  Revenue (ttm)                                        286.16M
#  Revenue Per Share (ttm)                                 3.72
#  Quarterly Revenue Growth (yoy)                        16.40%
#  Gross Profit (ttm)                                   200.18M
#  EBITDA                                                96.32M
#  Net Income Avi to Common (ttm)                        31.61M
#  Diluted EPS (ttm)                                       0.40
#  Quarterly Earnings Growth (yoy)                        4.80%
#  Total Cash (mrq)                                      29.55M
#  Total Cash Per Share (mrq)                              0.38
#  Total Debt (mrq)                                      253.5M
#  Total Debt/Equity (mrq)                                46.17
#  Current Ratio (mrq)                                     0.94
#  Book Value Per Share (mrq)                              7.11
#  Operating Cash Flow (ttm)                             82.66M
#  Levered Free Cash Flow (ttm)                          75.93M,
#                                                       LSPD.TO
#  Market Cap (intraday) 5                                3.36B
#  Enterprise Value 3                                     3.23B
#  Trailing P/E                                             NaN
#  Forward P/E 1                                        -222.78
#  PEG Ratio (5 yr expected) 1                              NaN
#  Price/Sales (ttm)                                      43.36
#  Price/Book (mrq)                                       17.08
#  Enterprise Value/Revenue 3                             41.68
#  Enterprise Value/EBITDA 6                            -161.10
#  Beta (3Y Monthly)                                        NaN
#  52-Week Change 3                                          ∞%
#  S&P500 52-Week Change 3                                2.86%
#  52 Week High 3                                         43.10
#  52 Week Low 3                                          18.05
#  50-Day Moving Average 3                                37.51
#  200-Day Moving Average 3                               28.67
#  Avg Vol (3 month) 3                                  178.06k
#  Avg Vol (10 day) 3                                   226.07k
#  Shares Outstanding 5                                  83.75M
#  Float                                                 67.04M
#  % Held by Insiders 1                                     NaN
#  % Held by Institutions 1                                 NaN
#  Shares Short (Jul 15, 2019) 4                         85.47k
#  Short Ratio (Jul 15, 2019) 4                            0.84
#  Short % of Float (Jul 15, 2019) 4                        NaN
#  Short % of Shares Outstanding (Jul 15, 2019) 4         0.23%
#  Shares Short (prior month Jun 14, 2019) 4            107.33k
#  Forward Annual Dividend Rate 4                           NaN
#  Forward Annual Dividend Yield 4                          NaN
#  Trailing Annual Dividend Rate 3                          NaN
#  Trailing Annual Dividend Yield 3                         NaN
#  5 Year Average Dividend Yield 4                          NaN
#  Payout Ratio 4                                         0.00%
#  Dividend Date 3                                          NaN
#  Ex-Dividend Date 4                                       NaN
#  Last Split Factor (new per old) 2                        NaN
#  Last Split Date 3                                        NaN
#  Fiscal Year Ends                                Mar 31, 2019
#  Most Recent Quarter (mrq)                       Mar 31, 2019
#  Profit Margin                                       -236.96%
#  Operating Margin (ttm)                               -28.11%
#  Return on Assets (ttm)                                -8.51%
#  Return on Equity (ttm)                                   NaN
#  Revenue (ttm)                                         77.45M
#  Revenue Per Share (ttm)                                 2.33
#  Quarterly Revenue Growth (yoy)                        35.70%
#  Gross Profit (ttm)                                    53.88M
#  EBITDA                                               -20.04M
#  Net Income Avi to Common (ttm)                      -183.52M
#  Diluted EPS (ttm)                                      -5.53
#  Quarterly Earnings Growth (yoy)                          NaN
#  Total Cash (mrq)                                      207.7M
#  Total Cash Per Share (mrq)                              2.48
#  Total Debt (mrq)                                         NaN
#  Total Debt/Equity (mrq)                                  NaN
#  Current Ratio (mrq)                                     4.56
#  Book Value Per Share (mrq)                              2.35
#  Operating Cash Flow (ttm)                             -7.56M
#  Levered Free Cash Flow (ttm)                         182.62k,
#                                                       ENGH.TO
#  Market Cap (intraday) 5                                1.84B
#  Enterprise Value 3                                     1.64B
#  Trailing P/E                                           27.74
#  Forward P/E 1                                          23.90
#  PEG Ratio (5 yr expected) 1                             1.83
#  Price/Sales (ttm)                                       5.29
#  Price/Book (mrq)                                        4.84
#  Enterprise Value/Revenue 3                              4.71
#  Enterprise Value/EBITDA 6                              16.31
#  Beta (3Y Monthly)                                       0.79
#  52-Week Change 3                                     -11.43%
#  S&P500 52-Week Change 3                                2.86%
#  52 Week High 3                                         43.49
#  52 Week Low 3                                          30.97
#  50-Day Moving Average 3                                35.09
#  200-Day Moving Average 3                               34.77
#  Avg Vol (3 month) 3                                   53.49k
#  Avg Vol (10 day) 3                                    60.13k
#  Shares Outstanding 5                                  50.34M
#  Float                                                 44.09M
#  % Held by Insiders 1                                     NaN
#  % Held by Institutions 1                                 NaN
#  Shares Short (Jul 15, 2019) 4                           303k
#  Short Ratio (Jul 15, 2019) 4                            5.48
#  Short % of Float (Jul 15, 2019) 4                        NaN
#  Short % of Shares Outstanding (Jul 15, 2019) 4         0.55%
#  Shares Short (prior month Jun 14, 2019) 4               327k
#  Forward Annual Dividend Rate 4                          0.44
#  Forward Annual Dividend Yield 4                        1.28%
#  Trailing Annual Dividend Rate 3                         0.40
#  Trailing Annual Dividend Yield 3                       1.16%
#  5 Year Average Dividend Yield 4                         0.97
#  Payout Ratio 4                                        37.04%
#  Dividend Date 3                                 Aug 30, 2019
#  Ex-Dividend Date 4                              Aug 15, 2019
#  Last Split Factor (new per old) 2                        1/2
#  Last Split Date 3                               Jan 28, 2019
#  Fiscal Year Ends                                Oct 31, 2018
#  Most Recent Quarter (mrq)                       Apr 30, 2019
#  Profit Margin                                         19.30%
#  Operating Margin (ttm)                                22.75%
#  Return on Assets (ttm)                                 9.62%
#  Return on Equity (ttm)                                18.96%
#  Revenue (ttm)                                        347.81M
#  Revenue Per Share (ttm)                                 6.38
#  Quarterly Revenue Growth (yoy)                         4.70%
#  Gross Profit (ttm)                                   239.42M
#  EBITDA                                               100.36M
#  Net Income Avi to Common (ttm)                        67.11M
#  Diluted EPS (ttm)                                       1.22
#  Quarterly Earnings Growth (yoy)                        8.00%
#  Total Cash (mrq)                                     205.52M
#  Total Cash Per Share (mrq)                              3.76
#  Total Debt (mrq)                                        760k
#  Total Debt/Equity (mrq)                                 0.20
#  Current Ratio (mrq)                                     2.20
#  Book Value Per Share (mrq)                              6.96
#  Operating Cash Flow (ttm)                             99.09M
#  Levered Free Cash Flow (ttm)                          89.55M]

# %%
for x in enumerate(retail_list):
    if retail_list[x[0]].iloc[0].name == 0:
        retail_list.pop(x[0])

# %%
retail_list
# Out:
# [                                                      CSU.TO
#  Market Cap (intraday) 5                               26.75B
#  Enterprise Value 3                                     27.1B
#  Trailing P/E                                           66.17
#  Forward P/E 1                                          34.04
#  PEG Ratio (5 yr expected) 1                             2.28
#  Price/Sales (ttm)                                       8.22
#  Price/Book (mrq)                                       47.44
#  Enterprise Value/Revenue 3                              8.33
#  Enterprise Value/EBITDA 6                              50.31
#  Beta (3Y Monthly)                                       0.91
#  52-Week Change 3                                      38.00%
#  S&P500 52-Week Change 3                                2.86%
#  52 Week High 3                                       1320.31
#  52 Week Low 3                                         814.32
#  50-Day Moving Average 3                              1242.58
#  200-Day Moving Average 3                             1152.68
#  Avg Vol (3 month) 3                                   42.17k
#  Avg Vol (10 day) 3                                     47.6k
#  Shares Outstanding 5                                  21.19M
#  Float                                                 19.72M
#  % Held by Insiders 1                                     NaN
#  % Held by Institutions 1                                 NaN
#  Shares Short (Jul 15, 2019) 4                        260.86k
#  Short Ratio (Jul 15, 2019) 4                            5.36
#  Short % of Float (Jul 15, 2019) 4                        NaN
#  Short % of Shares Outstanding (Jul 15, 2019) 4         1.23%
#  Shares Short (prior month Jun 14, 2019) 4            161.21k
#  Forward Annual Dividend Rate 4                          5.23
#  Forward Annual Dividend Yield 4                        0.41%
#  Trailing Annual Dividend Rate 3                         4.00
#  Trailing Annual Dividend Yield 3                       0.32%
#  5 Year Average Dividend Yield 4                         0.78
#  Payout Ratio 4                                        16.58%
#  Dividend Date 3                                  Jul 8, 2019
#  Ex-Dividend Date 4                              Sep 13, 2019
#  Last Split Factor (new per old) 2                        NaN
#  Last Split Date 3                                        NaN
#  Fiscal Year Ends                                Dec 31, 2018
#  Most Recent Quarter (mrq)                       Jun 30, 2019
#  Profit Margin                                         12.42%
#  Operating Margin (ttm)                                16.17%
#  Return on Assets (ttm)                                12.00%
#  Return on Equity (ttm)                                65.73%
#  Revenue (ttm)                                          3.25B
#  Revenue Per Share (ttm)                               153.56
#  Quarterly Revenue Growth (yoy)                        12.50%
#  Gross Profit (ttm)                                     1.13B
#  EBITDA                                                538.6M
#  Net Income Avi to Common (ttm)                        404.3M
#  Diluted EPS (ttm)                                      19.08
#  Quarterly Earnings Growth (yoy)                       40.40%
#  Total Cash (mrq)                                        219M
#  Total Cash Per Share (mrq)                             10.33
#  Total Debt (mrq)                                        563M
#  Total Debt/Equity (mrq)                                99.82
#  Current Ratio (mrq)                                     0.63
#  Book Value Per Share (mrq)                             26.61
#  Operating Cash Flow (ttm)                               685M
#  Levered Free Cash Flow (ttm)                         680.56M,
#                                                       OTEX.TO
#  Market Cap (intraday) 5                               13.81B
#  Enterprise Value 3                                    15.62B
#  Trailing P/E                                           50.25
#  Forward P/E 1                                            NaN
#  PEG Ratio (5 yr expected) 1                              NaN
#  Price/Sales (ttm)                                       4.80
#  Price/Book (mrq)                                        3.59
#  Enterprise Value/Revenue 3                              5.43
#  Enterprise Value/EBITDA 6                              17.72
#  Beta (3Y Monthly)                                       0.76
#  52-Week Change 3                                      11.39%
#  S&P500 52-Week Change 3                                2.86%
#  52 Week High 3                                         58.65
#  52 Week Low 3                                          42.10
#  50-Day Moving Average 3                                55.44
#  200-Day Moving Average 3                               52.30
#  Avg Vol (3 month) 3                                   555.4k
#  Avg Vol (10 day) 3                                    762.7k
#  Shares Outstanding 5                                 269.49M
#  Float                                                264.03M
#  % Held by Insiders 1                                     NaN
#  % Held by Institutions 1                                 NaN
#  Shares Short (Jul 15, 2019) 4                          1.67M
#  Short Ratio (Jul 15, 2019) 4                            2.92
#  Short % of Float (Jul 15, 2019) 4                        NaN
#  Short % of Shares Outstanding (Jul 15, 2019) 4         0.71%
#  Shares Short (prior month Jun 14, 2019) 4              1.71M
#  Forward Annual Dividend Rate 4                          0.92
#  Forward Annual Dividend Yield 4                        1.64%
#  Trailing Annual Dividend Rate 3                         0.61
#  Trailing Annual Dividend Yield 3                       1.08%
#  5 Year Average Dividend Yield 4                         1.45
#  Payout Ratio 4                                        59.53%
#  Dividend Date 3                                 Jun 21, 2019
#  Ex-Dividend Date 4                              May 30, 2019
#  Last Split Factor (new per old) 2                        1/2
#  Last Split Date 3                               Jan 25, 2017
#  Fiscal Year Ends                                Jun 30, 2018
#  Most Recent Quarter (mrq)                       Mar 31, 2019
#  Profit Margin                                          9.57%
#  Operating Margin (ttm)                                20.81%
#  Return on Assets (ttm)                                 4.77%
#  Return on Equity (ttm)                                 7.31%
#  Revenue (ttm)                                          2.88B
#  Revenue Per Share (ttm)                                10.72
#  Quarterly Revenue Growth (yoy)                         4.90%
#  Gross Profit (ttm)                                     2.05B
#  EBITDA                                               881.97M
#  Net Income Avi to Common (ttm)                       275.24M
#  Diluted EPS (ttm)                                       1.02
#  Quarterly Earnings Growth (yoy)                       23.80%
#  Total Cash (mrq)                                     765.22M
#  Total Cash Per Share (mrq)                              2.85
#  Total Debt (mrq)                                       2.62B
#  Total Debt/Equity (mrq)                                68.16
#  Current Ratio (mrq)                                     1.38
#  Book Value Per Share (mrq)                             14.29
#  Operating Cash Flow (ttm)                            852.36M
#  Levered Free Cash Flow (ttm)                         738.18M,
#                                                       REAL.TO
#  Market Cap (intraday) 5                               745.7M
#  Enterprise Value 3                                    686.7M
#  Trailing P/E                                             NaN
#  Forward P/E 1                                          36.29
#  PEG Ratio (5 yr expected) 1                             0.73
#  Price/Sales (ttm)                                       2.63
#  Price/Book (mrq)                                        4.44
#  Enterprise Value/Revenue 3                              2.42
#  Enterprise Value/EBITDA 6                              45.26
#  Beta (3Y Monthly)                                       2.38
#  52-Week Change 3                                      61.13%
#  S&P500 52-Week Change 3                                2.86%
#  52 Week High 3                                          9.04
#  52 Week Low 3                                           2.95
#  50-Day Moving Average 3                                 7.60
#  200-Day Moving Average 3                                5.89
#  Avg Vol (3 month) 3                                  110.62k
#  Avg Vol (10 day) 3                                   219.93k
#  Shares Outstanding 5                                  87.53M
#  Float                                                 76.94M
#  % Held by Insiders 1                                     NaN
#  % Held by Institutions 1                                 NaN
#  Shares Short (Jul 15, 2019) 4                        231.52k
#  Short Ratio (Jul 15, 2019) 4                            3.57
#  Short % of Float (Jul 15, 2019) 4                        NaN
#  Short % of Shares Outstanding (Jul 15, 2019) 4         0.27%
#  Shares Short (prior month Jun 14, 2019) 4            270.18k
#  Forward Annual Dividend Rate 4                           NaN
#  Forward Annual Dividend Yield 4                          NaN
#  Trailing Annual Dividend Rate 3                          NaN
#  Trailing Annual Dividend Yield 3                         NaN
#  5 Year Average Dividend Yield 4                          NaN
#  Payout Ratio 4                                         0.00%
#  Dividend Date 3                                          NaN
#  Ex-Dividend Date 4                                       NaN
#  Last Split Factor (new per old) 2                        NaN
#  Last Split Date 3                                        NaN
#  Fiscal Year Ends                                Sep 30, 2018
#  Most Recent Quarter (mrq)                       Jun 30, 2019
#  Profit Margin                                         -0.51%
#  Operating Margin (ttm)                                 0.45%
#  Return on Assets (ttm)                                 0.40%
#  Return on Equity (ttm)                                -0.23%
#  Revenue (ttm)                                         283.2M
#  Revenue Per Share (ttm)                                 3.25
#  Quarterly Revenue Growth (yoy)                        24.30%
#  Gross Profit (ttm)                                    82.77M
#  EBITDA                                                15.17M
#  Net Income Avi to Common (ttm)                        -1.44M
#  Diluted EPS (ttm)                                      -0.02
#  Quarterly Earnings Growth (yoy)                      412.50%
#  Total Cash (mrq)                                      60.49M
#  Total Cash Per Share (mrq)                              0.71
#  Total Debt (mrq)                                         25k
#  Total Debt/Equity (mrq)                                 0.01
#  Current Ratio (mrq)                                     5.51
#  Book Value Per Share (mrq)                              1.96
#  Operating Cash Flow (ttm)                             11.49M
#  Levered Free Cash Flow (ttm)                          11.33M,
#                                                        KXS.TO
#  Market Cap (intraday) 5                                2.16B
#  Enterprise Value 3                                     1.97B
#  Trailing P/E                                          132.84
#  Forward P/E 1                                          61.92
#  PEG Ratio (5 yr expected) 1                            15.88
#  Price/Sales (ttm)                                      13.22
#  Price/Book (mrq)                                       10.55
#  Enterprise Value/Revenue 3                             12.06
#  Enterprise Value/EBITDA 6                              68.86
#  Beta (3Y Monthly)                                       0.76
#  52-Week Change 3                                     -11.76%
#  S&P500 52-Week Change 3                                2.86%
#  52 Week High 3                                        100.68
#  52 Week Low 3                                          60.01
#  50-Day Moving Average 3                                82.09
#  200-Day Moving Average 3                               78.65
#  Avg Vol (3 month) 3                                   86.77k
#  Avg Vol (10 day) 3                                    82.43k
#  Shares Outstanding 5                                  26.12M
#  Float                                                 26.08M
#  % Held by Insiders 1                                     NaN
#  % Held by Institutions 1                                 NaN
#  Shares Short (Jul 15, 2019) 4                        226.65k
#  Short Ratio (Jul 15, 2019) 4                            3.05
#  Short % of Float (Jul 15, 2019) 4                        NaN
#  Short % of Shares Outstanding (Jul 15, 2019) 4         0.87%
#  Shares Short (prior month Jun 14, 2019) 4            238.32k
#  Forward Annual Dividend Rate 4                           NaN
#  Forward Annual Dividend Yield 4                          NaN
#  Trailing Annual Dividend Rate 3                          NaN
#  Trailing Annual Dividend Yield 3                         NaN
#  5 Year Average Dividend Yield 4                          NaN
#  Payout Ratio 4                                         0.00%
#  Dividend Date 3                                          NaN
#  Ex-Dividend Date 4                                       NaN
#  Last Split Factor (new per old) 2                        NaN
#  Last Split Date 3                                        NaN
#  Fiscal Year Ends                                Dec 31, 2018
#  Most Recent Quarter (mrq)                       Jun 30, 2019
#  Profit Margin                                         10.16%
#  Operating Margin (ttm)                                13.86%
#  Return on Assets (ttm)                                 4.91%
#  Return on Equity (ttm)                                 8.84%
#  Revenue (ttm)                                        162.99M
#  Revenue Per Share (ttm)                                 6.25
#  Quarterly Revenue Growth (yoy)                         8.60%
#  Gross Profit (ttm)                                   103.69M
#  EBITDA                                                28.55M
#  Net Income Avi to Common (ttm)                        16.56M
#  Diluted EPS (ttm)                                       0.62
#  Quarterly Earnings Growth (yoy)                       -6.20%
#  Total Cash (mrq)                                      200.9M
#  Total Cash Per Share (mrq)                              7.68
#  Total Debt (mrq)                                      11.15M
#  Total Debt/Equity (mrq)                                 5.46
#  Current Ratio (mrq)                                     2.97
#  Book Value Per Share (mrq)                              7.81
#  Operating Cash Flow (ttm)                             35.97M
#  Levered Free Cash Flow (ttm)                          28.27M,
#                                                       SHOP.TO
#  Market Cap (intraday) 5                               49.41B
#  Enterprise Value 3                                    47.51B
#  Trailing P/E                                             NaN
#  Forward P/E 1                                            NaN
#  PEG Ratio (5 yr expected) 1                              NaN
#  Price/Sales (ttm)                                      38.11
#  Price/Book (mrq)                                       22.86
#  Enterprise Value/Revenue 3                             36.65
#  Enterprise Value/EBITDA 6                            -506.44
#  Beta (3Y Monthly)                                       0.95
#  52-Week Change 3                                     144.19%
#  S&P500 52-Week Change 3                                2.86%
#  52 Week High 3                                        463.00
#  52 Week Low 3                                         159.25
#  50-Day Moving Average 3                               418.38
#  200-Day Moving Average 3                              323.14
#  Avg Vol (3 month) 3                                  300.73k
#  Avg Vol (10 day) 3                                   362.63k
#  Shares Outstanding 5                                  98.88M
#  Float                                                100.14M
#  % Held by Insiders 1                                     NaN
#  % Held by Institutions 1                                 NaN
#  Shares Short (Jul 15, 2019) 4                        602.48k
#  Short Ratio (Jul 15, 2019) 4                            2.06
#  Short % of Float (Jul 15, 2019) 4                        NaN
#  Short % of Shares Outstanding (Jul 15, 2019) 4         0.54%
#  Shares Short (prior month Jun 14, 2019) 4            761.99k
#  Forward Annual Dividend Rate 4                           NaN
#  Forward Annual Dividend Yield 4                          NaN
#  Trailing Annual Dividend Rate 3                          NaN
#  Trailing Annual Dividend Yield 3                         NaN
#  5 Year Average Dividend Yield 4                          NaN
#  Payout Ratio 4                                         0.00%
#  Dividend Date 3                                          NaN
#  Ex-Dividend Date 4                                       NaN
#  Last Split Factor (new per old) 2                        NaN
#  Last Split Date 3                                        NaN
#  Fiscal Year Ends                                Dec 31, 2018
#  Most Recent Quarter (mrq)                       Jun 30, 2019
#  Profit Margin                                         -5.98%
#  Operating Margin (ttm)                                -8.97%
#  Return on Assets (ttm)                                -3.40%
#  Return on Equity (ttm)                                -4.06%
#  Revenue (ttm)                                           1.3B
#  Revenue Per Share (ttm)                                11.86
#  Quarterly Revenue Growth (yoy)                        47.80%
#  Gross Profit (ttm)                                   596.27M
#  EBITDA                                               -93.82M
#  Net Income Avi to Common (ttm)                       -77.53M
#  Diluted EPS (ttm)                                      -0.71
#  Quarterly Earnings Growth (yoy)                          NaN
#  Total Cash (mrq)                                       2.01B
#  Total Cash Per Share (mrq)                             17.89
#  Total Debt (mrq)                                     114.52M
#  Total Debt/Equity (mrq)                                 5.30
#  Current Ratio (mrq)                                    11.44
#  Book Value Per Share (mrq)                             19.20
#  Operating Cash Flow (ttm)                             59.52M
#  Levered Free Cash Flow (ttm)                          18.21M,
#                                                      GIB-A.TO
#  Market Cap (intraday) 5                               27.49B
#  Enterprise Value 3                                    29.37B
#  Trailing P/E                                           22.91
#  Forward P/E 1                                          19.33
#  PEG Ratio (5 yr expected) 1                             1.91
#  Price/Sales (ttm)                                       2.30
#  Price/Book (mrq)                                        4.05
#  Enterprise Value/Revenue 3                              2.46
#  Enterprise Value/EBITDA 6                              14.42
#  Beta (3Y Monthly)                                       0.39
#  52-Week Change 3                                      23.51%
#  S&P500 52-Week Change 3                                2.86%
#  52 Week High 3                                        106.11
#  52 Week Low 3                                          75.54
#  50-Day Moving Average 3                               102.41
#  200-Day Moving Average 3                               95.03
#  Avg Vol (3 month) 3                                  475.43k
#  Avg Vol (10 day) 3                                   568.43k
#  Shares Outstanding 5                                     NaN
#  Float                                                200.52M
#  % Held by Insiders 1                                     NaN
#  % Held by Institutions 1                                 NaN
#  Shares Short (Jul 15, 2019) 4                             2M
#  Short Ratio (Jul 15, 2019) 4                               4
#  Short % of Float (Jul 15, 2019) 4                        NaN
#  Short % of Shares Outstanding (Jul 15, 2019) 4         0.76%
#  Shares Short (prior month Jun 14, 2019) 4              2.14M
#  Forward Annual Dividend Rate 4                           NaN
#  Forward Annual Dividend Yield 4                          NaN
#  Trailing Annual Dividend Rate 3                          NaN
#  Trailing Annual Dividend Yield 3                         NaN
#  5 Year Average Dividend Yield 4                          NaN
#  Payout Ratio 4                                         0.00%
#  Dividend Date 3                                          NaN
#  Ex-Dividend Date 4                                       NaN
#  Last Split Factor (new per old) 2                        1/2
#  Last Split Date 3                                Jan 5, 2000
#  Fiscal Year Ends                                Sep 30, 2018
#  Most Recent Quarter (mrq)                       Jun 30, 2019
#  Profit Margin                                         10.31%
#  Operating Margin (ttm)                                15.07%
#  Return on Assets (ttm)                                 9.02%
#  Return on Equity (ttm)                                18.40%
#  Revenue (ttm)                                         11.95B
#  Revenue Per Share (ttm)                                43.37
#  Quarterly Revenue Growth (yoy)                         6.10%
#  Gross Profit (ttm)                                     3.52B
#  EBITDA                                                 2.04B
#  Net Income Avi to Common (ttm)                         1.23B
#  Diluted EPS (ttm)                                       4.39
#  Quarterly Earnings Growth (yoy)                        7.30%
#  Total Cash (mrq)                                     225.15M
#  Total Cash Per Share (mrq)                              0.84
#  Total Debt (mrq)                                       2.59B
#  Total Debt/Equity (mrq)                                38.85
#  Current Ratio (mrq)                                     1.09
#  Book Value Per Share (mrq)                             24.85
#  Operating Cash Flow (ttm)                              1.57B
#  Levered Free Cash Flow (ttm)                           1.16B,
#                                                       CDAY.TO
#  Market Cap (intraday) 5                                9.81B
#  Enterprise Value 3                                    10.35B
#  Trailing P/E                                          579.08
#  Forward P/E 1                                            NaN
#  PEG Ratio (5 yr expected) 1                              NaN
#  Price/Sales (ttm)                                      12.60
#  Price/Book (mrq)                                        5.61
#  Enterprise Value/Revenue 3                             13.29
#  Enterprise Value/EBITDA 6                              72.42
#  Beta (3Y Monthly)                                        NaN
#  52-Week Change 3                                      42.07%
#  S&P500 52-Week Change 3                                2.86%
#  52 Week High 3                                         73.70
#  52 Week Low 3                                          42.62
#  50-Day Moving Average 3                                66.72
#  200-Day Moving Average 3                               65.03
#  Avg Vol (3 month) 3                                    2.13k
#  Avg Vol (10 day) 3                                     6.28k
#  Shares Outstanding 5                                  136.7M
#  Float                                                  69.6M
#  % Held by Insiders 1                                     NaN
#  % Held by Institutions 1                                 NaN
#  Shares Short (Jul 15, 2019) 4                         79.97k
#  Short Ratio (Jul 15, 2019) 4                           92.45
#  Short % of Float (Jul 15, 2019) 4                      0.18%
#  Short % of Shares Outstanding (Jul 15, 2019) 4         0.06%
#  Shares Short (prior month Jun 14, 2019) 4            100.73k
#  Forward Annual Dividend Rate 4                           NaN
#  Forward Annual Dividend Yield 4                          NaN
#  Trailing Annual Dividend Rate 3                          NaN
#  Trailing Annual Dividend Yield 3                         NaN
#  5 Year Average Dividend Yield 4                          NaN
#  Payout Ratio 4                                         0.00%
#  Dividend Date 3                                          NaN
#  Ex-Dividend Date 4                                       NaN
#  Last Split Factor (new per old) 2                        NaN
#  Last Split Date 3                                        NaN
#  Fiscal Year Ends                                Dec 31, 2018
#  Most Recent Quarter (mrq)                       Jun 30, 2019
#  Profit Margin                                          2.16%
#  Operating Margin (ttm)                                10.97%
#  Return on Assets (ttm)                                 0.82%
#  Return on Equity (ttm)                                 1.88%
#  Revenue (ttm)                                         778.6M
#  Revenue Per Share (ttm)                                 5.57
#  Quarterly Revenue Growth (yoy)                         9.70%
#  Gross Profit (ttm)                                    354.9M
#  EBITDA                                                142.9M
#  Net Income Avi to Common (ttm)                         30.8M
#  Diluted EPS (ttm)                                       0.12
#  Quarterly Earnings Growth (yoy)                          NaN
#  Total Cash (mrq)                                      237.9M
#  Total Cash Per Share (mrq)                              1.67
#  Total Debt (mrq)                                        716M
#  Total Debt/Equity (mrq)                                40.75
#  Current Ratio (mrq)                                     1.06
#  Book Value Per Share (mrq)                             12.38
#  Operating Cash Flow (ttm)                              54.9M
#  Levered Free Cash Flow (ttm)                          -19.2M,
#                                                        DSG.TO
#  Market Cap (intraday) 5                                3.95B
#  Enterprise Value 3                                     3.85B
#  Trailing P/E                                          117.52
#  Forward P/E 1                                            NaN
#  PEG Ratio (5 yr expected) 1                              NaN
#  Price/Sales (ttm)                                      13.82
#  Price/Book (mrq)                                        6.61
#  Enterprise Value/Revenue 3                             13.47
#  Enterprise Value/EBITDA 6                              40.01
#  Beta (3Y Monthly)                                       1.21
#  52-Week Change 3                                      12.10%
#  S&P500 52-Week Change 3                                2.86%
#  52 Week High 3                                         56.01
#  52 Week Low 3                                          33.96
#  50-Day Moving Average 3                                48.74
#  200-Day Moving Average 3                               48.57
#  Avg Vol (3 month) 3                                  172.35k
#  Avg Vol (10 day) 3                                   124.32k
#  Shares Outstanding 5                                  61.28M
#  Float                                                 76.93M
#  % Held by Insiders 1                                     NaN
#  % Held by Institutions 1                                 NaN
#  Shares Short (Jul 15, 2019) 4                        816.48k
#  Short Ratio (Jul 15, 2019) 4                            5.18
#  Short % of Float (Jul 15, 2019) 4                        NaN
#  Short % of Shares Outstanding (Jul 15, 2019) 4         0.98%
#  Shares Short (prior month Jun 14, 2019) 4            660.94k
#  Forward Annual Dividend Rate 4                           NaN
#  Forward Annual Dividend Yield 4                          NaN
#  Trailing Annual Dividend Rate 3                          NaN
#  Trailing Annual Dividend Yield 3                         NaN
#  5 Year Average Dividend Yield 4                          NaN
#  Payout Ratio 4                                         0.00%
#  Dividend Date 3                                          NaN
#  Ex-Dividend Date 4                                       NaN
#  Last Split Factor (new per old) 2                        NaN
#  Last Split Date 3                                        NaN
#  Fiscal Year Ends                                Jan 31, 2019
#  Most Recent Quarter (mrq)                       Apr 30, 2019
#  Profit Margin                                         11.05%
#  Operating Margin (ttm)                                16.91%
#  Return on Assets (ttm)                                 3.88%
#  Return on Equity (ttm)                                 5.97%
#  Revenue (ttm)                                        286.16M
#  Revenue Per Share (ttm)                                 3.72
#  Quarterly Revenue Growth (yoy)                        16.40%
#  Gross Profit (ttm)                                   200.18M
#  EBITDA                                                96.32M
#  Net Income Avi to Common (ttm)                        31.61M
#  Diluted EPS (ttm)                                       0.40
#  Quarterly Earnings Growth (yoy)                        4.80%
#  Total Cash (mrq)                                      29.55M
#  Total Cash Per Share (mrq)                              0.38
#  Total Debt (mrq)                                      253.5M
#  Total Debt/Equity (mrq)                                46.17
#  Current Ratio (mrq)                                     0.94
#  Book Value Per Share (mrq)                              7.11
#  Operating Cash Flow (ttm)                             82.66M
#  Levered Free Cash Flow (ttm)                          75.93M,
#                                                       LSPD.TO
#  Market Cap (intraday) 5                                3.36B
#  Enterprise Value 3                                     3.23B
#  Trailing P/E                                             NaN
#  Forward P/E 1                                        -222.78
#  PEG Ratio (5 yr expected) 1                              NaN
#  Price/Sales (ttm)                                      43.36
#  Price/Book (mrq)                                       17.08
#  Enterprise Value/Revenue 3                             41.68
#  Enterprise Value/EBITDA 6                            -161.10
#  Beta (3Y Monthly)                                        NaN
#  52-Week Change 3                                          ∞%
#  S&P500 52-Week Change 3                                2.86%
#  52 Week High 3                                         43.10
#  52 Week Low 3                                          18.05
#  50-Day Moving Average 3                                37.51
#  200-Day Moving Average 3                               28.67
#  Avg Vol (3 month) 3                                  178.06k
#  Avg Vol (10 day) 3                                   226.07k
#  Shares Outstanding 5                                  83.75M
#  Float                                                 67.04M
#  % Held by Insiders 1                                     NaN
#  % Held by Institutions 1                                 NaN
#  Shares Short (Jul 15, 2019) 4                         85.47k
#  Short Ratio (Jul 15, 2019) 4                            0.84
#  Short % of Float (Jul 15, 2019) 4                        NaN
#  Short % of Shares Outstanding (Jul 15, 2019) 4         0.23%
#  Shares Short (prior month Jun 14, 2019) 4            107.33k
#  Forward Annual Dividend Rate 4                           NaN
#  Forward Annual Dividend Yield 4                          NaN
#  Trailing Annual Dividend Rate 3                          NaN
#  Trailing Annual Dividend Yield 3                         NaN
#  5 Year Average Dividend Yield 4                          NaN
#  Payout Ratio 4                                         0.00%
#  Dividend Date 3                                          NaN
#  Ex-Dividend Date 4                                       NaN
#  Last Split Factor (new per old) 2                        NaN
#  Last Split Date 3                                        NaN
#  Fiscal Year Ends                                Mar 31, 2019
#  Most Recent Quarter (mrq)                       Mar 31, 2019
#  Profit Margin                                       -236.96%
#  Operating Margin (ttm)                               -28.11%
#  Return on Assets (ttm)                                -8.51%
#  Return on Equity (ttm)                                   NaN
#  Revenue (ttm)                                         77.45M
#  Revenue Per Share (ttm)                                 2.33
#  Quarterly Revenue Growth (yoy)                        35.70%
#  Gross Profit (ttm)                                    53.88M
#  EBITDA                                               -20.04M
#  Net Income Avi to Common (ttm)                      -183.52M
#  Diluted EPS (ttm)                                      -5.53
#  Quarterly Earnings Growth (yoy)                          NaN
#  Total Cash (mrq)                                      207.7M
#  Total Cash Per Share (mrq)                              2.48
#  Total Debt (mrq)                                         NaN
#  Total Debt/Equity (mrq)                                  NaN
#  Current Ratio (mrq)                                     4.56
#  Book Value Per Share (mrq)                              2.35
#  Operating Cash Flow (ttm)                             -7.56M
#  Levered Free Cash Flow (ttm)                         182.62k,
#                                                       ENGH.TO
#  Market Cap (intraday) 5                                1.84B
#  Enterprise Value 3                                     1.64B
#  Trailing P/E                                           27.74
#  Forward P/E 1                                          23.90
#  PEG Ratio (5 yr expected) 1                             1.83
#  Price/Sales (ttm)                                       5.29
#  Price/Book (mrq)                                        4.84
#  Enterprise Value/Revenue 3                              4.71
#  Enterprise Value/EBITDA 6                              16.31
#  Beta (3Y Monthly)                                       0.79
#  52-Week Change 3                                     -11.43%
#  S&P500 52-Week Change 3                                2.86%
#  52 Week High 3                                         43.49
#  52 Week Low 3                                          30.97
#  50-Day Moving Average 3                                35.09
#  200-Day Moving Average 3                               34.77
#  Avg Vol (3 month) 3                                   53.49k
#  Avg Vol (10 day) 3                                    60.13k
#  Shares Outstanding 5                                  50.34M
#  Float                                                 44.09M
#  % Held by Insiders 1                                     NaN
#  % Held by Institutions 1                                 NaN
#  Shares Short (Jul 15, 2019) 4                           303k
#  Short Ratio (Jul 15, 2019) 4                            5.48
#  Short % of Float (Jul 15, 2019) 4                        NaN
#  Short % of Shares Outstanding (Jul 15, 2019) 4         0.55%
#  Shares Short (prior month Jun 14, 2019) 4               327k
#  Forward Annual Dividend Rate 4                          0.44
#  Forward Annual Dividend Yield 4                        1.28%
#  Trailing Annual Dividend Rate 3                         0.40
#  Trailing Annual Dividend Yield 3                       1.16%
#  5 Year Average Dividend Yield 4                         0.97
#  Payout Ratio 4                                        37.04%
#  Dividend Date 3                                 Aug 30, 2019
#  Ex-Dividend Date 4                              Aug 15, 2019
#  Last Split Factor (new per old) 2                        1/2
#  Last Split Date 3                               Jan 28, 2019
#  Fiscal Year Ends                                Oct 31, 2018
#  Most Recent Quarter (mrq)                       Apr 30, 2019
#  Profit Margin                                         19.30%
#  Operating Margin (ttm)                                22.75%
#  Return on Assets (ttm)                                 9.62%
#  Return on Equity (ttm)                                18.96%
#  Revenue (ttm)                                        347.81M
#  Revenue Per Share (ttm)                                 6.38
#  Quarterly Revenue Growth (yoy)                         4.70%
#  Gross Profit (ttm)                                   239.42M
#  EBITDA                                               100.36M
#  Net Income Avi to Common (ttm)                        67.11M
#  Diluted EPS (ttm)                                       1.22
#  Quarterly Earnings Growth (yoy)                        8.00%
#  Total Cash (mrq)                                     205.52M
#  Total Cash Per Share (mrq)                              3.76
#  Total Debt (mrq)                                        760k
#  Total Debt/Equity (mrq)                                 0.20
#  Current Ratio (mrq)                                     2.20
#  Book Value Per Share (mrq)                              6.96
#  Operating Cash Flow (ttm)                             99.09M
#  Levered Free Cash Flow (ttm)                          89.55M]

# %%
indust = industry(retail_list)

# %%
d = indust.concat_df
d = d.fillna(np.nan)

# %%
d = indust.concat_df
d = d.fillna(np.nan)
d = d.infer_objects()
d['Average'] = d[1:].mean(axis=1)
d['Average'] = pandas.to_numeric(d['Average'], errors='coerce')

# %%
form = lambda x: float(d['Average'][x])
rnd = lambda x: round(d['Average'][x], 2)

# %%
d1 = d.iloc[1:]
d['Average'] = d.iloc[1:].mean(axis=1)
d_T = d.T.style.format({'perc_change': lambda x: "{:.2f}%".format(x*100), 
                        'price': lambda x: "${:.2f}".format(x), 
                        'dividend yield': lambda x: "{:.2f}%".format(x*100), 
                        'total_return': lambda x: "{:.2f}%".format(x*100), 
                        'returns (adj)': lambda x: "{:.2f}%".format(x*100), 
                        '1/PE': lambda x: "{:.2f}%".format(x*100), 
                       'dividend': lambda x: "${:.2f}".format(x),
                       'volume': lambda x: "{:,.0f}".format(x),
                       'marketcap': lambda x: "{:,.0f}".format(x),
                        'shares outstanding': lambda x: "{:,.0f}".format(x)
                       })
d_T
# Out:
# <style  type="text/css" >
# </style><table id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Market Cap (intraday) 5</th>        <th class="col_heading level0 col1" >Enterprise Value 3</th>        <th class="col_heading level0 col2" >Trailing P/E</th>        <th class="col_heading level0 col3" >Forward P/E 1</th>        <th class="col_heading level0 col4" >PEG Ratio (5 yr expected) 1</th>        <th class="col_heading level0 col5" >Price/Sales (ttm)</th>        <th class="col_heading level0 col6" >Price/Book (mrq)</th>        <th class="col_heading level0 col7" >Enterprise Value/Revenue 3</th>        <th class="col_heading level0 col8" >Enterprise Value/EBITDA 6</th>        <th class="col_heading level0 col9" >Beta (3Y Monthly)</th>        <th class="col_heading level0 col10" >52-Week Change 3</th>        <th class="col_heading level0 col11" >S&P500 52-Week Change 3</th>        <th class="col_heading level0 col12" >52 Week High 3</th>        <th class="col_heading level0 col13" >52 Week Low 3</th>        <th class="col_heading level0 col14" >50-Day Moving Average 3</th>        <th class="col_heading level0 col15" >200-Day Moving Average 3</th>        <th class="col_heading level0 col16" >Avg Vol (3 month) 3</th>        <th class="col_heading level0 col17" >Avg Vol (10 day) 3</th>        <th class="col_heading level0 col18" >Shares Outstanding 5</th>        <th class="col_heading level0 col19" >Float</th>        <th class="col_heading level0 col20" >% Held by Insiders 1</th>        <th class="col_heading level0 col21" >% Held by Institutions 1</th>        <th class="col_heading level0 col22" >Shares Short (Jul 15, 2019) 4</th>        <th class="col_heading level0 col23" >Short Ratio (Jul 15, 2019) 4</th>        <th class="col_heading level0 col24" >Short % of Float (Jul 15, 2019) 4</th>        <th class="col_heading level0 col25" >Short % of Shares Outstanding (Jul 15, 2019) 4</th>        <th class="col_heading level0 col26" >Shares Short (prior month Jun 14, 2019) 4</th>        <th class="col_heading level0 col27" >Forward Annual Dividend Rate 4</th>        <th class="col_heading level0 col28" >Forward Annual Dividend Yield 4</th>        <th class="col_heading level0 col29" >Trailing Annual Dividend Rate 3</th>        <th class="col_heading level0 col30" >Trailing Annual Dividend Yield 3</th>        <th class="col_heading level0 col31" >5 Year Average Dividend Yield 4</th>        <th class="col_heading level0 col32" >Payout Ratio 4</th>        <th class="col_heading level0 col33" >Dividend Date 3</th>        <th class="col_heading level0 col34" >Ex-Dividend Date 4</th>        <th class="col_heading level0 col35" >Last Split Factor (new per old) 2</th>        <th class="col_heading level0 col36" >Last Split Date 3</th>        <th class="col_heading level0 col37" >Fiscal Year Ends</th>        <th class="col_heading level0 col38" >Most Recent Quarter (mrq)</th>        <th class="col_heading level0 col39" >Profit Margin</th>        <th class="col_heading level0 col40" >Operating Margin (ttm)</th>        <th class="col_heading level0 col41" >Return on Assets (ttm)</th>        <th class="col_heading level0 col42" >Return on Equity (ttm)</th>        <th class="col_heading level0 col43" >Revenue (ttm)</th>        <th class="col_heading level0 col44" >Revenue Per Share (ttm)</th>        <th class="col_heading level0 col45" >Quarterly Revenue Growth (yoy)</th>        <th class="col_heading level0 col46" >Gross Profit (ttm)</th>        <th class="col_heading level0 col47" >EBITDA</th>        <th class="col_heading level0 col48" >Net Income Avi to Common (ttm)</th>        <th class="col_heading level0 col49" >Diluted EPS (ttm)</th>        <th class="col_heading level0 col50" >Quarterly Earnings Growth (yoy)</th>        <th class="col_heading level0 col51" >Total Cash (mrq)</th>        <th class="col_heading level0 col52" >Total Cash Per Share (mrq)</th>        <th class="co ...
#                 <tr>
#                         <th id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57level0_row0" class="row_heading level0 row0" >CSU.TO</th>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col0" class="data row0 col0" >26.75B</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col1" class="data row0 col1" >27.1B</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col2" class="data row0 col2" >66.17</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col3" class="data row0 col3" >34.04</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col4" class="data row0 col4" >2.28</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col5" class="data row0 col5" >8.22</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col6" class="data row0 col6" >47.44</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col7" class="data row0 col7" >8.33</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col8" class="data row0 col8" >50.31</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col9" class="data row0 col9" >0.91</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col10" class="data row0 col10" >38.00%</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col11" class="data row0 col11" >2.86%</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col12" class="data row0 col12" >1320.31</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col13" class="data row0 col13" >814.32</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col14" class="data row0 col14" >1242.58</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col15" class="data row0 col15" >1152.68</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col16" class="data row0 col16" >42.17k</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col17" class="data row0 col17" >47.6k</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col18" class="data row0 col18" >21.19M</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col19" class="data row0 col19" >19.72M</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col20" class="data row0 col20" >nan</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col21" class="data row0 col21" >nan</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col22" class="data row0 col22" >260.86k</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col23" class="data row0 col23" >5.36</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col24" class="data row0 col24" >nan</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col25" class="data row0 col25" >1.23%</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col26" class="data row0 col26" >161.21k</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col27" class="data row0 col27" >5.23</td>
#                         <td id="T_8036a8ee_b7df_11e9_b22c_0c541533fb57row0_col28" class="d
