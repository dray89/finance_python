# %%
from finance_python.stock import stock
from finance_python.industry import industry
import sys, os, time
import numpy as np
import pandas
from datetime import datetime, date, timedelta
from pandas import DataFrame

# %%
symbols = ['APHA.TO', 'ACB.TO', 'TRST.TO', 'WEED.TO', 
           'CRON.TO', 'EMH.V', 'N.V', 'OGI.V', 'FIRE.TO', 
           'VFF.TO', 'WMD.V', 'FAF.TO', 'TGOD.TO']

start = date.today() - timedelta(days=365)
end = date.today()

# %%
stock_loop = lambda x: stock(x, start, end)
stat = lambda x: stocks[x].stats()
bal = lambda x: stocks[x].balance()
fin = lambda x: stocks[x].financial()
ca = lambda x: stocks[x].cash()
an = lambda x: stocks[x].analyze()

# %%
timer_start = time.time()

stocks = list(map(stock_loop, symbols))

timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 77.36119437217712

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    stat(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 7.737562417984009

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    bal(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 7.088168382644653

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    fin(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 6.727048397064209

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    ca(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 6.733282089233398

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    an(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 17.25916290283203

# %%
APHA, ACB, TRST, WEED, CRON, EMH, N, OGI, FIRE, VFF, WMD, FAF, TGOD = stocks

# %%
price = list(map(lambda symbol, x: {symbol: stocks[x].price}, symbols, range(0, len(symbols))))

# %%
price
# Out:
# [{'APHA.TO': 7.34},
#  {'ACB.TO': 6.33},
#  {'TRST.TO': 1.52},
#  {'WEED.TO': 32.69},
#  {'CRON.TO': 12.73},
#  {'EMH.V': 1.58},
#  {'N.V': 0.49},
#  {'OGI.V': '6.22'},
#  {'FIRE.TO': 1.31},
#  {'VFF.TO': 12.39},
#  {'WMD.V': 1.33},
#  {'FAF.TO': 1.3},
#  {'TGOD.TO': 2.4}]

# %%
APHA.description
# Out:
# 'Aphria Inc. produces and sells medical cannabis in Canada and internationally. The company offers pharmaceutical-grade medical cannabis; and adult-use cannabis under the Solei, RIFF, Good Supply, and Broken Coast brands. It serves patients and consumers through distributors and online. The company is headquartered in Leamington, Canada.'

# %%
APHA.earnings_history
# Out:
#                  8/30/2018 11/29/2018  2/27/2019 5/30/2019
# Earnings History
# EPS Est.             -0.04       0.01       0.00     -0.05
# EPS Actual            0.07       0.16      -0.43      0.05
# Difference            0.11       0.15      -0.43       0.1
# Surprise %         275.00%  1,500.00%        NaN   200.00%

# %%
APHA.dividends
# Out:
# [                                                Date  Dividends
#  0  *Close price adjusted for splits.**Adjusted cl...        NaN]

# %%
APHA.statistics.dropna(how='all')
# Out:
#                                                 APHA.TO
# Market Cap (intraday) 5                          182.00
# Enterprise Value 3                               184.00
# Forward P/E 1                                     22.62
# Price/Sales (ttm)                                  7.66
# Price/Book (mrq)                                   1.07
# Enterprise Value/Revenue 3                         7.77
# Enterprise Value/EBITDA 6                        -44.83
# Beta (3Y Monthly)                                  3.70
# 52-Week Change 3                                 -61.37
# S&P500 52-Week Change 3                            2.72
# 52 Week High 3                                    20.96
# 52 Week Low 3                                      4.76
# 50-Day Moving Average 3                            8.53
# 200-Day Moving Average 3                           9.69
# Avg Vol (3 month) 3                                1.90
# Avg Vol (10 day) 3                                 1.66
# Shares Outstanding 5                             250.99
# Float                                            250.74
# Shares Short (Aug 30, 2019) 4                      4.28
# Short Ratio (Aug 30, 2019) 4                       1.54
# Short % of Shares Outstanding (Aug 30, 2019) 4     1.71
# Shares Short (prior month Jul 31, 2019) 4          5.84
# Payout Ratio 4                                     0.00
# Profit Margin                                     -6.96
# Operating Margin (ttm)                           -26.93
# Return on Assets (ttm)                            -2.13
# Return on Equity (ttm)                            -1.14
# Revenue (ttm)                                    237.11
# Revenue Per Share (ttm)                            0.98
# Quarterly Revenue Growth (yoy)                   969.10
# Gross Profit (ttm)                                75.42
# EBITDA                                           -41.08
# Net Income Avi to Common (ttm)                   -16.50
# Diluted EPS (ttm)                                 -0.07
# Total Cash (mrq)                                 571.00
# Total Cash Per Share (mrq)                         2.28
# Total Debt (mrq)                                 488.59
# Total Debt/Equity (mrq)                           28.19
# Current Ratio (mrq)                                5.64
# Book Value Per Share (mrq)                         6.79
# Operating Cash Flow (ttm)                        -55.60
# Levered Free Cash Flow (ttm)                    -230.63
# Total Returns                                    -61.37

# %%
APHA.cashflow.dropna()
# Out:
# Period Ending                               5/31/2019  5/31/2018  5/31/2017  \
# APHA.TO
# Net Income                                   -16499.0    29448.0     4198.0
# Depreciation                                  22779.0     6578.0     1874.0
# Adjustments To Net Income                    -40555.0   -31364.0      113.0
# Changes In Accounts Receivables               12458.0    -1797.0      953.0
# Changes In Liabilities                          691.0     3764.0     4534.0
# Changes In Inventories                       -22151.0    -7045.0     3057.0
# Changes In Other Operating Activities        -11607.0    -7995.0    -9472.0
# Total Cash Flow From Operating Activities    -55605.0    -5649.0     5325.0
# Capital Expenditure                         -205965.0  -203822.0   -67722.0
# Investments                                   62531.0    31515.0  -133406.0
# Other Cash flows from Investing Activities   -10949.0   -13361.0     -932.0
# Total Cash Flows From Investing Activities  -177885.0  -220870.0  -202027.0
# Net Borrowings                               470853.0    -7622.0    32181.0
# Total Cash Flows From Financing Activities   724550.0   206346.0   260139.0
# Change In Cash and Cash Equivalents          491060.0   -20173.0    63437.0
#
# Period Ending                               5/31/2016     Changes
# APHA.TO
# Net Income                                    397.961  -42.458836
# Depreciation                                  898.055   24.364816
# Adjustments To Net Income                    -740.165   53.791837
# Changes In Accounts Receivables             -1778.679   -8.004074
# Changes In Liabilities                        319.269    1.164319
# Changes In Inventories                       -778.388   27.457530
# Changes In Other Operating Activities         639.690  -19.144726
# Total Cash Flow From Operating Activities    -988.134   55.272732
# Capital Expenditure                         -4426.059   45.534626
# Investments                                 -1560.200  -41.078836
# Other Cash flows from Investing Activities     32.412 -338.806985
# Total Cash Flows From Investing Activities  -5970.982   28.791582
# Net Borrowings                              32181.000   13.631397
# Total Cash Flows From Financing Activities  16379.871   43.234170
# Change In Cash and Cash Equivalents          9420.755   51.125334

# %%
portfolio = industry()

# %%
portfolio.statistics(APHA.stats_list)

# %%
stats = portfolio.statistics
stats
# Out:
#                                                 APHA.TO  ACB.TO   TRST.TO  \
# 200-Day Moving Average 3                           9.69   10.02    6.3783
# 50-Day Moving Average 3                            8.53    7.67    2.3517
# 52 Week High 3                                    20.96   16.24   15.5000
# 52 Week Low 3                                      4.76    6.00    1.5000
# 52-Week Change 3                                 -61.37  -48.07  -87.8400
# Avg Vol (10 day) 3                                 1.66    6.09    2.7800
# Avg Vol (3 month) 3                                1.90    4.23    2.6000
# Beta (3Y Monthly)                                  3.70    2.76    4.6200
# Book Value Per Share (mrq)                         6.79    4.31    1.8000
# Current Ratio (mrq)                                5.64    1.52    5.6400
# Diluted EPS (ttm)                                 -0.07   -0.29   -0.1210
# EBITDA                                           -41.08 -209.94    1.2800
# Enterprise Value 3                               184.00  680.00  180.4300
# Enterprise Value/EBITDA 6                        -44.83  -32.41  141.1600
# Enterprise Value/Revenue 3                         7.77   27.44    3.3000
# Float                                            250.74  988.00  115.3300
# Forward P/E 1                                     22.62 -626.50  -38.2500
# Gross Profit (ttm)                                75.42  159.81   36.4900
# Levered Free Cash Flow (ttm)                    -230.63 -580.77  -75.7700
# Market Cap (intraday) 5                          182.00  636.00  216.0100
# Net Income Avi to Common (ttm)                   -16.50 -290.84  -12.1900
# Operating Cash Flow (ttm)                        -55.60 -192.24  -36.5700
# Operating Margin (ttm)                           -26.93 -119.80   -5.3100
# PEG Ratio (5 yr expected) 1                         NaN     NaN       NaN
# Payout Ratio 4                                     0.00    0.00    0.0000
# Price/Book (mrq)                                   1.07    1.45    0.8500
# Price/Sales (ttm)                                  7.66   25.65    3.9500
# Profit Margin                                     -6.96 -117.30  -22.3100
# Quarterly Earnings Growth (yoy)                     NaN     NaN   11.9000
# Quarterly Revenue Growth (yoy)                   969.10  416.70  115.0000
# Return on Assets (ttm)                            -2.13   -5.02   -1.0900
# Return on Equity (ttm)                            -1.14  -10.03   -8.7500
# Revenue (ttm)                                    237.11  247.94   54.6600
# Revenue Per Share (ttm)                            0.98    0.24    0.5300
# S&P500 52-Week Change 3                            2.72    2.72    2.7200
# Shares Outstanding 5                             250.99  102.00  141.1800
# Shares Short (Aug 30, 2019) 4                      4.28   21.02    4.7500
# Shares Short (prior month Jul 31, 2019) 4          5.84   31.56    4.5500
# Short % of Shares Outstanding (Aug 30, 2019) 4     1.71    2.07    3.3700
# Short Ratio (Aug 30, 2019) 4                       1.54    4.77    2.2300
# Total Cash (mrq)                                 571.00  315.98   42.7500
# Total Cash Per Share (mrq)                         2.28    0.31    0.3100
# Total Debt (mrq)                                 488.59  644.83   15.6000
# Total Debt/Equity (mrq)                           28.19   14.69    8.2000
# Total Returns                                    -61.37  -48.07  -87.8400
# Trailing P/E                                        NaN     NaN       NaN
#
#                                                 WEED.TO    CRON.TO     EMH.V  \
# 200-Day Moving Average 3                          51.17    20.2300    2.9204
# 50-Day Moving Average 3                           36.12    15.4100    1.8466
# 52 Week High 3                                    76.68    32.9500    5.2500
# 52 Week Low 3                                     30.30     8.4700    1.5200
# 52-Week Change 3                                 -51.67   -12.0200  -66.8800
# Avg Vol (10 day) 3                                 2.02     7.6651    2.7370
# Avg Vol (3 month) 3                                1.83     6.6714    3.8701
# Beta (3Y Monthly)                                  5.40     4.0700    2.2800
# Book Value Per Share (mrq)                        16.51     3.6400    1.3300
# Current Ratio (mrq)                               10.37     1.6800    0.9200
# Diluted EPS (ttm)                                 -6.22     0.7100   -0.1580
# EBITDA                                          -573.27   -34.7800  -44.6300
# Enterprise Value 3                              1036.00   196.0000  253.7500
# Enterprise Value/EBITDA 6                        -18.08   -56.3000   -5.6800
# Enterprise Value/Revenue 3                        35.62    75.1200   31.5600
# Float                                            217.81   176.9900  110.6100
# Forward P/E 1                                    -36.21 -1229.0000   -8.5000
# Gross Profit (ttm)                                88.93    11.2700   -2.7021
# Levered Free Cash Flow (ttm)                        NaN        NaN  -55.0600
# Market Cap (intraday) 5                         1121.00   413.0000  228.6500
# Net Income Avi to Common (ttm)                  -189.00   660.3000  -23.9600
# Operating Cash Flow (ttm)                       -611.16   -65.0900  -38.0000
# Operating Margin (ttm)                          -218.20  -143.1600 -613.0000
# PEG Ratio (5 yr expected) 1                       -1.44     0.4500       NaN
# Payout Ratio 4                                     0.00     0.0000    0.0000
# Price/Book (mrq)                                   1.95     3.3700    1.1500
# Price/Sales (ttm)                                 38.54   158.4600   28.4400
# Profit Margin                                      0.00        NaN -298.0700
# Quarterly Earnings Growth (yoy)                     NaN        NaN       NaN
# Quarterly Revenue Growth (yoy)                   249.10   201.6000       NaN
# Return on Assets (ttm)                            -7.37    -1.6100  -13.3500
# Return on Equity (ttm)                           -52.27    90.9000  -12.8300
# Revenue (ttm)                                    290.91    26.0700    8.0400
# Revenue Per Share (ttm)                            0.96     0.1000    0.0500
# S&P500 52-Week Change 3                            2.72     2.7200    2.7200
# Shares Outstanding 5                             347.87   336.1500  149.4400
# Shares Short (Aug 30, 2019) 4                     10.07     3.6400    2.5800
# Shares Short (prior month Jul 31, 2019) 4          8.72     3.4200    2.4300
# Short % of Shares Outstanding (Aug 30, 2019) 4     2.90     1.1100    2.3200
# Short Ratio (Aug 30, 2019) 4                       5.19     4.6300    6.3300
# Total Cash (mrq)                                 318.00   232.0000    2.6100
# Total Cash Per Share (mrq)                         9.13     6.9100    0.0200
# Total Debt (mrq)                                 220.00     3.5300    9.7100
# Total Debt/Equity (mrq)                           37.27     0.2900    4.7900
# Total Returns                                    -51.67   -12.0200  -66.8800
# Trailing P/E                                        NaN    17.2900       NaN
#
#                                                      N.V     OGI.V   FIRE.TO  \
# 200-Day Moving Average 3                          0.6227       NaN    1.6993
# 50-Day Moving Average 3                           0.4889       NaN    1.3971
# 52 Week High 3                                    3.1200       NaN    2.3600
# 52 Week Low 3                                     0.3800       NaN    1.1500
# 52-Week Change 3                                -82.9300       NaN  -41.7800
# Avg Vol (10 day) 3                                1.0400    6.7178    7.1186
# Avg Vol (3 month) 3                               1.4700    6.2143    6.7113
# Beta (3Y Monthly)                                 3.5900       NaN    4.2300
# Book Value Per Share (mrq)                        0.3100       NaN    0.7000
# Current Ratio (mrq)                              13.5900       NaN    3.4100
# Diluted EPS (ttm)                                -0.1450       NaN   -0.0520
# EBITDA                                          -38.2700       NaN    4.1800
# Enterprise Value 3                              114.6300       NaN  488.0200
# Enterprise Value/EBITDA 6                        -2.9900       NaN  116.6700
# Enterprise Value/Revenue 3                        6.3900       NaN   11.6700
# Float                                           296.1300       NaN  347.8800
# Forward P/E 1                                        NaN       NaN   11.6800
# Gross Profit (ttm)                                4.5100   52.5000   36.8500
# Levered Free Cash Flow (ttm)                         NaN       NaN -114.0900
# Market Cap (intraday) 5                         159.2600  107.0000  428.3200
# Net Income Avi to Common (ttm)                  -40.7300       NaN  -14.5000
# Operating Cash Flow (ttm)                       -28.6700       NaN  -14.8400
# Operating Margin (ttm)                         -221.9700       NaN   -4.4500
# PEG Ratio (5 yr expected) 1                          NaN       NaN    0.8000
# Payout Ratio 4                                    0.0000       NaN    0.0000
# Price/Book (mrq)                                  1.6000       NaN    1.8400
# Price/Sales (ttm)                                 8.8800       NaN   10.2400
# Profit Margin                                  -227.1800       NaN  -34.6500
# Quarterly Earnings Growth (yoy)                      NaN       NaN       NaN
# Quarterly Revenue Growth (yoy)                   -1.7000       NaN  436.1000
# Return on Assets (ttm)                               NaN       NaN   -0.4400
# Return on Equity (ttm)                               NaN       NaN   -8.1400
# Revenue (ttm)                                    17.9300       NaN   41.8300
# Revenue Per Share (ttm)                           0.0600       NaN    0.1500
# S&P500 52-Week Change 3                           2.7200       NaN    2.7200
# Shares Outstanding 5                            321.7400       NaN  333.3200
# Shares Short (Aug 30, 2019) 4                     1.6100       NaN    1.1300
# Shares Short (prior month Jul 31, 2019) 4         1.8200       NaN    1.2600
# Short % of Shares Outstanding (Aug 30, 2019) 4    0.4300       NaN    0.3400
# Short Ratio (Aug 30, 2019) 4                      1.3300       NaN    1.3600
# Total Cash (mrq)                                 55.8800       NaN   54.8200
# Total Cash Per Share (mrq)                        0.1700       NaN    0.1600
# Total Debt (mrq)                                  0.2973       NaN   79.0500
# Total Debt/Equity (mrq)                           0.0300       NaN   37.4700
# Total Returns                                   -82.9300       NaN  -41.7800
# Trailing P/E                                         NaN   30.8600       NaN
#
#                                                   VFF.TO     WMD.V    FAF.TO  \
# 200-Day Moving Average 3                         16.2900    1.6805    1.4134
# 50-Day Moving Average 3                          15.2900    1.5151    1.4134
# 52 Week High 3                                   24.2500    2.1500    1.6700
# 52 Week Low 3                                     3.9800    0.9900    1.0500
# 52-Week Change 3                                 73.2900  -39.5500       NaN
# Avg Vol (10 day) 3                                4.0562    2.5657    5.7729
# Avg Vol (3 month) 3                               5.2296    2.5120    3.5510
# Beta (3Y Monthly)                                 5.1400    2.7400       NaN
# Book Value Per Share (mrq)                        2.7200    0.8400    0.3400
# Current Ratio (mrq)                               2.4200    3.5000    1.8400
# Diluted EPS (ttm)                                 0.3100    0.1080   -0.6460
# EBITDA                                           -9.1400    3.4300  -22.9000
# Enterprise Value 3                              642.1600  176.4100  194.9900
# Enterprise Value/EBITDA 6                       -70.2500   51.4300   -8.5100
# Enterprise Value/Revenue 3                        4.2300   11.0000    8.6600
# Float                                            38.6400  109.3900   91.6300
# Forward P/E 1                                    13.2700       NaN  131.0000
# Gross Profit (ttm)                                8.8800    4.6300    4.9800
# Levered Free Cash Flow (ttm)                    -12.0500  -75.6700       NaN
# Market Cap (intraday) 5                         595.2500  161.2900  144.1600
# Net Income Avi to Common (ttm)                   15.8200   12.4100  -52.3900
# Operating Cash Flow (ttm)                        -4.4300    2.1300  -20.6000
# Operating Margin (ttm)                          -10.8200   17.8900 -106.4400
# PEG Ratio (5 yr expected) 1                          NaN       NaN       NaN
# Payout Ratio 4                                    0.0000    0.0000       NaN
# Price/Book (mrq)                                  4.4400    1.6800    3.8300
# Price/Sales (ttm)                                 3.9200   10.0600    6.4000
# Profit Margin                                    10.4300   77.3700 -232.6500
# Quarterly Earnings Growth (yoy)                      NaN       NaN       NaN
# Quarterly Revenue Growth (yoy)                   -1.7000  282.0000       NaN
# Return on Assets (ttm)                           -5.8600    1.6200       NaN
# Return on Equity (ttm)                           14.4000   15.2300       NaN
# Revenue (ttm)                                   151.6900   16.0400   22.5200
# Revenue Per Share (ttm)                           3.0700    0.1400    0.2800
# S&P500 52-Week Change 3                           2.7200    2.7200    2.7200
# Shares Outstanding 5                             49.2800  114.3900  110.0400
# Shares Short (Aug 30, 2019) 4                     2.5600    1.2598    8.6184
# Shares Short (prior month Jul 31, 2019) 4         1.8400    0.9136    1.6800
# Short % of Shares Outstanding (Aug 30, 2019) 4    4.9100    0.0600    0.7800
# Short Ratio (Aug 30, 2019) 4                      4.2100    0.2700    0.9600
# Total Cash (mrq)                                 11.7100   12.0200   25.3800
# Total Cash Per Share (mrq)                        0.2400    0.1000    0.2200
# Total Debt (mrq)                                 43.3400   36.2400   52.6300
# Total Debt/Equity (mrq)                          32.3100   37.6700  148.1200
# Total Returns                                    73.2900  -39.5500       NaN
# Trailing P/E                                     38.4700   13.0600       NaN
#
#                                                  TGOD.TO    Averages
# 200-Day Moving Average 3                          3.6131   10.477308
# 50-Day Moving Average 3                           2.9771    7.917492
# 52 Week High 3                                    7.5800   17.392500
# 52 Week Low 3                                     2.1900    5.190833
# 52-Week Change 3                                -68.3000  -44.283636
# Avg Vol (10 day) 3                                2.3400    4.043331
# Avg Vol (3 month) 3                               1.6200    3.723823
# Beta (3Y Monthly)                                    NaN    3.853000
# Book Value Per Share (mrq)                        1.4600    3.395833
# Current Ratio (mrq)                               4.6600    4.599167
# Diluted EPS (ttm)                                -0.2250   -0.566583
# EBITDA                                          -55.7500  -85.072500
# Enterprise Value 3                              652.4000  399.899167
# Enterprise Value/EBITDA 6                       -11.7000    4.875833
# Enterprise Value/Revenue 3                       90.8600   26.135000
# Float                                           268.7000  250.987500
# Forward P/E 1                                        NaN -195.543333
# Gross Profit (ttm)                                1.5000   37.159069
# Levered Free Cash Flow (ttm)                   -247.5400 -173.947500
# Market Cap (intraday) 5                         641.7900  387.210000
# Net Income Avi to Common (ttm)                  -59.8400   -0.951667
# Operating Cash Flow (ttm)                       -70.8400  -94.659167
# Operating Margin (ttm)                         -800.7400 -187.744167
# PEG Ratio (5 yr expected) 1                       0.0700   -0.030000
# Payout Ratio 4                                    0.0000    0.000000
# Price/Book (mrq)                                  1.6000    2.069167
# Price/Sales (ttm)                                89.3900   32.632500
# Profit Margin                                     0.0000  -77.392727
# Quarterly Earnings Growth (yoy)                      NaN   11.900000
# Quarterly Revenue Growth (yoy)                       NaN  296.244444
# Return on Assets (ttm)                           -9.5200   -4.477000
# Return on Equity (ttm)                          -17.0400    1.033000
# Revenue (ttm)                                     7.1800   93.493333
# Revenue Per Share (ttm)                           0.0300    0.549167
# S&P500 52-Week Change 3                           2.7200    2.720000
# Shares Outstanding 5                            275.4500  210.987500
# Shares Short (Aug 30, 2019) 4                    12.1300    6.137350
# Shares Short (prior month Jul 31, 2019) 4        10.1900    6.185300
# Short % of Shares Outstanding (Aug 30, 2019) 4    3.8100    1.984167
# Short Ratio (Aug 30, 2019) 4                      6.8900    3.309167
# Total Cash (mrq)                                 68.7200  142.572500
# Total Cash Per Share (mrq)                        0.2500    1.675000
# Total Debt (mrq)                                  2.4000  133.018108
# Total Debt/Equity (mrq)                           0.6000   29.135833
# Total Returns                                   -68.3000  -44.283636
# Trailing P/E                                         NaN   24.920000

# %%
stats.T.sort_values('Avg Vol (3 month) 3', ascending=False)['Avg Vol (3 month) 3']
# Out:
# FIRE.TO     6.711300
# CRON.TO     6.671400
# OGI.V       6.214300
# VFF.TO      5.229600
# ACB.TO      4.230000
# EMH.V       3.870100
# Averages    3.723823
# FAF.TO      3.551000
# TRST.TO     2.600000
# WMD.V       2.512000
# APHA.TO     1.900000
# WEED.TO     1.830000
# TGOD.TO     1.620000
# N.V         1.470000
# Name: Avg Vol (3 month) 3, dtype: float64

# %%
portfolio.cashflow(APHA.cash_list)

# %%
portfolio.cashflow.dropna(how='all')
# Out:
#                                                APHA.TO       ACB.TO  \
# Adjustments To Net Income                    53.791837   -36.608407
# Capital Expenditure                          45.534626   218.786737
# Change In Cash and Cash Equivalents          51.125334 -1684.192982
# Changes In Accounts Receivables              -8.004074   704.691358
# Changes In Inventories                       27.457530    43.381289
# Changes In Liabilities                        1.164319   105.903158
# Changes In Other Operating Activities       -19.144726  1068.818182
# Depreciation                                 24.364816   145.858347
# Effect Of Exchange Rate Changes                    NaN    14.452632
# Investments                                 -41.078836    -0.732004
# Net Borrowings                               13.631397   142.073529
# Net Income                                  -42.458836    49.818976
# Other Cash Flows from Financing Activities         NaN    87.222868
# Other Cash flows from Investing Activities -338.806985    66.320988
# Total Cash Flow From Operating Activities    55.272732    27.388216
# Total Cash Flows From Financing Activities   43.234170    68.482326
# Total Cash Flows From Investing Activities   28.791582   164.674801
#
#                                                TRST.TO     WEED.TO  \
# Adjustments To Net Income                    -1.789118  -28.487383
# Capital Expenditure                          45.649951   51.841587
# Change In Cash and Cash Equivalents         -41.690983 -357.797818
# Changes In Accounts Receivables              92.632181  511.787879
# Changes In Inventories                      -31.735633   13.414833
# Changes In Liabilities                       20.528236   35.715945
# Changes In Other Operating Activities        -0.190883  398.770642
# Depreciation                                  2.653818   19.007572
# Effect Of Exchange Rate Changes                    NaN    0.000000
# Investments                                -384.513005   43.280306
# Net Borrowings                                3.073240 -314.326316
# Net Income                                    1.113002  195.063501
# Other Cash Flows from Financing Activities  -39.802146 -980.159562
# Other Cash flows from Investing Activities    2.917399         NaN
# Total Cash Flow From Operating Activities     3.421185   37.479338
# Total Cash Flows From Financing Activities   21.610691  308.567140
# Total Cash Flows From Investing Activities  214.648081  282.704078
#
#                                                 CRON.TO        EMH.V  \
# Adjustments To Net Income                     -1.977260    -1.847288
# Capital Expenditure                           74.793330    57.343578
# Change In Cash and Cash Equivalents           69.600645     4.180982
# Changes In Accounts Receivables               52.035088 -7834.941176
# Changes In Inventories                         2.226415   120.451245
# Changes In Liabilities                        14.835408    62.366538
# Changes In Other Operating Activities         39.949855   -18.298438
# Depreciation                                  13.710424    74.333875
# Effect Of Exchange Rate Changes                     NaN          NaN
# Investments                                -3355.000000     0.031576
# Net Borrowings                                11.005600    -1.098623
# Net Income                                   -50.123952     7.743072
# Other Cash Flows from Financing Activities   -11.194554  -179.310424
# Other Cash flows from Investing Activities          NaN     9.183766
# Total Cash Flow From Operating Activities      6.070137    11.911015
# Total Cash Flows From Financing Activities    47.801516    88.501705
# Total Cash Flows From Investing Activities    82.232840   199.102106
#
#                                                     N.V       OGI.V  \
# Adjustments To Net Income                    662.074518    4.498755
# Capital Expenditure                           -0.100464    6.501481
# Change In Cash and Cash Equivalents        -1121.603878  -13.487009
# Changes In Accounts Receivables              -20.179934   -1.646105
# Changes In Inventories                         3.844734   32.969358
# Changes In Liabilities                        10.999984   24.958945
# Changes In Other Operating Activities          9.498787  243.146781
# Depreciation                                   2.043511    7.505283
# Effect Of Exchange Rate Changes               -8.445500         NaN
# Investments                                   -0.105545    0.888035
# Net Borrowings                                -2.186061   22.520098
# Net Income                                    14.461042  -17.065267
# Other Cash Flows from Financing Activities    53.902047   60.437743
# Other Cash flows from Investing Activities          NaN   37.050163
# Total Cash Flow From Operating Activities      7.167781    3.582620
# Total Cash Flows From Financing Activities    34.668745   26.126576
# Total Cash Flows From Investing Activities     8.799707   12.026006
#
#                                               FIRE.TO    VFF.TO       WMD.V  \
# Adjustments To Net Income                    1.545866 -0.652582    1.404317
# Capital Expenditure                         62.091480  0.490602  118.208417
# Change In Cash and Cash Equivalents         -1.339831 -4.499275    0.827354
# Changes In Accounts Receivables             45.693482 -2.916667 -136.178933
# Changes In Inventories                       5.183486 -4.509014   14.586814
# Changes In Liabilities                      31.189138 -1.490129   44.149449
# Changes In Other Operating Activities      -25.945958 -3.622222  194.442165
# Depreciation                                28.473879 -0.151841    7.627170
# Effect Of Exchange Rate Changes                   NaN -0.928571         NaN
# Investments                                       NaN       NaN    0.619117
# Net Borrowings                               0.941633 -0.824208         NaN
# Net Income                                   2.304697 -3.457020   -0.653243
# Other Cash Flows from Financing Activities        NaN  0.067108  -42.055982
# Other Cash flows from Investing Activities        NaN -0.000000         NaN
# Total Cash Flow From Operating Activities    5.741720 -1.307410   -0.200530
# Total Cash Flows From Financing Activities  12.430227 -4.103438  601.346979
# Total Cash Flows From Investing Activities  33.532118  5.501205   33.543400
#
#                                                  FAF.TO    TGOD.TO
# Adjustments To Net Income                     27.946939 -29.406883
# Capital Expenditure                           13.582421  23.798166
# Change In Cash and Cash Equivalents            0.447920   3.444849
# Changes In Accounts Receivables                3.050453  -0.000000
# Changes In Inventories                        -0.000000   8.254902
# Changes In Liabilities                        17.523346  15.282754
# Changes In Other Operating Activities          5.231380  44.337582
# Depreciation                                1840.940711   1.513540
# Effect Of Exchange Rate Changes                     NaN -10.147541
# Investments                                         NaN  -0.000000
# Net Borrowings                                20.077932  16.607954
# Net Income                                    16.551993  22.374640
# Other Cash Flows from Financing Activities    49.495513  99.306991
# Other Cash flows from Investing Activities          NaN  17.909290
# Total Cash Flow From Operating Activities      8.046142  37.757986
# Total Cash Flows From Financing Activities     4.675065   2.670859
# Total Cash Flows From Investing Activities    14.946487   1.338253

# %%
portfolio.balance_sheet(APHA.bs_list)

# %%
portfolio.balance_sheet.dropna(how='all')
# Out:
#                                   APHA.TO       ACB.TO       TRST.TO  \
# Accounts Payable                82.548100    23.981266  2.284943e+01
# Capital Surplus                       NaN          NaN           NaN
# Cash And Cash Equivalents       32.437032  1015.041176  2.352770e+00
# Common Stock                    39.454526   271.516795  2.997448e+01
# Goodwill                       557.205000          NaN           NaN
# Intangible Assets               89.802468  2494.918440           NaN
# Inventory                       42.817890    38.759010  1.632766e+01
# Long Term Debt                        NaN    87.999550 -4.097454e-01
# Long Term Investments           46.579157          NaN  1.156328e+07
# Net Receivables                 33.994879  1290.103448  6.733408e+01
# Net Tangible Assets             20.794347    88.654577 -1.926565e+01
# Other Assets                          NaN    51.376543  3.000000e+00
# Other Current Assets            29.169184    84.465677           NaN
# Other Current Liabilities             NaN   153.509579           NaN
# Other Liabilities                     NaN          NaN -1.051273e-01
# Other Stockholder Equity        14.456792    -1.670681  9.314370e+00
# Property, plant and equipment   67.940051    66.648268  1.055239e+01
# Retained Earnings               -2.454519    15.767439  1.945631e+00
# Short Term Investments                NaN          NaN  2.090797e+02
# Short/Current Long Term Debt          NaN          NaN           NaN
# Total Assets                    66.298593   298.131876  1.680129e+01
# Total Current Assets            34.665878   125.652746  2.101322e+01
# Total Current Liabilities      108.392716    53.586565  5.622102e+00
# Total Liabilities              558.371082    88.495175  3.357385e-01
# Total stockholders' equity      47.688200   734.598289 -1.949949e+01
# Treasury Stock                  14.456792    -1.670681  9.314370e+00
#
#                                   WEED.TO    CRON.TO         EMH.V  \
# Accounts Payable                31.255421   0.684558     50.468657
# Capital Surplus                       NaN        NaN      4.325537
# Cash And Cash Equivalents      160.124245  27.947789    439.418520
# Common Stock                    44.976640  14.236671     65.556385
# Goodwill                        72.998610   3.571429           NaN
# Intangible Assets               14.954920   5.972330  65764.099468
# Inventory                       11.414647        NaN     44.953334
# Long Term Debt                 241.795907        NaN           NaN
# Long Term Investments                 NaN  -0.522832           NaN
# Net Receivables                 70.987887        NaN    393.178714
# Net Tangible Assets             68.476540  19.464542   -202.963178
# Other Assets                    80.967662        NaN     75.081366
# Other Current Assets                  NaN        NaN           NaN
# Other Current Liabilities      145.283302  71.811791     22.367738
# Other Liabilities               25.524007  19.441026           NaN
# Other Stockholder Equity       261.670062   5.561154           NaN
# Property, plant and equipment   23.758700  62.666021     66.214258
# Retained Earnings               55.412849   3.519950      7.584642
# Short Term Investments                NaN        NaN           NaN
# Short/Current Long Term Debt   186.551537        NaN           NaN
# Total Assets                    59.907813  16.734429    267.197909
# Total Current Assets           112.056683  52.109784    196.606228
# Total Current Liabilities       56.231058  18.550140     29.526837
# Total Liabilities               75.131845  15.372981     29.774868
# Total stockholders' equity      55.158929  17.074399   -413.633041
# Treasury Stock                 261.670062   5.561154           NaN
#
#                                       N.V      OGI.V     FIRE.TO     VFF.TO  \
# Accounts Payable                 5.183492   6.356886   33.686958   0.648527
# Capital Surplus                 49.683905        NaN         NaN   0.836257
# Cash And Cash Equivalents      687.080816  36.364609   13.695345   1.404680
# Common Stock                    57.496996   8.418175    5.787978   1.444364
# Goodwill                         6.676059        NaN         NaN        NaN
# Intangible Assets                9.335197        NaN    1.911308        NaN
# Inventory                        5.114378  27.444410         NaN   0.378483
# Long Term Debt                        NaN  20.587166  146.296441  -0.269717
# Long Term Investments                 NaN        NaN  152.250000        NaN
# Net Receivables                 21.796210   3.872272   65.238524   1.351029
# Net Tangible Assets            -72.147014  22.502788   15.944940   0.600102
# Other Assets                          NaN        NaN  252.133333   0.451019
# Other Current Assets                  NaN        NaN         NaN  37.807339
# Other Current Liabilities       -0.748339        NaN         NaN        NaN
# Other Liabilities               -0.417056        NaN         NaN  -0.511995
# Other Stockholder Equity        30.897875  31.074057    3.792106  -7.244186
# Property, plant and equipment         NaN   9.292719   16.686396  -0.178247
# Retained Earnings               34.104364  -1.078153    1.541551  -0.095264
# Short Term Investments                NaN        NaN         NaN        NaN
# Short/Current Long Term Debt          NaN   0.478682         NaN  -0.221969
# Total Assets                    27.457225  20.343433   12.786746   0.229252
# Total Current Assets            70.254461  43.246780   18.795909   0.813267
# Total Current Liabilities        4.575272   5.436545    6.288823   0.425414
# Total Liabilities                2.045008  17.660753   24.169969  -0.118666
# Total stockholders' equity      64.000176  22.502788    9.894751   0.600102
# Treasury Stock                  30.897875  31.074057    3.792106  -7.244186
#
#                                     WMD.V      FAF.TO     TGOD.TO  \
# Accounts Payable               171.053210   21.921687  223.791770
# Capital Surplus                  7.865299    8.648691         NaN
# Cash And Cash Equivalents       24.016993    1.737504   75.030231
# Common Stock                     9.686686    2.863668   36.644255
# Goodwill                              NaN         NaN    4.332746
# Intangible Assets                     NaN  155.229962    1.305753
# Inventory                             NaN         NaN  128.725834
# Long Term Debt                        NaN         NaN         NaN
# Long Term Investments                 NaN         NaN         NaN
# Net Receivables                 15.508853    6.306033  365.454728
# Net Tangible Assets             28.433858    3.225553  162.845513
# Other Assets                          NaN    7.423204   61.648000
# Other Current Assets            19.234496  447.808541   14.861592
# Other Current Liabilities        0.996352         NaN   -0.754075
# Other Liabilities                     NaN         NaN    0.364768
# Other Stockholder Equity              NaN   97.228786         NaN
# Property, plant and equipment   23.996375   17.710983   94.787212
# Retained Earnings                2.088792   21.062393  364.011107
# Short Term Investments                NaN         NaN         NaN
# Short/Current Long Term Debt          NaN         NaN         NaN
# Total Assets                    27.454947   12.089246   28.035910
# Total Current Assets            27.047162   10.226676   46.073453
# Total Current Liabilities       21.469432   83.055670    7.417986
# Total Liabilities               21.469432   83.745445    5.319834
# Total stockholders' equity      28.576722    3.891897   39.345027
# Treasury Stock                        NaN   97.228786         NaN
#
#                                    Averages
# Accounts Payable               5.187923e+01
# Capital Surplus                1.427194e+01
# Cash And Cash Equivalents      1.935886e+02
# Common Stock                   4.523520e+01
# Goodwill                       1.289568e+02
# Intangible Assets              7.615281e+03
# Inventory                      3.510396e+01
# Long Term Debt                 8.266660e+01
# Long Term Investments          2.890870e+06
# Net Receivables                1.945939e+02
# Net Tangible Assets            1.050515e+01
# Other Assets                   6.651014e+01
# Other Current Assets           1.055578e+02
# Other Current Liabilities      5.606662e+01
# Other Liabilities              7.382604e+00
# Other Stockholder Equity       4.450803e+01
# Property, plant and equipment  3.833959e+01
# Retained Earnings              3.872391e+01
# Short Term Investments         2.090797e+02
# Short/Current Long Term Debt   6.226942e+01
# Total Assets                   6.565144e+01
# Total Current Assets           5.835094e+01
# Total Current Liabilities      3.081374e+01
# Total Liabilities              7.090565e+01
# Total stockholders' equity     4.539990e+01
# Treasury Stock                 4.450803e+01

# %%
portfolio.financials(APHA.fin_list)

# %%
portfolio.financials.dropna(how='all')
# Out:
#                                            APHA.TO      ACB.TO    TRST.TO  \
# Total Revenue                            27.113825  171.299514  73.979537
# Cost of Revenue                          85.646060 -116.496723 -76.149011
# Gross Profit                             10.483374   71.577203  48.953078
# Research Development                      5.311023   25.155752        NaN
# Selling General and Administrative       18.087969   56.541623   7.447597
# Total Operating Expenses                 30.598945   89.390778   9.505993
# Operating Income or Loss                 57.548898   63.711765   0.927109
# Total Other Income/Expenses Net         166.042013   23.340094   0.471751
# Earnings Before Interest and Taxes       57.548898   63.711765   0.927109
# Interest Expense                         19.090439   32.031401   1.323275
# Income Before Tax                        18.506533   54.897650   0.777224
# Income Tax Expense                       -1.711667  202.402685        NaN
# Minority Interest                         1.965449   -0.033319        NaN
# Net Income From Continuing Ops          -42.458836   51.057313   0.987342
# Discontinued Operations                        NaN         NaN        NaN
# Net Income                              -42.458836   49.818976   1.113002
# Net Income Applicable To Common Shares  -42.458836   49.818976   1.113002
#
#                                             WEED.TO    CRON.TO       EMH.V  \
# Total Revenue                             16.823529   3.612014   61.267777
# Cost of Revenue                          -22.856370   3.930616    9.886208
# Gross Profit                               3.683978   3.497627    0.566335
# Research Development                      20.134535   0.000000    3.936981
# Selling General and Administrative        22.342444  10.068383   12.114529
# Total Operating Expenses                  54.645716  10.429725   10.162283
# Operating Income or Loss                 419.064492 -41.542810    9.703924
# Total Other Income/Expenses Net           49.746101   1.626656 -752.480730
# Earnings Before Interest and Taxes       419.064492 -41.542810    9.703924
# Interest Expense                         130.535714        NaN   24.921973
# Income Before Tax                        194.185757 -87.984003    7.866061
# Income Tax Expense                        96.761905  -3.859649         NaN
# Minority Interest                      -9057.718750   0.000000         NaN
# Net Income From Continuing Ops           190.674485 -50.732498    7.859310
# Discontinued Operations                         NaN        NaN         NaN
# Net Income                               195.063501 -50.123952    7.743072
# Net Income Applicable To Common Shares   195.063501 -50.123952    7.743072
#
#                                               N.V       OGI.V     FIRE.TO  \
# Total Revenue                            4.456248   11.596840         NaN
# Cost of Revenue                          5.131281  117.022686         NaN
# Gross Profit                             3.029381   38.586423         NaN
# Research Development                          NaN         NaN         NaN
# Selling General and Administrative      10.076463    4.319953   10.761650
# Total Operating Expenses                 8.211681  -12.179441    9.173082
# Operating Income or Loss                14.681654  -32.421301   -0.566934
# Total Other Income/Expenses Net         13.736762   72.277069  110.135312
# Earnings Before Interest and Taxes      14.681654  -32.421301   -0.566934
# Interest Expense                              NaN   86.465881   55.466104
# Income Before Tax                       14.625806  -22.754249    1.750304
# Income Tax Expense                            NaN         NaN         NaN
# Minority Interest                        0.915072         NaN         NaN
# Net Income From Continuing Ops          14.468929  -18.326961    2.304697
# Discontinued Operations                       NaN   20.197368         NaN
# Net Income                              14.461042  -17.065267    2.304697
# Net Income Applicable To Common Shares  14.461042  -17.065267    2.304697
#
#                                           VFF.TO      WMD.V       FAF.TO  \
# Total Revenue                           0.056829        NaN          NaN
# Cost of Revenue                         0.117697        NaN          NaN
# Gross Profit                           -0.433346        NaN          NaN
# Research Development                         NaN        NaN          NaN
# Selling General and Administrative      0.291881  13.271577    12.053755
# Total Operating Expenses                0.132869   9.448032    14.921977
# Operating Income or Loss               -2.838656   4.952278     8.865904
# Total Other Income/Expenses Net        -0.650982 -12.869718  1605.492621
# Earnings Before Interest and Taxes     -2.838656   4.952278     8.865904
# Interest Expense                        0.204787   0.013534   184.514759
# Income Before Tax                      -9.167203  -0.653243    16.551993
# Income Tax Expense                      1.131783        NaN          NaN
# Minority Interest                            NaN        NaN          NaN
# Net Income From Continuing Ops         -3.457020  -0.653243    16.551993
# Discontinued Operations                      NaN        NaN          NaN
# Net Income                             -3.457020  -0.653243    16.551993
# Net Income Applicable To Common Shares -3.457020  -0.653243    16.551993
#
#                                           TGOD.TO     Averages
# Total Revenue                                 NaN    41.134013
# Cost of Revenue                         -1.955927     0.427652
# Gross Profit                             2.746134    18.269019
# Research Development                     2.946690     9.580830
# Selling General and Administrative      24.720546    15.546028
# Total Operating Expenses                28.183580    20.201940
# Operating Income or Loss                26.965924    40.696327
# Total Other Income/Expenses Net          3.934048    98.523154
# Earnings Before Interest and Taxes      26.965924    40.696327
# Interest Expense                        -0.000000    48.597079
# Income Before Tax                       21.451176    16.157985
# Income Tax Expense                       2.670284    49.565890
# Minority Interest                             NaN -1810.974310
# Net Income From Continuing Ops          22.374640    14.665396
# Discontinued Operations                       NaN    20.197368
# Net Income                              22.374640    15.051739
# Net Income Applicable To Common Shares  22.374640    15.051739

# %%
GP = DataFrame(portfolio.financials.dropna(how='all').T.sort_values('Gross Profit', ascending=False)['Gross Profit'])
statistics_df = portfolio.statistics.dropna(how='all').T.sort_values("Diluted EPS (ttm)", ascending=False)[['Diluted EPS (ttm)', 'EBITDA', 'Levered Free Cash Flow (ttm)', 'Beta (3Y Monthly)', 'Profit Margin']]
Debt = portfolio.balance_sheet.dropna(how='all').T.sort_values('Long Term Debt', ascending=False)['Long Term Debt']
NI = portfolio.cashflow.dropna(how='all').T.sort_values("Net Income", ascending=False)['Net Income']
pandas.concat([statistics_df, NI, Debt, GP], axis=1, sort=True).sort_values('Diluted EPS (ttm)', ascending=False)
# Out:
#           Diluted EPS (ttm)    EBITDA  Levered Free Cash Flow (ttm)  \
# CRON.TO            0.710000  -34.7800                           NaN
# VFF.TO             0.310000   -9.1400                      -12.0500
# WMD.V              0.108000    3.4300                      -75.6700
# FIRE.TO           -0.052000    4.1800                     -114.0900
# APHA.TO           -0.070000  -41.0800                     -230.6300
# TRST.TO           -0.121000    1.2800                      -75.7700
# N.V               -0.145000  -38.2700                           NaN
# EMH.V             -0.158000  -44.6300                      -55.0600
# TGOD.TO           -0.225000  -55.7500                     -247.5400
# ACB.TO            -0.290000 -209.9400                     -580.7700
# Averages          -0.566583  -85.0725                     -173.9475
# FAF.TO            -0.646000  -22.9000                           NaN
# WEED.TO           -6.220000 -573.2700                           NaN
# OGI.V                   NaN       NaN                           NaN
#
#           Beta (3Y Monthly)  Profit Margin  Net Income  Long Term Debt  \
# CRON.TO               4.070            NaN  -50.123952             NaN
# VFF.TO                5.140      10.430000   -3.457020       -0.269717
# WMD.V                 2.740      77.370000   -0.653243             NaN
# FIRE.TO               4.230     -34.650000    2.304697      146.296441
# APHA.TO               3.700      -6.960000  -42.458836             NaN
# TRST.TO               4.620     -22.310000    1.113002       -0.409745
# N.V                   3.590    -227.180000   14.461042             NaN
# EMH.V                 2.280    -298.070000    7.743072             NaN
# TGOD.TO                 NaN       0.000000   22.374640             NaN
# ACB.TO                2.760    -117.300000   49.818976       87.999550
# Averages              3.853     -77.392727         NaN       82.666600
# FAF.TO                  NaN    -232.650000   16.551993             NaN
# WEED.TO               5.400       0.000000  195.063501      241.795907
# OGI.V                   NaN            NaN  -17.065267       20.587166
#
#           Gross Profit
# CRON.TO       3.497627
# VFF.TO       -0.433346
# WMD.V              NaN
# FIRE.TO            NaN
# APHA.TO      10.483374
# TRST.TO      48.953078
# N.V           3.029381
# EMH.V         0.566335
# TGOD.TO       2.746134
# ACB.TO       71.577203
# Averages     18.269019
# FAF.TO             NaN
# WEED.TO       3.683978
# OGI.V        38.586423

# %%
ACB.earnings_est
# Out:
#                    Current Qtr. (Sep 2019)  Next Qtr. (Dec 2019)  \
# Earnings Estimate
# No. of Analysts                       9.00                  9.00
# Avg. Estimate                        -0.05                 -0.04
# Low Estimate                         -0.10                 -0.08
# High Estimate                        -0.02                 -0.01
# Year Ago EPS                          0.12                 -0.25
#
#                    Current Year (2020)  Next Year (2021)
# Earnings Estimate
# No. of Analysts                  15.00             14.00
# Avg. Estimate                    -0.14             -0.01
# Low Estimate                     -0.32             -0.28
# High Estimate                     0.05              0.22
# Year Ago EPS                     -0.29             -0.14

# %%
ACB.financials
# Out:
# Period Ending                           6/30/2019  6/30/2018  6/30/2017  \
# ACB.TO
# Total Revenue                            247939.0    55196.0    18067.0
# Cost of Revenue                           88124.0    11677.0     2011.0
# Gross Profit                             159815.0    43519.0    16056.0
# Operating Expenses                            NaN        NaN        NaN
# Research Development                      14778.0     1679.0      314.0
# Selling General and Administrative       271654.0    72410.0    17083.0
# Non Recurring                                 NaN        NaN        NaN
# Others                                        NaN        NaN        NaN
# Total Operating Expenses                 544966.0   135304.0    27708.0
# Operating Income or Loss                -297027.0   -80108.0    -9641.0
# Income from Continuing Operations             NaN        NaN        NaN
# Total Other Income/Expenses Net          -31204.0   157435.0    -7623.0
# Earnings Before Interest and Taxes      -297027.0   -80108.0    -9641.0
# Interest Expense                         -41025.0   -11762.0    -4862.0
# Income Before Tax                       -328231.0    77327.0   -17264.0
# Income Tax Expense                       -30307.0     8100.0    -4296.0
# Minority Interest                          4410.0     4562.0     4562.0
# Net Income From Continuing Ops          -297924.0    69227.0   -12968.0
# Non-recurring Events                          NaN        NaN        NaN
# Discontinued Operations                       NaN        NaN        NaN
# Extraordinary Items                           NaN        NaN        NaN
# Effect Of Accounting Changes                  NaN        NaN        NaN
# Other Items                                   NaN        NaN        NaN
# Net Income                              -290837.0    71936.0   -12968.0
# Preferred Stock And Other Adjustments         NaN        NaN        NaN
# Net Income Applicable To Common Shares  -290837.0    71936.0   -12968.0
#
# Period Ending                           6/30/2016     Changes
# ACB.TO
# Total Revenue                              1439.0  171.299514
# Cost of Revenue                            -763.0 -116.496723
# Gross Profit                               2202.0   71.577203
# Operating Expenses                            NaN         NaN
# Research Development                        565.0   25.155752
# Selling General and Administrative         4721.0   56.541623
# Non Recurring                                 NaN         NaN
# Others                                        NaN         NaN
# Total Operating Expenses                   6029.0   89.390778
# Operating Income or Loss                  -4590.0   63.711765
# Income from Continuing Operations             NaN         NaN
# Total Other Income/Expenses Net           -1282.0   23.340094
# Earnings Before Interest and Taxes        -4590.0   63.711765
# Interest Expense                          -1242.0   32.031401
# Income Before Tax                         -5872.0   54.897650
# Income Tax Expense                         -149.0  202.402685
# Minority Interest                          4562.0   -0.033319
# Net Income From Continuing Ops            -5723.0   51.057313
# Non-recurring Events                          NaN         NaN
# Discontinued Operations                       NaN         NaN
# Extraordinary Items                           NaN         NaN
# Effect Of Accounting Changes                  NaN         NaN
# Other Items                                   NaN         NaN
# Net Income                                -5723.0   49.818976
# Preferred Stock And Other Adjustments         NaN         NaN
# Net Income Applicable To Common Shares    -5723.0   49.818976

# %%
g = stock_loop('GSY.TO')

# %%
g.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()']]

# %%
g.stats()

# %%
g.balance()

# %%
g.financial()

# %%
g.cash()

# %%
g.analyze()

# %%
g.statistics.dropna()
# Out:
#                                                     GSY.TO
# Market Cap (intraday) 5                         864.840000
# Enterprise Value 3                              155.000000
# Trailing P/E                                     13.580000
# Forward P/E 1                                    11.450000
# Price/Sales (ttm)                                 2.370000
# Price/Book (mrq)                                  2.710000
# Enterprise Value/Revenue 3                        4.240000
# Beta (3Y Monthly)                                 1.900000
# 52-Week Change 3                                  8.630000
# S&P500 52-Week Change 3                           2.720000
# 52 Week High 3                                   60.000000
# 52 Week Low 3                                    30.420000
# 50-Day Moving Average 3                          54.940000
# 200-Day Moving Average 3                         51.020000
# Avg Vol (3 month) 3                               0.300800
# Avg Vol (10 day) 3                                0.463300
# Shares Outstanding 5                             14.410000
# Float                                            10.420000
# Shares Short (Aug 30, 2019) 4                     3.430200
# Short Ratio (Aug 30, 2019) 4                      9.090000
# Short % of Shares Outstanding (Aug 30, 2019) 4    2.380000
# Shares Short (prior month Jul 31, 2019) 4         3.464300
# Forward Annual Dividend Rate 4                    1.240000
# Forward Annual Dividend Yield 4                   2.100000
# Trailing Annual Dividend Rate 3                   1.070000
# Trailing Annual Dividend Yield 3                  1.820000
# 5 Year Average Dividend Yield 4                   1.980000
# Payout Ratio 4                                   24.210000
# Profit Margin                                    18.650000
# Operating Margin (ttm)                           25.160000
# Return on Assets (ttm)                            7.070000
# Return on Equity (ttm)                           24.720000
# Revenue (ttm)                                   365.080000
# Revenue Per Share (ttm)                          25.170000
# Quarterly Revenue Growth (yoy)                   14.800000
# Gross Profit (ttm)                              341.410000
# Net Income Avi to Common (ttm)                   68.070000
# Diluted EPS (ttm)                                 4.420000
# Quarterly Earnings Growth (yoy)                  65.500000
# Total Cash (mrq)                                 39.650000
# Total Cash Per Share (mrq)                        2.750000
# Total Debt (mrq)                                734.260000
# Total Debt/Equity (mrq)                         229.940000
# Current Ratio (mrq)                              16.260000
# Book Value Per Share (mrq)                       22.150000
# Operating Cash Flow (ttm)                      -145.770000
# Adjusted Returns                                  1.105263
# Total Returns                                    10.730000
