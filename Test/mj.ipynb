# %%
from finance_python.stock import stock
from finance_python.industry import industry
import sys, os, time
import numpy as np
import pandas
from datetime import datetime, date, timedelta
from pandas import DataFrame

# %%
symbols = [ 'APHA.TO', 'ACB.TO', 'TRST.TO', 'WEED.TO', 
           'CRON.TO', 'EMH.V', 'N.V', 'OGI.V', 'FIRE.TO', 
           'VFF.TO', 'WMD.V']

start = date.today() - timedelta(days=365)
end = date.today()

# %%
stock_loop = lambda x: stock(x, start, end)
stat = lambda x: stocks[x].stats()
bal = lambda x: stocks[x].balance()
fin = lambda x: stocks[x].financial()
ca = lambda x: stocks[x].cash()
an = lambda x: stocks[x].analyze()

# %%
timer_start = time.time()

stocks = list(map(stock_loop, symbols))

timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 34.83316135406494

# %%
faf = stock_loop('FAF.TO')

# %%
faf.stats()
faf.balance()

# %%
faf.financial()
faf.cash()
faf.analyze()

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    stat(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 5.3304667472839355

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    bal(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 4.1669697761535645

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    fin(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 4.309514045715332

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    ca(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 4.411674737930298

# %%
timer_start = time.time()

for each in range(0, len(stocks)):
    an(each)
    
timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 8.255691528320312

# %%
APHA, ACB, TRST, WEED, CRON, EMH, N, OGI, FIRE, VFF, WMD = stocks

# %%
price = list(map(lambda symbol, x: {symbol: stocks[x].price}, symbols, range(0, len(symbols))))

# %%
price
# Out:
# [{'APHA.TO': 9.31},
#  {'ACB.TO': 8.02},
#  {'TRST.TO': 2.33},
#  {'WEED.TO': 36.45},
#  {'CRON.TO': 15.71},
#  {'EMH.V': 1.9},
#  {'N.V': 0.68},
#  {'OGI.V': '6.22'},
#  {'FIRE.TO': 1.43},
#  {'VFF.TO': 15.66},
#  {'WMD.V': 1.48}]

# %%
APHA.description
# Out:
# 'Aphria Inc. produces and sells medical cannabis in Canada and internationally. The company offers pharmaceutical-grade medical cannabis; and adult-use cannabis under the Solei, RIFF, Good Supply, and Broken Coast brands. It serves patients and consumers through distributors and online. The company is headquartered in Leamington, Canada.'

# %%
APHA.earnings_history
# Out:
#                  8/30/2018 11/29/2018  2/27/2019 5/30/2019
# Earnings History
# EPS Est.             -0.04       0.01       0.00     -0.05
# EPS Actual            0.07       0.16      -0.43      0.05
# Difference            0.11       0.15      -0.43       0.1
# Surprise %         275.00%  1,500.00%        NaN   200.00%

# %%
APHA.dividends
# Out:
# [                                                Date  Dividends
#  0  *Close price adjusted for splits.**Adjusted cl...        NaN]

# %%
APHA.statistics.dropna(how='all')
# Out:
#                                                 APHA.TO
# Market Cap (intraday) 5                          216.00
# Enterprise Value 3                               228.00
# Forward P/E 1                                     27.38
# Price/Sales (ttm)                                  9.12
# Price/Book (mrq)                                   1.37
# Enterprise Value/Revenue 3                         9.63
# Enterprise Value/EBITDA 6                        -55.58
# Beta (3Y Monthly)                                  3.70
# 52-Week Change 3                                 -55.47
# S&P500 52-Week Change 3                            3.63
# 52 Week High 3                                    22.00
# 52 Week Low 3                                      4.76
# 50-Day Moving Average 3                            8.36
# 200-Day Moving Average 3                          10.18
# Avg Vol (3 month) 3                                1.99
# Avg Vol (10 day) 3                                 1.83
# Shares Outstanding 5                             250.99
# Float                                            250.74
# Shares Short (Aug 15, 2019) 4                      5.84
# Short Ratio (Aug 15, 2019) 4                       1.86
# Short % of Shares Outstanding (Aug 15, 2019) 4     1.95
# Shares Short (prior month Jul 15, 2019) 4          8.00
# Payout Ratio 4                                     0.00
# Profit Margin                                     -6.96
# Operating Margin (ttm)                           -26.93
# Return on Assets (ttm)                            -2.13
# Return on Equity (ttm)                            -1.14
# Revenue (ttm)                                    237.11
# Revenue Per Share (ttm)                            0.98
# Quarterly Revenue Growth (yoy)                   969.10
# Gross Profit (ttm)                                75.42
# EBITDA                                           -41.08
# Net Income Avi to Common (ttm)                   -16.50
# Diluted EPS (ttm)                                 -0.07
# Total Cash (mrq)                                 571.00
# Total Cash Per Share (mrq)                         2.28
# Total Debt (mrq)                                 488.59
# Total Debt/Equity (mrq)                           28.19
# Current Ratio (mrq)                                5.64
# Book Value Per Share (mrq)                         6.79
# Operating Cash Flow (ttm)                        -55.60
# Levered Free Cash Flow (ttm)                    -230.63
# Total Returns                                    -55.47

# %%
APHA.cashflow.dropna()
# Out:
# Period Ending                               5/31/2019  5/31/2018  5/31/2017  \
# APHA.TO
# Net Income                                   -16499.0    29448.0     4198.0
# Depreciation                                  22779.0     6578.0     1874.0
# Adjustments To Net Income                    -40555.0   -31364.0      113.0
# Changes In Accounts Receivables               12458.0    -1797.0      953.0
# Changes In Liabilities                          691.0     3764.0     4534.0
# Changes In Inventories                       -22151.0    -7045.0     3057.0
# Changes In Other Operating Activities        -11607.0    -7995.0    -9472.0
# Total Cash Flow From Operating Activities    -55605.0    -5649.0     5325.0
# Capital Expenditure                         -205965.0  -203822.0   -67722.0
# Investments                                   62531.0    31515.0  -133406.0
# Other Cash flows from Investing Activities   -10949.0   -13361.0     -932.0
# Total Cash Flows From Investing Activities  -177885.0  -220870.0  -202027.0
# Net Borrowings                               470853.0    -7622.0    32181.0
# Total Cash Flows From Financing Activities   724550.0   206346.0   260139.0
# Change In Cash and Cash Equivalents          491060.0   -20173.0    63437.0
#
# Period Ending                               5/31/2016     Changes
# APHA.TO
# Net Income                                    397.961  -42.458836
# Depreciation                                  898.055   24.364816
# Adjustments To Net Income                    -740.165   53.791837
# Changes In Accounts Receivables             -1778.679   -8.004074
# Changes In Liabilities                        319.269    1.164319
# Changes In Inventories                       -778.388   27.457530
# Changes In Other Operating Activities         639.690  -19.144726
# Total Cash Flow From Operating Activities    -988.134   55.272732
# Capital Expenditure                         -4426.059   45.534626
# Investments                                 -1560.200  -41.078836
# Other Cash flows from Investing Activities     32.412 -338.806985
# Total Cash Flows From Investing Activities  -5970.982   28.791582
# Net Borrowings                              32181.000   13.631397
# Total Cash Flows From Financing Activities  16379.871   43.234170
# Change In Cash and Cash Equivalents          9420.755   51.125334

# %%
portfolio = industry()

# %%
portfolio.statistics(APHA.stats_list)

# %%
stats = portfolio.statistics
stats
# Out:
#                                                 APHA.TO  ACB.TO   TRST.TO  \
# 200-Day Moving Average 3                          10.18   10.26    7.3476
# 50-Day Moving Average 3                            8.36    8.12    2.7703
# 52 Week High 3                                    22.00   16.24   15.5000
# 52 Week Low 3                                      4.76    6.21    2.1300
# 52-Week Change 3                                 -55.47   -4.56  -77.4800
# Avg Vol (10 day) 3                                 1.83    4.02    1.3600
# Avg Vol (3 month) 3                                1.99    3.78    2.4300
# Beta (3Y Monthly)                                  3.70    2.76    4.6200
# Book Value Per Share (mrq)                         6.79    4.32    1.8000
# Current Ratio (mrq)                                5.64    2.37    5.6400
# Diluted EPS (ttm)                                 -0.07   -0.25   -0.1210
# EBITDA                                           -41.08 -205.82    1.2800
# Enterprise Value 3                               228.00  826.00  291.0400
# Enterprise Value/EBITDA 6                        -55.58  -40.16  227.7100
# Enterprise Value/Revenue 3                         9.63   49.15    5.3200
# Float                                            250.74  976.23  115.3300
# Forward P/E 1                                     27.38 -100.25   46.6000
# Gross Profit (ttm)                                75.42   43.52   36.4900
# Levered Free Cash Flow (ttm)                    -230.63 -558.70  -75.7700
# Market Cap (intraday) 5                          216.00  771.00  326.1200
# Net Income Avi to Common (ttm)                   -16.50 -210.78  -12.1900
# Operating Cash Flow (ttm)                        -55.60 -232.76  -36.5700
# Operating Margin (ttm)                           -26.93 -170.22   -5.3100
# PEG Ratio (5 yr expected) 1                         NaN     NaN       NaN
# Payout Ratio 4                                     0.00    0.00    0.0000
# Price/Book (mrq)                                   1.37    1.85    1.2900
# Price/Sales (ttm)                                  9.12   45.86    5.9700
# Profit Margin                                     -6.96 -125.35  -22.3100
# Quarterly Earnings Growth (yoy)                     NaN     NaN   11.9000
# Quarterly Revenue Growth (yoy)                   969.10  304.60  115.0000
# Return on Assets (ttm)                            -2.13   -4.95   -1.0900
# Return on Equity (ttm)                            -1.14   -7.49   -8.7500
# Revenue (ttm)                                    237.11  168.14   54.6600
# Revenue Per Share (ttm)                            0.98    0.20    0.5300
# S&P500 52-Week Change 3                            3.63    3.63    3.6300
# Shares Outstanding 5                             250.99  102.00  141.1800
# Shares Short (Aug 15, 2019) 4                      5.84   31.56    5.2100
# Shares Short (prior month Jul 15, 2019) 4          8.00   36.59    4.5300
# Short % of Shares Outstanding (Aug 15, 2019) 4     1.95    3.15    3.6900
# Short Ratio (Aug 15, 2019) 4                       1.86    7.38    1.1300
# Total Cash (mrq)                                 571.00  535.17   42.7500
# Total Cash Per Share (mrq)                         2.28    0.53    0.3100
# Total Debt (mrq)                                 488.59  639.10   15.6000
# Total Debt/Equity (mrq)                           28.19   14.55    8.2000
# Total Returns                                    -55.47   -4.56  -77.4800
# Trailing P/E                                        NaN     NaN       NaN
#
#                                                 WEED.TO    CRON.TO     EMH.V  \
# 200-Day Moving Average 3                          53.62    21.6500    3.1226
# 50-Day Moving Average 3                           39.45    17.0200    1.9791
# 52 Week High 3                                    76.68    32.9500    5.9200
# 52 Week Low 3                                     30.30     8.4700    1.6700
# 52-Week Change 3                                 -48.42    -2.9100  -64.8100
# Avg Vol (10 day) 3                                 2.34     6.1466    3.7653
# Avg Vol (3 month) 3                                1.85     7.7998    4.4608
# Beta (3Y Monthly)                                  5.40     4.0700    2.2800
# Book Value Per Share (mrq)                        16.51     3.6400    1.3300
# Current Ratio (mrq)                               10.37     1.6800    0.9200
# Diluted EPS (ttm)                                 -6.22     0.7100   -0.1580
# EBITDA                                          -573.27   -34.7800  -44.6300
# Enterprise Value 3                              1198.00   296.0000  299.1600
# Enterprise Value/EBITDA 6                        -20.90   -85.1000   -6.7000
# Enterprise Value/Revenue 3                        41.19   113.5400   37.2100
# Float                                            217.81   177.0200  110.6100
# Forward P/E 1                                    -41.42 -1571.0000  -10.5600
# Gross Profit (ttm)                                88.93    11.2700   -2.7021
# Levered Free Cash Flow (ttm)                        NaN        NaN  -55.0600
# Market Cap (intraday) 5                         1142.00   506.0000  279.2900
# Net Income Avi to Common (ttm)                  -189.00   660.3000  -23.9600
# Operating Cash Flow (ttm)                       -611.16   -65.0900  -38.0000
# Operating Margin (ttm)                          -218.20  -143.1600 -613.0000
# PEG Ratio (5 yr expected) 1                       -1.57     0.4700       NaN
# Payout Ratio 4                                     0.00     0.0000    0.0000
# Price/Book (mrq)                                   2.21     4.3100    1.4300
# Price/Sales (ttm)                                 39.25   193.9800   34.7400
# Profit Margin                                      0.00        NaN -298.0700
# Quarterly Earnings Growth (yoy)                     NaN        NaN       NaN
# Quarterly Revenue Growth (yoy)                   249.10   201.6000       NaN
# Return on Assets (ttm)                            -7.37    -1.6100  -13.3500
# Return on Equity (ttm)                           -52.27    90.9000  -12.8300
# Revenue (ttm)                                    290.91    26.0700    8.0400
# Revenue Per Share (ttm)                            0.96     0.1000    0.0500
# S&P500 52-Week Change 3                            3.63     3.6300    3.6300
# Shares Outstanding 5                             347.87   336.1500  149.4400
# Shares Short (Aug 15, 2019) 4                      8.72     3.6400    2.5800
# Shares Short (prior month Jul 15, 2019) 4          8.95     3.5400    1.9600
# Short % of Shares Outstanding (Aug 15, 2019) 4     2.75     1.0800    1.7200
# Short Ratio (Aug 15, 2019) 4                       5.75     6.2700    8.1200
# Total Cash (mrq)                                 318.00   232.0000    2.6100
# Total Cash Per Share (mrq)                         9.13     6.9100    0.0200
# Total Debt (mrq)                                 220.00     3.5300    9.7100
# Total Debt/Equity (mrq)                           37.27     0.2900    4.7900
# Total Returns                                    -48.42    -2.9100  -64.8100
# Trailing P/E                                        NaN    22.1000       NaN
#
#                                                      N.V     OGI.V   FIRE.TO  \
# 200-Day Moving Average 3                          0.6679       NaN    1.7564
# 50-Day Moving Average 3                           0.4809       NaN    1.4041
# 52 Week High 3                                    3.9500       NaN    2.4300
# 52 Week Low 3                                     0.3800       NaN    1.1500
# 52-Week Change 3                                -75.7200       NaN  -31.0300
# Avg Vol (10 day) 3                                3.1400    6.7178    6.3573
# Avg Vol (3 month) 3                               1.3800    6.3706    5.7462
# Beta (3Y Monthly)                                 3.4800       NaN    4.2300
# Book Value Per Share (mrq)                        0.3100       NaN    0.7000
# Current Ratio (mrq)                              13.5900       NaN    4.1500
# Diluted EPS (ttm)                                -0.1450       NaN   -0.0510
# EBITDA                                          -38.2700       NaN   -9.2200
# Enterprise Value 3                               87.2800       NaN  421.0400
# Enterprise Value/EBITDA 6                        -2.2800       NaN  -45.6600
# Enterprise Value/Revenue 3                        4.8700       NaN   15.9700
# Float                                           296.1300       NaN  288.8600
# Forward P/E 1                                        NaN       NaN   71.5000
# Gross Profit (ttm)                                4.5100   52.5000    8.9200
# Levered Free Cash Flow (ttm)                         NaN       NaN -101.4000
# Market Cap (intraday) 5                         211.4100  107.0000  469.8400
# Net Income Avi to Common (ttm)                  -40.7300       NaN  -13.8400
# Operating Cash Flow (ttm)                       -28.6700       NaN  -10.0700
# Operating Margin (ttm)                         -221.9700       NaN  -50.0200
# PEG Ratio (5 yr expected) 1                          NaN       NaN   -0.6800
# Payout Ratio 4                                    0.0000       NaN    0.0000
# Price/Book (mrq)                                  2.2000       NaN    2.0400
# Price/Sales (ttm)                                11.7900       NaN   17.8200
# Profit Margin                                  -227.1800       NaN  -52.4800
# Quarterly Earnings Growth (yoy)                      NaN       NaN       NaN
# Quarterly Revenue Growth (yoy)                   -1.7000       NaN  381.9000
# Return on Assets (ttm)                               NaN       NaN   -3.3200
# Return on Equity (ttm)                               NaN       NaN   -7.9700
# Revenue (ttm)                                    17.9300       NaN   26.3700
# Revenue Per Share (ttm)                           0.0600       NaN    0.1000
# S&P500 52-Week Change 3                           3.6300       NaN    3.6300
# Shares Outstanding 5                            216.5100       NaN  333.3200
# Shares Short (Aug 15, 2019) 4                     1.6100       NaN    1.0700
# Shares Short (prior month Jul 15, 2019) 4         2.7200       NaN    2.3900
# Short % of Shares Outstanding (Aug 15, 2019) 4    0.5000       NaN    0.3200
# Short Ratio (Aug 15, 2019) 4                      1.4100       NaN    1.3600
# Total Cash (mrq)                                 55.8800       NaN   75.0200
# Total Cash Per Share (mrq)                        0.1700       NaN    0.2500
# Total Debt (mrq)                                  0.2973       NaN   75.5000
# Total Debt/Equity (mrq)                           0.0300       NaN   36.8200
# Total Returns                                   -75.7200       NaN  -31.0300
# Trailing P/E                                         NaN   30.8600       NaN
#
#                                                   VFF.TO     WMD.V    FAF.TO  \
# 200-Day Moving Average 3                         16.2100    1.7343    1.3777
# 50-Day Moving Average 3                          15.4100    1.5779    1.3777
# 52 Week High 3                                   24.2500    2.4900    1.5300
# 52 Week Low 3                                     3.9800    0.9900    1.0500
# 52-Week Change 3                                122.4500  -33.3300       NaN
# Avg Vol (10 day) 3                                4.8234    2.8776    1.8122
# Avg Vol (3 month) 3                               5.5796    2.9064    2.7335
# Beta (3Y Monthly)                                 5.1400    2.7400       NaN
# Book Value Per Share (mrq)                        2.7200    0.8400    0.3400
# Current Ratio (mrq)                               2.4200    3.5000    1.8400
# Diluted EPS (ttm)                                 0.3100    0.1080   -0.6460
# EBITDA                                           -9.1400    3.4300  -22.9000
# Enterprise Value 3                              803.3000  193.5800  198.5100
# Enterprise Value/EBITDA 6                       -87.8800   56.4400   -8.6700
# Enterprise Value/Revenue 3                        5.3000   12.0700    8.8200
# Float                                            38.6400  109.3600   91.6300
# Forward P/E 1                                    19.3300       NaN  148.0000
# Gross Profit (ttm)                                8.8800    4.6300    4.9800
# Levered Free Cash Flow (ttm)                    -12.0500  -75.6700       NaN
# Market Cap (intraday) 5                         702.8900  183.0300  150.2500
# Net Income Avi to Common (ttm)                   15.8200   12.4100  -52.3900
# Operating Cash Flow (ttm)                        -4.4300    2.1300  -20.6000
# Operating Margin (ttm)                          -10.8200   17.8900 -106.4400
# PEG Ratio (5 yr expected) 1                          NaN       NaN       NaN
# Payout Ratio 4                                    0.0000    0.0000       NaN
# Price/Book (mrq)                                  5.7500    1.7600    4.3300
# Price/Sales (ttm)                                 4.6300   11.4100    6.6700
# Profit Margin                                    10.4300   77.3700 -232.6500
# Quarterly Earnings Growth (yoy)                      NaN       NaN       NaN
# Quarterly Revenue Growth (yoy)                   -1.7000  282.0000       NaN
# Return on Assets (ttm)                           -5.8600    1.6200       NaN
# Return on Equity (ttm)                           14.4000   15.2300       NaN
# Revenue (ttm)                                   151.6900   16.0400   22.5200
# Revenue Per Share (ttm)                           3.0700    0.1400    0.2800
# S&P500 52-Week Change 3                           3.6300    3.6300    3.5300
# Shares Outstanding 5                             49.2800  114.3900  110.0400
# Shares Short (Aug 15, 2019) 4                     2.5600    0.9136    6.3929
# Shares Short (prior month Jul 15, 2019) 4         1.9500    1.2642    0.9692
# Short % of Shares Outstanding (Aug 15, 2019) 4    5.1900    0.1100    0.5800
# Short Ratio (Aug 15, 2019) 4                      3.1400    0.4900    0.9600
# Total Cash (mrq)                                 11.7100   12.0200   25.3800
# Total Cash Per Share (mrq)                        0.2400    0.1000    0.2200
# Total Debt (mrq)                                 43.3400   36.2400   52.6300
# Total Debt/Equity (mrq)                          32.3100   37.6700  148.1200
# Total Returns                                   122.4500  -33.3300       NaN
# Trailing P/E                                     49.8700   13.7000       NaN
#
#                                                   Averages
# 200-Day Moving Average 3                         11.629682
# 50-Day Moving Average 3                           8.904545
# 52 Week High 3                                   18.540000
# 52 Week Low 3                                     5.553636
# 52-Week Change 3                                -27.128000
# Avg Vol (10 day) 3                                3.765850
# Avg Vol (3 month) 3                               3.918908
# Beta (3Y Monthly)                                 3.842000
# Book Value Per Share (mrq)                        3.572727
# Current Ratio (mrq)                               4.738182
# Diluted EPS (ttm)                                -0.593909
# EBITDA                                          -88.581818
# Enterprise Value 3                              440.173636
# Enterprise Value/EBITDA 6                        -6.252727
# Enterprise Value/Revenue 3                       27.551818
# Float                                           242.941818
# Forward P/E 1                                  -156.713333
# Gross Profit (ttm)                               28.112325
# Levered Free Cash Flow (ttm)                   -158.468571
# Market Cap (intraday) 5                         422.069167
# Net Income Avi to Common (ttm)                   11.740000
# Operating Cash Flow (ttm)                      -100.074545
# Operating Margin (ttm)                         -140.743636
# PEG Ratio (5 yr expected) 1                      -0.593333
# Payout Ratio 4                                    0.000000
# Price/Book (mrq)                                  2.594545
# Price/Sales (ttm)                                34.658182
# Profit Margin                                   -87.720000
# Quarterly Earnings Growth (yoy)                  11.900000
# Quarterly Revenue Growth (yoy)                  277.766667
# Return on Assets (ttm)                           -4.228889
# Return on Equity (ttm)                            3.342222
# Revenue (ttm)                                    92.680000
# Revenue Per Share (ttm)                           0.588182
# S&P500 52-Week Change 3                           3.620909
# Shares Outstanding 5                            195.560909
# Shares Short (Aug 15, 2019) 4                     6.372409
# Shares Short (prior month Jul 15, 2019) 4         6.623945
# Short % of Shares Outstanding (Aug 15, 2019) 4    1.912727
# Short Ratio (Aug 15, 2019) 4                      3.442727
# Total Cash (mrq)                                171.049091
# Total Cash Per Share (mrq)                        1.832727
# Total Debt (mrq)                                144.048845
# Total Debt/Equity (mrq)                          31.658182
# Total Returns                                   -27.128000
# Trailing P/E                                     29.132500

# %%
portfolio.statistics.T["Market Cap (intraday) 5"].sort_values(ascending=False)
# Out:
# WEED.TO     1142.000000
# ACB.TO       771.000000
# VFF.TO       702.890000
# CRON.TO      506.000000
# FIRE.TO      469.840000
# Averages     422.069167
# TRST.TO      326.120000
# EMH.V        279.290000
# APHA.TO      216.000000
# N.V          211.410000
# WMD.V        183.030000
# FAF.TO       150.250000
# OGI.V        107.000000
# Name: Market Cap (intraday) 5, dtype: float64

# %%
portfolio.cashflow(APHA.cash_list)

# %%
portfolio.cashflow.dropna(how='all')
# Out:
#                                                APHA.TO      ACB.TO  \
# Adjustments To Net Income                    53.791837  -24.745702
# Capital Expenditure                          45.534626   34.190280
# Change In Cash and Cash Equivalents          51.125334  116.357891
# Changes In Accounts Receivables              -8.004074   71.679012
# Changes In Inventories                       27.457530  352.811642
# Changes In Liabilities                        1.164319    5.246238
# Changes In Other Operating Activities       -19.144726   35.203930
# Depreciation                                 24.364816   39.223625
# Effect Of Exchange Rate Changes                    NaN    0.868421
# Investments                                 -41.078836   27.512706
# Net Borrowings                               13.631397   27.671744
# Net Income                                  -42.458836   -8.557597
# Other Cash Flows from Financing Activities         NaN    5.845177
# Other Cash flows from Investing Activities -338.806985    3.925926
# Total Cash Flow From Operating Activities    55.272732   23.567577
# Total Cash Flows From Financing Activities   43.234170   50.953003
# Total Cash Flows From Investing Activities   28.791582   67.632871
#
#                                                TRST.TO     WEED.TO  \
# Adjustments To Net Income                    -1.789118  -28.487383
# Capital Expenditure                          45.649951   51.841587
# Change In Cash and Cash Equivalents         -41.690983 -357.797818
# Changes In Accounts Receivables              92.632181  511.787879
# Changes In Inventories                      -31.735633   13.414833
# Changes In Liabilities                       20.528236   35.715945
# Changes In Other Operating Activities        -0.190883  398.770642
# Depreciation                                  2.653818   19.007572
# Effect Of Exchange Rate Changes                    NaN    0.000000
# Investments                                -384.513005   43.280306
# Net Borrowings                                3.073240 -314.326316
# Net Income                                    1.113002  195.063501
# Other Cash Flows from Financing Activities  -39.802146 -980.159562
# Other Cash flows from Investing Activities    2.917399         NaN
# Total Cash Flow From Operating Activities     3.421185   37.479338
# Total Cash Flows From Financing Activities   21.610691  308.567140
# Total Cash Flows From Investing Activities  214.648081  282.704078
#
#                                                 CRON.TO        EMH.V  \
# Adjustments To Net Income                     -1.977260    -1.847288
# Capital Expenditure                           74.793330    57.343578
# Change In Cash and Cash Equivalents           69.600645     4.180982
# Changes In Accounts Receivables               52.035088 -7834.941176
# Changes In Inventories                         2.226415   120.451245
# Changes In Liabilities                        14.835408    62.366538
# Changes In Other Operating Activities         39.949855   -18.298438
# Depreciation                                  13.710424    74.333875
# Effect Of Exchange Rate Changes                     NaN          NaN
# Investments                                -3355.000000     0.031576
# Net Borrowings                                11.005600    -1.098623
# Net Income                                   -50.123952     7.743072
# Other Cash Flows from Financing Activities   -11.194554  -179.310424
# Other Cash flows from Investing Activities          NaN     9.183766
# Total Cash Flow From Operating Activities      6.070137    11.911015
# Total Cash Flows From Financing Activities    47.801516    88.501705
# Total Cash Flows From Investing Activities    82.232840   199.102106
#
#                                                     N.V       OGI.V  \
# Adjustments To Net Income                    662.074518    4.498755
# Capital Expenditure                           -0.100464    6.501481
# Change In Cash and Cash Equivalents        -1121.603878  -13.487009
# Changes In Accounts Receivables              -20.179934   -1.646105
# Changes In Inventories                         3.844734   32.969358
# Changes In Liabilities                        10.999984   24.958945
# Changes In Other Operating Activities          9.498787  243.146781
# Depreciation                                   2.043511    7.505283
# Effect Of Exchange Rate Changes               -8.445500         NaN
# Investments                                   -0.105545    0.888035
# Net Borrowings                                -2.186061   22.520098
# Net Income                                    14.461042  -17.065267
# Other Cash Flows from Financing Activities    53.902047   60.437743
# Other Cash flows from Investing Activities          NaN   37.050163
# Total Cash Flow From Operating Activities      7.167781    3.582620
# Total Cash Flows From Financing Activities    34.668745   26.126576
# Total Cash Flows From Investing Activities     8.799707   12.026006
#
#                                                FIRE.TO    VFF.TO       WMD.V  \
# Adjustments To Net Income                    -1.358314 -0.652582    1.404317
# Capital Expenditure                          16.768763  0.490602  118.208417
# Change In Cash and Cash Equivalents           2.240111 -4.499275    0.827354
# Changes In Accounts Receivables            -452.877835 -2.916667 -136.178933
# Changes In Inventories                       -0.000000 -4.509014   14.586814
# Changes In Liabilities                      -89.488279 -1.490129   44.149449
# Changes In Other Operating Activities         4.137912 -3.622222  194.442165
# Depreciation                                 29.151381 -0.151841    7.627170
# Effect Of Exchange Rate Changes                    NaN -0.928571         NaN
# Investments                                   9.124698       NaN    0.619117
# Net Borrowings                               25.760517 -0.824208         NaN
# Net Income                                    0.268402 -3.457020   -0.653243
# Other Cash Flows from Financing Activities         NaN  0.067108  -42.055982
# Other Cash flows from Investing Activities         NaN -0.000000         NaN
# Total Cash Flow From Operating Activities    -1.412174 -1.307410   -0.200530
# Total Cash Flows From Financing Activities   11.215060 -4.103438  601.346979
# Total Cash Flows From Investing Activities   20.060857  5.501205   33.543400
#
#                                                  FAF.TO
# Adjustments To Net Income                     27.946939
# Capital Expenditure                           13.582421
# Change In Cash and Cash Equivalents            0.447920
# Changes In Accounts Receivables                3.050453
# Changes In Inventories                        -0.000000
# Changes In Liabilities                        17.523346
# Changes In Other Operating Activities          5.231380
# Depreciation                                1840.940711
# Effect Of Exchange Rate Changes                     NaN
# Investments                                         NaN
# Net Borrowings                                20.077932
# Net Income                                    16.551993
# Other Cash Flows from Financing Activities    49.495513
# Other Cash flows from Investing Activities          NaN
# Total Cash Flow From Operating Activities      8.046142
# Total Cash Flows From Financing Activities     4.675065
# Total Cash Flows From Investing Activities    14.946487

# %%
portfolio.balance_sheet(APHA.bs_list)

# %%
portfolio.balance_sheet.dropna(how='all')
# Out:
#                                   APHA.TO        ACB.TO       TRST.TO  \
# Accounts Payable                82.548100     34.588783  2.284943e+01
# Capital Surplus                       NaN           NaN           NaN
# Cash And Cash Equivalents       32.437032    281.387693  2.352770e+00
# Common Stock                    39.454526    127.263444  2.997448e+01
# Goodwill                       557.205000           NaN           NaN
# Intangible Assets               89.802468    869.383775           NaN
# Inventory                       42.817890   1699.775316  1.632766e+01
# Long Term Debt                        NaN     86.483988 -4.097454e-01
# Long Term Investments           46.579157           NaN  1.156328e+07
# Net Receivables                 33.994879     23.028766  6.733408e+01
# Net Tangible Assets             20.794347    160.213228 -1.926565e+01
# Other Assets                          NaN     73.347845  3.000000e+00
# Other Current Assets            29.169184           NaN           NaN
# Other Current Liabilities             NaN           NaN           NaN
# Other Liabilities                     NaN           NaN -1.051273e-01
# Other Stockholder Equity        14.456792      0.172450  9.314370e+00
# Property, plant and equipment   67.940051     22.157747  1.055239e+01
# Retained Earnings               -2.454519     -8.736708  1.945631e+00
# Short Term Investments                NaN  39457.666667  2.090797e+02
# Short/Current Long Term Debt          NaN      0.741801           NaN
# Total Assets                    66.298593    140.255962  1.680129e+01
# Total Current Assets            34.665878    206.145989  2.101322e+01
# Total Current Liabilities      108.392716      9.154957  5.622102e+00
# Total Liabilities              558.371082     34.856379  3.357385e-01
# Total stockholders' equity      47.688200    405.638732 -1.949949e+01
# Treasury Stock                  14.456792      0.172450  9.314370e+00
#
#                                   WEED.TO    CRON.TO         EMH.V  \
# Accounts Payable                31.255421   0.684558     50.468657
# Capital Surplus                       NaN        NaN      4.325537
# Cash And Cash Equivalents      160.124245  27.947789    439.418520
# Common Stock                    44.976640  14.236671     65.556385
# Goodwill                        72.998610   3.571429           NaN
# Intangible Assets               14.954920   5.972330  65764.099468
# Inventory                       11.414647        NaN     44.953334
# Long Term Debt                 241.795907        NaN           NaN
# Long Term Investments                 NaN  -0.522832           NaN
# Net Receivables                 70.987887        NaN    393.178714
# Net Tangible Assets             68.476540  19.464542   -202.963178
# Other Assets                    80.967662        NaN     75.081366
# Other Current Assets                  NaN        NaN           NaN
# Other Current Liabilities      145.283302  71.811791     22.367738
# Other Liabilities               25.524007  19.441026           NaN
# Other Stockholder Equity       261.670062   5.561154           NaN
# Property, plant and equipment   23.758700  62.666021     66.214258
# Retained Earnings               55.412849   3.519950      7.584642
# Short Term Investments                NaN        NaN           NaN
# Short/Current Long Term Debt   186.551537        NaN           NaN
# Total Assets                    59.907813  16.734429    267.197909
# Total Current Assets           112.056683  52.109784    196.606228
# Total Current Liabilities       56.231058  18.550140     29.526837
# Total Liabilities               75.131845  15.372981     29.774868
# Total stockholders' equity      55.158929  17.074399   -413.633041
# Treasury Stock                 261.670062   5.561154           NaN
#
#                                       N.V      OGI.V     FIRE.TO     VFF.TO  \
# Accounts Payable                 5.183492   6.356886  155.509298   0.648527
# Capital Surplus                 49.683905        NaN         NaN   0.836257
# Cash And Cash Equivalents      687.080816  36.364609   97.033914   1.404680
# Common Stock                    57.496996   8.418175    4.914680   1.444364
# Goodwill                         6.676059        NaN         NaN        NaN
# Intangible Assets                9.335197        NaN    0.000000        NaN
# Inventory                        5.114378  27.444410         NaN   0.378483
# Long Term Debt                        NaN  20.587166   38.184383  -0.269717
# Long Term Investments                 NaN        NaN         NaN        NaN
# Net Receivables                 21.796210   3.872272  198.130679   1.351029
# Net Tangible Assets            -72.147014  22.502788   25.346205   0.600102
# Other Assets                          NaN        NaN   30.801437   0.451019
# Other Current Assets                  NaN        NaN         NaN  37.807339
# Other Current Liabilities       -0.748339        NaN         NaN        NaN
# Other Liabilities               -0.417056        NaN         NaN  -0.511995
# Other Stockholder Equity        30.897875  31.074057    8.911243  -7.244186
# Property, plant and equipment         NaN   9.292719   10.306050  -0.178247
# Retained Earnings               34.104364  -1.078153    1.845164  -0.095264
# Short Term Investments                NaN        NaN         NaN        NaN
# Short/Current Long Term Debt          NaN   0.478682         NaN  -0.221969
# Total Assets                    27.457225  20.343433    9.837296   0.229252
# Total Current Assets            70.254461  43.246780   66.617597   0.813267
# Total Current Liabilities        4.575272   5.436545    4.675366   0.425414
# Total Liabilities                2.045008  17.660753   10.271516  -0.118666
# Total stockholders' equity      64.000176  22.502788    9.682381   0.600102
# Treasury Stock                  30.897875  31.074057    8.911243  -7.244186
#
#                                     WMD.V      FAF.TO      Averages
# Accounts Payable               171.053210   21.921687  4.858900e+01
# Capital Surplus                  7.865299    8.648691  1.427194e+01
# Cash And Cash Equivalents       24.016993    1.737504  1.492755e+02
# Common Stock                     9.686686    2.863668  3.385723e+01
# Goodwill                              NaN         NaN  1.601128e+02
# Intangible Assets                     NaN  155.229962  8.363597e+03
# Inventory                             NaN         NaN  2.310283e+02
# Long Term Debt                        NaN         NaN  6.439533e+01
# Long Term Investments                 NaN         NaN  3.854442e+06
# Net Receivables                 15.508853    6.306033  7.595358e+01
# Net Tangible Assets             28.433858    3.225553  4.556777e+00
# Other Assets                          NaN    7.423204  3.872465e+01
# Other Current Assets            19.234496  447.808541  1.335049e+02
# Other Current Liabilities        0.996352         NaN  4.794217e+01
# Other Liabilities                     NaN         NaN  8.786171e+00
# Other Stockholder Equity              NaN   97.228786  4.520426e+01
# Property, plant and equipment   23.996375   17.710983  2.858337e+01
# Retained Earnings                2.088792   21.062393  9.599928e+00
# Short Term Investments                NaN         NaN  1.983337e+04
# Short/Current Long Term Debt          NaN         NaN  4.688751e+01
# Total Assets                    27.454947   12.089246  5.538395e+01
# Total Current Assets            27.047162   10.226676  7.006698e+01
# Total Current Liabilities       21.469432   83.055670  2.892629e+01
# Total Liabilities               21.469432   83.745445  7.074303e+01
# Total stockholders' equity      28.576722    3.891897  1.847348e+01
# Treasury Stock                        NaN   97.228786  4.520426e+01

# %%
portfolio.financials(APHA.fin_list)

# %%
portfolio.financials.dropna(how='all')
# Out:
#                                            APHA.TO     ACB.TO    TRST.TO  \
# Total Revenue                            27.113825        NaN  73.979537
# Cost of Revenue                          85.646060        NaN -76.149011
# Gross Profit                             10.483374        NaN  48.953078
# Research Development                      5.311023   2.883122        NaN
# Selling General and Administrative       18.087969  25.260159   7.447597
# Total Operating Expenses                 30.598945  29.982035   9.505993
# Operating Income or Loss                 57.548898  17.343204   0.927109
# Total Other Income/Expenses Net         166.042013 -30.378225   0.471751
# Earnings Before Interest and Taxes       57.548898  17.343204   0.927109
# Interest Expense                         19.090439  43.388342   1.323275
# Income Before Tax                        18.506533  -8.950482   0.777224
# Income Tax Expense                       -1.711667 -39.997054        NaN
# Minority Interest                         1.965449   0.000000        NaN
# Net Income From Continuing Ops          -42.458836  -8.272990   0.987342
# Discontinued Operations                        NaN        NaN        NaN
# Net Income                              -42.458836  -8.557597   1.113002
# Net Income Applicable To Common Shares  -42.458836  -8.557597   1.113002
#
#                                             WEED.TO    CRON.TO       EMH.V  \
# Total Revenue                             16.823529   3.612014   61.267777
# Cost of Revenue                          -22.856370   3.930616    9.886208
# Gross Profit                               3.683978   3.497627    0.566335
# Research Development                      20.134535   0.000000    3.936981
# Selling General and Administrative        22.342444  10.068383   12.114529
# Total Operating Expenses                  54.645716  10.429725   10.162283
# Operating Income or Loss                 419.064492 -41.542810    9.703924
# Total Other Income/Expenses Net           49.746101   1.626656 -752.480730
# Earnings Before Interest and Taxes       419.064492 -41.542810    9.703924
# Interest Expense                         130.535714        NaN   24.921973
# Income Before Tax                        194.185757 -87.984003    7.866061
# Income Tax Expense                        96.761905  -3.859649         NaN
# Minority Interest                      -9057.718750   0.000000         NaN
# Net Income From Continuing Ops           190.674485 -50.732498    7.859310
# Discontinued Operations                         NaN        NaN         NaN
# Net Income                               195.063501 -50.123952    7.743072
# Net Income Applicable To Common Shares   195.063501 -50.123952    7.743072
#
#                                               N.V       OGI.V   FIRE.TO  \
# Total Revenue                            4.456248   11.596840       NaN
# Cost of Revenue                          5.131281  117.022686       NaN
# Gross Profit                             3.029381   38.586423       NaN
# Research Development                          NaN         NaN       NaN
# Selling General and Administrative      10.076463    4.319953  2.058721
# Total Operating Expenses                 8.211681  -12.179441  1.869415
# Operating Income or Loss                14.681654  -32.421301  0.260953
# Total Other Income/Expenses Net         13.736762   72.277069 -2.188629
# Earnings Before Interest and Taxes      14.681654  -32.421301  0.260953
# Interest Expense                              NaN   86.465881  7.706708
# Income Before Tax                       14.625806  -22.754249  0.139433
# Income Tax Expense                            NaN         NaN       NaN
# Minority Interest                        0.915072         NaN       NaN
# Net Income From Continuing Ops          14.468929  -18.326961  0.268402
# Discontinued Operations                       NaN   20.197368       NaN
# Net Income                              14.461042  -17.065267  0.268402
# Net Income Applicable To Common Shares  14.461042  -17.065267  0.268402
#
#                                           VFF.TO      WMD.V       FAF.TO  \
# Total Revenue                           0.056829        NaN          NaN
# Cost of Revenue                         0.117697        NaN          NaN
# Gross Profit                           -0.433346        NaN          NaN
# Research Development                         NaN        NaN          NaN
# Selling General and Administrative      0.291881  13.271577    12.053755
# Total Operating Expenses                0.132869   9.448032    14.921977
# Operating Income or Loss               -2.838656   4.952278     8.865904
# Total Other Income/Expenses Net        -0.650982 -12.869718  1605.492621
# Earnings Before Interest and Taxes     -2.838656   4.952278     8.865904
# Interest Expense                        0.204787   0.013534   184.514759
# Income Before Tax                      -9.167203  -0.653243    16.551993
# Income Tax Expense                      1.131783        NaN          NaN
# Minority Interest                            NaN        NaN          NaN
# Net Income From Continuing Ops         -3.457020  -0.653243    16.551993
# Discontinued Operations                      NaN        NaN          NaN
# Net Income                             -3.457020  -0.653243    16.551993
# Net Income Applicable To Common Shares -3.457020  -0.653243    16.551993
#
#                                            Averages
# Total Revenue                             24.863325
# Cost of Revenue                           15.341146
# Gross Profit                              13.545856
# Research Development                       6.453132
# Selling General and Administrative        11.449453
# Total Operating Expenses                  13.977436
# Operating Income or Loss                  38.045471
# Total Other Income/Expenses Net           92.568724
# Earnings Before Interest and Taxes        38.045471
# Interest Expense                          49.816541
# Income Before Tax                         10.261969
# Income Tax Expense                        10.465064
# Minority Interest                      -1810.967646
# Net Income From Continuing Ops             8.909076
# Discontinued Operations                   20.197368
# Net Income                                 9.407091
# Net Income Applicable To Common Shares     9.407091

# %%
GP = DataFrame(portfolio.financials.dropna(how='all').T.sort_values('Gross Profit', ascending=False)['Gross Profit'])
statistics_df = portfolio.statistics.dropna(how='all').T.sort_values("Diluted EPS (ttm)", ascending=False)[['Diluted EPS (ttm)', 'EBITDA', 'Levered Free Cash Flow (ttm)', 'Beta (3Y Monthly)', 'Profit Margin']]
Debt = portfolio.balance_sheet.dropna(how='all').T.sort_values('Long Term Debt', ascending=False)['Long Term Debt']
NI = portfolio.cashflow.dropna(how='all').T.sort_values("Net Income", ascending=False)['Net Income']
pandas.concat([statistics_df, NI, Debt, GP], axis=1, sort=True).sort_values('Profit Margin', ascending=False)
# Out:
#           Diluted EPS (ttm)      EBITDA  Levered Free Cash Flow (ttm)  \
# WMD.V              0.108000    3.430000                    -75.670000
# VFF.TO             0.310000   -9.140000                    -12.050000
# WEED.TO           -6.220000 -573.270000                           NaN
# APHA.TO           -0.070000  -41.080000                   -230.630000
# TRST.TO           -0.121000    1.280000                    -75.770000
# FIRE.TO           -0.051000   -9.220000                   -101.400000
# Averages          -0.593909  -88.581818                   -158.468571
# ACB.TO            -0.250000 -205.820000                   -558.700000
# N.V               -0.145000  -38.270000                           NaN
# FAF.TO            -0.646000  -22.900000                           NaN
# EMH.V             -0.158000  -44.630000                    -55.060000
# CRON.TO            0.710000  -34.780000                           NaN
# OGI.V                   NaN         NaN                           NaN
#
#           Beta (3Y Monthly)  Profit Margin  Net Income  Long Term Debt  \
# WMD.V                 2.740          77.37   -0.653243             NaN
# VFF.TO                5.140          10.43   -3.457020       -0.269717
# WEED.TO               5.400           0.00  195.063501      241.795907
# APHA.TO               3.700          -6.96  -42.458836             NaN
# TRST.TO               4.620         -22.31    1.113002       -0.409745
# FIRE.TO               4.230         -52.48    0.268402       38.184383
# Averages              3.842         -87.72         NaN       64.395330
# ACB.TO                2.760        -125.35   -8.557597       86.483988
# N.V                   3.480        -227.18   14.461042             NaN
# FAF.TO                  NaN        -232.65   16.551993             NaN
# EMH.V                 2.280        -298.07    7.743072             NaN
# CRON.TO               4.070            NaN  -50.123952             NaN
# OGI.V                   NaN            NaN  -17.065267       20.587166
#
#           Gross Profit
# WMD.V              NaN
# VFF.TO       -0.433346
# WEED.TO       3.683978
# APHA.TO      10.483374
# TRST.TO      48.953078
# FIRE.TO            NaN
# Averages     13.545856
# ACB.TO             NaN
# N.V           3.029381
# FAF.TO             NaN
# EMH.V         0.566335
# CRON.TO       3.497627
# OGI.V        38.586423
