# %%
from news_updates.news_sources_v3 import News
import time

# %%
pwd
# Out:
# 'C:\\Users\\rayde\\iCloudDrive\\GitHub'

# %%
search = ['Protect-Canada-TSX-Stocks-Retirement']

# %%
start_time = time.time()
Weed = News(search[0])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 78.29703116416931 seconds ---

# %%
Weed

# %%
len(Weed.links)
# Out:
# 20

# %%
arts = Weed.art_list

for each in arts:
    if each.summary == ' ':
        print(each.index)
    else:
        pass

# %%
len(arts)
# Out:
# 20

# %%
for each in arts:
    print(each.title, each.authors, '\n', each.summary, '\n' + '-'*100)
# Out:
# Retire Rich: Add These Stocks to Become a Dividend Millionaire []
#  The Motley Fool Canada » Bank Stocks » Retire Rich: Add These Stocks to Become a Dividend MillionaireEveryone wants to be free from financial worries when their golden retirement years arrive.
# One of the best ways to generate cash is by purchasing dividend stocks.
# Luckily, there are some stocks that make excellent income stocks for retirement that are not quite as expensive as the electrical utilities and telecoms.
# Nevertheless, the historical performance of the Canadian banks and their relatively steady dividend increases should be enough to comfort investors focusing on steady retirement income.
# Start buying today, and you will have strong, steady income to live a millionaire for years to come.
# ----------------------------------------------------------------------------------------------------
# How to Prepare Your TFSA for a Market Downturn []
#  The Motley Fool Canada » Investing » How to Prepare Your TFSA for a Market DownturnA lot of investors seem to go into panic mode before a potential recession.
# Despite having dozens of recessions in the last 100 years, investors still seem to be at a loss of what to do before a market downturn.
# A great option to consider is Fortis (TSX:FTS)(NYSE:FTS), a utilities company tied to 99% regulated assets, meaning there shouldn’t be too many surprises in this company’s future.
# Even during the last recession, the company increased its dividend yield, which sits at 3.29% as of writing.
# Foolish takeawayIf you’re looking for a strong portfolio to take you through any major economic downturn, I would strongly consider these two stocks.
# ----------------------------------------------------------------------------------------------------
# TFSA Investors: Don’t Miss Out on These Tax-Free Benefits []
#  The Motley Fool Canada » Bank Stocks » TFSA Investors: Don’t Miss Out on These Tax-Free BenefitsA new survey released by Royal Bank of Canada shows that Canadians fail to properly invest in mutual funds, stocks, and exchange-traded funds.
# Primarily, Tax-Free Savings Account (TFSA) investors mostly use their TFSAs to store savings rather than invest in high-return assets.
# The survey found that 42% of TFSA savings do not take advantage of tax-free returns because they are not earning interest from dividend stocks.
# Don’t be one of the four in 10 Canadians who believe that TFSAs are for savings and not tax-free income generation.
# Remember that the dividend returns are tax-free, and they represent the interest earned on your investment.
# ----------------------------------------------------------------------------------------------------
# TFSA Investors: Double Your Savings With These 3 Dividend-Growth Stocks []
#  The Motley Fool Canada » Bank Stocks » TFSA Investors: Double Your Savings With These 3 Dividend-Growth StocksTax-Free Savings Accounts (TFSAs) are among the best accounts available for holding income investments.
# Although RRSPs are generally better for long-term retirement savings, TFSAs are the absolute best option for building dividend income for use in the near future.
# Right now, the TSX abounds with dividend stocks that can reward you richly in your TFSA.
# With that in mind, here are three dividend stocks that could easily double your savings and give you a steady income stream to boot.
# In addition to delivering solid dividend income, TD has also had a pretty good run in terms of capital gains, rising 13% in the past year.
# ----------------------------------------------------------------------------------------------------
# 3 Super Stocks for RRSP Retirement Savers []
#  The Motley Fool Canada » Bank Stocks » 3 Super Stocks for RRSP Retirement SaversIf you’re saving for retirement, it pays to get as much money as possible into RRSPs.
# While you do pay taxes on RRSP withdrawals, you’ll save net-tax if you’re in a low tax bracket when you retire.
# In addition to having one, you also need to make sure you’re picking the right investments in it.
# With that in mind, here are three stocks that align well with the goal of long-term RRSP investing.
# The bank also has a huge investment in TD Ameritrade, which is growing earnings at 27% year-over-year.
# ----------------------------------------------------------------------------------------------------
# Every Retiree Should Know These Stocks []
#  The Motley Fool Canada » Dividend Stocks » Every Retiree Should Know These StocksRetirement should be enjoyable, but most people still need to keep a close watch on their finances.
# With that in mind, it’s necessary to know which stocks can give you the best of both worlds: limited volatility with plenty of upside.
# Fairfax Financial Holdings (TSX:FFH) is one of those stocks.
# Today, Fairfax Financial is still headed by Prem Watsa, largely regarded as the Warren Buffett of Canada.
# In several stock market crashes over recent decades, Fairfax Financial has outperformed the market.
# ----------------------------------------------------------------------------------------------------
# TFSA Investors: This Bank Stock Will Soar on Rising Dividends []
#  The Motley Fool Canada » Bank Stocks » TFSA Investors: This Bank Stock Will Soar on Rising DividendsCanadian investors should be on the lookout for reliable dividend payers like Canadian Imperial Bank of Commerce (TSX:CM)(NYSE:CM) during this bear market.
# Savvy investors who value high dividends and steady stock prices will want to increase their holdings of bank stocks.
# Tax-Free Savings Account (TFSA) or Registered Retirement Savings Plan (RRSP) investors should feel comfortable entrusting their long-term savings to Canadian banks.
# Well-capitalized banks are a relief for informed investors worried about financial market turbulence and falling asset prices.
# It might be terrifying to see stock prices fluctuating and hear the news media talk about financial market disruptions.
# ----------------------------------------------------------------------------------------------------
# 3 TSX Index Stocks With Dividend Yields Higher Than 5% []
#  The Motley Fool Canada » Bank Stocks » 3 TSX Index Stocks With Dividend Yields Higher Than 5%The stock market can be a volatile place.
# In this environment, dividend stocks are an oasis in the desert.
# If you’re looking for solid stocks with high and dependable dividend income, the following three may fit the bill.
# RioCan has faced some criticism over the years for its focus on retail space.
# There’s a general perception that e-commerce is going to gradually kill or curb the growth of retail stores, and many of RioCan’s top properties cater to such outlets.
# ----------------------------------------------------------------------------------------------------
# Why this portfolio manager is selling Canadian stocks []
#  Facebook Users Revive Lawsuit Over Cambridge Analytica ScandalFour Facebook Inc. users revived a lawsuit against the social media company, claiming it invaded their privacy and violated its terms of service by selling their data to Cambridge Analytica and more than 150 other companies.
# ----------------------------------------------------------------------------------------------------
# Millionaire Wannabes: Turn Your TFSA Into $1,000,000 []
#  The Motley Fool Canada » Bank Stocks » Millionaire Wannabes: Turn Your TFSA Into $1,000,000The best years to save for retirement or the future are when you’re between the ages of 20 and 30.
# It’s only been a decade since the government introduced the Tax-Free Savings Account (TFSA).
# Stock for the wannabe millionaireThere is wisdom in investing in a bank stock like Laurentian (TSX:LB).
# The stock pays an annual dividend yield of 5.9%, which is higher than the dividend yield paid out by the bigger banks.
# Laurentian Bank can turn an average portfolio into a very profitable one.
# ----------------------------------------------------------------------------------------------------
# Overseas shopping spree by pension funds protects Canada’s AAA rating ['Esteban Duarte']
#  Canada’s trove of overseas assets, including airports and roads owned by pension funds, is helping to protect the country’s top credit rating, according to Fitch Ratings.
# The current account includes trade in goods and services, as well as net earnings on cross-border investments and transfer payments.
# Pension funds such as the Canada Pension Plan Investment Board and the Caisse de dépôt et placement du Québec are playing a key role in bolstering Canada’s presence abroad.
# Almost two-thirds of the Caisse’s $309.5 billion of assets at the end of last year were invested outside of Canada.
# Also, the country’s net international investment position declined by $109.1 billion in the last quarter after reaching record $637.7 billion at the end September, according to government data.
# ----------------------------------------------------------------------------------------------------
# Why investors need to be concerned about misleading risk ratings ['Follow Tim Shufelt On Twitter', 'Tim Shufelt']
#  A 0A +2A +4A +6The subject who is truly loyal to the Chief Magistrate will neither advise nor submit to arbitrary measures.
# ----------------------------------------------------------------------------------------------------
# TFSA Investors: 2 Costly Mistakes You’ll Want to Avoid! []
#  The Motley Fool Canada » Bank Stocks » TFSA Investors: 2 Costly Mistakes You’ll Want to Avoid!
# A TFSA account can be a great way for investors to save for retirement.
# However, there are some important limitations that investors need to be aware of, because treating a TFSA as a normal investing account could prove costly down the road.
# Below, I’ll go over two potentially expensive mistakes that TFSA investors could make and how to avoid them.
# The problem is that it’s ultimately up to the courts to decide if your trading activities are considered business income or not.
# ----------------------------------------------------------------------------------------------------
# How high household debt could be good for your dividend portfolio, anger builds over fund fees, and bets against TSX stocks ['Follow Us On Twitter']
#  Every hike in borrowing costs would result in more mortgage defaults for households already struggling with high debt loads.
# Do you have a couple of other balanced funds that you like and recommend that I could invest in along with the Mawer fund?
# The asset allocation is about the same as the Mawer fund (60 per cent equities, 40 per cent bonds and cash).
# For example, the Dynamic fund has more than a third of its portfolio (36.6 per cent) invested in information technology stocks.
# Clearly, the Dynamic fund is higher risk but when it does well it can shoot out the lights.
# ----------------------------------------------------------------------------------------------------
# Investment Product and Service Launches []
#  Ascensus Partners with NextCapital for Investment and Fiduciary SolutionsAscensus is implementing NextCapital’s technology platform to provide better investment and fiduciary solutions at the institutional and participant levels.
# Russell Investments will become the first firm to provide participant-level 3(38) protection for its personalized retirement accounts (PRAs) utilizing the NextCapital technology.
# Third parties, including financial advisers and Ascensus’ key distribution partners, can customize the NextCapital platform and assume the role of the fiduciary.
# Axioma Releases Canadian Risk Model to Suite of FundsAxioma has added a new Canada equity risk model (AXCA4) to its next-generation Equity Factor Risk Model suite.
# “There are notable differences in the behavior of factors in the Canadian market,” says Melissa Brown, head of Applied Research at Axioma.
# ----------------------------------------------------------------------------------------------------
# 2 Insurance Stocks to Protect Your Retirement []
#  The Motley Fool Canada » Investing » 2 Insurance Stocks to Protect Your RetirementInvestors interested in protecting retirement savings from inflation should consider insurance stocks on the Toronto Stock Exchange.
# On average, insurance stocks yielded a total return of 28% last year, including dividends and capital gains.
# Two top TSX insurance stocks in particular are shaking up the industry: Power Corporation of Canada (TSX:POW) and Manulife Financial (TSX:MFC)(NYSE:MFC).
# In the insurance sector, Power boasts recognizable life insurance assets such as Great-West Lifeco, London Life Insurance Company, and Irish Life Group Limited.
# The insurance industry is heating upThe insurance industry is heating up in a favourable macroeconomic environment, and these two giants offer the most value in terms of earnings per share.
# ----------------------------------------------------------------------------------------------------
# Retirees: Boost Your RRSP Payments the Easy Way []
#  The Motley Fool Canada » Bank Stocks » Retirees: Boost Your RRSP Payments the Easy WayAre you a soon-to-be retiree who has been building RRSP assets and thinking about ways to maximize your payments when the big day arrives?
# So, with the most obvious option for boosting your RRSP payments out of the question, what are you to do?
# Diversify with growth stocks and blue-chip dividend stocksIf you really want to boost your RRSP payments, you need to contribute as much as possible and then maximize your returns.
# One of the best ways to get such a mix is to diversify with growth stocks and blue-chip dividend stocks.
# Those kinds of results can really increase your eventual RRSP payments.
# ----------------------------------------------------------------------------------------------------
# Is This Divisive Stock the Best Play on the TSX? []
#  The Motley Fool Canada » Energy Stocks » Is This Divisive Stock the Best Play on the TSX?
# Uranium stocks on the U.S. markets took a turn for the worse, while Cameco sat pretty on the TSX.
# With a host of reactors slated to come online and a range of other uses for the alternative fuel source drawing renewed interest to the sector, investors could clean up.
# Uranium stocks are in an unusual position which could end up protecting them from the worst effects of a recession.
# Because the generation of nuclear energy relies on pre-existing stockpiles, prices of uranium won’t have much of an effect on mining companies’ bottom lines.
# ----------------------------------------------------------------------------------------------------
# Gold rally energized Canadian stocks even before Ray Dalio's essay ['Aoyon Ashraf']
#  Investors in Canadian gold stocks are way ahead of him.
# Gold producers have been on a tear in Canada, keeping the benchmark S&P/TSX Composite Index near its all-time high.
# The gold firms have taken the reins from technology and pot stocks, which were the drivers earlier this year.
# The S&P/TSX had been rising out of an ugly trough reached in December, in part thanks to Shopify Inc.’s (SHOP.TO) gravity-defying rally and several high-flying pot stocks.
# And materials stocks, which were the worst performers year-to-date until the end of May, are now among the top five.
# ----------------------------------------------------------------------------------------------------
# TFSA Investors: How You Can Earn $500/Month With Less Than $100k []
#  The Motley Fool Canada » Dividend Stocks » TFSA Investors: How You Can Earn $500/Month With Less Than $100kThere are a few reasons why every Canadian should be aggressively saving inside their TFSAs.
# This is very possible, especially if you invest your TFSA into some of Canada’s top dividend stocks.
# Capital PowerIt seems like Capital Power Corporation (TSX:CPX) isn’t really a big deal outside of its Edmonton home base, which is a shame.
# A few years ago, Alberta’s newly-elected government made the decision to phase out all coal-fired power plants from the province by 2030.
# As one of the largest owners of these power plants, Capital Power was hit hard.
# ----------------------------------------------------------------------------------------------------

# %%
keywords = set()
for each in arts:
    for i in each.keywords:
        keywords.add(i)

# %%
for each in keywords:
    print(each + ",")
# Out:
# quarter,
# 1000000,
# ascensus,
# dynamic,
# yield,
# play,
# debt,
# market,
# longterm,
# household,
# strong,
# canadians,
# avoid,
# index,
# good,
# steady,
# power,
# retirees,
# banks,
# costly,
# sptsx,
# company,
# concerned,
# oil,
# soar,
# likely,
# arbitrary,
# rally,
# tfsas,
# factors,
# recession,
# youll,
# pot,
# stores,
# cent,
# millionaire,
# technology,
# pension,
# way,
# benefits,
# misleading,
# rich,
# quite,
# silver,
# energized,
# nuclear,
# globe,
# returns,
# earnings,
# rrsp,
# dividendgrowth,
# retail,
# owns,
# cambridge,
# submit,
# fiduciary,
# investors,
# manager,
# measures,
# 6the,
# dividend,
# banking,
# fund,
# violated,
# worst,
# advise,
# easy,
# international,
# rising,
# 500month,
# launches,
# invest,
# retiree,
# sector,
# dont,
# canada,
# retirement,
# downturn,
# boost,
# rates,
# youre,
# fees,
# product,
# nextcapital,
# huge,
# mawer,
# savings,
# prepare,
# economy,
# dalios,
# theres,
# overseas,
# financial,
# users,
# energy,
# capital,
# magistrate,
# plants,
# rating,
# need,
# lawsuit,
# payments,
# turn,
# high,
# value,
# business,
# facebook,
# insurance,
# funds,
# know,
# higher,
# uranium,
# portfolio,
# terms,
# assets,
# ray,
# north,
# income,
# tsx,
# ratings,
# life,
# canadian,
# savers,
# worth,
# growth,
# cameco,
# pipelines,
# net,
# double,
# watsa,
# looking,
# yields,
# shares,
# shopify,
# best,
# investment,
# taxfree,
# model,
# solutions,
# manulife,
# divisive,
# super,
# growing,
# investments,
# shopping,
# protect,
# earn,
# loyal,
# dividends,
# social,
# prices,
# trading,
# account,
# canadas,
# stock,
# truly,
# protects,
# potentially,
# materials,
# spree,
# retire,
# interest,
# subject,
# gold,
# industry,
# tfsa,
# analytica,
# 100k,
# wannabes,
# mistakes,
# cibc,
# chief,
# essay,
# fairfax,
# countrys,
# selling,
# laurentian,
# risk,
# tax,
# billion,
# pays,
# miss,
# utilities,
# space,
# stocks,
# td,
# add,
# service,
# bank,
# advice,
# aaa,

# %%
search = ['Brookfield-Property-Partners']

# %%
start_time = time.time()
Weed = News(search[0])
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 53.3295578956604 seconds ---

# %%
Weed

# %%
arts = Weed.art_list

for each in arts:
    if each.summary == ' ':
        print(each.index)
    else:
        pass

# %%
for each in keywords:
    print(each + ",")
# Out:
# quarter,
# 1000000,
# ascensus,
# dynamic,
# yield,
# play,
# debt,
# market,
# longterm,
# household,
# strong,
# canadians,
# avoid,
# index,
# good,
# steady,
# power,
# retirees,
# banks,
# costly,
# sptsx,
# company,
# concerned,
# oil,
# soar,
# likely,
# arbitrary,
# rally,
# tfsas,
# factors,
# recession,
# youll,
# pot,
# stores,
# cent,
# millionaire,
# technology,
# pension,
# way,
# benefits,
# misleading,
# rich,
# quite,
# silver,
# energized,
# nuclear,
# globe,
# returns,
# earnings,
# rrsp,
# dividendgrowth,
# retail,
# owns,
# cambridge,
# submit,
# fiduciary,
# investors,
# manager,
# measures,
# 6the,
# dividend,
# banking,
# fund,
# violated,
# worst,
# advise,
# easy,
# international,
# rising,
# 500month,
# launches,
# invest,
# retiree,
# sector,
# dont,
# canada,
# retirement,
# downturn,
# boost,
# rates,
# youre,
# fees,
# product,
# nextcapital,
# huge,
# mawer,
# savings,
# prepare,
# economy,
# dalios,
# theres,
# overseas,
# financial,
# users,
# energy,
# capital,
# magistrate,
# plants,
# rating,
# need,
# lawsuit,
# payments,
# turn,
# high,
# value,
# business,
# facebook,
# insurance,
# funds,
# know,
# higher,
# uranium,
# portfolio,
# terms,
# assets,
# ray,
# north,
# income,
# tsx,
# ratings,
# life,
# canadian,
# savers,
# worth,
# growth,
# cameco,
# pipelines,
# net,
# double,
# watsa,
# looking,
# yields,
# shares,
# shopify,
# best,
# investment,
# taxfree,
# model,
# solutions,
# manulife,
# divisive,
# super,
# growing,
# investments,
# shopping,
# protect,
# earn,
# loyal,
# dividends,
# social,
# prices,
# trading,
# account,
# canadas,
# stock,
# truly,
# protects,
# potentially,
# materials,
# spree,
# retire,
# interest,
# subject,
# gold,
# industry,
# tfsa,
# analytica,
# 100k,
# wannabes,
# mistakes,
# cibc,
# chief,
# essay,
# fairfax,
# countrys,
# selling,
# laurentian,
# risk,
# tax,
# billion,
# pays,
# miss,
# utilities,
# space,
# stocks,
# td,
# add,
# service,
# bank,
# advice,
# aaa,
