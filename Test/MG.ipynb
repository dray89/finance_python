# %%
from finance_python.stock import stock
from finance_python.industry import industry
import sys, os, time
import numpy as np
import pandas
from datetime import datetime, date, timedelta
from pandas import DataFrame

# %%
symbols = ['MG.TO']
start = date.today() - timedelta(days=365)
end = date.today()

# %%
stock_loop = lambda x: stock(x, start, end)

# %%
timer_start = time.time()

stocks = list(map(stock_loop, symbols))

timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 3.523660182952881

# %%
MG = stocks[0]

# %%
MG.description
# Out:
# 'Magna International Inc. designs, develops, and manufactures automotive systems, assemblies, modules, and components in North America, Europe, Asia Pacific, and internationally. The Body Exteriors  Structures segment provides body structures; chassis structures, such as frame and structural assemblies, chassis subframes, and suspension systems; exterior systems and modules, including hoods, roofs, door panels, front end modules, liftgate modules, polycarbonate roof panels, liftgate sensor integration systems, and fascia; trim and automotive jewelry comprises engineered glass, trim and roof racks, and running boards; non-visible and visible active grille shutters, active air deflectors, and underbody panels; and fuel systems, pipes and components, and alternative energy storage systems. Its Power  Vision segment offers manual, hybrid, and dual-clutch transmissions systems; mild hybrid solutions; high voltage edrives and electrified components; chassis, glow plug control, powertrain c
# ...

# %%
MG.sector
# Out:
# 'Auto Parts'

# %%
MG.price
# Out:
# 66.66

# %%
MG.dividends
# Out:
# [                                                Date       Dividends
#  0                                       Aug 22, 2019  0.485 Dividend
#  1                                       May 23, 2019  0.365 Dividend
#  2                                       Mar 07, 2019  0.365 Dividend
#  3                                       Nov 22, 2018   0.33 Dividend
#  4                                       Nov 21, 2018   0.33 Dividend
#  5  *Close price adjusted for splits.**Adjusted cl...             NaN]

# %%
MG.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()']]

# %%
MG.stats()

# %%
MG.statistics.dropna()
# Out:
#                                                   MG.TO
# Market Cap (intraday) 5                         2044.00
# Trailing P/E                                       8.57
# Price/Sales (ttm)                                  0.50
# Price/Book (mrq)                                   1.82
# Enterprise Value/Revenue 3                         0.64
# Enterprise Value/EBITDA 6                          6.25
# Beta (3Y Monthly)                                  1.66
# 52-Week Change 3                                  -5.97
# S&P500 52-Week Change 3                            0.96
# 52 Week High 3                                    76.11
# 52 Week Low 3                                     57.34
# 50-Day Moving Average 3                           64.49
# 200-Day Moving Average 3                          65.72
# Shares Outstanding 5                             322.36
# Float                                            309.06
# Shares Short (Aug 15, 2019) 4                      2.73
# ...

# %%
MG.balance()

# %%
MG.balance_sheet.dropna()
# Out:
# Period Ending                         12/31/2018  12/31/2017  12/31/2016  \
# MG.TO
# Cash And Cash Equivalents               684000.0    726000.0    974000.0
# Net Receivables                        6605000.0   6695000.0   6165000.0
# Inventory                              3403000.0   3542000.0   2804000.0
# Other Current Assets                    980000.0     60000.0     21000.0
# Total Current Assets                  11834000.0  11200000.0  10163000.0
# Long Term Investments                  2189000.0   2079000.0   1850000.0
# Property, plant and equipment          8095000.0   8176000.0   7022000.0
# Goodwill                               1979000.0   2099000.0   1923000.0
# Intangible Assets                       560000.0    650000.0    621000.0
# Other Assets                           1288000.0   1264000.0    987000.0
# Deferred Long Term Asset Charges        300000.0    238000.0    268000.0
# Total Assets                          25945000.0  25468000.0  22566000.0
# ...

# %%
MG.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list'],
#  ['balance_sheet', 'bs_list']]

# %%
MG.financial()

# %%
MG.financials.dropna()
# Out:
# Period Ending                           12/31/2018  12/31/2017  12/31/2016  \
# MG.TO
# Total Revenue                           40827000.0  36588000.0  36445000.0
# Cost of Revenue                         35055000.0  30895000.0  31123000.0
# Gross Profit                             5772000.0   5693000.0   5322000.0
# Selling General and Administrative       1664000.0   1668000.0   1601000.0
# Total Operating Expenses                37997000.0  33747000.0  33780000.0
# Operating Income or Loss                 2830000.0   2841000.0   2665000.0
# Total Other Income/Expenses Net           121000.0    144000.0    115000.0
# Earnings Before Interest and Taxes       2830000.0   2841000.0   2665000.0
# Interest Expense                         -113000.0    -90000.0   -100000.0
# Income Before Tax                        2951000.0   2985000.0   2780000.0
# Income Tax Expense                        619000.0    741000.0    706000.0
# ...

# %%
MG.cash()

# %%
MG.cashflow.dropna()
# Out:
# Period Ending                               12/31/2018  12/31/2017  \
# MG.TO
# Net Income                                   2296000.0   2196000.0
# Depreciation                                 1450000.0   1311000.0
# Adjustments To Net Income                     125000.0     52000.0
# Changes In Accounts Receivables              -351000.0   -292000.0
# Changes In Liabilities                        265000.0    512000.0
# Changes In Inventories                        -92000.0   -397000.0
# Changes In Other Operating Activities         111000.0     17000.0
# Total Cash Flow From Operating Activities    3718000.0   3346000.0
# Capital Expenditure                         -1650000.0  -1875000.0
# Investments                                  -701000.0   -651000.0
# Total Cash Flows From Investing Activities  -2276000.0  -2145000.0
# Dividends Paid                               -448000.0   -400000.0
# Net Borrowings                                867000.0    112000.0
# ...

# %%
MG.analyze()

# %%
MG.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list'],
#  ['balance_sheet', 'bs_list'],
#  ['financials', 'fin_list'],
#  ['cashflow', 'cash_list'],
#  ['earnings_est',
#   'revenue',
#   'earnings_history',
#   'eps_trend',
#   'eps_revisions',
#   'growth_estimates',
#   'a_list']]

# %%
MG.earnings_est
# Out:
#                    Current Qtr. (Dec 2018)  Next Qtr. (Mar 2019)  \
# Earnings Estimate
# No. of Analysts                       0.00                  0.00
# Avg. Estimate                         0.00                  0.00
# Low Estimate                          0.00                  0.00
# High Estimate                         0.00                  0.00
# Year Ago EPS                          1.57                  1.84
#
#                    Current Year (2018)  Next Year (2019)
# Earnings Estimate
# No. of Analysts                    0.0               0.0
# Avg. Estimate                      0.0               0.0
# Low Estimate                       0.0               0.0
# High Estimate                      0.0               0.0
# Year Ago EPS                       NaN               NaN

# %%
MG.revenue
# Out:
#                         Current Qtr. (Dec 2018) Next Qtr. (Mar 2019)  \
# Revenue Estimate
# No. of Analysts                               9                    6
# Avg. Estimate                             10.2B               10.66B
# Low Estimate                              9.87B               10.41B
# High Estimate                            10.32B                10.9B
# Year Ago Sales                           10.39B               10.79B
# Sales Growth (year/est)                  -1.80%               -1.20%
#
#                         Current Year (2018) Next Year (2019)
# Revenue Estimate
# No. of Analysts                          12               12
# Avg. Estimate                        40.93B            41.5B
# Low Estimate                         40.56B           39.51B
# High Estimate                        41.21B           43.06B
# Year Ago Sales                       38.95B           40.93B
# Sales Growth (year/est)               5.10%            1.40%

# %%
MG.earnings_history
# Out:
#                  12/30/2017 3/30/2018 6/29/2018 9/29/2018
# Earnings History
# EPS Est.               1.55       1.7      1.72      1.51
# EPS Actual             1.57      1.84      1.67      1.56
# Difference             0.02      0.14     -0.05      0.05
# Surprise %            1.30%     8.20%    -2.90%     3.30%

# %%
MG.eps_trend
# Out:
#                   Current Qtr. (Dec 2018)  Next Qtr. (Mar 2019)  \
# EPS Trend
# Current Estimate                     0.00                  0.00
# 7 Days Ago                           1.63                  1.86
# 30 Days Ago                          1.63                  1.86
# 60 Days Ago                          1.63                  1.86
# 90 Days Ago                          1.63                  1.86
#
#                   Current Year (2018)  Next Year (2019)
# EPS Trend
# Current Estimate                 0.00              0.00
# 7 Days Ago                       6.71              7.19
# 30 Days Ago                      6.71              7.19
# 60 Days Ago                      6.71              7.19
# 90 Days Ago                      6.71              7.19

# %%
MG.eps_revisions
# Out:
#                    Current Qtr. (Dec 2018)  Next Qtr. (Mar 2019)  \
# EPS Revisions
# Up Last 7 Days                         NaN                   NaN
# Up Last 30 Days                        NaN                   NaN
# Down Last 7 Days                       NaN                   NaN
# Down Last 30 Days                      NaN                   NaN
#
#                    Current Year (2018)  Next Year (2019)
# EPS Revisions
# Up Last 7 Days                     NaN               NaN
# Up Last 30 Days                    NaN               NaN
# Down Last 7 Days                   NaN               NaN
# Down Last 30 Days                  NaN               NaN

# %%
MG.growth_estimates
# Out:
#                            MG.TO  Industry  Sector  S&P 500
# Growth Estimates
# Current Qtr.                 NaN       NaN     NaN     0.00
# Next Qtr.                    NaN       NaN     NaN     0.08
# Current Year                 NaN       NaN     NaN     0.03
# Next Year                    NaN       NaN     NaN     0.10
# Next 5 Years (per annum)  -4.00%       NaN     NaN     0.08
# Past 5 Years (per annum)     NaN       NaN     NaN      NaN
