# %%
from news_updates.news_sources_v3 import News
import time

# %%
pwd
# Out:
# 'C:\\Users\\rayde\\iCloudDrive\\GitHub'

# %%
search = 'FIRE-Supreme-Cannabis'

# %%
cweb = News(search)

# %%
links = cweb.links

# %%
cweb_arts = cweb.art_list

# %%
for each in cweb_arts:
    if each.summary == ' ':
        print(each.index)
    else:
        pass

# %%
keywords_ngod = set()
for each in cweb_arts:
    for i in each.keywords:
        keywords_ngod.add(i)

# %%
keywords_ngod
# Out:
# {'126',
#  '13',
#  '2019',
#  '2020',
#  '6the',
#  '7acres',
#  'acquires',
#  'acquisition',
#  'action',
#  'adjusted',
#  'advise',
#  'advocate',
#  'alan',
#  'announces',
#  'appetite',
#  'appoints',
#  'arbitrary',
#  'away',
#  'balance',
#  'beta',
#  'blissco',
#  'board',
#  'branding',
#  'business',
#  'buy',
#  'canadian',
#  'cannabis',
#  'cannabiss',
#  'cash',
#  'cbd',
#  'cent',
#  'ceo',
#  'cfn',
#  'chaotic',
#  'checking',
#  'chief',
#  'close',
#  'closing',
#  'companies',
#  'company',
#  'companys',
#  'composition',
#  'consider',
#  'content',
#  'creates',
#  'deal',
#  'debt',
#  'dhaliwal',
#  'does',
#  'duds',
#  'ebitda',
#  'epicenter',
#  'epilepsy',
#  'etf',
#  'etfs',
#  'europe',
#  'european',
#  'exploding',
#  'facility',
#  'factors',
#  'fires',
#  'fiscal',
#  'flow',
#  'focus',
#  'forwardlooking',
#  'gets',
#  'gmp',
#  'going',
#  'group',
#  'growing',
#  'growth',
#  'guidance',
#  'guides',
#  'happened',
#  'harvest',
# ...

# %%
for each in keywords_ngod:
    print(each + ",")
# Out:
# view,
# stocks,
# verticalsfor,
# market,
# advocate,
# wild,
# 2020,
# epilepsy,
# guides,
# irresponsible,
# million,
# shares,
# creates,
# tsefire,
# ratio,
# understand,
# involved,
# composition,
# appetite,
# information,
# cannabiss,
# cannabis,
# subsidiary,
# flow,
# upside,
# talks,
# subject,
# whet,
# epicenter,
# closing,
# adjusted,
# tgod,
# signals,
# action,
# runs,
# veryard,
# cfn,
# quarter,
# chaotic,
# officer,
# happened,
# picture,
# truverra,
# cbd,
# european,
# truly,
# gets,
# chief,
# 6the,
# board,
# version,
# investor,
# overall,
# branding,
# movers,
# checking,
# harvest,
# 13,
# debt,
# company,
# going,
# beta,
# products,
# away,
# trend,
# previously,
# growing,
# content,
# rajendra,
# ebitda,
# business,
# securities,
# sell,
# switching,
# ceo,
# close,
# sign,
# fires,
# consider,
# touch,
# volatility,
# etf,
# transaction,
# alan,
# liabilities,
# loyal,
# dhaliwal,
# media,
# magistrate,
# submit,
# does,
# otc,
# measures,
# duds,
# ...

# %%
for each in cweb_arts:
    print(each.summary)
# Out:
# We note that The Supreme Cannabis Company, Inc. (TSE:FIRE) does have debt on its balance sheet.
# See our latest analysis for Supreme Cannabis CompanyHow Much Debt Does Supreme Cannabis Company Carry?
# In the last year Supreme Cannabis Company managed to grow its revenue by 397%, to CA$26m.
# Caveat EmptorDespite the top line growth, Supreme Cannabis Company still had negative earnings before interest and tax (EBIT), over the last year.
# For riskier companies like Supreme Cannabis Company I always like to keep an eye on whether insiders are buying or selling.
# Seattle, Washington--(Newsfile Corp. - August 16, 2019) - CFN Media Group ("CFN Media"), the leading agency and financial media network dedicated to the North American cannabis industry announces publication of an article discussing The Supreme Cannabis Company (OTCQX: SPRWF) (TSX: FIRE).
# Further, it is a jump of roughly 97% from $9.9 million in the third quarter of fiscal 2019.
# ...

# %%
articles[4].summary

# %%
articles[3].summary

# %%
articles[8].summary

# %%
articles[9].summary

# %%
articles[10].summary

# %%
articles[11].summary

# %%
articles[14].summary

# %%
articles[15].summary

# %%
articles[17].summary

# %%
len(articles)
