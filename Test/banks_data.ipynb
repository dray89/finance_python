# %%
import sys, os, time
import finance_python
from finance_python.stock_scraper_v3 import get_data
from finance_python.balance_sheet import balance_sheet
from finance_python.financials import financials
from finance_python.industry import industry
import numpy as np
import pandas
from datetime import datetime, date
from pandas import DataFrame

# %%
ind_list = ['RY.TO', 'TD.TO', 'BNS.TO', 'BMO.TO', 'CM.TO', 'NA.TO', 'CWB.TO', "FN.TO", 'LB.TO', 'EQB.TO', 'HCG.TO']

# %%
dict1 = []
start = date(2018, 8, 14)
end = date(2019, 8, 14)

timer_start = time.time()

for each in ind_list:
    dict1.append({each: get_data(each, start, end)})

timer_end = time.time()

print(timer_end - timer_start)
# Out:
# 213.1046462059021

# %%
data = list(map(lambda x, y: {y: dict1[x][y]}, range(0, len(dict1)), ind_list))

# %%
data
# Out:
# [{'RY.TO': <finance_python.stock_scraper_v3.get_data at 0x257a09e5710>},
#  {'TD.TO': <finance_python.stock_scraper_v3.get_data at 0x257a0b839b0>},
#  {'BNS.TO': <finance_python.stock_scraper_v3.get_data at 0x257a1c5b320>},
#  {'BMO.TO': <finance_python.stock_scraper_v3.get_data at 0x257a1cf5198>},
#  {'CM.TO': <finance_python.stock_scraper_v3.get_data at 0x257a1cad630>},
#  {'NA.TO': <finance_python.stock_scraper_v3.get_data at 0x257a1cbc470>},
#  {'CWB.TO': <finance_python.stock_scraper_v3.get_data at 0x257a1db5f28>},
#  {'FN.TO': <finance_python.stock_scraper_v3.get_data at 0x257a1db00b8>},
#  {'LB.TO': <finance_python.stock_scraper_v3.get_data at 0x257a1d80278>},
#  {'EQB.TO': <finance_python.stock_scraper_v3.get_data at 0x257a1da3c18>},
#  {'HCG.TO': <finance_python.stock_scraper_v3.get_data at 0x257a1d16a58>}]

# %%
ind_bsd = list(map(lambda x, y: dict1[x][y].bsd, range(0, len(ind_list)), ind_list))

# %%
for index, each in enumerate(ind_bsd):
    if hasattr(ind_bsd[index], 'changes'):
        pass
    else:
        ind_bsd.pop(index)

# %%
len(ind_bsd)
# Out:
# 11

# %%
ind_df = list(map(lambda x: pandas.DataFrame(ind_bsd[x].changes), range(0, len(ind_bsd))))

# %%
ind_df
# Out:
# [                                     RY.TO
#  Cash And Cash Equivalents         0.065193
#  Short Term Investments            0.305955
#  Net Receivables                   0.459705
#  Other Current Assets              0.035368
#  Total Current Assets              0.147954
#  Long Term Investments             0.042467
#  Property, plant and equipment     0.060674
#  Goodwill                          0.014576
#  Intangible Assets                 0.039938
#  Other Assets                      0.064991
#  Deferred Long Term Asset Charges -0.148383
#  Total Assets                      0.100491
#  Accounts Payable                  0.060244
#  Short/Current Long Term Debt      0.446237
#  Other Current Liabilities         0.019831
#  Total Current Liabilities         0.112949
#  Long Term Debt                   -0.021074
#  Other Liabilities                 0.166601
#  Minority Interest                -0.843072
#  Total Liabilities                 0.102206
#  Common Stock                     -0.005358
#  Retained Earnings                 0.126833
#  Treasury Stock                    0.110469
#  Other Stockholder Equity          0.107717
#  Total stockholders' equity        0.091017
#  Net Tangible Assets               0.111607,
#                                       TD.TO
#  Cash And Cash Equivalents         0.174263
#  Short Term Investments           -0.171458
#  Net Receivables                  -0.032232
#  Inventory                         0.038462
#  Other Current Assets              0.246856
#  Total Current Assets              0.002885
#  Long Term Investments             0.087887
#  Property, plant and equipment     0.002070
#  Goodwill                          0.023521
#  Intangible Assets                -0.060733
#  Other Assets                      0.055655
#  Deferred Long Term Asset Charges  0.126151
#  Total Assets                      0.043712
#  Accounts Payable                  0.052857
#  Short/Current Long Term Debt      0.108160
#  Other Current Liabilities         0.044229
#  Total Current Liabilities         0.046576
#  Long Term Debt                   -0.011153
#  Other Liabilities                -0.042557
#  Minority Interest                 0.010173
#  Total Liabilities                 0.042414
#  Common Stock                      0.013855
#  Retained Earnings                 0.139692
#  Treasury Stock                   -0.170498
#  Capital Surplus                  -0.098131
#  Other Stockholder Equity         -0.170747
#  Total stockholders' equity        0.066077
#  Net Tangible Assets               0.086191,
#                                      BNS.TO
#  Cash And Cash Equivalents        -0.795580
#  Short Term Investments            0.068858
#  Net Receivables                   0.547351
#  Inventory                         0.033981
#  Other Current Assets              0.084246
#  Total Current Assets              0.056946
#  Long Term Investments             0.127119
#  Property, plant and equipment     0.127257
#  Goodwill                          0.381610
#  Intangible Assets                 0.585852
#  Other Assets                      0.097763
#  Deferred Long Term Asset Charges  0.131349
#  Total Assets                      0.090924
#  Accounts Payable                  0.086528
#  Short/Current Long Term Debt      0.056488
#  Other Current Liabilities         0.194917
#  Total Current Liabilities         0.087013
#  Long Term Debt                   -0.039933
#  Other Liabilities                 0.152121
#  Minority Interest                 0.540201
#  Total Liabilities                 0.090394
#  Common Stock                      0.165559
#  Retained Earnings                 0.086497
#  Treasury Stock                   -0.091300
#  Other Stockholder Equity         -0.091300
#  Total stockholders' equity        0.098046
#  Net Tangible Assets              -0.000512,
#                                      BMO.TO
#  Cash And Cash Equivalents         0.299159
#  Short Term Investments            0.144953
#  Net Receivables                   0.069402
#  Inventory                         0.054545
#  Other Current Assets              0.110317
#  Total Current Assets              0.081372
#  Long Term Investments             0.266790
#  Property, plant and equipment    -0.012834
#  Goodwill                          0.020660
#  Intangible Assets                 0.052339
#  Other Assets                      0.069124
#  Deferred Long Term Asset Charges -0.289005
#  Total Assets                      0.090854
#  Accounts Payable                  0.088942
#  Short/Current Long Term Debt      0.016470
#  Other Current Liabilities         0.137316
#  Total Current Liabilities         0.092315
#  Long Term Debt                    0.118344
#  Other Liabilities                 0.132903
#  Total Liabilities                 0.094847
#  Common Stock                     -0.007904
#  Retained Earnings                 0.090556
#  Treasury Stock                   -0.249185
#  Capital Surplus                  -0.022801
#  Other Stockholder Equity         -0.249185
#  Total stockholders' equity        0.031735
#  Net Tangible Assets               0.032512,
#                                         CM.TO
#  Cash And Cash Equivalents           0.312250
#  Short Term Investments              0.110891
#  Net Receivables                     0.227011
#  Inventory                          -0.333333
#  Other Current Assets                0.148751
#  Total Current Assets                0.059595
#  Long Term Investments               0.145588
#  Property, plant and equipment       0.006730
#  Goodwill                            0.036706
#  Intangible Assets                  -0.016684
#  Other Assets                        0.045116
#  Deferred Long Term Asset Charges   -0.173315
#  Total Assets                        0.056319
#  Accounts Payable                    0.051046
#  Short/Current Long Term Debt      297.594595
#  Other Current Liabilities           0.154228
#  Total Current Liabilities           0.072599
#  Long Term Debt                     -0.193302
#  Other Liabilities                   0.204614
#  Minority Interest                  -0.143564
#  Total Liabilities                   0.052349
#  Common Stock                        0.055387
#  Retained Earnings                   0.151295
#  Treasury Stock                      0.719027
#  Capital Surplus                    -0.007299
#  Other Stockholder Equity            0.719027
#  Total stockholders' equity          0.118168
#  Net Tangible Assets                 0.150322,
#                                    NA.TO
#  Cash And Cash Equivalents      0.508014
#  Short Term Investments        -0.126509
#  Other Current Assets           0.232637
#  Total Current Assets           0.076420
#  Long Term Investments          0.227759
#  Property, plant and equipment  0.077061
#  Goodwill                       0.002129
#  Intangible Assets              0.060533
#  Other Assets                   0.052838
#  Total Assets                   0.067671
#  Accounts Payable               0.088508
#  Short/Current Long Term Debt   0.106426
#  Other Current Liabilities      0.147048
#  Total Current Liabilities      0.091335
#  Long Term Debt                -0.247501
#  Other Liabilities             -0.026577
#  Minority Interest             -0.521465
#  Total Liabilities              0.067432
#  Common Stock                   0.019509
#  Retained Earnings              0.119598
#  Treasury Stock                 0.107595
#  Capital Surplus               -0.017241
#  Other Stockholder Equity       0.107595
#  Total stockholders' equity     0.092408
#  Net Tangible Assets            0.113501,
#                                          CWB.TO
#  Cash And Cash Equivalents             6.060835
#  Short Term Investments               -0.946765
#  Net Receivables                       0.713869
#  Inventory                             2.342410
#  Other Current Assets                  0.293651
#  Total Current Assets                 -0.457380
#  Long Term Investments                -0.046747
#  Property, plant and equipment         0.053159
#  Goodwill                             -0.005848
#  Intangible Assets                     0.073866
#  Other Assets                          0.127835
#  Deferred Long Term Asset Charges      0.155563
#  Total Assets                          0.097325
#  Accounts Payable                      0.083917
#  Other Current Liabilities            -0.465530
#  Total Current Liabilities             0.111799
#  Long Term Debt                       -0.029125
#  Other Liabilities                    -0.179528
#  Deferred Long Term Liability Charges  0.140444
#  Minority Interest                    -0.016446
#  Total Liabilities                     0.102126
#  Common Stock                          0.017511
#  Retained Earnings                     0.107859
#  Treasury Stock                        1.988682
#  Other Stockholder Equity              1.988682
#  Total stockholders' equity            0.056787
#  Net Tangible Assets                   0.058220,
#                                    FN.TO
#  Short Term Investments         0.001275
#  Net Receivables                0.108471
#  Other Current Assets           0.061952
#  Total Current Assets           0.099684
#  Property, plant and equipment -0.197001
#  Goodwill                       0.000000
#  Total Assets                   0.099488
#  Other Current Liabilities     -0.216116
#  Total Current Liabilities      0.018426
#  Long Term Debt                 0.111795
#  Other Liabilities              0.054181
#  Total Liabilities              0.101507
#  Common Stock                   0.000000
#  Retained Earnings             -0.024468
#  Total stockholders' equity    -0.024725
#  Net Tangible Assets           -0.026494,
#                                        LB.TO
#  Cash And Cash Equivalents          0.040294
#  Short Term Investments             0.211695
#  Net Receivables                    0.145826
#  Inventory                          1.016129
#  Other Current Assets              -0.558447
#  Total Current Assets               0.116541
#  Long Term Investments             -0.020726
#  Property, plant and equipment      0.583670
#  Goodwill                          -0.012557
#  Intangible Assets                  0.251934
#  Other Assets                      -0.044545
#  Deferred Long Term Asset Charges  -0.342747
#  Total Assets                      -0.016879
#  Accounts Payable                  -0.032417
#  Other Current Liabilities          0.175638
#  Total Current Liabilities         -0.053933
#  Long Term Debt                     0.152536
#  Other Liabilities                 -0.281417
#  Total Liabilities                 -0.021504
#  Common Stock                       0.169768
#  Retained Earnings                  0.112670
#  Treasury Stock                    30.697581
#  Other Stockholder Equity          30.697581
#  Total stockholders' equity         0.132418
#  Net Tangible Assets                0.121039,
#                                          EQB.TO
#  Cash And Cash Equivalents            -0.277922
#  Net Receivables                       0.169412
#  Inventory                            -0.392540
#  Other Current Assets                 -0.099401
#  Total Current Assets                  0.201585
#  Long Term Investments                -0.965223
#  Property, plant and equipment        -0.011176
#  Intangible Assets                     0.315773
#  Other Assets                          0.220524
#  Total Assets                          0.213378
#  Accounts Payable                      0.222318
#  Other Current Liabilities            -0.018214
#  Total Current Liabilities             0.217579
#  Long Term Debt                        0.220804
#  Other Liabilities                     0.130317
#  Deferred Long Term Liability Charges -0.881228
#  Total Liabilities                     0.218555
#  Common Stock                          0.010732
#  Retained Earnings                     0.171399
#  Treasury Stock                        1.856924
#  Capital Surplus                       0.170160
#  Other Stockholder Equity              1.856924
#  Total stockholders' equity            0.133179
#  Net Tangible Assets                   0.128631,
#                                      HCG.TO
#  Cash And Cash Equivalents        -0.501588
#  Net Receivables                   1.794753
#  Other Current Assets             -0.046190
#  Total Current Assets             -0.352106
#  Long Term Investments             0.162016
#  Property, plant and equipment    -0.169303
#  Goodwill                          0.000000
#  Intangible Assets                -0.154425
#  Other Assets                      0.077763
#  Deferred Long Term Asset Charges -0.635690
#  Total Assets                      0.031297
#  Accounts Payable                  0.066278
#  Short/Current Long Term Debt     -0.354925
#  Total Current Liabilities         0.066272
#  Long Term Debt                   -0.033907
#  Other Liabilities                -0.204646
#  Total Liabilities                 0.045852
#  Common Stock                     -0.226574
#  Retained Earnings                -0.072973
#  Treasury Stock                    0.778928
#  Capital Surplus                  -0.079349
#  Other Stockholder Equity          0.778928
#  Total stockholders' equity       -0.095337
#  Net Tangible Assets              -0.092062]

# %%
frame = pandas.concat(ind_df, sort=True, axis=1)
frame.dropna(how='all')
# Out:
#                                          RY.TO     TD.TO    BNS.TO    BMO.TO  \
# Accounts Payable                      0.060244  0.052857  0.086528  0.088942
# Capital Surplus                            NaN -0.098131       NaN -0.022801
# Cash And Cash Equivalents             0.065193  0.174263 -0.795580  0.299159
# Common Stock                         -0.005358  0.013855  0.165559 -0.007904
# Deferred Long Term Asset Charges     -0.148383  0.126151  0.131349 -0.289005
# Deferred Long Term Liability Charges       NaN       NaN       NaN       NaN
# Goodwill                              0.014576  0.023521  0.381610  0.020660
# Intangible Assets                     0.039938 -0.060733  0.585852  0.052339
# Inventory                                  NaN  0.038462  0.033981  0.054545
# Long Term Debt                       -0.021074 -0.011153 -0.039933  0.118344
# Long Term Investments                 0.042467  0.087887  0.127119  0.266790
# Minority Interest                    -0.843072  0.010173  0.540201       NaN
# Net Receivables                       0.459705 -0.032232  0.547351  0.069402
# Net Tangible Assets                   0.111607  0.086191 -0.000512  0.032512
# Other Assets                          0.064991  0.055655  0.097763  0.069124
# Other Current Assets                  0.035368  0.246856  0.084246  0.110317
# Other Current Liabilities             0.019831  0.044229  0.194917  0.137316
# Other Liabilities                     0.166601 -0.042557  0.152121  0.132903
# Other Stockholder Equity              0.107717 -0.170747 -0.091300 -0.249185
# Property, plant and equipment         0.060674  0.002070  0.127257 -0.012834
# Retained Earnings                     0.126833  0.139692  0.086497  0.090556
# Short Term Investments                0.305955 -0.171458  0.068858  0.144953
# Short/Current Long Term Debt          0.446237  0.108160  0.056488  0.016470
# Total Assets                          0.100491  0.043712  0.090924  0.090854
# Total Current Assets                  0.147954  0.002885  0.056946  0.081372
# Total Current Liabilities             0.112949  0.046576  0.087013  0.092315
# Total Liabilities                     0.102206  0.042414  0.090394  0.094847
# Total stockholders' equity            0.091017  0.066077  0.098046  0.031735
# Treasury Stock                        0.110469 -0.170498 -0.091300 -0.249185
#
#                                            CM.TO     NA.TO    CWB.TO  \
# Accounts Payable                        0.051046  0.088508  0.083917
# Capital Surplus                        -0.007299 -0.017241       NaN
# Cash And Cash Equivalents               0.312250  0.508014  6.060835
# Common Stock                            0.055387  0.019509  0.017511
# Deferred Long Term Asset Charges       -0.173315       NaN  0.155563
# Deferred Long Term Liability Charges         NaN       NaN  0.140444
# Goodwill                                0.036706  0.002129 -0.005848
# Intangible Assets                      -0.016684  0.060533  0.073866
# Inventory                              -0.333333       NaN  2.342410
# Long Term Debt                         -0.193302 -0.247501 -0.029125
# Long Term Investments                   0.145588  0.227759 -0.046747
# Minority Interest                      -0.143564 -0.521465 -0.016446
# Net Receivables                         0.227011       NaN  0.713869
# Net Tangible Assets                     0.150322  0.113501  0.058220
# Other Assets                            0.045116  0.052838  0.127835
# Other Current Assets                    0.148751  0.232637  0.293651
# Other Current Liabilities               0.154228  0.147048 -0.465530
# Other Liabilities                       0.204614 -0.026577 -0.179528
# Other Stockholder Equity                0.719027  0.107595  1.988682
# Property, plant and equipment           0.006730  0.077061  0.053159
# Retained Earnings                       0.151295  0.119598  0.107859
# Short Term Investments                  0.110891 -0.126509 -0.946765
# Short/Current Long Term Debt          297.594595  0.106426       NaN
# Total Assets                            0.056319  0.067671  0.097325
# Total Current Assets                    0.059595  0.076420 -0.457380
# Total Current Liabilities               0.072599  0.091335  0.111799
# Total Liabilities                       0.052349  0.067432  0.102126
# Total stockholders' equity              0.118168  0.092408  0.056787
# Treasury Stock                          0.719027  0.107595  1.988682
#
#                                          FN.TO      LB.TO    EQB.TO    HCG.TO
# Accounts Payable                           NaN  -0.032417  0.222318  0.066278
# Capital Surplus                            NaN        NaN  0.170160 -0.079349
# Cash And Cash Equivalents                  NaN   0.040294 -0.277922 -0.501588
# Common Stock                          0.000000   0.169768  0.010732 -0.226574
# Deferred Long Term Asset Charges           NaN  -0.342747       NaN -0.635690
# Deferred Long Term Liability Charges       NaN        NaN -0.881228       NaN
# Goodwill                              0.000000  -0.012557       NaN  0.000000
# Intangible Assets                          NaN   0.251934  0.315773 -0.154425
# Inventory                                  NaN   1.016129 -0.392540       NaN
# Long Term Debt                        0.111795   0.152536  0.220804 -0.033907
# Long Term Investments                      NaN  -0.020726 -0.965223  0.162016
# Minority Interest                          NaN        NaN       NaN       NaN
# Net Receivables                       0.108471   0.145826  0.169412  1.794753
# Net Tangible Assets                  -0.026494   0.121039  0.128631 -0.092062
# Other Assets                               NaN  -0.044545  0.220524  0.077763
# Other Current Assets                  0.061952  -0.558447 -0.099401 -0.046190
# Other Current Liabilities            -0.216116   0.175638 -0.018214       NaN
# Other Liabilities                     0.054181  -0.281417  0.130317 -0.204646
# Other Stockholder Equity                   NaN  30.697581  1.856924  0.778928
# Property, plant and equipment        -0.197001   0.583670 -0.011176 -0.169303
# Retained Earnings                    -0.024468   0.112670  0.171399 -0.072973
# Short Term Investments                0.001275   0.211695       NaN       NaN
# Short/Current Long Term Debt               NaN        NaN       NaN -0.354925
# Total Assets                          0.099488  -0.016879  0.213378  0.031297
# Total Current Assets                  0.099684   0.116541  0.201585 -0.352106
# Total Current Liabilities             0.018426  -0.053933  0.217579  0.066272
# Total Liabilities                     0.101507  -0.021504  0.218555  0.045852
# Total stockholders' equity           -0.024725   0.132418  0.133179 -0.095337
# Treasury Stock                             NaN  30.697581  1.856924  0.778928

# %%
maximum = frame.idxmax(axis=1).dropna()
maximum
# Out:
# Accounts Payable                        EQB.TO
# Capital Surplus                         EQB.TO
# Cash And Cash Equivalents               CWB.TO
# Common Stock                             LB.TO
# Deferred Long Term Asset Charges        CWB.TO
# Deferred Long Term Liability Charges    CWB.TO
# Goodwill                                BNS.TO
# Intangible Assets                       BNS.TO
# Inventory                               CWB.TO
# Long Term Debt                          EQB.TO
# Long Term Investments                   BMO.TO
# Minority Interest                       BNS.TO
# Net Receivables                         HCG.TO
# Net Tangible Assets                      CM.TO
# Other Assets                            EQB.TO
# Other Current Assets                    CWB.TO
# Other Current Liabilities               BNS.TO
# Other Liabilities                        CM.TO
# Other Stockholder Equity                 LB.TO
# Property, plant and equipment            LB.TO
# Retained Earnings                       EQB.TO
# Short Term Investments                   RY.TO
# Short/Current Long Term Debt             CM.TO
# Total Assets                            EQB.TO
# Total Current Assets                    EQB.TO
# Total Current Liabilities               EQB.TO
# Total Liabilities                       EQB.TO
# Total stockholders' equity              EQB.TO
# Treasury Stock                           LB.TO
# dtype: object

# %%
minimum = frame.idxmin(axis=1).dropna()

# %%
minimum
# Out:
# Common Stock                     HCG.TO
# Long Term Debt                    NA.TO
# Net Tangible Assets              HCG.TO
# Other Current Assets              LB.TO
# Other Liabilities                 LB.TO
# Property, plant and equipment     FN.TO
# Retained Earnings                HCG.TO
# Total Assets                      LB.TO
# Total Current Assets             CWB.TO
# Total Current Liabilities         LB.TO
# Total Liabilities                 LB.TO
# Total stockholders' equity       HCG.TO
# dtype: object

# %%
debt_inc = "{0} increased its debt by {1} in the past year, the largest increase in debt in the industry."
debt_dec =  "Meanwhile, {0} decreased its debt by {1}."

# %%
# Out:
# '{0} increased its debt by {1} in the past year, the largest increase in debt in the industry.'

# %%
maximum
# Out:
# [{'50-Day Moving Average 3': 103.39},
#  {'Market Cap (intraday) 5': 14254.0},
#  {'Return on Assets (ttm)': 0.96}]

# %%
max_sentence = "{0} increased its {1} by {2} in the past year."
min_sentence =  "{0} decreased its {1} by {2}."

# %%
for index, each in enumerate(maximum):
    print(max_sentence.format(maximum[index], maximum[index], maximum[index]))
# Out:
# {'50-Day Moving Average 3': 103.39} increased its {'50-Day Moving Average 3': 103.39} by {'50-Day Moving Average 3': 103.39} in the past year.
# {'Market Cap (intraday) 5': 14254.0} increased its {'Market Cap (intraday) 5': 14254.0} by {'Market Cap (intraday) 5': 14254.0} in the past year.
# {'Return on Assets (ttm)': 0.96} increased its {'Return on Assets (ttm)': 0.96} by {'Return on Assets (ttm)': 0.96} in the past year.

# %%
bsd_list = list(map(lambda x, y: y.stats, range(0, len(ind_bsd)), ind_bsd))

# %%
ind_bsd
# Out:
# [<finance_python.balance_sheet.balance_sheet at 0x2579f984860>,
#  <finance_python.balance_sheet.balance_sheet at 0x257a0baaeb8>,
#  <finance_python.balance_sheet.balance_sheet at 0x257a1c58b38>,
#  <finance_python.balance_sheet.balance_sheet at 0x257a1d03668>,
#  <finance_python.balance_sheet.balance_sheet at 0x257a1cb3080>,
#  <finance_python.balance_sheet.balance_sheet at 0x257a1daa0b8>,
#  <finance_python.balance_sheet.balance_sheet at 0x257a1e46f60>,
#  <finance_python.balance_sheet.balance_sheet at 0x257a1cb80f0>,
#  <finance_python.balance_sheet.balance_sheet at 0x257a1d87240>,
#  <finance_python.balance_sheet.balance_sheet at 0x257a1d26390>,
#  <finance_python.balance_sheet.balance_sheet at 0x257a1d156a0>]

# %%
len(bsd_list)
# Out:
# 11

# %%
dataframe = pandas.concat(bsd_list, sort=True, axis=1)
dataframe = dataframe.dropna(how='all')

# %%
a = industry(bsd_list)
# Out:
# C:\Users\rayde\iCloudDrive\GitHub\finance_python\industry.py:24: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   ind = pandas.concat(self.df_list, axis=1).dropna(how='all')

# %%
a.attributes
# Out:
# ['ind',
#  'maximum',
#  'minimum',
#  'max_list',
#  'min_list',
#  'max_sentence',
#  'min_sentence']

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-ee2496431308> in <module>
# ----> 1 a.min_list
#
# AttributeError: 'industry' object has no attribute 'min_list'

# %%
averages = ind.mean(axis=1).dropna()

# %%
ind['Averages'] = averages

# %%
ind
# Out:
#                                                    RY.TO     TD.TO   BNS.TO  \
# 200-Day Moving Average 3                          103.61     75.38    71.55
# 5 Year Average Dividend Yield 4                     3.77      3.49     4.18
# 50-Day Moving Average 3                           103.39     76.00    69.74
# 52 Week High 3                                    107.91     80.05    78.60
# 52 Week Low 3                                      90.10     65.56    66.36
# 52-Week Change 3                                   -2.08     -7.04   -11.65
# Avg Vol (10 day) 3                                  2.08      2.90     1.72
# Avg Vol (3 month) 3                                 2.20      3.02     2.29
# Beta (3Y Monthly)                                   0.96      1.09     0.97
# Book Value Per Share (mrq)                         53.06     43.51    52.01
# Current Ratio (mrq)                                  NaN       NaN      NaN
# Diluted EPS (ttm)                                   8.64      6.20     6.70
# Enterprise Value/Revenue 3                         -1.92      0.20    -2.57
# Float                                                NaN       NaN      NaN
# Forward Annual Dividend Rate 4                      4.08      2.96     3.48
# Forward Annual Dividend Yield 4                     4.06      4.05     5.08
# Forward P/E 1                                      10.45      9.88     8.97
# Gross Profit (ttm)                                   NaN       NaN      NaN
# Market Cap (intraday) 5                         14254.00  13195.00  8209.00
# Net Income Avi to Common (ttm)                       NaN       NaN      NaN
# Operating Cash Flow (ttm)                            NaN       NaN      NaN
# Operating Margin (ttm)                             39.20     37.59    40.42
# PEG Ratio (5 yr expected) 1                         2.05      1.45     1.84
# Payout Ratio 4                                     45.42     44.35    50.60
# Price/Book (mrq)                                    1.87      1.66     1.31
# Price/Sales (ttm)                                   3.30      3.52     3.05
# Profit Margin                                      29.54     30.92    31.50
# Quarterly Earnings Growth (yoy)                     5.70      9.50     3.90
# Quarterly Revenue Growth (yoy)                     13.20      7.50     6.20
# Return on Assets (ttm)                              0.96      0.88     0.88
# Return on Equity (ttm)                             16.16     14.42    13.07
# Revenue (ttm)                                        NaN       NaN      NaN
# Revenue Per Share (ttm)                            30.00     20.50    21.98
# S&P500 52-Week Change 3                             1.31      1.31     1.31
# Shares Outstanding 5                                 NaN       NaN      NaN
# Shares Short (Jul 15, 2019) 4                        NaN       NaN      NaN
# Shares Short (Jul 31, 2019) 4                       8.68     49.70    35.93
# Shares Short (prior month Jun 14, 2019) 4            NaN       NaN      NaN
# Shares Short (prior month Jun 28, 2019) 4           9.22     50.03    34.86
# Short % of Shares Outstanding (Jul 15, 2019) 4       NaN       NaN      NaN
# Short % of Shares Outstanding (Jul 31, 2019) 4      0.60      2.72     2.97
# Short Ratio (Jul 15, 2019) 4                         NaN       NaN      NaN
# Short Ratio (Jul 31, 2019) 4                        3.96     12.77    13.13
# Total Cash (mrq)                                     NaN       NaN      NaN
# Total Cash Per Share (mrq)                        382.12    195.96   265.67
# Total Debt/Equity (mrq)                              NaN       NaN      NaN
# Trailing Annual Dividend Rate 3                     3.92      2.75     3.39
# Trailing Annual Dividend Yield 3                    3.90      3.76     4.95
# Trailing P/E                                       11.50     11.63    10.14
#
#                                                  BMO.TO    CM.TO    NA.TO  \
# 200-Day Moving Average 3                         100.75   107.48    62.47
# 5 Year Average Dividend Yield 4                    3.88     4.53     4.18
# 50-Day Moving Average 3                           98.00   102.29    63.09
# 52 Week High 3                                   109.00   125.21    65.91
# 52 Week Low 3                                     86.25    97.55    54.37
# 52-Week Change 3                                 -11.08   -17.83    -6.73
# Avg Vol (10 day) 3                                 1.45     1.19      NaN
# Avg Vol (3 month) 3                                1.43     1.67     1.07
# Beta (3Y Monthly)                                  1.30     1.17     1.06
# Book Value Per Share (mrq)                        69.99    77.49    35.49
# Current Ratio (mrq)                                 NaN      NaN      NaN
# Diluted EPS (ttm)                                  9.43    11.36     6.05
# Enterprise Value/Revenue 3                        -2.45    -0.62    -7.30
# Float                                            638.38   444.50   334.49
# Forward Annual Dividend Rate 4                     4.12     5.60     2.72
# Forward Annual Dividend Yield 4                    4.38     5.61     4.26
# Forward P/E 1                                      9.24     7.89     9.31
# Gross Profit (ttm)                                  NaN      NaN      NaN
# Market Cap (intraday) 5                         5917.00  4392.00  2042.00
# Net Income Avi to Common (ttm)                      NaN      NaN      NaN
# Operating Cash Flow (ttm)                           NaN      NaN      NaN
# Operating Margin (ttm)                            35.23    38.20    40.20
# PEG Ratio (5 yr expected) 1                        1.83     3.25     1.40
# Payout Ratio 4                                    41.61    47.98    41.98
# Price/Book (mrq)                                   1.32     1.27     1.72
# Price/Sales (ttm)                                  2.48     2.58     2.98
# Profit Margin                                     26.13    30.28    31.67
# Quarterly Earnings Growth (yoy)                   20.10     2.10     3.30
# Quarterly Revenue Growth (yoy)                    11.40     3.00     1.40
# Return on Assets (ttm)                             0.79     0.84     0.86
# Return on Equity (ttm)                            13.40    14.60    15.62
# Revenue (ttm)                                       NaN      NaN      NaN
# Revenue Per Share (ttm)                           37.34    38.35    20.34
# S&P500 52-Week Change 3                            1.31     1.31     1.31
# Shares Outstanding 5                             638.83   444.75   338.05
# Shares Short (Jul 15, 2019) 4                       NaN      NaN     6.80
# Shares Short (Jul 31, 2019) 4                      7.89    14.75      NaN
# Shares Short (prior month Jun 14, 2019) 4           NaN      NaN     7.12
# Shares Short (prior month Jun 28, 2019) 4          8.59    15.16      NaN
# Short % of Shares Outstanding (Jul 15, 2019) 4      NaN      NaN     2.30
# Short % of Shares Outstanding (Jul 31, 2019) 4     1.23     3.32      NaN
# Short Ratio (Jul 15, 2019) 4                        NaN      NaN     5.58
# Short Ratio (Jul 31, 2019) 4                       6.24     8.95      NaN
# Total Cash (mrq)                                    NaN      NaN      NaN
# Total Cash Per Share (mrq)                       428.26   425.96   303.62
# Total Debt/Equity (mrq)                             NaN      NaN      NaN
# Trailing Annual Dividend Rate 3                    3.92     5.45     2.54
# Trailing Annual Dividend Yield 3                   4.17     5.45     4.15
# Trailing P/E                                       9.82     8.69    10.07
#
#                                                 CWB.TO    FN.TO   LB.TO  \
# 200-Day Moving Average 3                         29.34    30.93   43.34
# 5 Year Average Dividend Yield 4                   3.14     6.46    4.82
# 50-Day Moving Average 3                          29.66    32.54   45.08
# 52 Week High 3                                   38.96    35.36   48.41
# 52 Week Low 3                                    24.33    25.38   36.21
# 52-Week Change 3                                -18.74    16.97   -5.48
# Avg Vol (10 day) 3                                 NaN      NaN     NaN
# Avg Vol (3 month) 3                                NaN      NaN     NaN
# Beta (3Y Monthly)                                 1.75     1.00    1.15
# Book Value Per Share (mrq)                       28.20     7.24   54.52
# Current Ratio (mrq)                                NaN     9.84     NaN
# Diluted EPS (ttm)                                 2.88     2.48    4.19
# Enterprise Value/Revenue 3                        5.59    78.05   10.78
# Float                                            86.73    15.86   42.26
# Forward Annual Dividend Rate 4                    1.08     1.90    2.64
# Forward Annual Dividend Yield 4                   3.58     5.45    5.86
# Forward P/E 1                                     8.91    11.20    9.16
# Gross Profit (ttm)                              755.10   390.14  999.41
# Market Cap (intraday) 5                         259.00   209.00  192.00
# Net Income Avi to Common (ttm)                  255.33   148.80  176.25
# Operating Cash Flow (ttm)                          NaN   344.83     NaN
# Operating Margin (ttm)                           49.98    44.50   24.24
# PEG Ratio (5 yr expected) 1                       1.45     0.75   -2.43
# Payout Ratio 4                                   36.11    75.94   61.58
# Price/Book (mrq)                                  1.07     4.77    0.83
# Price/Sales (ttm)                                 3.33     4.47    2.01
# Profit Margin                                    34.87    32.57   19.79
# Quarterly Earnings Growth (yoy)                   5.30    -4.70  -26.80
# Quarterly Revenue Growth (yoy)                    5.40    10.90   -7.90
# Return on Assets (ttm)                            0.94     0.42    0.41
# Return on Equity (ttm)                           10.14    27.51    7.58
# Revenue (ttm)                                   778.69   466.20  956.54
# Revenue Per Share (ttm)                           8.81     7.77   22.74
# S&P500 52-Week Change 3                           1.31     1.31    1.31
# Shares Outstanding 5                             66.64    59.97   41.25
# Shares Short (Jul 15, 2019) 4                      NaN      NaN     NaN
# Shares Short (Jul 31, 2019) 4                     1.50      NaN    3.54
# Shares Short (prior month Jun 14, 2019) 4          NaN      NaN     NaN
# Shares Short (prior month Jun 28, 2019) 4         1.41      NaN    3.69
# Short % of Shares Outstanding (Jul 15, 2019) 4     NaN      NaN     NaN
# Short % of Shares Outstanding (Jul 31, 2019) 4    1.72     0.24    8.37
# Short Ratio (Jul 15, 2019) 4                       NaN      NaN     NaN
# Short Ratio (Jul 31, 2019) 4                      8.04    11.65   20.27
# Total Cash (mrq)                                625.37      NaN     NaN
# Total Cash Per Share (mrq)                        7.17    38.41   79.79
# Total Debt/Equity (mrq)                            NaN  6869.02     NaN
# Trailing Annual Dividend Rate 3                   1.04     1.88    2.58
# Trailing Annual Dividend Yield 3                  3.39     5.40    5.66
# Trailing P/E                                     10.48    13.91   10.84
#
#                                                 EQB.TO  HCG.TO     Averages
# 200-Day Moving Average 3                         72.71   18.75    65.119091
# 5 Year Average Dividend Yield 4                   1.44     NaN     3.989000
# 50-Day Moving Average 3                          82.49   22.53    65.891818
# 52 Week High 3                                   97.96   25.45    73.892727
# 52 Week Low 3                                    56.12   12.48    55.882727
# 52-Week Change 3                                 46.92   70.24     4.863636
# Avg Vol (10 day) 3                                 NaN     NaN     1.868000
# Avg Vol (3 month) 3                                NaN     NaN     1.946667
# Beta (3Y Monthly)                                 1.62    1.74     1.255455
# Book Value Per Share (mrq)                       77.22   27.80    47.866364
# Current Ratio (mrq)                                NaN     NaN     9.840000
# Diluted EPS (ttm)                                10.71    1.83     6.406364
# Enterprise Value/Revenue 3                       25.98    8.77    10.410000
# Float                                            11.15   51.70   203.133750
# Forward Annual Dividend Rate 4                    1.32     NaN     2.990000
# Forward Annual Dividend Yield 4                   1.41     NaN     4.374000
# Forward P/E 1                                     7.16    9.55     9.247273
# Gross Profit (ttm)                              373.96  398.48   583.418000
# Market Cap (intraday) 5                         158.00  148.00  4452.272727
# Net Income Avi to Common (ttm)                  178.84  128.14   177.472000
# Operating Cash Flow (ttm)                          NaN     NaN   344.830000
# Operating Margin (ttm)                           59.18   44.54    41.207273
# PEG Ratio (5 yr expected) 1                       0.31    2.23     1.284545
# Payout Ratio 4                                   10.83    0.00    41.490909
# Price/Book (mrq)                                  1.23    0.90     1.631818
# Price/Sales (ttm)                                 3.77    3.62     3.191818
# Profit Margin                                    43.66   31.37    31.118182
# Quarterly Earnings Growth (yoy)                  43.90    7.80     6.372727
# Quarterly Revenue Growth (yoy)                   36.40   10.60     8.918182
# Return on Assets (ttm)                            0.76    0.70     0.767273
# Return on Equity (ttm)                           14.27    7.27    14.003636
# Revenue (ttm)                                   420.50  408.50   606.086000
# Revenue Per Share (ttm)                          25.37    5.84    21.730909
# S&P500 52-Week Change 3                           1.31    1.31     1.310000
# Shares Outstanding 5                             16.67   80.25   210.801250
# Shares Short (Jul 15, 2019) 4                      NaN     NaN     6.800000
# Shares Short (Jul 31, 2019) 4                      NaN    3.99    15.747500
# Shares Short (prior month Jun 14, 2019) 4          NaN     NaN     7.120000
# Shares Short (prior month Jun 28, 2019) 4          NaN    4.06    15.877500
# Short % of Shares Outstanding (Jul 15, 2019) 4     NaN     NaN     2.300000
# Short % of Shares Outstanding (Jul 31, 2019) 4    5.51    6.09     3.277000
# Short Ratio (Jul 15, 2019) 4                       NaN     NaN     5.580000
# Short Ratio (Jul 31, 2019) 4                     29.32   14.59    12.892000
# Total Cash (mrq)                                772.78  866.56   754.903333
# Total Cash Per Share (mrq)                       46.35   14.62   198.902727
# Total Debt/Equity (mrq)                            NaN     NaN  6869.020000
# Trailing Annual Dividend Rate 3                   1.16    0.00     2.602727
# Trailing Annual Dividend Yield 3                  1.22    0.00     3.822727
# Trailing P/E                                      8.87   13.65    10.872727

# %%
maximum = []
for each in enumerate(ind.idxmax(axis=1)):
    if 'RY.TO' in each:
        i = ind.idxmax(axis=1).index[each[0]]
        maximum.append({i: ind['RY.TO'].T[i]})

# %%
maximum
# Out:
# [{'50-Day Moving Average 3': 103.39},
#  {'Market Cap (intraday) 5': 14254.0},
#  {'Return on Assets (ttm)': 0.96}]

# %%
minimum = []
for each in enumerate(ind.idxmin(axis=1)):
    if 'RY.TO' in each:
        i = ind.idxmin(axis=1).index[each[0]]
        minimum.append({i: ind['RY.TO'].T[i]})

# %% [markdown]
# minimum

# %%
minimum
# Out:
# [{'Beta (3Y Monthly)': 0.96},
#  {'S&P500 52-Week Change 3': 1.31},
#  {'Short Ratio (Jul 31, 2019) 4': 3.96}]

# %%
ind_bsd
# Out:
# [<finance_python.balance_sheet.balance_sheet at 0x2579f984860>,
#  <finance_python.balance_sheet.balance_sheet at 0x257a0baaeb8>,
#  <finance_python.balance_sheet.balance_sheet at 0x257a1c58b38>,
#  <finance_python.balance_sheet.balance_sheet at 0x257a1d03668>,
#  <finance_python.balance_sheet.balance_sheet at 0x257a1cb3080>,
#  <finance_python.balance_sheet.balance_sheet at 0x257a1daa0b8>,
#  <finance_python.balance_sheet.balance_sheet at 0x257a1e46f60>,
#  <finance_python.balance_sheet.balance_sheet at 0x257a1cb80f0>,
#  <finance_python.balance_sheet.balance_sheet at 0x257a1d87240>,
#  <finance_python.balance_sheet.balance_sheet at 0x257a1d26390>,
#  <finance_python.balance_sheet.balance_sheet at 0x257a1d156a0>]

# %%
frame = pandas.concat(ind_df, sort=True, axis=1)
frame = frame.dropna()

# %%
averages = ind.mean(axis=1).dropna()

# %%
ind['Averages'] = averages

# %%
ind
# Out:
#                                                    RY.TO     TD.TO   BNS.TO  \
# 200-Day Moving Average 3                          103.61     75.38    71.55
# 5 Year Average Dividend Yield 4                     3.77      3.49     4.18
# 50-Day Moving Average 3                           103.39     76.00    69.74
# 52 Week High 3                                    107.91     80.05    78.60
# 52 Week Low 3                                      90.10     65.56    66.36
# 52-Week Change 3                                   -2.08     -7.04   -11.65
# Avg Vol (10 day) 3                                  2.08      2.90     1.72
# Avg Vol (3 month) 3                                 2.20      3.02     2.29
# Beta (3Y Monthly)                                   0.96      1.09     0.97
# Book Value Per Share (mrq)                         53.06     43.51    52.01
# Current Ratio (mrq)                                  NaN       NaN      NaN
# Diluted EPS (ttm)                                   8.64      6.20     6.70
# Enterprise Value/Revenue 3                         -1.92      0.20    -2.57
# Float                                                NaN       NaN      NaN
# Forward Annual Dividend Rate 4                      4.08      2.96     3.48
# Forward Annual Dividend Yield 4                     4.06      4.05     5.08
# Forward P/E 1                                      10.45      9.88     8.97
# Gross Profit (ttm)                                   NaN       NaN      NaN
# Market Cap (intraday) 5                         14254.00  13195.00  8209.00
# Net Income Avi to Common (ttm)                       NaN       NaN      NaN
# Operating Cash Flow (ttm)                            NaN       NaN      NaN
# Operating Margin (ttm)                             39.20     37.59    40.42
# PEG Ratio (5 yr expected) 1                         2.05      1.45     1.84
# Payout Ratio 4                                     45.42     44.35    50.60
# Price/Book (mrq)                                    1.87      1.66     1.31
# Price/Sales (ttm)                                   3.30      3.52     3.05
# Profit Margin                                      29.54     30.92    31.50
# Quarterly Earnings Growth (yoy)                     5.70      9.50     3.90
# Quarterly Revenue Growth (yoy)                     13.20      7.50     6.20
# Return on Assets (ttm)                              0.96      0.88     0.88
# Return on Equity (ttm)                             16.16     14.42    13.07
# Revenue (ttm)                                        NaN       NaN      NaN
# Revenue Per Share (ttm)                            30.00     20.50    21.98
# S&P500 52-Week Change 3                             1.31      1.31     1.31
# Shares Outstanding 5                                 NaN       NaN      NaN
# Shares Short (Jul 15, 2019) 4                        NaN       NaN      NaN
# Shares Short (Jul 31, 2019) 4                       8.68     49.70    35.93
# Shares Short (prior month Jun 14, 2019) 4            NaN       NaN      NaN
# Shares Short (prior month Jun 28, 2019) 4           9.22     50.03    34.86
# Short % of Shares Outstanding (Jul 15, 2019) 4       NaN       NaN      NaN
# Short % of Shares Outstanding (Jul 31, 2019) 4      0.60      2.72     2.97
# Short Ratio (Jul 15, 2019) 4                         NaN       NaN      NaN
# Short Ratio (Jul 31, 2019) 4                        3.96     12.77    13.13
# Total Cash (mrq)                                     NaN       NaN      NaN
# Total Cash Per Share (mrq)                        382.12    195.96   265.67
# Total Debt/Equity (mrq)                              NaN       NaN      NaN
# Trailing Annual Dividend Rate 3                     3.92      2.75     3.39
# Trailing Annual Dividend Yield 3                    3.90      3.76     4.95
# Trailing P/E                                       11.50     11.63    10.14
#
#                                                  BMO.TO    CM.TO    NA.TO  \
# 200-Day Moving Average 3                         100.75   107.48    62.47
# 5 Year Average Dividend Yield 4                    3.88     4.53     4.18
# 50-Day Moving Average 3                           98.00   102.29    63.09
# 52 Week High 3                                   109.00   125.21    65.91
# 52 Week Low 3                                     86.25    97.55    54.37
# 52-Week Change 3                                 -11.08   -17.83    -6.73
# Avg Vol (10 day) 3                                 1.45     1.19      NaN
# Avg Vol (3 month) 3                                1.43     1.67     1.07
# Beta (3Y Monthly)                                  1.30     1.17     1.06
# Book Value Per Share (mrq)                        69.99    77.49    35.49
# Current Ratio (mrq)                                 NaN      NaN      NaN
# Diluted EPS (ttm)                                  9.43    11.36     6.05
# Enterprise Value/Revenue 3                        -2.45    -0.62    -7.30
# Float                                            638.38   444.50   334.49
# Forward Annual Dividend Rate 4                     4.12     5.60     2.72
# Forward Annual Dividend Yield 4                    4.38     5.61     4.26
# Forward P/E 1                                      9.24     7.89     9.31
# Gross Profit (ttm)                                  NaN      NaN      NaN
# Market Cap (intraday) 5                         5917.00  4392.00  2042.00
# Net Income Avi to Common (ttm)                      NaN      NaN      NaN
# Operating Cash Flow (ttm)                           NaN      NaN      NaN
# Operating Margin (ttm)                            35.23    38.20    40.20
# PEG Ratio (5 yr expected) 1                        1.83     3.25     1.40
# Payout Ratio 4                                    41.61    47.98    41.98
# Price/Book (mrq)                                   1.32     1.27     1.72
# Price/Sales (ttm)                                  2.48     2.58     2.98
# Profit Margin                                     26.13    30.28    31.67
# Quarterly Earnings Growth (yoy)                   20.10     2.10     3.30
# Quarterly Revenue Growth (yoy)                    11.40     3.00     1.40
# Return on Assets (ttm)                             0.79     0.84     0.86
# Return on Equity (ttm)                            13.40    14.60    15.62
# Revenue (ttm)                                       NaN      NaN      NaN
# Revenue Per Share (ttm)                           37.34    38.35    20.34
# S&P500 52-Week Change 3                            1.31     1.31     1.31
# Shares Outstanding 5                             638.83   444.75   338.05
# Shares Short (Jul 15, 2019) 4                       NaN      NaN     6.80
# Shares Short (Jul 31, 2019) 4                      7.89    14.75      NaN
# Shares Short (prior month Jun 14, 2019) 4           NaN      NaN     7.12
# Shares Short (prior month Jun 28, 2019) 4          8.59    15.16      NaN
# Short % of Shares Outstanding (Jul 15, 2019) 4      NaN      NaN     2.30
# Short % of Shares Outstanding (Jul 31, 2019) 4     1.23     3.32      NaN
# Short Ratio (Jul 15, 2019) 4                        NaN      NaN     5.58
# Short Ratio (Jul 31, 2019) 4                       6.24     8.95      NaN
# Total Cash (mrq)                                    NaN      NaN      NaN
# Total Cash Per Share (mrq)                       428.26   425.96   303.62
# Total Debt/Equity (mrq)                             NaN      NaN      NaN
# Trailing Annual Dividend Rate 3                    3.92     5.45     2.54
# Trailing Annual Dividend Yield 3                   4.17     5.45     4.15
# Trailing P/E                                       9.82     8.69    10.07
#
#                                                 CWB.TO    FN.TO   LB.TO  \
# 200-Day Moving Average 3                         29.34    30.93   43.34
# 5 Year Average Dividend Yield 4                   3.14     6.46    4.82
# 50-Day Moving Average 3                          29.66    32.54   45.08
# 52 Week High 3                                   38.96    35.36   48.41
# 52 Week Low 3                                    24.33    25.38   36.21
# 52-Week Change 3                                -18.74    16.97   -5.48
# Avg Vol (10 day) 3                                 NaN      NaN     NaN
# Avg Vol (3 month) 3                                NaN      NaN     NaN
# Beta (3Y Monthly)                                 1.75     1.00    1.15
# Book Value Per Share (mrq)                       28.20     7.24   54.52
# Current Ratio (mrq)                                NaN     9.84     NaN
# Diluted EPS (ttm)                                 2.88     2.48    4.19
# Enterprise Value/Revenue 3                        5.59    78.05   10.78
# Float                                            86.73    15.86   42.26
# Forward Annual Dividend Rate 4                    1.08     1.90    2.64
# Forward Annual Dividend Yield 4                   3.58     5.45    5.86
# Forward P/E 1                                     8.91    11.20    9.16
# Gross Profit (ttm)                              755.10   390.14  999.41
# Market Cap (intraday) 5                         259.00   209.00  192.00
# Net Income Avi to Common (ttm)                  255.33   148.80  176.25
# Operating Cash Flow (ttm)                          NaN   344.83     NaN
# Operating Margin (ttm)                           49.98    44.50   24.24
# PEG Ratio (5 yr expected) 1                       1.45     0.75   -2.43
# Payout Ratio 4                                   36.11    75.94   61.58
# Price/Book (mrq)                                  1.07     4.77    0.83
# Price/Sales (ttm)                                 3.33     4.47    2.01
# Profit Margin                                    34.87    32.57   19.79
# Quarterly Earnings Growth (yoy)                   5.30    -4.70  -26.80
# Quarterly Revenue Growth (yoy)                    5.40    10.90   -7.90
# Return on Assets (ttm)                            0.94     0.42    0.41
# Return on Equity (ttm)                           10.14    27.51    7.58
# Revenue (ttm)                                   778.69   466.20  956.54
# Revenue Per Share (ttm)                           8.81     7.77   22.74
# S&P500 52-Week Change 3                           1.31     1.31    1.31
# Shares Outstanding 5                             66.64    59.97   41.25
# Shares Short (Jul 15, 2019) 4                      NaN      NaN     NaN
# Shares Short (Jul 31, 2019) 4                     1.50      NaN    3.54
# Shares Short (prior month Jun 14, 2019) 4          NaN      NaN     NaN
# Shares Short (prior month Jun 28, 2019) 4         1.41      NaN    3.69
# Short % of Shares Outstanding (Jul 15, 2019) 4     NaN      NaN     NaN
# Short % of Shares Outstanding (Jul 31, 2019) 4    1.72     0.24    8.37
# Short Ratio (Jul 15, 2019) 4                       NaN      NaN     NaN
# Short Ratio (Jul 31, 2019) 4                      8.04    11.65   20.27
# Total Cash (mrq)                                625.37      NaN     NaN
# Total Cash Per Share (mrq)                        7.17    38.41   79.79
# Total Debt/Equity (mrq)                            NaN  6869.02     NaN
# Trailing Annual Dividend Rate 3                   1.04     1.88    2.58
# Trailing Annual Dividend Yield 3                  3.39     5.40    5.66
# Trailing P/E                                     10.48    13.91   10.84
#
#                                                 EQB.TO  HCG.TO     Averages
# 200-Day Moving Average 3                         72.71   18.75    65.119091
# 5 Year Average Dividend Yield 4                   1.44     NaN     3.989000
# 50-Day Moving Average 3                          82.49   22.53    65.891818
# 52 Week High 3                                   97.96   25.45    73.892727
# 52 Week Low 3                                    56.12   12.48    55.882727
# 52-Week Change 3                                 46.92   70.24     4.863636
# Avg Vol (10 day) 3                                 NaN     NaN     1.868000
# Avg Vol (3 month) 3                                NaN     NaN     1.946667
# Beta (3Y Monthly)                                 1.62    1.74     1.255455
# Book Value Per Share (mrq)                       77.22   27.80    47.866364
# Current Ratio (mrq)                                NaN     NaN     9.840000
# Diluted EPS (ttm)                                10.71    1.83     6.406364
# Enterprise Value/Revenue 3                       25.98    8.77    10.410000
# Float                                            11.15   51.70   203.133750
# Forward Annual Dividend Rate 4                    1.32     NaN     2.990000
# Forward Annual Dividend Yield 4                   1.41     NaN     4.374000
# Forward P/E 1                                     7.16    9.55     9.247273
# Gross Profit (ttm)                              373.96  398.48   583.418000
# Market Cap (intraday) 5                         158.00  148.00  4452.272727
# Net Income Avi to Common (ttm)                  178.84  128.14   177.472000
# Operating Cash Flow (ttm)                          NaN     NaN   344.830000
# Operating Margin (ttm)                           59.18   44.54    41.207273
# PEG Ratio (5 yr expected) 1                       0.31    2.23     1.284545
# Payout Ratio 4                                   10.83    0.00    41.490909
# Price/Book (mrq)                                  1.23    0.90     1.631818
# Price/Sales (ttm)                                 3.77    3.62     3.191818
# Profit Margin                                    43.66   31.37    31.118182
# Quarterly Earnings Growth (yoy)                  43.90    7.80     6.372727
# Quarterly Revenue Growth (yoy)                   36.40   10.60     8.918182
# Return on Assets (ttm)                            0.76    0.70     0.767273
# Return on Equity (ttm)                           14.27    7.27    14.003636
# Revenue (ttm)                                   420.50  408.50   606.086000
# Revenue Per Share (ttm)                          25.37    5.84    21.730909
# S&P500 52-Week Change 3                           1.31    1.31     1.310000
# Shares Outstanding 5                             16.67   80.25   210.801250
# Shares Short (Jul 15, 2019) 4                      NaN     NaN     6.800000
# Shares Short (Jul 31, 2019) 4                      NaN    3.99    15.747500
# Shares Short (prior month Jun 14, 2019) 4          NaN     NaN     7.120000
# Shares Short (prior month Jun 28, 2019) 4          NaN    4.06    15.877500
# Short % of Shares Outstanding (Jul 15, 2019) 4     NaN     NaN     2.300000
# Short % of Shares Outstanding (Jul 31, 2019) 4    5.51    6.09     3.277000
# Short Ratio (Jul 15, 2019) 4                       NaN     NaN     5.580000
# Short Ratio (Jul 31, 2019) 4                     29.32   14.59    12.892000
# Total Cash (mrq)                                772.78  866.56   754.903333
# Total Cash Per Share (mrq)                       46.35   14.62   198.902727
# Total Debt/Equity (mrq)                            NaN     NaN  6869.020000
# Trailing Annual Dividend Rate 3                   1.16    0.00     2.602727
# Trailing Annual Dividend Yield 3                  1.22    0.00     3.822727
# Trailing P/E                                      8.87   13.65    10.872727
