# %%
from finance_python.stock import stock
from finance_python.industry import industry
import sys, os, time
import numpy as np
import pandas
from datetime import datetime, date, timedelta
from pandas import DataFrame

# %%
symbols = ['L.TO', 'WN.TO']
start = date.today() - timedelta(days=365)
end = date.today()

# %%
stock_loop = lambda x: stock(x, start, end)

# %%
timer_start = time.time()

stocks = list(map(stock_loop, symbols))

timer_end = time.time()
print(timer_end - timer_start)
# Out:
# 6.163048505783081

# %%
L = stocks[0]

# %%
WN = stocks[1]

# %%
L.description
# Out:
# "Loblaw Companies Limited, a food and pharmacy company, engages in the grocery, pharmacy, health and beauty, apparel, general merchandise, financial services, and wireless mobile products and services businesses in Canada. It operates in two segments, Retail and Financial Services. The Retail segment operates corporate and franchise-owned retail food, and associate-owned drug stores comprising in-store pharmacies, other health and beauty product stores, apparel stores, and other general merchandise stores, as well as supports the PC Optimum reward program. The Financial Services segment provides credit card services, the PC Optimum reward program, insurance brokerage services, deposit taking services, and telecommunication services. Loblaw Companies Limited provides its products and services under the President's Choice, Life Brand, and no name brands. The company was founded in 1919 and is headquartered in Brampton, Canada. Loblaw Companies Limited is a subsidiary of George Weston L
# ...

# %%
WN.description
# Out:
# 'George Weston Limited engages in the food processing and distribution business in Canada and internationally. The company operates through three segments: Weston Foods, Loblaw, and Choice Properties. The Weston Foods segment produces fresh, frozen, and specialty bakery products, such as breads, rolls, bagels, tortillas, cakes, donuts, pies, cookies, crackers, and other baked goods through national and regional supermarkets, wholesale and club stores, dollar stores, convenience store chains, food service distributors, and outlets. This segment also supplies control brand products to retailers and consumer food companies; ice cream cones and sandwich wafers to manufacturers in the frozen novelty category; and Girl Scout cookies. The Loblaw segment provides grocery, pharmacy, health and beauty, apparel, general merchandise, credit card, insurance brokerage, gift cards, and telecommunication services in approximately 2,300 corporate, franchised, and associate-owned locations. It operate
# ...

# %%
L.sector
# Out:
# 'Grocery Stores'

# %%
WN.sector
# Out:
# 'Grocery Stores'

# %%
L.price
# Out:
# 72.87

# %%
WN.price
# Out:
# 108.17

# %%
L.dividends
# Out:
# [                                                Date       Dividends
#  0                                       Jun 13, 2019  0.315 Dividend
#  1                                       Mar 14, 2019  0.295 Dividend
#  2                                       Dec 13, 2018  0.295 Dividend
#  3                                       Sep 14, 2018  0.295 Dividend
#  4                                       Sep 13, 2018  0.295 Dividend
#  5  *Close price adjusted for splits.**Adjusted cl...             NaN]

# %%
WN.dividends
# Out:
# [                                                Date       Dividends
#  0                                       Jun 13, 2019  0.525 Dividend
#  1                                       Mar 14, 2019  0.515 Dividend
#  2                                       Dec 13, 2018  0.515 Dividend
#  3                                       Sep 14, 2018   0.49 Dividend
#  4  *Close price adjusted for splits.**Adjusted cl...             NaN]

# %%
L.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()']]

# %%
L.stats()
WN.stats()

# %%
L.statistics.dropna()
# Out:
#                                                    L.TO
# Market Cap (intraday) 5                         2637.00
# Trailing P/E                                      33.69
# Forward P/E 1                                     15.44
# PEG Ratio (5 yr expected) 1                        6.03
# Price/Sales (ttm)                                  0.56
# Price/Book (mrq)                                   2.41
# Enterprise Value/Revenue 3                         0.89
# Enterprise Value/EBITDA 6                         12.32
# Beta (3Y Monthly)                                  0.30
# 52-Week Change 3                                  36.48
# S&P500 52-Week Change 3                            0.96
# 52 Week High 3                                    73.10
# 52 Week Low 3                                     50.26
# 50-Day Moving Average 3                           69.65
# 200-Day Moving Average 3                          67.74
# Shares Outstanding 5                             368.52
# ...

# %%
WN.statistics.dropna()
# Out:
#                                                   WN.TO
# Market Cap (intraday) 5                         1661.00
# Trailing P/E                                     983.36
# Forward P/E 1                                     14.01
# PEG Ratio (5 yr expected) 1                        2.66
# Price/Sales (ttm)                                  0.34
# Price/Book (mrq)                                   2.53
# Enterprise Value/Revenue 3                         0.86
# Enterprise Value/EBITDA 6                          9.45
# Beta (3Y Monthly)                                  0.64
# 52-Week Change 3                                   8.94
# S&P500 52-Week Change 3                            0.96
# 52 Week High 3                                   109.17
# 52 Week Low 3                                     86.72
# 50-Day Moving Average 3                          104.79
# 200-Day Moving Average 3                         100.34
# Shares Outstanding 5                             127.96
# ...

# %%
L.balance()
WN.balance()

# %%
L.balance_sheet.dropna()
# Out:
# Period Ending                     12/29/2018  12/30/2017  12/31/2016  \
# L.TO
# Cash And Cash Equivalents          1065000.0   1798000.0   1314000.0
# Short Term Investments               94000.0    546000.0    241000.0
# Net Receivables                    4527000.0   4314000.0   4048000.0
# Inventory                          4803000.0   4438000.0   4371000.0
# Other Current Assets                858000.0     41000.0     58000.0
# Total Current Assets              11637000.0  11327000.0  10204000.0
# Long Term Investments                31000.0     75000.0     84000.0
# Property, plant and equipment      5931000.0  10669000.0  10559000.0
# Goodwill                           3942000.0   3922000.0   3895000.0
# Intangible Assets                  7798000.0   8251000.0   8745000.0
# Other Assets                        814000.0    903000.0    949000.0
# Deferred Long Term Asset Charges    144000.0    134000.0    130000.0
# ...

# %%
WN.balance_sheet.dropna()
# Out:
# Period Ending                     12/31/2018  12/31/2017  12/31/2016  \
# WN.TO
# Cash And Cash Equivalents          1521000.0   2034000.0   1560000.0
# Short Term Investments              281000.0   1113000.0   1011000.0
# Net Receivables                    4732000.0   4459000.0   4204000.0
# Inventory                          5001000.0   4623000.0   4559000.0
# Other Current Assets                 64000.0     29000.0     64000.0
# Total Current Assets              11855000.0  12463000.0  11581000.0
# Long Term Investments               765000.0     75000.0     79000.0
# Property, plant and equipment     12101000.0  11689000.0  11534000.0
# Goodwill                           4781000.0   4377000.0   4364000.0
# Intangible Assets                  7958000.0   8368000.0   8875000.0
# Other Assets                       6354000.0   1568000.0   1513000.0
# Deferred Long Term Asset Charges    286000.0    247000.0    201000.0
# ...

# %%
L.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list'],
#  ['balance_sheet', 'bs_list']]

# %%
L.financial()
WN.financial()

# %%
L.financials.dropna()
# Out:
# Period Ending                           12/29/2018  12/30/2017  12/31/2016  \
# L.TO
# Total Revenue                           46693000.0  46587000.0  46385000.0
# Cost of Revenue                         32537000.0  32913000.0  33206000.0
# Gross Profit                            14156000.0  13674000.0  13179000.0
# Selling General and Administrative      12161000.0  12060000.0  10921000.0
# Total Operating Expenses                44698000.0  44973000.0  44127000.0
# Operating Income or Loss                 1995000.0   1614000.0   2258000.0
# Total Other Income/Expenses Net         -1200000.0     71000.0   -819000.0
# Earnings Before Interest and Taxes       1995000.0   1614000.0   2258000.0
# Interest Expense                         -400000.0   -388000.0   -552000.0
# Income Before Tax                        1359000.0   1675000.0   1439000.0
# Income Tax Expense                        606000.0    365000.0    449000.0
# ...

# %%
L.cash()
WN.cash()

# %%
L.cashflow.dropna()
WN.cashflow.dropna()
# Out:
# Period Ending                               12/31/2018  12/31/2017  \
# WN.TO
# Net Income                                    574000.0    766000.0
# Depreciation                                 1468000.0   1428000.0
# Adjustments To Net Income                    1359000.0   1011000.0
# Changes In Other Operating Activities        -951000.0    -27000.0
# Total Cash Flow From Operating Activities    2719000.0   3425000.0
# Capital Expenditure                         -1191000.0  -1177000.0
# Investments                                   832000.0   -135000.0
# Other Cash flows from Investing Activities    -83000.0    -56000.0
# Total Cash Flows From Investing Activities  -2256000.0  -1075000.0
# Dividends Paid                               -285000.0   -273000.0
# Net Borrowings                               1582000.0    248000.0
# Other Cash Flows from Financing Activities  -2295000.0  -1824000.0
# Total Cash Flows From Financing Activities   -987000.0  -1865000.0
# ...

# %%
L.analyze()
WN.analyze()

# %%
L.attributes
# Out:
# [['dividends', 'sector', 'description', 'history', 'price'],
#  ['stats()', 'balance()', 'financial()', 'cash()', 'analyze()'],
#  ['statistics', 'stats_list'],
#  ['balance_sheet', 'bs_list'],
#  ['financials', 'fin_list'],
#  ['cashflow', 'cash_list'],
#  ['earnings_est',
#   'revenue',
#   'earnings_history',
#   'eps_trend',
#   'eps_revisions',
#   'growth_estimates',
#   'a_list']]

# %%
L.earnings_est
# Out:
#                    Current Qtr. (Sep 2019)  Next Qtr. (Dec 2019)  \
# Earnings Estimate
# No. of Analysts                       8.00                  8.00
# Avg. Estimate                         1.26                  1.15
# Low Estimate                          1.22                  1.07
# High Estimate                         1.35                  1.19
# Year Ago EPS                          1.49                  1.07
#
#                    Current Year (2019)  Next Year (2020)
# Earnings Estimate
# No. of Analysts                  10.00             10.00
# Avg. Estimate                     4.24              4.72
# Low Estimate                      4.08              4.61
# High Estimate                     4.46              4.92
# Year Ago EPS                      4.60              4.24

# %%
WN.earnings_est
# Out:
#                    Current Qtr. (Sep 2019)  Next Qtr. (Dec 2019)  \
# Earnings Estimate
# No. of Analysts                       4.00                  4.00
# Avg. Estimate                         2.14                  1.90
# Low Estimate                          1.81                  1.80
# High Estimate                         2.47                  2.15
# Year Ago EPS                          2.25                  1.59
#
#                    Current Year (2019)  Next Year (2020)
# Earnings Estimate
# No. of Analysts                   5.00              5.00
# Avg. Estimate                     7.14              7.72
# Low Estimate                      6.62              7.11
# High Estimate                     7.63              9.02
# Year Ago EPS                      6.85              7.14

# %%
L.revenue
# Out:
#                         Current Qtr. (Sep 2019) Next Qtr. (Dec 2019)  \
# Revenue Estimate
# No. of Analysts                               2                    1
# Avg. Estimate                            14.65B               11.69B
# Low Estimate                              14.6B               11.69B
# High Estimate                            14.71B               11.69B
# Year Ago Sales                           14.47B               11.22B
# Sales Growth (year/est)                   1.30%                4.20%
#
#                         Current Year (2019) Next Year (2020)
# Revenue Estimate
# No. of Analysts                          10                9
# Avg. Estimate                        48.01B           49.76B
# Low Estimate                         47.39B           48.98B
# High Estimate                        48.26B           50.68B
# Year Ago Sales                       46.69B           48.01B
# Sales Growth (year/est)               2.80%            3.60%

# %%
WN.revenue
# Out:
#                         Current Qtr. (Sep 2019) Next Qtr. (Dec 2019)  \
# Revenue Estimate
# No. of Analysts                               1                    1
# Avg. Estimate                            15.14B               12.18B
# Low Estimate                             15.14B               12.18B
# High Estimate                            15.14B               12.18B
# Year Ago Sales                           14.86B               11.72B
# Sales Growth (year/est)                   1.90%                4.00%
#
#                         Current Year (2019) Next Year (2020)
# Revenue Estimate
# No. of Analysts                           6                5
# Avg. Estimate                         50.1B           51.95B
# Low Estimate                         49.89B           50.94B
# High Estimate                        50.43B           52.98B
# Year Ago Sales                       48.57B            50.1B
# Sales Growth (year/est)               3.20%            3.70%

# %%
L.earnings_history
# Out:
#                  9/29/2018 12/30/2018 3/30/2019 6/29/2019
# Earnings History
# EPS Est.              1.44       1.04       0.8      1.01
# EPS Actual            1.49       1.07      0.78      1.01
# Difference            0.05       0.03     -0.02         0
# Surprise %           3.50%      2.90%    -2.50%     0.00%

# %%
WN.earnings_history
# Out:
#                  9/29/2018 12/30/2018 3/30/2019 6/29/2019
# Earnings History
# EPS Est.              2.19       1.57      1.34      1.57
# EPS Actual            2.25       1.59       1.3       1.7
# Difference            0.06       0.02     -0.04      0.13
# Surprise %           2.70%      1.30%    -3.00%     8.30%

# %%
L.eps_trend
# Out:
#                   Current Qtr. (Sep 2019)  Next Qtr. (Dec 2019)  \
# EPS Trend
# Current Estimate                     1.26                  1.15
# 7 Days Ago                           1.26                  1.15
# 30 Days Ago                          1.26                  1.15
# 60 Days Ago                          1.31                  1.13
# 90 Days Ago                          1.32                  1.10
#
#                   Current Year (2019)  Next Year (2020)
# EPS Trend
# Current Estimate                 4.24              4.72
# 7 Days Ago                       4.21              4.70
# 30 Days Ago                      4.24              4.72
# 60 Days Ago                      4.27              4.75
# 90 Days Ago                      4.25              4.75

# %%
WN.eps_trend
# Out:
#                   Current Qtr. (Sep 2019)  Next Qtr. (Dec 2019)  \
# EPS Trend
# Current Estimate                     2.14                  1.90
# 7 Days Ago                           2.25                  1.93
# 30 Days Ago                          2.14                  1.90
# 60 Days Ago                          2.08                  1.76
# 90 Days Ago                          2.08                  1.76
#
#                   Current Year (2019)  Next Year (2020)
# EPS Trend
# Current Estimate                 7.14              7.72
# 7 Days Ago                       7.27              7.80
# 30 Days Ago                      7.00              7.72
# 60 Days Ago                      6.75              7.25
# 90 Days Ago                      6.75              7.25

# %%
L.eps_revisions
# Out:
#                    Current Qtr. (Sep 2019)  Next Qtr. (Dec 2019)  \
# EPS Revisions
# Up Last 7 Days                         NaN                   NaN
# Up Last 30 Days                        NaN                   6.0
# Down Last 7 Days                       NaN                   NaN
# Down Last 30 Days                      NaN                   NaN
#
#                    Current Year (2019)  Next Year (2020)
# EPS Revisions
# Up Last 7 Days                     NaN               NaN
# Up Last 30 Days                    2.0               1.0
# Down Last 7 Days                   NaN               NaN
# Down Last 30 Days                  NaN               NaN

# %%
WN.eps_revisions
# Out:
#                    Current Qtr. (Sep 2019)  Next Qtr. (Dec 2019)  \
# EPS Revisions
# Up Last 7 Days                         NaN                   NaN
# Up Last 30 Days                        2.0                   3.0
# Down Last 7 Days                       NaN                   NaN
# Down Last 30 Days                      NaN                   NaN
#
#                    Current Year (2019)  Next Year (2020)
# EPS Revisions
# Up Last 7 Days                     NaN               NaN
# Up Last 30 Days                    5.0               4.0
# Down Last 7 Days                   NaN               NaN
# Down Last 30 Days                  NaN               NaN

# %%
L.growth_estimates
# Out:
#                              L.TO  Industry  Sector  S&P 500
# Growth Estimates
# Current Qtr.              -15.40%       NaN     NaN     0.00
# Next Qtr.                   7.50%       NaN     NaN     0.08
# Current Year               -7.80%       NaN     NaN     0.03
# Next Year                  11.30%       NaN     NaN     0.10
# Next 5 Years (per annum)    2.81%       NaN     NaN     0.08
# Past 5 Years (per annum)    6.06%       NaN     NaN      NaN

# %%
WN.growth_estimates
# Out:
#                            WN.TO  Industry  Sector  S&P 500
# Growth Estimates
# Current Qtr.              -4.90%       NaN     NaN     0.00
# Next Qtr.                 19.50%       NaN     NaN     0.08
# Current Year               4.20%       NaN     NaN     0.03
# Next Year                  8.10%       NaN     NaN     0.10
# Next 5 Years (per annum)   5.70%       NaN     NaN     0.08
# Past 5 Years (per annum)   4.30%       NaN     NaN      NaN
